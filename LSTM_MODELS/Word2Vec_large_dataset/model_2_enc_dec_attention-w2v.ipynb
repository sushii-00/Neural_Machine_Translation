# %% [markdown]
# # SEQUENCE-TO-SEQUENCE NMT WITH ATTENTION MECHANISM

# %% [markdown]
# # DATA

# %%
import numpy as np
import re
import string
import unicodedata
from unicodedata import normalize
import sys
import indicnlp
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from numpy import array
from numpy import asarray
from numpy import zeros
# from keras.models import Model
# from keras.layers import Input, LSTM, GRU, Dense, Embedding
from tensorflow.keras.utils import plot_model
import numpy as np
# !pip install tensorflow-addons==0.11.2
import tensorflow_addons as tfa
from sklearn.model_selection import train_test_split
import gensim
from tensorflow import keras
# !pip install indic-nlp-library : this is necessary, without this common wont be found and correct indic nlp wont get installed
import os
import io
import time
INDIC_NLP_LIB_HOME=r"C:\Users\sudha\Desktop\ALL_PROJECTS\NMT_PROJECTS\Language_Translation_Chat_Bot\LSTM_MODELS\GLOve_large_dataset\anoopkunchukuttan-indic_nlp_library-eccde81"
INDIC_NLP_RESOURCES=r"C:\Users\sudha\Desktop\ALL_PROJECTS\NMT_PROJECTS\Language_Translation_Chat_Bot\LSTM_MODELS\GLOve_large_dataset\indic_nlp_resources-master"
sys.path.append(r'{}'.format(INDIC_NLP_LIB_HOME))
from indicnlp import common
common.set_resources_path(INDIC_NLP_RESOURCES)
from indicnlp import loader
loader.load()
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
from indicnlp.tokenize import indic_tokenize

# %% [markdown]
# # LOAD DATA

# %%
def load_doc(doc):
    file = open(doc , mode = 'rt' , encoding = 'utf -8')
    text = file.read()
    file.close()
    return text

def clean_english_data(lines):
    re_print = re.compile('[^%s]' %re.escape(string.printable))
    table = str.maketrans('' , '' , string.punctuation)
    
    
    clean_eng_lines = []
    ans = list()
    ans.append(lines)
    
    for line in ans:
        line = normalize('NFD' , line).encode('ascii' , 'ignore')
        line = line.decode('UTF-8')
        line = line.split()
        line = [word.lower() for word in line]
        line = [word.translate(table) for word in line]
        line = [word for word in line if word.isalpha()]
        line = ' '.join(line)
        line = '<start> ' + line +' <end>'
        clean_eng_lines.append(line)
    return clean_eng_lines

def clean_text(line):
    text = line
    text = text.replace(u',' ,'')
    text = text.replace(u'"' ,'')
    text = text.replace(u'(' ,'')
    text = text.replace(u')' ,'')
    text = text.replace(u'"' ,'')
    text = text.replace(u':' ,'')
    text = text.replace(u"'" ,'')
    text = text.replace(u"'" ,'')
    text=text.replace(u"‘‘",'')
    text=text.replace(u"’’",'')
    text=text.replace(u"''",'')
    text=text.replace(u".",'')
    text=text.replace(u"-",'')
    text=text.replace(u"।",'')
    text=text.replace(u"?",'')
    text=text.replace(u"\\",'')
    text=text.replace(u"_",'')
    text = re.sub('[a-zA-Z]' , '' , text)
    text = re.sub('[0-9+\-*/.%&!]' , '' , text)
    return text

def clean_hindi_data(lines):
    clean_hin_lines = []
    ans = list()
    ans.append(lines)
    for line in ans:
        remove_nuktas = True
        factory = IndicNormalizerFactory()
        normalizer = factory.get_normalizer("hi" , remove_nuktas = True )
        line = clean_text(line)
        tokens = list()
        for t in indic_tokenize.trivial_tokenize(line):
            tokens.append(t)
        line = tokens
        line = [ word.lower() for word in line]
        line = [word for word in line if not re.search(r'\d', word)]
        line = ' '.join(line)
        line = '<start> ' + line +' <end>'
        clean_hin_lines.append(line)
        
    return clean_hin_lines   


def to_pairs(text):
    lines = text.strip().split('\n')
    
    eng_hin_pairs = [line.split('\t') for line in lines]
    eng_hin_pairs = np.delete(eng_hin_pairs, [0,1,2,3,4] , axis = 1)
    eng_hin_pairs = eng_hin_pairs.tolist()
    clean_data = list()
    for pair in eng_hin_pairs:
        temp_data = list()
        for i, sentence in enumerate(pair):
            if i == 0:
                x = clean_english_data(sentence)
                temp_data.append(x)
            if i == 1:
                y = clean_hindi_data(sentence)
                temp_data.append(y)
        clean_data.append(temp_data)
    return eng_hin_pairs, clean_data

doc = load_doc("hindi-visual-genome-train.txt")
pairs , clean_data = to_pairs(doc)

# %%
clean_data
# Out:
# [[['<start> it is an indoor scene <end>'],
#   ['<start> यह एक इनडोर दृश्य है <end>']],
#  [['<start> computer screens turned on <end>'],
#   ['<start> कंप्यूटर स्क्रीन चालू <end>']],
#  [['<start> man has short hair <end>'],
#   ['<start> आदमी के छोटे बाल हैं <end>']],
#  [['<start> photo album open on an adults lap <end>'],
#   ['<start> एक वयस्क की गोद में फोटो एल्बम खुला <end>']],
#  [['<start> there is a group of girls beside the black car <end>'],
#   ['<start> काली कार के पास लड़कियों का एक समूह है <end>']],
#  [['<start> child in a stroller <end>'],
#   ['<start> एक घुमक्कड़ में बच्चा <end>']],
#  [['<start> tall metal lightpost <end>'],
#   ['<start> लंबा धातु प्रकाश पोस्ट <end>']],
#  [['<start> wall is painted white <end>'],
#   ['<start> दीवार सफेद रंग की है <end>']],
#  [['<start> there are several pictures on the wall <end>'],
#   ['<start> दीवार पर कई चित्र हैं <end>']],
#  [['<start> woman facing the ocean <end>'],
#   ['<start> सागर का सामना कर रही महिला <end>']],
#  [['<start> this is an office layout <end>'],
#   ['<start> यह एक कार्यालय लेआउट है <end>']],
#  [['<start> four metallic chairs <end>'],
#   ['<start> चार धातु की कुर्सियाँ <end>']],
#  [['<start> clutter is on a table <end>'],
#   ['<start> क्लटर एक मेज पर है <end>']],
#  [['<start> a white microwave oven <end>'],
#   ['<start> एक सफेद माइक्रोवेव ओवन <end>']],
#  [['<start> white suv driving through intersection <end>'],
#   ['<start> चौराहे के माध्यम से सफेद एसयूवी ड्राइविंग <end>']],
#  [['<start> person crossing street with umbrella <end>'],
#   ['<start> छतरी के साथ सड़क पार करते व्यक्ति <end>']],
#  [['<start> man in gray pants leaning on building <end>'],
#   ['<start> इमारत पर झुकाव में आदमी ग्रे पैंट में <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> a man standing in between cars <end>'],
#   ['<start> कारों के बीच में खड़ा एक आदमी <end>']],
#  [['<start> painting hanging on wall <end>'],
#   ['<start> दीवार पर चित्रकला <end>']],
#  [['<start> leg of the chair <end>'], ['<start> कुर्सी का पैर <end>']],
#  [['<start> window of a boat <end>'], ['<start> एक नाव की खिड़की <end>']],
#  [['<start> the cabinet is wood <end>'], ['<start> कैबिनेट लकड़ी है <end>']],
#  [['<start> a man reading a book <end>'],
#   ['<start> एक आदमी एक किताब पढ़ रहा है <end>']],
#  [['<start> a person swimming in water <end>'],
#   ['<start> पानी में तैरता हुआ व्यक्ति <end>']],
#  [['<start> lamp with glowing shade <end>'],
#   ['<start> चमकती छाया के साथ दीपक <end>']],
#  [['<start> fruit on the plate <end>'], ['<start> प्लेट पर फल <end>']],
#  [['<start> a porcelain white plate <end>'],
#   ['<start> एक चीनी मिट्टी के बरतन सफ़ेद प्लेट <end>']],
#  [['<start> black game controller <end>'],
#   ['<start> काला खेल नियंत्रक <end>']],
#  [['<start> a person putting something in the trunk of the car <end>'],
#   ['<start> कार की डिक्की में कुछ डालने वाला व्यक्ति <end>']],
#  [['<start> green car parked along a street <end>'],
#   ['<start> एक सड़क के साथ ग्रीन कार पार्क किया <end>']],
#  [['<start> car on the street <end>'], ['<start> गली पर कार <end>']],
#  [['<start> construction worker wearing coveralls <end>'],
#   ['<start> निर्माण कर्मचारी कवरलेस पहनते हैं <end>']],
#  [['<start> a black car with a yellow door <end>'],
#   ['<start> पीले दरवाजे के साथ एक काली कार <end>']],
#  [['<start> chair at the table <end>'], ['<start> मेज पर कुर्सी <end>']],
#  [['<start> a navel orange on a counter <end>'],
#   ['<start> एक काउंटर पर एक नारंगी संतरा <end>']],
#  [['<start> three windows of a building <end>'],
#   ['<start> एक इमारत की तीन खिड़कियां <end>']],
#  [['<start> window on a building <end>'], ['<start> इमारत पर खिडकि <end>']],
#  [['<start> brown table standing on top of a floor <end>'],
#   ['<start> भूरे रंग की मेज एक मंजिल के ऊपर खड़ी है <end>']],
#  [['<start> floor lamp is on <end>'], ['<start> फ्लोर लैंप चालू है <end>']],
#  [['<start> a yellow bus <end>'], ['<start> एक पीली बस <end>']],
#  [['<start> branch of the tree <end>'], ['<start> वृक्ष की शाखा <end>']],
#  [['<start> cement bench outside the building <end>'],
#   ['<start> भवन के बाहर सीमेंट की बेंच <end>']],
#  [['<start> thick black pole with a white stripe <end>'],
#   ['<start> एक सफेद पट्टी के साथ मोटी काली पोल <end>']],
#  [['<start> a wooden park bench <end>'], ['<start> लकड़ी पार्क बेंच <end>']],
#  [['<start> a cup <end>'], ['<start> एक कप <end>']],
#  [['<start> man has brown hair <end>'],
#   ['<start> आदमी के भूरे बाल हैं <end>']],
#  [['<start> grass in a field <end>'], ['<start> एक खेत में घास <end>']],
#  [['<start> a large brown tree trunk <end>'],
#   ['<start> एक बड़ा भूरा पेड़ का तना <end>']],
#  [['<start> silver car in front of a building <end>'],
#   ['<start> इमारत के सामने चांदी कार <end>']],
#  [['<start> man sits at counter <end>'],
#   ['<start> आदमी काउंटर पर बैठता है <end>']],
#  [['<start> woman standing at a book cart <end>'],
#   ['<start> किताब की गाड़ी पर खड़ी महिला <end>']],
#  [['<start> two story blue bus <end>'], ['<start> दो कहानी नीली बस <end>']],
#  [['<start> a gray laundry basket <end>'],
#   ['<start> एक ग्रे कपड़े धोने की टोकरी <end>']],
#  [['<start> the yellow construction hats <end>'],
#   ['<start> पीले रंग की निर्माण टोपी <end>']],
#  [['<start> wooden floor in the room <end>'],
#   ['<start> कमरे में लकड़ी का फर्श <end>']],
#  [['<start> a tall palm tree above the horizon <end>'],
#   ['<start> क्षितिज के ऊपर एक लंबा ताड़ का पेड़ <end>']],
#  [['<start> chair inside an auditorium <end>'],
#   ['<start> एक सभागार के अंदर कुर्सी <end>']],
#  [['<start> a tall leafy tree <end>'],
#   ['<start> एक लंबा पत्ते का पेड़ <end>']],
#  [['<start> mirror is on far wall <end>'],
#   ['<start> दर्पण दूर की दीवार पर है <end>']],
#  [['<start> the sidewalk <end>'], ['<start> फ़ुटपाथ <end>']],
#  [['<start> the drivers side door is open <end>'],
#   ['<start> ड्राइवर के बगल का द्वार खुला है <end>']],
#  [['<start> a plate full of food <end>'], ['<start> भोजन से भरी थाली <end>']],
#  [['<start> the building is white <end>'], ['<start> इमारत सफेद है <end>']],
#  [['<start> small picture on wall <end>'],
#   ['<start> दीवार पर छोटी सी तस्वीर <end>']],
#  [['<start> intersection of wooden logs <end>'],
#   ['<start> लकड़ी के लॉग का चौराहे <end>']],
#  [['<start> light attached to building <end>'],
#   ['<start> इमारत से संबद्ध प्रकाश <end>']],
#  [['<start> do not enter sign <end>'], ['<start> साइन न करें <end>']],
#  [['<start> colorful pillow of blues and reds on a white striped couch <end>'],
#   ['<start> सफेद धारीदार सोफे पर ब्लूज़ और रेड्स का रंगीन तकिया <end>']],
#  [['<start> dent is in the vehicle <end>'],
#   ['<start> डेंट वाहन में है <end>']],
#  [['<start> the roof is grey <end>'], ['<start> छत ग्रे है <end>']],
#  [['<start> brown frame on mirror <end>'],
#   ['<start> दर्पण पर भूरे रंग का फ्रेम <end>']],
#  [['<start> white flowers beneath tree <end>'],
#   ['<start> पेड़ के नीचे सफेद फूल <end>']],
#  [['<start> white ambulance on the street <end>'],
#   ['<start> सड़क पर सफेद एम्बुलेंस <end>']],
#  [['<start> green trees in distance <end>'],
#   ['<start> दूरी में हरे पेड़ <end>']],
#  [['<start> the sign is blue <end>'], ['<start> यह चिह्न नीला है <end>']],
#  [['<start> man sitting off to side of road <end>'],
#   ['<start> सड़क के किनारे बैठा आदमी <end>']],
#  [['<start> a man crossing the street <end>'],
#   ['<start> सड़क पार करने वाला एक आदमी <end>']],
#  [['<start> sign on the wall <end>'], ['<start> दीवार पर साइन इन करें <end>']],
#  [['<start> window in a brick house <end>'],
#   ['<start> एक ईंट के घर में खिड़की <end>']],
#  [['<start> the computer screen is blue <end>'],
#   ['<start> कंप्यूटर की स्क्रीन नीली है <end>']],
#  [['<start> bike route sign <end>'], ['<start> बाइक मार्ग का चिह्न <end>']],
#  [['<start> grey beard hair on a man <end>'],
#   ['<start> एक आदमी पर ग्रे दाढ़ी बाल <end>']],
#  [['<start> the rear view of a car <end>'],
#   ['<start> कार का पिछला दृश्य <end>']],
#  [['<start> burger with cheese sauce <end>'],
#   ['<start> पनीर सॉस के साथ बर्गर <end>']],
#  [['<start> side of thee silver suv <end>'],
#   ['<start> रजत एसयूवी की ओर <end>']],
#  [['<start> woman walking across street <end>'],
#   ['<start> सड़क पर घूमती हुई महिला <end>']],
#  [['<start> woman wearing pink jacket <end>'],
#   ['<start> गुलाबी जैकेट पहने महिला <end>']],
#  [['<start> red car parked by street light <end>'],
#   ['<start> गली की बत्ती से के पास खड़ी लाल कार <end>']],
#  [['<start> the traffic lights are yellow <end>'],
#   ['<start> ट्रैफिक लाइट पीले हैं <end>']],
#  [['<start> white painted line on pavement <end>'],
#   ['<start> फुटपाथ पर सफेद रंग की लाइन <end>']],
#  [['<start> the black tipped pen on the desk <end>'],
#   ['<start> मेज पर काले रंग की कलम <end>']],
#  [['<start> man in white shirt walking down the sidewalk <end>'],
#   ['<start> सफेद शर्ट में आदमी फुटपाथ के नीचे चल रहा है <end>']],
#  [['<start> large light fixture in ceiling <end>'],
#   ['<start> छत में बड़ा प्रकाश आकार <end>']],
#  [['<start> white monitor on desk <end>'],
#   ['<start> सफेद मॉनिटर डेस्क पर <end>']],
#  [['<start> black computer monitor on desk <end>'],
#   ['<start> डेस्क पर ब्लैक कंप्यूटर मॉनिटर <end>']],
#  [['<start> handle on the mug <end>'], ['<start> मग पर संभाल <end>']],
#  [['<start> a man sitting in front of a computer monitor <end>'],
#   ['<start> कंप्यूटर मॉनिटर के सामने बैठा आदमी <end>']],
#  [['<start> turned on black monitor <end>'],
#   ['<start> ब्लैक मॉनीटर पर दिया <end>']],
#  [['<start> man wearing brown sunglasses <end>'],
#   ['<start> आदमी भूरा धूप का चश्मा पहने हुए <end>']],
#  [['<start> brick on the building <end>'], ['<start> इमारत पर ईंट <end>']],
#  [['<start> silver metal table on ground <end>'],
#   ['<start> जमीन पर धातु तालिका <end>']],
#  [['<start> a grey trash bin <end>'], ['<start> एक ग्रे कचरा बिन <end>']],
#  [['<start> boy holding ball <end>'], ['<start> बॉल पकड़े हुए लड़का <end>']],
#  [['<start> projection screen is white <end>'],
#   ['<start> प्रोजेक्शन स्क्रीन सफेद है <end>']],
#  [['<start> yellow traffic signal attached to a gray pole <end>'],
#   ['<start> पीले ट्रैफिक सिग्नल एक ग्रे पोल से जुड़ा हुआ है <end>']],
#  [['<start> red truck behind silver car <end>'],
#   ['<start> चांदी की कार के पीछे लाल ट्रक <end>']],
#  [['<start> two mopeds are parked <end>'],
#   ['<start> दो मोपेड खड़ी हैं <end>']],
#  [['<start> a blue car on the street <end>'],
#   ['<start> सड़क पर एक नीली कार <end>']],
#  [['<start> black car with yellow doors <end>'],
#   ['<start> पीली डोर वाली काली कार <end>']],
#  [['<start> a car with four doors <end>'],
#   ['<start> चार दरवाजों वाली एक कार <end>']],
#  [['<start> bike parked on the sidewalk <end>'],
#   ['<start> फुटपाथ पर खड़ी बाइक <end>']],
#  [['<start> red motorcycle on sidewalk <end>'],
#   ['<start> फुटपाथ पर लाल मोटरसाइकिल <end>']],
#  [['<start> man wearing blue shirt <end>'],
#   ['<start> नीली कमीज पहने आदमी <end>']],
#  [['<start> group of scooters parked next to each other <end>'],
#   ['<start> स्कूटरों का समूह एक दूसरे के बगल में खड़ा था <end>']],
#  [['<start> yellow vw leaving parking lot <end>'],
#   ['<start> पीले वीडब्ल्यू पार्किंग को छोड़कर <end>']],
#  [['<start> bag of oranges <end>'], ['<start> संतरे का बैग <end>']],
#  [['<start> there is a band on stage <end>'],
#   ['<start> मंच पर एक बैंड है <end>']],
#  [['<start> window on white house <end>'],
#   ['<start> सफेद घर पर खिड़की <end>']],
#  [['<start> these are tall buildings <end>'],
#   ['<start> ये ऊंची इमारतें हैं <end>']],
#  [['<start> small car beside curb <end>'],
#   ['<start> कर्ब के पास छोटी कार <end>']],
#  [['<start> this is a person <end>'], ['<start> यह एक व्यक्ति है <end>']],
#  [['<start> bull on the sand <end>'], ['<start> रेत पर बैल <end>']],
#  [['<start> the building with a yellow roof <end>'],
#   ['<start> एक पीले रंग की छत के साथ इमारत <end>']],
#  [['<start> the cup is upside down <end>'], ['<start> कप उल्टा है <end>']],
#  [['<start> light in the ceiling <end>'], ['<start> छत में प्रकाश <end>']],
#  [['<start> black truck is parked <end>'],
#   ['<start> काला ट्रक पार्क किया गया है <end>']],
#  [['<start> the man in the light blue coat <end>'],
#   ['<start> हल्के नीले कोट में आदमी <end>']],
#  [['<start> bike leaning against black gate <end>'],
#   ['<start> काले फाटक के खिलाफ बाइक झुकाव <end>']],
#  [['<start> white curtain on window <end>'],
#   ['<start> विंडो पर श्वेत पर्दा <end>']],
#  [['<start> the alarm clock is off <end>'],
#   ['<start> अलार्म घड़ी बंद है <end>']],
#  [['<start> a medium sized picture on the wall <end>'],
#   ['<start> दीवार पर एक मध्यम आकार का चित्र <end>']],
#  [['<start> a bottle of water on the table <end>'],
#   ['<start> टेबल पर पानी की एक बोतल <end>']],
#  [['<start> wired telephone connected to the wall <end>'],
#   ['<start> तार से जुड़ा तार <end>']],
#  [['<start> chair next to wood desk <end>'],
#   ['<start> लकड़ी के मेज़ के बगल में कुर्सी <end>']],
#  [['<start> lamppost next to television <end>'],
#   ['<start> टेलीविजन के बगल में लैम्पपोस्ट <end>']],
#  [['<start> black backpack beside a bed <end>'],
#   ['<start> एक बिस्तर के बगल में काला बैग <end>']],
#  [['<start> a silver faucet in a bathroom <end>'],
#   ['<start> एक बाथरूम में एक चांदी का नल <end>']],
#  [['<start> small plant on porch <end>'],
#   ['<start> पोर्च पर छोटा पौधा <end>']],
#  [['<start> cedar shingles on the house <end>'],
#   ['<start> देवदार घर पर दाद <end>']],
#  [['<start> a white and tan hotel room <end>'],
#   ['<start> एक सफेद और टैन होटल का कमरा <end>']],
#  [['<start> five knobs on a stove <end>'],
#   ['<start> एक डंडे पर पाँच गाँठ <end>']],
#  [['<start> the sink is stainless steel <end>'],
#   ['<start> सिंक स्टेनलेस स्टील है <end>']],
#  [['<start> a wooden floor <end>'], ['<start> एक लकड़ी के फर्श <end>']],
#  [['<start> the window is shut <end>'], ['<start> खिड़की बंद है <end>']],
#  [['<start> black car tire with silver rim <end>'],
#   ['<start> चांदी रिम के साथ काली कार टायर <end>']],
#  [['<start> a four legged steel chair <end>'],
#   ['<start> एक चार पैर वाली स्टील कुर्सी <end>']],
#  [['<start> red desk lamp sitting on desk <end>'],
#   ['<start> लाल डेस्क लैंप डेस्क पर बैठे <end>']],
#  [['<start> the wooden night stand <end>'],
#   ['<start> लकड़ी की रात स्टैंड <end>']],
#  [['<start> tall grassy plants <end>'], ['<start> लंबे घास के पौधे <end>']],
#  [['<start> part of a house plant <end>'], ['<start> मकान पौधे का भाग <end>']],
#  [['<start> red and green plaid sofa <end>'],
#   ['<start> लाल और हरे रंग का प्लेड सोफा <end>']],
#  [['<start> large kitchen area <end>'], ['<start> बड़ा रसोई क्षेत्र <end>']],
#  [['<start> boat on the water <end>'], ['<start> पानी पर नाव <end>']],
#  [['<start> vehicles parked on the side of the road <end>'],
#   ['<start> सड़क के किनारे वाहन खड़े कर दिए <end>']],
#  [['<start> a woman standing on the sidewalk <end>'],
#   ['<start> फुटपाथ पर खड़ी एक महिला <end>']],
#  [['<start> man standing on the phone <end>'],
#   ['<start> फोन पर खड़ा आदमी <end>']],
#  [['<start> a woman wearing a rain jacket <end>'],
#   ['<start> रेन जैकेट पहने एक महिला <end>']],
#  [['<start> taxi cab driving on street <end>'],
#   ['<start> सड़क पर टैक्सी टैक्सी चला रहे हैं <end>']],
#  [['<start> yellow taxi driving on a street <end>'],
#   ['<start> एक सड़क पर पीली टैक्सी चलती है <end>']],
#  [['<start> person walking down the sidewalk in a busy city <end>'],
#   ['<start> एक व्यस्त शहर में फुटपाथ के नीचे चलने वाला व्यक्ति <end>']],
#  [['<start> person walks on sidewalk <end>'],
#   ['<start> व्यक्ति फुटपाथ पर चलता है <end>']],
#  [['<start> group of people is standing <end>'],
#   ['<start> लोगों का समूह खड़ा है <end>']],
#  [['<start> black car on the street <end>'],
#   ['<start> सड़क पर काली कार <end>']],
#  [['<start> window of a car <end>'], ['<start> कार की खिड़की <end>']],
#  [['<start> flowers next to water <end>'],
#   ['<start> पानी के बगल में फूल <end>']],
#  [['<start> a food stand on a sidewalk <end>'],
#   ['<start> एक खाना फुटपाथ पर खड़ा है <end>']],
#  [['<start> person crossing on crosswalk <end>'],
#   ['<start> क्रॉसवॉक पर पार करने वाला व्यक्ति <end>']],
#  [['<start> van driving under light <end>'],
#   ['<start> प्रकाश के तहत वैन ड्राइविंग <end>']],
#  [['<start> yellow taxi on the road <end>'],
#   ['<start> सड़क पर पीली टैक्सी <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> women is wearing a pink shirt <end>'],
#   ['<start> एक ऑरत ने गुलाबी कुर्ता पहना हुआ हैं <end>']],
#  [['<start> tan hat hanging on a post <end>'],
#   ['<start> एक पोस्ट पर लटका तन टोपी <end>']],
#  [['<start> a white plane on a tarmac <end>'],
#   ['<start> एक टरमैक पर एक सफेद विमान <end>']],
#  [['<start> planes parked on the tarmac <end>'],
#   ['<start> टरमैक पर पार्क किए गए विमान <end>']],
#  [['<start> small window on airplane <end>'],
#   ['<start> हवाई जहाज पर छोटी खिड़की <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> small rocks <end>'], ['<start> छोटी चट्टानें <end>']],
#  [['<start> tree trunk is broken <end>'],
#   ['<start> पेड़ का तना टूट गया है <end>']],
#  [['<start> person in red shorts <end>'],
#   ['<start> लाल शॉर्ट्स में व्यक्ति <end>']],
#  [['<start> the shrub is very short <end>'],
#   ['<start> झाड़ी बहुत कम है <end>']],
#  [['<start> clouds in the sky <end>'], ['<start> आकाश में बादल <end>']],
#  [['<start> a buffalo near a road <end>'],
#   ['<start> एक सड़क के पास एक भैंस <end>']],
#  [['<start> cloud in the sky <end>'], ['<start> आकाश में बादल <end>']],
#  [['<start> white moving through the water <end>'],
#   ['<start> सफेद पानी के माध्यम से चलती है <end>']],
#  [['<start> parrot is on top of cage <end>'],
#   ['<start> तोता पिंजरे के ऊपर है <end>']],
#  [['<start> a bird standing in water <end>'],
#   ['<start> पानी में खड़ा एक पक्षी <end>']],
#  [['<start> right eye <end>'], ['<start> दाहिना आँख <end>']],
#  [['<start> light on the pole <end>'], ['<start> पोल पर प्रकाश <end>']],
#  [['<start> highway in a quiet area <end>'],
#   ['<start> एक शांत क्षेत्र में राजमार्ग <end>']],
#  [['<start> white cloud in sky <end>'], ['<start> आकाश में सफेद बादल <end>']],
#  [['<start> white boat next to the dock <end>'],
#   ['<start> गोदी के आगे सफेद नाव <end>']],
#  [['<start> boat in the water <end>'], ['<start> पानी में नाव <end>']],
#  [['<start> boat is orange <end>'], ['<start> नाव नारंगी है <end>']],
#  [['<start> bikes in line by sidewalk <end>'],
#   ['<start> फुटपाथ से लाइन में बाइक <end>']],
#  [['<start> small green minivan <end>'], ['<start> छोटे हरे मिनीवान <end>']],
#  [['<start> american flag hanging on side of building <end>'],
#   ['<start> इमारत के किनारे लटकता हुआ अमेरिकी झंडा <end>']],
#  [['<start> tree behind building <end>'],
#   ['<start> निर्माण के पीछे पेड़ <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> orange beak on white duck <end>'],
#   ['<start> सफेद बतख पर नारंगी चोंच <end>']],
#  [['<start> grey and white sky <end>'], ['<start> ग्रे और सफेद आकाश <end>']],
#  [['<start> man holding long yellow skis <end>'],
#   ['<start> आदमी लंबी पीली स्की पकड़े हुए <end>']],
#  [['<start> the red flag in the snow <end>'],
#   ['<start> बर्फ में लाल झंडा <end>']],
#  [['<start> black scooter on the road <end>'],
#   ['<start> सड़क पर काला स्कूटर <end>']],
#  [['<start> black metal lock box <end>'],
#   ['<start> काला धातु लॉक बक्सा <end>']],
#  [['<start> glass window on building <end>'],
#   ['<start> इमारत पर कांच विंडो <end>']],
#  [['<start> sidewalk is light grey <end>'],
#   ['<start> फुटपाथ हल्का भूरा है <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> paved road with parked cars <end>'],
#   ['<start> पार्क किए गए कारों सहित सड़क <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> window on a building <end>'], ['<start> इमारत पर खिडकि <end>']],
#  [['<start> white lines in the middle of the road <end>'],
#   ['<start> सड़क के बीच में सफेद लाइनें <end>']],
#  [['<start> car parked on a narrow road <end>'],
#   ['<start> एक संकरी सड़क पर खड़ी कार <end>']],
#  [['<start> red helmet on his head <end>'],
#   ['<start> उसके सिर पर लाल हेलमेट <end>']],
#  [['<start> boat on the water <end>'], ['<start> पानी पर नाव <end>']],
#  [['<start> the boat is at a dock <end>'],
#   ['<start> नाव एक गोदी में है <end>']],
#  [['<start> pink pants <end>'], ['<start> गुलाबी पैंट <end>']],
#  [['<start> blue parking lines on the pavement <end>'],
#   ['<start> फुटपाथ पर नीली पार्किंग लाइनें <end>']],
#  [['<start> the man is walking <end>'], ['<start> आदमी चल रहा है <end>']],
#  [['<start> the sidewalk <end>'], ['<start> फ़ुटपाथ <end>']],
#  [['<start> green palm on radio <end>'],
#   ['<start> रेडियो पर हरी हथेली <end>']],
#  [['<start> hole in silver hubcap <end>'],
#   ['<start> सिल्वर हबकैप में छेद <end>']],
#  [['<start> girl in blue jean skirt <end>'],
#   ['<start> नीली जीन स्कर्ट में लड़की <end>']],
#  [['<start> the electrical box on the post <end>'],
#   ['<start> पोस्ट पर विद्युत बॉक्स <end>']],
#  [['<start> sign on side of road <end>'],
#   ['<start> सड़क के किनारे साइन इन करें <end>']],
#  [['<start> green grass in a field <end>'],
#   ['<start> क्षेत्र में हरी घास <end>']],
#  [['<start> blue sign with large black base <end>'],
#   ['<start> बड़े काले आधार के साथ नीला चिन्ह <end>']],
#  [['<start> green palm on tree <end>'], ['<start> पेड़ पर हरा हथेली <end>']],
#  [['<start> picture in a frame <end>'], ['<start> एक फ्रेम में तस्वीर <end>']],
#  [['<start> the car is black <end>'], ['<start> कार काला है <end>']],
#  [['<start> red car near plant <end>'],
#   ['<start> संयंत्र के पास लाल कार <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> white bus on the street <end>'],
#   ['<start> सड़क पर सफेद बस <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> a decorated christmas tree <end>'],
#   ['<start> एक सजाया हुआ क्रिसमस ट्री <end>']],
#  [['<start> yellow dump truck by the mountain <end>'],
#   ['<start> पहाड़ द्वारा पीला डंप ट्रक <end>']],
#  [['<start> green palm on tree <end>'], ['<start> पेड़ पर हरा हथेली <end>']],
#  [['<start> sun in the sky <end>'], ['<start> आकाश में सूर्य <end>']],
#  [['<start> white print style letter <end>'],
#   ['<start> सफेद प्रिंट शैली <end>']],
#  [['<start> the light is on the ceiling <end>'],
#   ['<start> छत पर प्रकाश है <end>']],
#  [['<start> light brown wooden step <end>'],
#   ['<start> हल्के भूरे रंग का लकड़ी का कदम <end>']],
#  [['<start> womens lips <end>'], ['<start> महिला के होंठ <end>']],
#  [['<start> brick with grass around it <end>'],
#   ['<start> इसके चारों ओर घास के साथ ईंट <end>']],
#  [['<start> a seagull is standing <end>'], ['<start> एक सीगल खड़ा है <end>']],
#  [['<start> the building is large <end>'], ['<start> इमारत बड़ी है <end>']],
#  [['<start> a dark colored van <end>'], ['<start> गहरे रंग की एक वैन <end>']],
#  [['<start> a dark haired woman in a colorful top <end>'],
#   ['<start> एक रंगीन शीर्ष में एक काले बालों वाली महिला <end>']],
#  [['<start> ear of the cat <end>'], ['<start> बिल्ली का कान <end>']],
#  [['<start> the woman is next to the man <end>'],
#   ['<start> महिला पुरुष के बगल में है <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> grey colored sidewalk brick <end>'],
#   ['<start> धूसर रंग के ईंट फ़ुटपाथ <end>']],
#  [['<start> the man is standing <end>'], ['<start> आदमी खड़ा है <end>']],
#  [['<start> three men standing in a group <end>'],
#   ['<start> एक समूह में तीन आदमी खड़े थे <end>']],
#  [['<start> a luggage cart on a tarmac <end>'],
#   ['<start> एक टार्मेक पर एक सामान गाड़ी <end>']],
#  [['<start> the tail of an airplane <end>'],
#   ['<start> एक हवाई जहाज की पूंछ <end>']],
#  [['<start> black restroom sign attached to the wall <end>'],
#   ['<start> ब्लैक टॉयलेट साइन दीवार से जुड़ा हुआ <end>']],
#  [['<start> a long metal rack <end>'], ['<start> एक लंबा धातु रैक <end>']],
#  [['<start> light on a machine <end>'], ['<start> एक मशीन पर प्रकाश <end>']],
#  [['<start> child wearing striped shirt <end>'],
#   ['<start> धारीदार शर्ट पहने बच्चा <end>']],
#  [['<start> cameras on the ceiling of the room <end>'],
#   ['<start> कमरे की छत पर लगे कैमरे <end>']],
#  [['<start> vase on the mantel <end>'],
#   ['<start> अग्निस्थान के उप्पर ग़ुलदान <end>']],
#  [['<start> the man has a goatee <end>'],
#   ['<start> आदमी के पास एक बकरी है <end>']],
#  [['<start> man painting on canvas <end>'],
#   ['<start> कैनवास पर आदमी पेंटिंग <end>']],
#  [['<start> a row of red chairs <end>'],
#   ['<start> लाल कुर्सियों की एक पंक्ति <end>']],
#  [['<start> two police officers <end>'], ['<start> दो पुलिस अधिकारी <end>']],
#  [['<start> houseboat in the water <end>'],
#   ['<start> पानी में हाउसबोट <end>']],
#  [['<start> bread in a basket <end>'], ['<start> एक टोकरी में रोटी <end>']],
#  [['<start> man with short black hair <end>'],
#   ['<start> छोटे काले बालों वाला आदमी <end>']],
#  [['<start> a big grey ball <end>'], ['<start> एक बड़ी ग्रे बॉल <end>']],
#  [['<start> white table cloth on the table <end>'],
#   ['<start> मेज पर सफेद कपड़ा तालिका <end>']],
#  [['<start> a person sitting in the baptism tub <end>'],
#   ['<start> एक व्यक्ति दीक्षास्नान टब में बैठे व्यक्ति | <end>']],
#  [['<start> horizontal venetian blinds on the window <end>'],
#   ['<start> क्षैतिज विनीशियन खिड़की पर अंधा कर रही है <end>']],
#  [['<start> flatscreen television on the dresser <end>'],
#   ['<start> ड्रेसर पर फ्लैट स्क्रीन टेलीविजन <end>']],
#  [['<start> lights suspended from ceiling <end>'],
#   ['<start> छत से निलंबित प्रकाश <end>']],
#  [['<start> the man has gray hair <end>'],
#   ['<start> आदमी के भूरे बाल हैं <end>']],
#  [['<start> man wearing white shirt <end>'],
#   ['<start> आदमी सफेद शर्ट पहने हुए <end>']],
#  [['<start> people sitting in a bus <end>'],
#   ['<start> एक बस में बैठे लोग <end>']],
#  [['<start> man and woman in a candy store <end>'],
#   ['<start> एक कैंडी की दुकान में आदमी और औरत <end>']],
#  [['<start> chair desk combo in the room <end>'],
#   ['<start> कमरे में कुर्सी डेस्क कॉम्बो <end>']],
#  [['<start> the man is wearing glasses <end>'],
#   ['<start> आदमी चश्मा पहन रहा है | <end>']],
#  [['<start> a man with no shirt in the snow <end>'],
#   ['<start> बर्फ में कुर्ता के साथ एक व्यक्ति <end>']],
#  [['<start> grey dividers for cubicles <end>'],
#   ['<start> क्यूबिकल्स के लिए ग्रे डिवाइडर <end>']],
#  [['<start> windown pane on door <end>'],
#   ['<start> द्वार पर विन्ड फलक <end>']],
#  [['<start> truck has white cargo holder <end>'],
#   ['<start> ट्रक में सफेद कार्गो धारक है <end>']],
#  [['<start> the chair has no arms <end>'],
#   ['<start> कुर्सी के पास कोई हथियार नहीं है <end>']],
#  [['<start> man has head turned <end>'],
#   ['<start> आदमी का सिर मुड़ गया है <end>']],
#  [['<start> child walking into plane <end>'],
#   ['<start> बच्चा विमान में घूम रहा है <end>']],
#  [['<start> purple tissue paper around bouquet <end>'],
#   ['<start> गुलदस्ता के चारों ओर बैंगनी टिशू पेपर <end>']],
#  [['<start> pool table in a large room <end>'],
#   ['<start> एक बड़े कमरे में पूल टेबल <end>']],
#  [['<start> paddle on a table <end>'], ['<start> एक तालिका पर पैडल <end>']],
#  [['<start> man standing in a room <end>'],
#   ['<start> एक कमरे में खड़ा आदमी <end>']],
#  [['<start> man relaxing in the water <end>'],
#   ['<start> आदमी पानी में आराम करता है <end>']],
#  [['<start> man is in a pool <end>'], ['<start> आदमी एक कुंड में है <end>']],
#  [['<start> boy has brown hair <end>'],
#   ['<start> लड़के के भूरे बाल हैं <end>']],
#  [['<start> a brown and white staircase <end>'],
#   ['<start> एक भूरे और सफेद सीढ़ी <end>']],
#  [['<start> building is painted green <end>'],
#   ['<start> भवन को हरे रंग से रंगा गया है <end>']],
#  [['<start> many people in snow <end>'], ['<start> बर्फ में कई लोग <end>']],
#  [['<start> the silver toilet <end>'], ['<start> चाँदी का शौचालय <end>']],
#  [['<start> yellow slide in the room <end>'],
#   ['<start> कमरे में पीली स्लाइड <end>']],
#  [['<start> child shopping cart filled with fake food <end>'],
#   ['<start> बाल शॉपिंग गाड़ी से भरा हुआ भोजन <end>']],
#  [['<start> this is a kitchen <end>'], ['<start> यह एक रसोई है <end>']],
#  [['<start> a faucet on the sink <end>'], ['<start> सिंक पर एक नल <end>']],
#  [['<start> assorted cereals on a kitchen shelf <end>'],
#   ['<start> एक रसोई के शेल्फ पर अनाज रखा <end>']],
#  [['<start> white microwave oven in corner <end>'],
#   ['<start> कोने में सफेद माइक्रोवेव ओवन <end>']],
#  [['<start> wall papered wall in a kitchen <end>'],
#   ['<start> एक रसोई घर में दीवार दीवार <end>']],
#  [['<start> a wall of orange dryers <end>'],
#   ['<start> नारंगी ड्रायर्स की एक दीवार <end>']],
#  [['<start> white pipe on the wall <end>'],
#   ['<start> दीवार पर सफेद पाइप <end>']],
#  [['<start> dolphin statue near the pool <end>'],
#   ['<start> पूल के निकट डॉल्फिन <end>']],
#  [['<start> microwave on top of counter <end>'],
#   ['<start> काउंटर के ऊपर माइक्रोवेव <end>']],
#  [['<start> logo on the hat <end>'], ['<start> टोपी पर लोगो <end>']],
#  [['<start> a person kneeling down <end>'],
#   ['<start> एक व्यक्ति ने घुटने टेक दिए <end>']],
#  [['<start> person wearing black pants <end>'],
#   ['<start> व्यक्ति ने काला पैंट पहना है <end>']],
#  [['<start> people sitting on a couch <end>'],
#   ['<start> एक सोफे पर बैठे लोग <end>']],
#  [['<start> light hanging from the ceiling <end>'],
#   ['<start> छत से लटके हुए प्रकाश <end>']],
#  [['<start> square hole in chair <end>'],
#   ['<start> कुर्सी में चौकोर छेद <end>']],
#  [['<start> arms up in the air <end>'], ['<start> हवा में हथियार <end>']],
#  [['<start> orange pail hanging from wall <end>'],
#   ['<start> नारंगी की दीवार से लटकी हुई <end>']],
#  [['<start> white washer situated under a counter <end>'],
#   ['<start> एक काउंटर के नीचे स्थित सफेद वॉशर <end>']],
#  [['<start> person sitting in front of window <end>'],
#   ['<start> खिड़की के सामने बैठा व्यक्ति <end>']],
#  [['<start> light of daytime sky <end>'],
#   ['<start> दिन के आकाश का प्रकाश <end>']],
#  [['<start> brown lounge chair next to the pool <end>'],
#   ['<start> पूल के बगल में ब्राउन लाउंज कुर्सी <end>']],
#  [['<start> a group of umbrellas at a pool <end>'],
#   ['<start> एक पूल में छतरियों का एक समूह <end>']],
#  [['<start> red bench near elegant chair <end>'],
#   ['<start> सुरुचिपूर्ण कुर्सी के पास लाल बेंच <end>']],
#  [['<start> green turtle pool in stack <end>'],
#   ['<start> स्टैक में हरा कछुआ पूल <end>']],
#  [['<start> many people in a room <end>'],
#   ['<start> एक कमरे में कई लोग <end>']],
#  [['<start> man with a blue and black plaid shirt <end>'],
#   ['<start> एक नीले और काले प्लेड शर्ट के साथ आदमी <end>']],
#  [['<start> the word polar on the truck <end>'],
#   ['<start> ट्रक पर ध्रुवीय शब्द <end>']],
#  [['<start> a black and brown area rug <end>'],
#   ['<start> एक काला और भूरा क्षेत्र गलीचा <end>']],
#  [['<start> black chair to the left of brown table <end>'],
#   ['<start> भूरे रंग की मेज के बाईं ओर काली कुर्सी <end>']],
#  [['<start> brown colored wooden stair <end>'],
#   ['<start> भूरे रंग की लकड़ी की सीढ़ी <end>']],
#  [['<start> a yellow and black tie on a man <end>'],
#   ['<start> एक पीला और काला बांध आदमी पर <end>']],
#  [['<start> person walking on trail <end>'],
#   ['<start> राह पर चलते व्यक्ति <end>']],
#  [['<start> woman wearing red scarf <end>'],
#   ['<start> लाल स्कार्फ पहनने वाली महिला <end>']],
#  [['<start> pigeon on ground <end>'], ['<start> जमीन पर कबूतर <end>']],
#  [['<start> back of docked houseboat <end>'],
#   ['<start> गोदी हाउसबोट की पीठ <end>']],
#  [['<start> a yellow skirt <end>'], ['<start> एक पीला स्कर्ट <end>']],
#  [['<start> black tv in room <end>'], ['<start> कक्ष में काला टीवी <end>']],
#  [['<start> television remote sitting on a red tablecloth <end>'],
#   ['<start> टेलीविज़न रिमोट एक लाल मेज़पोश पर बैठा है <end>']],
#  [['<start> mirror on the wall <end>'], ['<start> दीवार पर लगा दर्पण <end>']],
#  [['<start> picture hanging on the wall <end>'],
#   ['<start> दीवार पर टंगी तस्वीर <end>']],
#  [['<start> a large painting on a wall <end>'],
#   ['<start> एक दीवार पर एक बड़ी पेंटिंग <end>']],
#  [['<start> photo taken during the day <end>'],
#   ['<start> दिन के दौरान लिया गया फोटो <end>']],
#  [['<start> people walking on the bridge <end>'],
#   ['<start> पुल पर चलते लोग <end>']],
#  [['<start> tower with pointed top <end>'],
#   ['<start> नुकीले शीर्ष वाला टॉवर <end>']],
#  [['<start> these are old structures <end>'],
#   ['<start> ये पुराने ढाँचे हैं <end>']],
#  [['<start> grey steps on stairs <end>'],
#   ['<start> सीढ़ियों पर ग्रे कदम <end>']],
#  [['<start> person walking on spiral stairs <end>'],
#   ['<start> सर्पिल सीढ़ियों पर चलने वाला व्यक्ति <end>']],
#  [['<start> window on a residential building <end>'],
#   ['<start> एक आवासीय भवन पर खिड़की <end>']],
#  [['<start> the silver butter knives <end>'],
#   ['<start> चांदी मक्खन चाकू <end>']],
#  [['<start> utensil to the left of plate <end>'],
#   ['<start> थाली के बाईं ओर बर्तन <end>']],
#  [['<start> black letters on paper <end>'],
#   ['<start> कागज पर काले अक्षर <end>']],
#  [['<start> coffee cup full of frothy coffee <end>'],
#   ['<start> फ्राई कॉफी से भरा कॉफी कप <end>']],
#  [['<start> cut banana in bowl <end>'],
#   ['<start> केले को कटोरे में काट लें <end>']],
#  [['<start> juice in glass bottle <end>'],
#   ['<start> शीशे की बोतल में रस <end>']],
#  [['<start> a vase full of red flowers <end>'],
#   ['<start> लाल फूलों से भरा फूलदान <end>']],
#  [['<start> the rainbow looks like a half moon <end>'],
#   ['<start> इंद्रधनुष आधा चाँद की तरह दिखता है <end>']],
#  [['<start> wooden slat on chair <end>'],
#   ['<start> कुर्सी पर लकड़ी की बस्ती <end>']],
#  [['<start> a brown wooden cabinet door <end>'],
#   ['<start> एक भूरे रंग की लकड़ी की कैबिनेट दरवाजा <end>']],
#  [['<start> the gun is shiny <end>'], ['<start> बंदूक चमकदार है <end>']],
#  [['<start> clear blue sky above a mountaintop <end>'],
#   ['<start> एक पहाड़ के ऊपर स्पष्ट नीला आकाश <end>']],
#  [['<start> a window in an apartment building <end>'],
#   ['<start> एक अपार्टमेंट इमारत में एक खिड़की <end>']],
#  [['<start> a black street light <end>'],
#   ['<start> एक काली स्ट्रीट लाइट <end>']],
#  [['<start> a black chair <end>'], ['<start> एक काली कुर्सी <end>']],
#  [['<start> two men sitting at a desk <end>'],
#   ['<start> एक डेस्क पर दो आदमी बैठे थे <end>']],
#  [['<start> phone with twisted cord <end>'],
#   ['<start> मुड़ कॉर्ड के साथ फोन <end>']],
#  [['<start> a white car parked on the street <end>'],
#   ['<start> एक सफेद कार सड़क पर खड़ी थी <end>']],
#  [['<start> white car parked near the fence <end>'],
#   ['<start> सफेद कार बाड़ के पास खड़ी है <end>']],
#  [['<start> window side of building <end>'],
#   ['<start> भवन की खिड़की का किनारा <end>']],
#  [['<start> this is a woman <end>'], ['<start> यह एक महिला है <end>']],
#  [['<start> the field is green <end>'], ['<start> क्षेत्र हरा है <end>']],
#  [['<start> yellow lines on the street <end>'],
#   ['<start> सड़क पर पीली लाइनें <end>']],
#  [['<start> black car parked on the street <end>'],
#   ['<start> सड़क पर काली कार पार्क <end>']],
#  [['<start> the street <end>'], ['<start> सड़क <end>']],
#  [['<start> this is a car <end>'], ['<start> यह एक कार है <end>']],
#  [['<start> the water is green in color <end>'],
#   ['<start> पानी का रंग हरा है <end>']],
#  [['<start> license plate on the car <end>'],
#   ['<start> कार पर लगी लाइसेंस प्लेट <end>']],
#  [['<start> black car on a road <end>'],
#   ['<start> एक सड़क पर काली कार <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> pane on the window <end>'], ['<start> खिड़की पर फलक <end>']],
#  [['<start> tall outdoor lamp post <end>'],
#   ['<start> लंबा आउटडोर लैंप पोस्ट <end>']],
#  [['<start> tire of the car <end>'], ['<start> गाड़ी का टायर <end>']],
#  [['<start> the brown delivery truck <end>'],
#   ['<start> भूरे रंग का डिलीवरी ट्रक <end>']],
#  [['<start> car tire made of black rubber and silver metal <end>'],
#   ['<start> कार का टायर काला रबर और चांदी की धातु से बना है <end>']],
#  [['<start> the parked white car <end>'], ['<start> खड़ी सफेद कार <end>']],
#  [['<start> a brightly lit rear brake light <end>'],
#   ['<start> एक उज्ज्वल जला हुआ रियर ब्रेक लाइट <end>']],
#  [['<start> window in a large office building <end>'],
#   ['<start> एक बड़े कार्यालय भवन में खिड़की <end>']],
#  [['<start> window in front of building <end>'],
#   ['<start> भवन के सामने की खिड़की <end>']],
#  [['<start> blue house with light brown roof <end>'],
#   ['<start> हल्के भूरे रंग की छत वाला नीला घर <end>']],
#  [['<start> the older woman walking on the sidewalk <end>'],
#   ['<start> फुटपाथ पर चलने वाली वृद्ध महिला <end>']],
#  [['<start> a large black trashcan <end>'],
#   ['<start> एक बड़े काले ट्रैशकैन <end>']],
#  [['<start> street signs says ames <end>'],
#   ['<start> स्ट्रीट संकेत कहते हैं एम्स <end>']],
#  [['<start> woman standing on sidewalk <end>'],
#   ['<start> फुटपाथ पर खड़ी महिला <end>']],
#  [['<start> square window on building <end>'],
#   ['<start> इमारत पर वर्ग खिड़की <end>']],
#  [['<start> book on brown wooden bookshelf <end>'],
#   ['<start> भूरी लकड़ी की बुकशेल्फ़ पर किताब <end>']],
#  [['<start> paper cup on top of desk <end>'],
#   ['<start> डेस्क के शीर्ष पर पेपर कप <end>']],
#  [['<start> clock on the wall <end>'], ['<start> दीवार पर घड़ी <end>']],
#  [['<start> vase on the table <end>'], ['<start> मेज पर फूलदान <end>']],
#  [['<start> a glossy blue coffee mug <end>'],
#   ['<start> एक चमकदार नीली कॉफी मग <end>']],
#  [['<start> silver faucet on kitchen sink <end>'],
#   ['<start> रसोई के सिंक पर चांदी का नल <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> the woman in jeans and a black shirt <end>'],
#   ['<start> जींस और काले रंग की शर्ट में महिला <end>']],
#  [['<start> a blue and white parking sign <end>'],
#   ['<start> एक नीले और सफेद पार्किंग साइन <end>']],
#  [['<start> the plant on the toilet <end>'],
#   ['<start> शौचालय पर संयंत्र <end>']],
#  [['<start> white book with black writing <end>'],
#   ['<start> काले लेखन के साथ सफेद किताब <end>']],
#  [['<start> a tan car parked <end>'], ['<start> एक टैन कार खड़ी थी <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> woman has black hair <end>'],
#   ['<start> स्त्री के काले बाल है <end>']],
#  [['<start> man walking on sidewalk <end>'],
#   ['<start> फुटपाथ पर चलने वाला आदमी <end>']],
#  [['<start> banners on the post <end>'], ['<start> पोस्ट पर बैनर <end>']],
#  [['<start> reflection on store window <end>'],
#   ['<start> दुकान की खिड़की पर प्रतिबिंब <end>']],
#  [['<start> the bench is long <end>'], ['<start> बेंच लंबा है <end>']],
#  [['<start> wood plank on porch <end>'],
#   ['<start> पोर्च पर लकड़ी प्लांक <end>']],
#  [['<start> crisp brown leaf fallen off of a tree <end>'],
#   ['<start> एक पेड़ से गिरने वाला कुरकुरा भूरा पत्ता <end>']],
#  [['<start> a stone in a leaf filled field <end>'],
#   ['<start> पत्ती से भरे खेत में एक पत्थर <end>']],
#  [['<start> silver suv parked on road <end>'],
#   ['<start> चांदी एसयूवी सड़क पर खड़ी है <end>']],
#  [['<start> paint on a mailbox <end>'], ['<start> मेलबॉक्स पर पेंट <end>']],
#  [['<start> window in front of white building <end>'],
#   ['<start> सफेद इमारत के सामने की खिड़की <end>']],
#  [['<start> clock on the wall <end>'], ['<start> दीवार पर घड़ी <end>']],
#  [['<start> the silver car <end>'], ['<start> चाँदी की कार <end>']],
#  [['<start> a women standing <end>'], ['<start> एक महिला खड़ी है <end>']],
#  [['<start> window in front of brick building <end>'],
#   ['<start> ईंट निर्माण के सामने की खिड़की <end>']],
#  [['<start> do not enter street sign <end>'],
#   ['<start> सड़क चिह्न नहीं दाखिल करें <end>']],
#  [['<start> the red headed woman wlaking on the sidewalk <end>'],
#   ['<start> लाल बालों वाली औरत सड़्क पर चलते हुए <end>']],
#  [['<start> window in front of building <end>'],
#   ['<start> भवन के सामने की खिड़की <end>']],
#  [['<start> maroon car parked at the curb <end>'],
#   ['<start> मैरून कार कर्ब पर खड़ी <end>']],
#  [['<start> blue vehicle parked on the street <end>'],
#   ['<start> सड़क पर खड़ा नीला वाहन <end>']],
#  [['<start> jeep suv parked on curb <end>'],
#   ['<start> जीप एसयूवी पर अंकुश लगा दिया <end>']],
#  [['<start> a street light on a metal pole <end>'],
#   ['<start> एक धातु के खंभे पर एक स्ट्रीट लाइट <end>']],
#  [['<start> the shelf is color brown <end>'],
#   ['<start> शेल्फ का रंग भूरा है <end>']],
#  [['<start> a computer is on front a keyboard <end>'],
#   ['<start> एक कंप्यूटर एक कीबोर्ड पर होता है <end>']],
#  [['<start> blue and white coffee mug <end>'],
#   ['<start> नीला और सफेद कॉफी कि जग <end>']],
#  [['<start> an empty poster board on the wall <end>'],
#   ['<start> दीवार पर एक खाली पोस्टर बोर्ड <end>']],
#  [['<start> yellow box of snack crackers <end>'],
#   ['<start> स्नैक बिस्कुट का पीला बक्सा <end>']],
#  [['<start> black monitor on desk <end>'],
#   ['<start> ब्लैक मॉनिटर ऑन डेस्क <end>']],
#  [['<start> black and white desk lamp <end>'],
#   ['<start> ब्लैक एंड व्हाइट डेस्क लैंप <end>']],
#  [['<start> gray plastic trash can under desk <end>'],
#   ['<start> डेस्क के नीचे ग्रे प्लास्टिक कचरा हो सकता है <end>']],
#  [['<start> whtie microwave oven <end>'], ['<start> माइक्रोवेव ओवन <end>']],
#  [['<start> office chair in front of computer monitor <end>'],
#   ['<start> कंप्यूटर मॉनिटर के सामने कार्यालय की कुर्सी <end>']],
#  [['<start> blue cardigan draped over blue chair <end>'],
#   ['<start> नीली कुर्सी पर नीला कार्डिगन लिपटा हुआ <end>']],
#  [['<start> a row of binders on a shelf <end>'],
#   ['<start> एक शेल्फ पर बाँधने की एक पंक्ति <end>']],
#  [['<start> a white piece of paper <end>'],
#   ['<start> कागज का एक सफेद टुकड़ा <end>']],
#  [['<start> white keyboard on top of desk <end>'],
#   ['<start> डेस्क के ऊपर सफेद कीबोर्ड <end>']],
#  [['<start> an old black tire <end>'], ['<start> एक पुरानी काली टायर <end>']],
#  [['<start> maroon suv driving down the road <end>'],
#   ['<start> सड़क के नीचे जाती लाल रंग की एसयूवी <end>']],
#  [['<start> a map hanging on the wall <end>'],
#   ['<start> दीवार पर लटका एक नक्शा <end>']],
#  [['<start> fluorescent ceiling lights <end>'],
#   ['<start> फ्लोरोसेंट छत रोशनी <end>']],
#  [['<start> a tan wooden desk <end>'], ['<start> एक लकड़ी की मेज <end>']],
#  [['<start> the blue walls <end>'], ['<start> नीली दीवारों <end>']],
#  [['<start> large window with white sill <end>'],
#   ['<start> सफेद खिड़की के साथ बड़ी खिड़की <end>']],
#  [['<start> red street sign with white lettering <end>'],
#   ['<start> लाल स्ट्रीट लाल चिह्न सफेद पट्टी के साथ <end>']],
#  [['<start> a red sign with a white stripe <end>'],
#   ['<start> एक सफेद पट्टी के साथ एक लाल संकेत <end>']],
#  [['<start> car driving on road <end>'], ['<start> सड़क पर कार चलाना <end>']],
#  [['<start> blue banner with white decorations <end>'],
#   ['<start> सफेद सजावट के साथ नीला बैनर <end>']],
#  [['<start> black railingon the sidewalk <end>'],
#   ['<start> काला रेलिंगोन सिडीचलन <end>']],
#  [['<start> person on the surfboard <end>'],
#   ['<start> सर्फ़बोर्ड पर व्यक्ति <end>']],
#  [['<start> boat in the water <end>'], ['<start> पानी में नाव <end>']],
#  [['<start> a row of parked cars <end>'],
#   ['<start> खड़ी कारों की एक पंक्ति <end>']],
#  [['<start> a black computer monitor <end>'],
#   ['<start> एक काला कंप्यूटर मॉनीटर <end>']],
#  [['<start> multicolored rainbow over water <end>'],
#   ['<start> पानी के ऊपर बहु रंगीन इंद्रधनुष <end>']],
#  [['<start> the hedges to the right <end>'],
#   ['<start> हेज करने के लिए सही है <end>']],
#  [['<start> a coffee cup on a table <end>'],
#   ['<start> एक मेज पर एक कॉफी कप <end>']],
#  [['<start> street light is off <end>'],
#   ['<start> स्ट्रीट लाइट बंद है <end>']],
#  [['<start> man standing in a black suit and blue shirt <end>'],
#   ['<start> एक काले सूट और नीली शर्ट में खड़ा आदमी <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> yellow and black pedestrian crossing signal <end>'],
#   ['<start> पीले और काले पैदल यात्री क्रॉसिंग सिग्नल <end>']],
#  [['<start> a window on a building <end>'],
#   ['<start> एक इमारत पर एक खिड़की <end>']],
#  [['<start> person in black tank top <end>'],
#   ['<start> काला टैंक टॉप में व्यक्ति <end>']],
#  [['<start> boy wearing a black shirt <end>'],
#   ['<start> एक काला शर्ट पहनने हुए लड़का <end>']],
#  [['<start> a small gray motorcycle <end>'],
#   ['<start> एक छोटी ग्रे मोटरसाइकिल <end>']],
#  [['<start> window on large building <end>'],
#   ['<start> बड़ी इमारत पर खिड़की <end>']],
#  [['<start> this is a motor vehicle <end>'],
#   ['<start> यह एक मोटर वाहन है <end>']],
#  [['<start> two people talking at the bottom of the stairs <end>'],
#   ['<start> सीढ़ियों के नीचे बात कर रहे हैं दो लोग | <end>']],
#  [['<start> the van is blue white and green <end>'],
#   ['<start> वैन नीले सफेद और हरे रंग की है <end>']],
#  [['<start> a door way to a business <end>'],
#   ['<start> किसी व्यापार का दरवाज़ा <end>']],
#  [['<start> wheel of the vehicle <end>'], ['<start> वाहन का पहिया <end>']],
#  [['<start> a car with four doors <end>'],
#   ['<start> चार द्वारों के साथ एक कार <end>']],
#  [['<start> man walking on the street <end>'],
#   ['<start> आदमी सड़क पर चल रहा है <end>']],
#  [['<start> the white car is parked <end>'],
#   ['<start> सफेद कार खड़ी है <end>']],
#  [['<start> the red tip of a pole <end>'],
#   ['<start> एक पोल की लाल टिप <end>']],
#  [['<start> a coca cola sign <end>'], ['<start> कोका कोला चिह्न <end>']],
#  [['<start> a window on a building <end>'], ['<start> इमारत पर खिड़्की <end>']],
#  [['<start> a red and white umbrella <end>'],
#   ['<start> एक लाल और सफेद छाता <end>']],
#  [['<start> the head of a man <end>'], ['<start> एक आदमी का सिर <end>']],
#  [['<start> the picture frame is gold in color <end>'],
#   ['<start> यह तस्वीर रंग में सोना है | <end>']],
#  [['<start> the stairs leading to entrance <end>'],
#   ['<start> प्रवेश द्वार की ओर जाने वाली सीढ़ियाँ <end>']],
#  [['<start> window on the building <end>'], ['<start> इमारत पर विंडो <end>']],
#  [['<start> this is a taxi cab <end>'], ['<start> यह एक टैक्सी कैब है <end>']],
#  [['<start> large tree with no leaves <end>'],
#   ['<start> बिना पत्तों वाला बड़ा पेड़ <end>']],
#  [['<start> work truck is white <end>'], ['<start> कार्य ट्रक सफेद है <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> a white car parked on the side of a street <end>'],
#   ['<start> एक सड़क के किनारे खड़ी एक सफेद कार <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> black car parked on the street <end>'],
#   ['<start> काली कार सड़क पर खड़ी <end>']],
#  [['<start> window on red brick window <end>'],
#   ['<start> लाल ईंट विंडो पर विंडो <end>']],
#  [['<start> the car is red and parked in the street <end>'],
#   ['<start> कार लाल है और गली में खड़ी है <end>']],
#  [['<start> windows on the building <end>'],
#   ['<start> इमारत पर खिड़कियाँ <end>']],
#  [['<start> window on side of building <end>'],
#   ['<start> भवन के किनारे की खिड़की <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> brown tree trunk <end>'],
#   ['<start> भूरे रंग का पेड़ का तना <end>']],
#  [['<start> townhouse is painted yellow <end>'],
#   ['<start> घर का रंग पीला होता है <end>']],
#  [['<start> a row of parked cars <end>'],
#   ['<start> खड़ी कारों की एक पंक्ति <end>']],
#  [['<start> window on side of a building <end>'],
#   ['<start> एक इमारत की तरफ खिड़की <end>']],
#  [['<start> man standing wearing orange lifesaving <end>'],
#   ['<start> नारंगी नारंगी जीवन धारण किए हुए आदमी खड़ा है <end>']],
#  [['<start> a pot on the stairs <end>'],
#   ['<start> सीढ़ियों पर एक घड़ा <end>']],
#  [['<start> tall green tree on grass <end>'],
#   ['<start> घास पर लंबा हरा पेड़ <end>']],
#  [['<start> a vast space of water <end>'],
#   ['<start> पानी का एक विशाल स्थान <end>']],
#  [['<start> moss on the wall <end>'], ['<start> दीवार पर काई <end>']],
#  [['<start> thick trees surrounding the town <end>'],
#   ['<start> शहर के चारों ओर घने पेड़ <end>']],
#  [['<start> mountains in the background <end>'],
#   ['<start> पृष्ठभूमि में पर्वत <end>']],
#  [['<start> big white boat traveling in water <end>'],
#   ['<start> पानी में बड़ी सफेद नाव यात्रा <end>']],
#  [['<start> a wheel <end>'], ['<start> एक पहिया <end>']],
#  [['<start> a red fire hydrant is visible at a distance <end>'],
#   ['<start> की दूरी पर एक लाल अग्नि हाइड्रेंट दिखाई देता है <end>']],
#  [['<start> the girls brown hair <end>'], ['<start> लड़की भूरे बाल | <end>']],
#  [['<start> window on front of brick building <end>'],
#   ['<start> ईंट इमारत के सामने खिड़की <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> brown tree trunk <end>'],
#   ['<start> भूरे रंग का पेड़ का तना <end>']],
#  [['<start> bird near a lake <end>'], ['<start> झील के निकट पक्षी <end>']],
#  [['<start> old shed with a metal roof <end>'],
#   ['<start> एक धातु की छत के साथ पुराना शेड <end>']],
#  [['<start> tall and brown mountain <end>'],
#   ['<start> लंबा और भूरा पर्वत <end>']],
#  [['<start> the pile of gray and brown rocks <end>'],
#   ['<start> ग्रे और भूरी चट्टानों का ढेर <end>']],
#  [['<start> the people are walking <end>'], ['<start> लोग चल रहे हैं <end>']],
#  [['<start> post in the ground <end>'], ['<start> जमीन पर डाक <end>']],
#  [['<start> a window with a rounded top <end>'],
# ...
#   ['<start> एक लाल जैकेट पहनने वाला आदमी <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> इमारत पर कांच की खिड़्की <end>']],
#  [['<start> a white parked car <end>'], ['<start> एक सफेद पार्क कार <end>']],
#  [['<start> bicycle leaning against pole <end>'],
#   ['<start> पोल के खिलाफ साइकिल झुकाव <end>']],
#  [['<start> the house is green <end>'], ['<start> घर हरा है <end>']],
#  [['<start> the person is walking <end>'],
#   ['<start> व्यक्ति चल रहा है <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> a window on a building <end>'], ['<start> इमारत पर खिड़्की <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> भवन पर कांच की खिड़की <end>']],
#  [['<start> a long curve walkway <end>'], ['<start> लंबा वक्र वाल्केम <end>']],
#  [['<start> a womans blue bag <end>'], ['<start> एक महिला का नीला बैग <end>']],
#  [['<start> this is a large building <end>'],
#   ['<start> यह एक बड़ी इमारत है <end>']],
#  [['<start> a light blue sky with large white clouds <end>'],
#   ['<start> बड़े सफेद बादलों के साथ एक हल्का नीला आकाश <end>']],
#  [['<start> green street sign that says congress st <end>'],
#   ['<start> हरे रंग की सड़क का संकेत जो कांग्रेस को सेंट कहता है <end>']],
#  [['<start> red and grey suv <end>'], ['<start> लाल और ग्रे एसयूवी <end>']],
#  [['<start> window on building facing street <end>'],
#   ['<start> इमारत का सामना करना पड़ सड़क पर खिड़की <end>']],
#  [['<start> some deep tire tracks in the snow <end>'],
#   ['<start> बर्फ में कुछ गहरे टायर ट्रैक <end>']],
#  [['<start> a street covered with snow <end>'],
#   ['<start> बर्फ से ढकी एक सड़क <end>']],
#  [['<start> the cars are covered in snow <end>'],
#   ['<start> कारें बर्फ में ढकी हुई हैं <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> windown on dark red building <end>'],
#   ['<start> अंधेरे लाल इमारत पर विचलित <end>']],
#  [['<start> white snow on the ground <end>'],
#   ['<start> जमीन पर सफेद बर्फ <end>']],
#  [['<start> window on top floor of white building <end>'],
#   ['<start> सफेद इमारत की ऊपरी मंजिल पर खिड़की <end>']],
#  [['<start> a yellow and blue sign <end>'],
#   ['<start> एक पीला और नीला चिह्न <end>']],
#  [['<start> person walking on the sidewalk <end>'],
#   ['<start> फुटपाथ पर चलने वाला व्यक्ति <end>']],
#  [['<start> red dresses in the window <end>'],
#   ['<start> विंडो में लाल ड्रेस <end>']],
#  [['<start> this is a city street <end>'],
#   ['<start> यह एक शहर की सड़क है <end>']],
#  [['<start> the red blurry sign <end>'], ['<start> लाल बल्री चिह्न <end>']],
#  [['<start> woman in dress walking <end>'],
#   ['<start> कपड़े पहने महिला <end>']],
#  [['<start> sign on the building <end>'],
#   ['<start> इमारत पर हस्ताक्षर <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> भवन पर कांच की खिड़की <end>']],
#  [['<start> an ornate black street light <end>'],
#   ['<start> एक अलंकृत काली स्ट्रीट लाइट <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> भवन पर कांच की खिड़की <end>']],
#  [['<start> orange bar on fence <end>'],
#   ['<start> बाड़ पर नारंगी पट्टी <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> pole on the sidewalk <end>'], ['<start> फुटपाथ पर पोल <end>']],
#  [['<start> these are a bunch of buildings <end>'],
#   ['<start> ये इमारतों का एक समूह हैं <end>']],
#  [['<start> car <end>'], ['<start> गाड़ी <end>']],
#  [['<start> the person is standing <end>'], ['<start> व्यक्ति खड़ा है <end>']],
#  [['<start> the person is walking <end>'],
#   ['<start> व्यक्ति चल रहा है <end>']],
#  [['<start> window on corner building <end>'],
#   ['<start> कोने के निर्माण पर खिड़की <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> इमारत पर कांच की खिड़्की <end>']],
#  [['<start> tractor parked on sidewalk <end>'],
#   ['<start> ट्रैक्टर फुटपाथ पर खड़ा था <end>']],
#  [['<start> leg of the bench <end>'], ['<start> बेंच का पैर <end>']],
#  [['<start> a person walking on a sidewalk <end>'],
#   ['<start> एक व्यक्ति जो फ़ुटपाथ पर चलता है <end>']],
#  [['<start> a car on a street <end>'], ['<start> एक सड़क पर एक कार <end>']],
#  [['<start> light on the pole <end>'], ['<start> पोल पर प्रकाश <end>']],
#  [['<start> round black tire on car <end>'],
#   ['<start> कार पर गोल काला टायर <end>']],
#  [['<start> a white line in the street <end>'],
#   ['<start> सड़क में एक सफेद रेखा <end>']],
#  [['<start> car parked at the curb <end>'],
#   ['<start> कार पर अंकुश लगाया <end>']],
#  [['<start> the sky is grey and white <end>'],
#   ['<start> आकाश ग्रे और सफेद है <end>']],
#  [['<start> lamp pole near a road <end>'],
#   ['<start> एक सड़क के पास लैंप पोल <end>']],
#  [['<start> this is a car <end>'], ['<start> यह एक कार है <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> the car is gold <end>'], ['<start> कार सोना है <end>']],
#  [['<start> the grey car driving on the street <end>'],
#   ['<start> सड़क पर ग्रे कार चला रहा है <end>']],
#  [['<start> a red and white sign <end>'],
#   ['<start> एक लाल और सफेद संकेत <end>']],
#  [['<start> two semicircular tunnels set in a hill <end>'],
#   ['<start> एक पहाड़ी में सेट दो अर्ध गोलाकार ट्यूनेल <end>']],
#  [['<start> silver car parked in the street <end>'],
#   ['<start> सड़क में सिल्वर कार पार्क किया <end>']],
#  [['<start> this is a man <end>'], ['<start> यह एक आदमी है <end>']],
#  [['<start> taillight of a vehicle <end>'], ['<start> वाहन <end>']],
#  [['<start> white van parked in front of sidewalk <end>'],
#   ['<start> फुटपाथ के सामने खड़ी सफेद वैन <end>']],
#  [['<start> the car is white <end>'], ['<start> कार सफेद है <end>']],
#  [['<start> the vehicles on the road <end>'], ['<start> सड़क पर वाहन <end>']],
#  [['<start> metal guard rail beside of road <end>'],
#   ['<start> सड़क के अतिरिक्त धातु रेल <end>']],
#  [['<start> window on the building <end>'], ['<start> इमारत पर विंडो <end>']],
#  [['<start> flower bed in street <end>'],
#   ['<start> सड़क में फूलों का बिस्तर <end>']],
#  [['<start> red car parked in the street <end>'],
#   ['<start> गली में खड़ी लाल कार <end>']],
#  [['<start> round ball with letters airis <end>'],
#   ['<start> पत्र के साथ गोल गेंद <end>']],
#  [['<start> the car is black <end>'], ['<start> कार काली है <end>']],
#  [['<start> a round blue and white sign <end>'],
#   ['<start> एक गोल नीला और सफेद निशान <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> the small stone wall on the side of the road <end>'],
#   ['<start> सड़क के किनारे पर छोटी पत्थर दीवार <end>']],
#  [['<start> a red vehicle on a highway <end>'],
#   ['<start> एक राजमार्ग पर एक लाल वाहन <end>']],
#  [['<start> window on the car <end>'], ['<start> कार पर खिड़की <end>']],
#  [['<start> a car on a street <end>'], ['<start> एक सड़क पर एक कार <end>']],
#  [['<start> the black aentenna ont he hood <end>'],
#   ['<start> काले एंटेंना वह हूड पर था <end>']],
#  [['<start> board on the building <end>'], ['<start> इमारत पर बोर्ड <end>']],
#  [['<start> the car is silver <end>'], ['<start> कार चांदी है <end>']],
#  [['<start> leaves on the tree <end>'],
#   ['<start> पेड़ पर छोड़ देता है <end>']],
#  [['<start> the wooden bench on the sidewalk <end>'],
#   ['<start> फुटपाथ पर लकड़ी के बेंच <end>']],
#  [['<start> trunk of the tree <end>'], ['<start> पेड़ का तना <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> tree is bare and in the park <end>'],
#   ['<start> पेड़ नंगे और पार्क में है <end>']],
#  [['<start> leaf in the water <end>'], ['<start> पानी में पत्ती <end>']],
#  [['<start> person in black shorts <end>'],
#   ['<start> काले शॉर्ट्स में व्यक्ति <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> a tree in a city <end>'], ['<start> एक शहर में एक वृक्ष <end>']],
#  [['<start> the sitting arrangement on a street <end>'],
#   ['<start> एक सड़क पर बैठने की व्यवस्था <end>']],
#  [['<start> the numbers above the door <end>'],
#   ['<start> दरवाजे के ऊपर की संख्या <end>']],
#  [['<start> a window on a building <end>'],
#   ['<start> एक इमारत पर एक खिड़की <end>']],
#  [['<start> the plate is black in color <end>'],
#   ['<start> प्लेट का रंग काला है <end>']],
#  [['<start> orange color on truck <end>'],
#   ['<start> ट्रक पर नारंगी रंग <end>']],
#  [['<start> white lines on the road <end>'],
#   ['<start> सड़क पर सफेद लाइनें <end>']],
#  [['<start> the car is silver <end>'], ['<start> कार चाँदी है <end>']],
#  [['<start> silver car parked along the street <end>'],
#   ['<start> सड़क के किनारे खड़ी चांदी की कार <end>']],
#  [['<start> skyscraper in front of car <end>'],
#   ['<start> कार के सामने गगनचुंबी इमारत <end>']],
#  [['<start> parked silver suv <end>'], ['<start> पार्क की गई सिल्वर <end>']],
#  [['<start> round white lamp on top of lamp post <end>'],
#   ['<start> लैंप पोस्ट के शीर्ष पर गोल सफेद दीपक <end>']],
#  [['<start> green shutters on the building <end>'],
#   ['<start> इमारत पर हरे शटर | <end>']],
#  [['<start> the door is brown <end>'], ['<start> दरवाजा भूरा है <end>']],
#  [['<start> shallow pool with three fountain heads <end>'],
#   ['<start> तीन फाउंटेन हेड्स वाला उथला पूल <end>']],
#  [['<start> woman in white and red shirt <end>'],
#   ['<start> सफेद और लाल शर्ट में महिला <end>']],
#  [['<start> thick hedge bordering the sidewalk <end>'],
#   ['<start> फुटपाथ की सीमा पर मोटी हेज <end>']],
#  [['<start> the sky is shining and blue <end>'],
#   ['<start> आकाश चमक रहा है और नीला है <end>']],
#  [['<start> leaves on the tree <end>'],
#   ['<start> पेड़ पर छोड़ देता है <end>']],
#  [['<start> two street lights <end>'], ['<start> दो सड़क रोशनी <end>']],
#  [['<start> person in red jacket <end>'],
#   ['<start> लाल जैकेट में व्यक्ति <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> people eating outside <end>'],
#   ['<start> बाहर खाने वाले लोग <end>']],
#  [['<start> two traffic lights lit up red <end>'],
#   ['<start> दो यातायात रोशनी लाल जलाया <end>']],
#  [['<start> a black parked car <end>'],
#   ['<start> एक काले रंग की खड़ी कार <end>']],
#  [['<start> a parked black car <end>'], ['<start> एक खड़ी कार <end>']],
#  [['<start> dark green suv <end>'], ['<start> गहरा हरा सुव <end>']],
#  [['<start> mural of bird on a building <end>'],
#   ['<start> एक इमारत पर पक्षियों का भित्ति चित्र <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> man standing in front of wall <end>'],
#   ['<start> दीवार के सामने खड़ा आदमी <end>']],
#  [['<start> man with brown hair <end>'],
#   ['<start> भूरे बालों वाला आदमी <end>']],
#  [['<start> one grey stapler <end>'], ['<start> एक ग्रे स्टेपलर <end>']],
#  [['<start> woman has an eye <end>'], ['<start> महिला की एक आंख है <end>']],
#  [['<start> bench with person sitting and waiting <end>'],
#   ['<start> बेंच पर बैठे और प्रतीक्षा करता आदमी <end>']],
#  [['<start> he is wearing blue jeans <end>'],
#   ['<start> उसने नीली जींस पहनी हुई है <end>']],
#  [['<start> the truck is red <end>'], ['<start> ट्रक लाल है <end>']],
#  [['<start> person wearing shirt <end>'], ['<start> शर्ट पहने व्यक्ति <end>']],
#  [['<start> man in a white shirt <end>'],
#   ['<start> एक सफेद शर्ट में आदमी <end>']],
#  [['<start> man walking wearing white shoes <end>'],
#   ['<start> सफेद जूते पहने हुए आदमी <end>']],
#  [['<start> tall dog in a field <end>'],
#   ['<start> मैदान मे लम्बा कुत्ते <end>']],
#  [['<start> man has white teeth <end>'],
#   ['<start> आदमी के सफेद दांत हैं <end>']],
#  [['<start> person looking at the camera <end>'],
#   ['<start> कैमरे को देख रहे व्यक्ति <end>']],
#  [['<start> person standing on mountain <end>'],
#   ['<start> पहाड़ पर खड़ा व्यक्ति <end>']],
#  [['<start> sidewalk with block pattern <end>'],
#   ['<start> ब्लॉक पैटर्न के साथ साइडवॉक <end>']],
#  [['<start> the building is tall <end>'], ['<start> भवन लंबा है <end>']],
#  [['<start> a man with short hair and a goatee <end>'],
#   ['<start> छोटे बाल और एक बकरी के साथ एक आदमी <end>']],
#  [['<start> the trunk of a tree <end>'], ['<start> एक पेड़ का तना <end>']],
#  [['<start> dog is sitting in grass <end>'],
#   ['<start> कुत्ता घास में बैठा है <end>']],
#  [['<start> man wearing a yellow sweater <end>'],
#   ['<start> पीला स्वेटर पहने व्यक्ति <end>']],
#  [['<start> a scene during the day time <end>'],
#   ['<start> दिन के समय एक दृश्य <end>']],
#  [['<start> the hand is on table <end>'], ['<start> हाथ मेज पर है | <end>']],
#  [['<start> the stapler laying on the floor <end>'],
#   ['<start> मंजिल पर रखे स्टेपलर <end>']],
#  [['<start> cliff in the water <end>'], ['<start> पानी में चट्टान <end>']],
#  [['<start> car in the arch of the hotel entrance <end>'],
#   ['<start> होटल प्रवेश के मार्च में कार <end>']],
#  [['<start> boat at the edge of water <end>'],
#   ['<start> पानी के किनारे नाव <end>']],
#  [['<start> head shot of a young white man <end>'],
#   ['<start> एक युवा श्वेत व्यक्ति के सिर में गोली लगी <end>']],
#  [['<start> a scene during the day time <end>'],
#   ['<start> दिन के समय एक दृश्य <end>']],
#  [['<start> plane sitting on the runway <end>'],
#   ['<start> विमान रनवे पर बैठा <end>']],
#  [['<start> a gray stapler on the corner desk <end>'],
#   ['<start> कोने की मेज पर एक ग्रे स्टेपलर <end>']],
#  [['<start> the person wearing red <end>'],
#   ['<start> लाल रंग का व्यक्ति <end>']],
#  [['<start> head shot of a young woman <end>'],
#   ['<start> युवती के सिर में गोली लगी <end>']],
#  [['<start> photo taken during the day <end>'],
#   ['<start> दिन के दौरान लिया गया फोटो <end>']],
#  [['<start> license plate of a car <end>'],
#   ['<start> कार की लाइसेंस प्लेट <end>']],
#  [['<start> circle on the wood door <end>'],
#   ['<start> लकड़ी के दरवाजे पर घेरा <end>']],
#  [['<start> brown rock near highway <end>'],
#   ['<start> राजमार्ग के निकट भूरी चट्टान <end>']],
#  [['<start> man in the kitchen <end>'], ['<start> आदमी रसोई में <end>']],
#  [['<start> underside of the lane highway <end>'],
#   ['<start> लेन राजमार्ग के नीचे <end>']],
#  [['<start> man has short hair <end>'],
#   ['<start> मनुष्य के बाल छोटे है <end>']],
#  [['<start> person wears a green shirt <end>'],
#   ['<start> व्यक्ति हरे रंग की शर्ट पहनता है <end>']],
#  [['<start> a green parrot <end>'], ['<start> एक हरा पारोट <end>']],
#  [['<start> green leaves on brown tree <end>'],
#   ['<start> हरे पेड़ पर हरे पत्ते <end>']],
#  [['<start> window facing red building <end>'],
#   ['<start> खिड़की लाल इमारत का सामना करना पड़ <end>']],
#  [['<start> windows on the top level <end>'],
#   ['<start> शीर्ष स्तर पर विंडोज <end>']],
#  [['<start> right ear of a man <end>'],
#   ['<start> किसी व्यक्ति का दाहिना कान <end>']],
#  [['<start> stone block on pier <end>'], ['<start> घाट पर पत्थर ब्लॉक <end>']],
#  [['<start> green wall behind a man <end>'],
#   ['<start> एक व्यक्ति के पीछे हरी दीवार <end>']],
#  [['<start> the background is blue <end>'],
#   ['<start> बैकग्राउंड नीला है <end>']],
#  [['<start> guy with short brown hair <end>'],
#   ['<start> छोटे भूरे बालों के साथ लड़का <end>']],
#  [['<start> four black chairs around a table <end>'],
#   ['<start> एक तालिका के आसपास चार काले कुर्सियाँ <end>']],
#  [['<start> big green truck on dirt road <end>'],
#   ['<start> गंदगी सड़क पर बड़ा हरा ट्रक <end>']],
#  [['<start> man wearing yellow sweater <end>'],
#   ['<start> पीला स्वेटर पहने हुए आदमी <end>']],
#  [['<start> a person walking on a sidewalk <end>'],
#   ['<start> फुटपाथ पर चलने वाला व्यक्ति <end>']],
#  [['<start> laptop computer sitting on desk <end>'],
#   ['<start> लैपटॉप कंप्यूटर डेस्क पर बैठे <end>']],
#  [['<start> coffee cup on the table <end>'], ['<start> मेज पर कॉफी कप <end>']],
#  [['<start> black sign with white letters <end>'],
#   ['<start> सफेद अक्षरों के साथ काला हस्ताक्षर <end>']],
#  [['<start> trunk of tree <end>'], ['<start> पेड़ का ट्रंक | <end>']],
#  [['<start> a rock in water <end>'], ['<start> पानी में एक चट्टान <end>']],
#  [['<start> white van in the parking lot <end>'],
#   ['<start> पार्किंग में सफेद वैन <end>']],
#  [['<start> parrot sitting on a tree branch <end>'],
#   ['<start> तोता एक पेड़ शाखा पर बैठे हुए <end>']],
#  ...]

# %%
# shuffling values
import random
BUFFER_SIZE = 28930
BATCH_SIZE = 64
num_examples = 20000
# train_dataset = clean_data[:n_train]
# val_dataset = clean_data[n_train:]
# # Let's limit the #training examples for faster training

# train_dataset = random.shuffle(train_dataset)
# val_dataset = random.shuffle(val_dataset)
# type(clean_data[0][1])

# %%
# train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# %%
clean_hindi_lines = []
clean_english_lines = []
for i in range(len(clean_data)):
    clean_hindi_lines.append(clean_data[i][1])
    clean_english_lines.append(clean_data[i][0])

# %%
clean_hindi = list()
for i in range(len(clean_hindi_lines)):
    clean_hindi.append(clean_hindi_lines[i][0])
    
clean_english = list()
for i in range(len(clean_english_lines)):
    clean_english.append(clean_english_lines[i][0])

# %%
clean_hindi
# Out:
# ['<start> यह एक इनडोर दृश्य है <end>',
#  '<start> कंप्यूटर स्क्रीन चालू <end>',
#  '<start> आदमी के छोटे बाल हैं <end>',
#  '<start> एक वयस्क की गोद में फोटो एल्बम खुला <end>',
#  '<start> काली कार के पास लड़कियों का एक समूह है <end>',
#  '<start> एक घुमक्कड़ में बच्चा <end>',
#  '<start> लंबा धातु प्रकाश पोस्ट <end>',
#  '<start> दीवार सफेद रंग की है <end>',
#  '<start> दीवार पर कई चित्र हैं <end>',
#  '<start> सागर का सामना कर रही महिला <end>',
#  '<start> यह एक कार्यालय लेआउट है <end>',
#  '<start> चार धातु की कुर्सियाँ <end>',
#  '<start> क्लटर एक मेज पर है <end>',
#  '<start> एक सफेद माइक्रोवेव ओवन <end>',
#  '<start> चौराहे के माध्यम से सफेद एसयूवी ड्राइविंग <end>',
#  '<start> छतरी के साथ सड़क पार करते व्यक्ति <end>',
#  '<start> इमारत पर झुकाव में आदमी ग्रे पैंट में <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> कारों के बीच में खड़ा एक आदमी <end>',
#  '<start> दीवार पर चित्रकला <end>',
#  '<start> कुर्सी का पैर <end>',
#  '<start> एक नाव की खिड़की <end>',
#  '<start> कैबिनेट लकड़ी है <end>',
#  '<start> एक आदमी एक किताब पढ़ रहा है <end>',
#  '<start> पानी में तैरता हुआ व्यक्ति <end>',
#  '<start> चमकती छाया के साथ दीपक <end>',
#  '<start> प्लेट पर फल <end>',
#  '<start> एक चीनी मिट्टी के बरतन सफ़ेद प्लेट <end>',
#  '<start> काला खेल नियंत्रक <end>',
#  '<start> कार की डिक्की में कुछ डालने वाला व्यक्ति <end>',
#  '<start> एक सड़क के साथ ग्रीन कार पार्क किया <end>',
#  '<start> गली पर कार <end>',
#  '<start> निर्माण कर्मचारी कवरलेस पहनते हैं <end>',
#  '<start> पीले दरवाजे के साथ एक काली कार <end>',
#  '<start> मेज पर कुर्सी <end>',
#  '<start> एक काउंटर पर एक नारंगी संतरा <end>',
#  '<start> एक इमारत की तीन खिड़कियां <end>',
#  '<start> इमारत पर खिडकि <end>',
#  '<start> भूरे रंग की मेज एक मंजिल के ऊपर खड़ी है <end>',
#  '<start> फ्लोर लैंप चालू है <end>',
#  '<start> एक पीली बस <end>',
#  '<start> वृक्ष की शाखा <end>',
#  '<start> भवन के बाहर सीमेंट की बेंच <end>',
#  '<start> एक सफेद पट्टी के साथ मोटी काली पोल <end>',
#  '<start> लकड़ी पार्क बेंच <end>',
#  '<start> एक कप <end>',
#  '<start> आदमी के भूरे बाल हैं <end>',
#  '<start> एक खेत में घास <end>',
#  '<start> एक बड़ा भूरा पेड़ का तना <end>',
#  '<start> इमारत के सामने चांदी कार <end>',
#  '<start> आदमी काउंटर पर बैठता है <end>',
#  '<start> किताब की गाड़ी पर खड़ी महिला <end>',
#  '<start> दो कहानी नीली बस <end>',
#  '<start> एक ग्रे कपड़े धोने की टोकरी <end>',
#  '<start> पीले रंग की निर्माण टोपी <end>',
#  '<start> कमरे में लकड़ी का फर्श <end>',
#  '<start> क्षितिज के ऊपर एक लंबा ताड़ का पेड़ <end>',
#  '<start> एक सभागार के अंदर कुर्सी <end>',
#  '<start> एक लंबा पत्ते का पेड़ <end>',
#  '<start> दर्पण दूर की दीवार पर है <end>',
#  '<start> फ़ुटपाथ <end>',
#  '<start> ड्राइवर के बगल का द्वार खुला है <end>',
#  '<start> भोजन से भरी थाली <end>',
#  '<start> इमारत सफेद है <end>',
#  '<start> दीवार पर छोटी सी तस्वीर <end>',
#  '<start> लकड़ी के लॉग का चौराहे <end>',
#  '<start> इमारत से संबद्ध प्रकाश <end>',
#  '<start> साइन न करें <end>',
#  '<start> सफेद धारीदार सोफे पर ब्लूज़ और रेड्स का रंगीन तकिया <end>',
#  '<start> डेंट वाहन में है <end>',
#  '<start> छत ग्रे है <end>',
#  '<start> दर्पण पर भूरे रंग का फ्रेम <end>',
#  '<start> पेड़ के नीचे सफेद फूल <end>',
#  '<start> सड़क पर सफेद एम्बुलेंस <end>',
#  '<start> दूरी में हरे पेड़ <end>',
#  '<start> यह चिह्न नीला है <end>',
#  '<start> सड़क के किनारे बैठा आदमी <end>',
#  '<start> सड़क पार करने वाला एक आदमी <end>',
#  '<start> दीवार पर साइन इन करें <end>',
#  '<start> एक ईंट के घर में खिड़की <end>',
#  '<start> कंप्यूटर की स्क्रीन नीली है <end>',
#  '<start> बाइक मार्ग का चिह्न <end>',
#  '<start> एक आदमी पर ग्रे दाढ़ी बाल <end>',
#  '<start> कार का पिछला दृश्य <end>',
#  '<start> पनीर सॉस के साथ बर्गर <end>',
#  '<start> रजत एसयूवी की ओर <end>',
#  '<start> सड़क पर घूमती हुई महिला <end>',
#  '<start> गुलाबी जैकेट पहने महिला <end>',
#  '<start> गली की बत्ती से के पास खड़ी लाल कार <end>',
#  '<start> ट्रैफिक लाइट पीले हैं <end>',
#  '<start> फुटपाथ पर सफेद रंग की लाइन <end>',
#  '<start> मेज पर काले रंग की कलम <end>',
#  '<start> सफेद शर्ट में आदमी फुटपाथ के नीचे चल रहा है <end>',
#  '<start> छत में बड़ा प्रकाश आकार <end>',
#  '<start> सफेद मॉनिटर डेस्क पर <end>',
#  '<start> डेस्क पर ब्लैक कंप्यूटर मॉनिटर <end>',
#  '<start> मग पर संभाल <end>',
#  '<start> कंप्यूटर मॉनिटर के सामने बैठा आदमी <end>',
#  '<start> ब्लैक मॉनीटर पर दिया <end>',
#  '<start> आदमी भूरा धूप का चश्मा पहने हुए <end>',
#  '<start> इमारत पर ईंट <end>',
#  '<start> जमीन पर धातु तालिका <end>',
#  '<start> एक ग्रे कचरा बिन <end>',
#  '<start> बॉल पकड़े हुए लड़का <end>',
#  '<start> प्रोजेक्शन स्क्रीन सफेद है <end>',
#  '<start> पीले ट्रैफिक सिग्नल एक ग्रे पोल से जुड़ा हुआ है <end>',
#  '<start> चांदी की कार के पीछे लाल ट्रक <end>',
#  '<start> दो मोपेड खड़ी हैं <end>',
#  '<start> सड़क पर एक नीली कार <end>',
#  '<start> पीली डोर वाली काली कार <end>',
#  '<start> चार दरवाजों वाली एक कार <end>',
#  '<start> फुटपाथ पर खड़ी बाइक <end>',
#  '<start> फुटपाथ पर लाल मोटरसाइकिल <end>',
#  '<start> नीली कमीज पहने आदमी <end>',
#  '<start> स्कूटरों का समूह एक दूसरे के बगल में खड़ा था <end>',
#  '<start> पीले वीडब्ल्यू पार्किंग को छोड़कर <end>',
#  '<start> संतरे का बैग <end>',
#  '<start> मंच पर एक बैंड है <end>',
#  '<start> सफेद घर पर खिड़की <end>',
#  '<start> ये ऊंची इमारतें हैं <end>',
#  '<start> कर्ब के पास छोटी कार <end>',
#  '<start> यह एक व्यक्ति है <end>',
#  '<start> रेत पर बैल <end>',
#  '<start> एक पीले रंग की छत के साथ इमारत <end>',
#  '<start> कप उल्टा है <end>',
#  '<start> छत में प्रकाश <end>',
#  '<start> काला ट्रक पार्क किया गया है <end>',
#  '<start> हल्के नीले कोट में आदमी <end>',
#  '<start> काले फाटक के खिलाफ बाइक झुकाव <end>',
#  '<start> विंडो पर श्वेत पर्दा <end>',
#  '<start> अलार्म घड़ी बंद है <end>',
#  '<start> दीवार पर एक मध्यम आकार का चित्र <end>',
#  '<start> टेबल पर पानी की एक बोतल <end>',
#  '<start> तार से जुड़ा तार <end>',
#  '<start> लकड़ी के मेज़ के बगल में कुर्सी <end>',
#  '<start> टेलीविजन के बगल में लैम्पपोस्ट <end>',
#  '<start> एक बिस्तर के बगल में काला बैग <end>',
#  '<start> एक बाथरूम में एक चांदी का नल <end>',
#  '<start> पोर्च पर छोटा पौधा <end>',
#  '<start> देवदार घर पर दाद <end>',
#  '<start> एक सफेद और टैन होटल का कमरा <end>',
#  '<start> एक डंडे पर पाँच गाँठ <end>',
#  '<start> सिंक स्टेनलेस स्टील है <end>',
#  '<start> एक लकड़ी के फर्श <end>',
#  '<start> खिड़की बंद है <end>',
#  '<start> चांदी रिम के साथ काली कार टायर <end>',
#  '<start> एक चार पैर वाली स्टील कुर्सी <end>',
#  '<start> लाल डेस्क लैंप डेस्क पर बैठे <end>',
#  '<start> लकड़ी की रात स्टैंड <end>',
#  '<start> लंबे घास के पौधे <end>',
#  '<start> मकान पौधे का भाग <end>',
#  '<start> लाल और हरे रंग का प्लेड सोफा <end>',
#  '<start> बड़ा रसोई क्षेत्र <end>',
#  '<start> पानी पर नाव <end>',
#  '<start> सड़क के किनारे वाहन खड़े कर दिए <end>',
#  '<start> फुटपाथ पर खड़ी एक महिला <end>',
#  '<start> फोन पर खड़ा आदमी <end>',
#  '<start> रेन जैकेट पहने एक महिला <end>',
#  '<start> सड़क पर टैक्सी टैक्सी चला रहे हैं <end>',
#  '<start> एक सड़क पर पीली टैक्सी चलती है <end>',
#  '<start> एक व्यस्त शहर में फुटपाथ के नीचे चलने वाला व्यक्ति <end>',
#  '<start> व्यक्ति फुटपाथ पर चलता है <end>',
#  '<start> लोगों का समूह खड़ा है <end>',
#  '<start> सड़क पर काली कार <end>',
#  '<start> कार की खिड़की <end>',
#  '<start> पानी के बगल में फूल <end>',
#  '<start> एक खाना फुटपाथ पर खड़ा है <end>',
#  '<start> क्रॉसवॉक पर पार करने वाला व्यक्ति <end>',
#  '<start> प्रकाश के तहत वैन ड्राइविंग <end>',
#  '<start> सड़क पर पीली टैक्सी <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> एक ऑरत ने गुलाबी कुर्ता पहना हुआ हैं <end>',
#  '<start> एक पोस्ट पर लटका तन टोपी <end>',
#  '<start> एक टरमैक पर एक सफेद विमान <end>',
#  '<start> टरमैक पर पार्क किए गए विमान <end>',
#  '<start> हवाई जहाज पर छोटी खिड़की <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> छोटी चट्टानें <end>',
#  '<start> पेड़ का तना टूट गया है <end>',
#  '<start> लाल शॉर्ट्स में व्यक्ति <end>',
#  '<start> झाड़ी बहुत कम है <end>',
#  '<start> आकाश में बादल <end>',
#  '<start> एक सड़क के पास एक भैंस <end>',
#  '<start> आकाश में बादल <end>',
#  '<start> सफेद पानी के माध्यम से चलती है <end>',
#  '<start> तोता पिंजरे के ऊपर है <end>',
#  '<start> पानी में खड़ा एक पक्षी <end>',
#  '<start> दाहिना आँख <end>',
#  '<start> पोल पर प्रकाश <end>',
#  '<start> एक शांत क्षेत्र में राजमार्ग <end>',
#  '<start> आकाश में सफेद बादल <end>',
#  '<start> गोदी के आगे सफेद नाव <end>',
#  '<start> पानी में नाव <end>',
#  '<start> नाव नारंगी है <end>',
#  '<start> फुटपाथ से लाइन में बाइक <end>',
#  '<start> छोटे हरे मिनीवान <end>',
#  '<start> इमारत के किनारे लटकता हुआ अमेरिकी झंडा <end>',
#  '<start> निर्माण के पीछे पेड़ <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> सफेद बतख पर नारंगी चोंच <end>',
#  '<start> ग्रे और सफेद आकाश <end>',
#  '<start> आदमी लंबी पीली स्की पकड़े हुए <end>',
#  '<start> बर्फ में लाल झंडा <end>',
#  '<start> सड़क पर काला स्कूटर <end>',
#  '<start> काला धातु लॉक बक्सा <end>',
#  '<start> इमारत पर कांच विंडो <end>',
#  '<start> फुटपाथ हल्का भूरा है <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> पार्क किए गए कारों सहित सड़क <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> इमारत पर खिडकि <end>',
#  '<start> सड़क के बीच में सफेद लाइनें <end>',
#  '<start> एक संकरी सड़क पर खड़ी कार <end>',
#  '<start> उसके सिर पर लाल हेलमेट <end>',
#  '<start> पानी पर नाव <end>',
#  '<start> नाव एक गोदी में है <end>',
#  '<start> गुलाबी पैंट <end>',
#  '<start> फुटपाथ पर नीली पार्किंग लाइनें <end>',
#  '<start> आदमी चल रहा है <end>',
#  '<start> फ़ुटपाथ <end>',
#  '<start> रेडियो पर हरी हथेली <end>',
#  '<start> सिल्वर हबकैप में छेद <end>',
#  '<start> नीली जीन स्कर्ट में लड़की <end>',
#  '<start> पोस्ट पर विद्युत बॉक्स <end>',
#  '<start> सड़क के किनारे साइन इन करें <end>',
#  '<start> क्षेत्र में हरी घास <end>',
#  '<start> बड़े काले आधार के साथ नीला चिन्ह <end>',
#  '<start> पेड़ पर हरा हथेली <end>',
#  '<start> एक फ्रेम में तस्वीर <end>',
#  '<start> कार काला है <end>',
#  '<start> संयंत्र के पास लाल कार <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> सड़क पर सफेद बस <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> एक सजाया हुआ क्रिसमस ट्री <end>',
#  '<start> पहाड़ द्वारा पीला डंप ट्रक <end>',
#  '<start> पेड़ पर हरा हथेली <end>',
#  '<start> आकाश में सूर्य <end>',
#  '<start> सफेद प्रिंट शैली <end>',
#  '<start> छत पर प्रकाश है <end>',
#  '<start> हल्के भूरे रंग का लकड़ी का कदम <end>',
#  '<start> महिला के होंठ <end>',
#  '<start> इसके चारों ओर घास के साथ ईंट <end>',
#  '<start> एक सीगल खड़ा है <end>',
#  '<start> इमारत बड़ी है <end>',
#  '<start> गहरे रंग की एक वैन <end>',
#  '<start> एक रंगीन शीर्ष में एक काले बालों वाली महिला <end>',
#  '<start> बिल्ली का कान <end>',
#  '<start> महिला पुरुष के बगल में है <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> धूसर रंग के ईंट फ़ुटपाथ <end>',
#  '<start> आदमी खड़ा है <end>',
#  '<start> एक समूह में तीन आदमी खड़े थे <end>',
#  '<start> एक टार्मेक पर एक सामान गाड़ी <end>',
#  '<start> एक हवाई जहाज की पूंछ <end>',
#  '<start> ब्लैक टॉयलेट साइन दीवार से जुड़ा हुआ <end>',
#  '<start> एक लंबा धातु रैक <end>',
#  '<start> एक मशीन पर प्रकाश <end>',
#  '<start> धारीदार शर्ट पहने बच्चा <end>',
#  '<start> कमरे की छत पर लगे कैमरे <end>',
#  '<start> अग्निस्थान के उप्पर ग़ुलदान <end>',
#  '<start> आदमी के पास एक बकरी है <end>',
#  '<start> कैनवास पर आदमी पेंटिंग <end>',
#  '<start> लाल कुर्सियों की एक पंक्ति <end>',
#  '<start> दो पुलिस अधिकारी <end>',
#  '<start> पानी में हाउसबोट <end>',
#  '<start> एक टोकरी में रोटी <end>',
#  '<start> छोटे काले बालों वाला आदमी <end>',
#  '<start> एक बड़ी ग्रे बॉल <end>',
#  '<start> मेज पर सफेद कपड़ा तालिका <end>',
#  '<start> एक व्यक्ति दीक्षास्नान टब में बैठे व्यक्ति | <end>',
#  '<start> क्षैतिज विनीशियन खिड़की पर अंधा कर रही है <end>',
#  '<start> ड्रेसर पर फ्लैट स्क्रीन टेलीविजन <end>',
#  '<start> छत से निलंबित प्रकाश <end>',
#  '<start> आदमी के भूरे बाल हैं <end>',
#  '<start> आदमी सफेद शर्ट पहने हुए <end>',
#  '<start> एक बस में बैठे लोग <end>',
#  '<start> एक कैंडी की दुकान में आदमी और औरत <end>',
#  '<start> कमरे में कुर्सी डेस्क कॉम्बो <end>',
#  '<start> आदमी चश्मा पहन रहा है | <end>',
#  '<start> बर्फ में कुर्ता के साथ एक व्यक्ति <end>',
#  '<start> क्यूबिकल्स के लिए ग्रे डिवाइडर <end>',
#  '<start> द्वार पर विन्ड फलक <end>',
#  '<start> ट्रक में सफेद कार्गो धारक है <end>',
#  '<start> कुर्सी के पास कोई हथियार नहीं है <end>',
#  '<start> आदमी का सिर मुड़ गया है <end>',
#  '<start> बच्चा विमान में घूम रहा है <end>',
#  '<start> गुलदस्ता के चारों ओर बैंगनी टिशू पेपर <end>',
#  '<start> एक बड़े कमरे में पूल टेबल <end>',
#  '<start> एक तालिका पर पैडल <end>',
#  '<start> एक कमरे में खड़ा आदमी <end>',
#  '<start> आदमी पानी में आराम करता है <end>',
#  '<start> आदमी एक कुंड में है <end>',
#  '<start> लड़के के भूरे बाल हैं <end>',
#  '<start> एक भूरे और सफेद सीढ़ी <end>',
#  '<start> भवन को हरे रंग से रंगा गया है <end>',
#  '<start> बर्फ में कई लोग <end>',
#  '<start> चाँदी का शौचालय <end>',
#  '<start> कमरे में पीली स्लाइड <end>',
#  '<start> बाल शॉपिंग गाड़ी से भरा हुआ भोजन <end>',
#  '<start> यह एक रसोई है <end>',
#  '<start> सिंक पर एक नल <end>',
#  '<start> एक रसोई के शेल्फ पर अनाज रखा <end>',
#  '<start> कोने में सफेद माइक्रोवेव ओवन <end>',
#  '<start> एक रसोई घर में दीवार दीवार <end>',
#  '<start> नारंगी ड्रायर्स की एक दीवार <end>',
#  '<start> दीवार पर सफेद पाइप <end>',
#  '<start> पूल के निकट डॉल्फिन <end>',
#  '<start> काउंटर के ऊपर माइक्रोवेव <end>',
#  '<start> टोपी पर लोगो <end>',
#  '<start> एक व्यक्ति ने घुटने टेक दिए <end>',
#  '<start> व्यक्ति ने काला पैंट पहना है <end>',
#  '<start> एक सोफे पर बैठे लोग <end>',
#  '<start> छत से लटके हुए प्रकाश <end>',
#  '<start> कुर्सी में चौकोर छेद <end>',
#  '<start> हवा में हथियार <end>',
#  '<start> नारंगी की दीवार से लटकी हुई <end>',
#  '<start> एक काउंटर के नीचे स्थित सफेद वॉशर <end>',
#  '<start> खिड़की के सामने बैठा व्यक्ति <end>',
#  '<start> दिन के आकाश का प्रकाश <end>',
#  '<start> पूल के बगल में ब्राउन लाउंज कुर्सी <end>',
#  '<start> एक पूल में छतरियों का एक समूह <end>',
#  '<start> सुरुचिपूर्ण कुर्सी के पास लाल बेंच <end>',
#  '<start> स्टैक में हरा कछुआ पूल <end>',
#  '<start> एक कमरे में कई लोग <end>',
#  '<start> एक नीले और काले प्लेड शर्ट के साथ आदमी <end>',
#  '<start> ट्रक पर ध्रुवीय शब्द <end>',
#  '<start> एक काला और भूरा क्षेत्र गलीचा <end>',
#  '<start> भूरे रंग की मेज के बाईं ओर काली कुर्सी <end>',
#  '<start> भूरे रंग की लकड़ी की सीढ़ी <end>',
#  '<start> एक पीला और काला बांध आदमी पर <end>',
#  '<start> राह पर चलते व्यक्ति <end>',
#  '<start> लाल स्कार्फ पहनने वाली महिला <end>',
#  '<start> जमीन पर कबूतर <end>',
#  '<start> गोदी हाउसबोट की पीठ <end>',
#  '<start> एक पीला स्कर्ट <end>',
#  '<start> कक्ष में काला टीवी <end>',
#  '<start> टेलीविज़न रिमोट एक लाल मेज़पोश पर बैठा है <end>',
#  '<start> दीवार पर लगा दर्पण <end>',
#  '<start> दीवार पर टंगी तस्वीर <end>',
#  '<start> एक दीवार पर एक बड़ी पेंटिंग <end>',
#  '<start> दिन के दौरान लिया गया फोटो <end>',
#  '<start> पुल पर चलते लोग <end>',
#  '<start> नुकीले शीर्ष वाला टॉवर <end>',
#  '<start> ये पुराने ढाँचे हैं <end>',
#  '<start> सीढ़ियों पर ग्रे कदम <end>',
#  '<start> सर्पिल सीढ़ियों पर चलने वाला व्यक्ति <end>',
#  '<start> एक आवासीय भवन पर खिड़की <end>',
#  '<start> चांदी मक्खन चाकू <end>',
#  '<start> थाली के बाईं ओर बर्तन <end>',
#  '<start> कागज पर काले अक्षर <end>',
#  '<start> फ्राई कॉफी से भरा कॉफी कप <end>',
#  '<start> केले को कटोरे में काट लें <end>',
#  '<start> शीशे की बोतल में रस <end>',
#  '<start> लाल फूलों से भरा फूलदान <end>',
#  '<start> इंद्रधनुष आधा चाँद की तरह दिखता है <end>',
#  '<start> कुर्सी पर लकड़ी की बस्ती <end>',
#  '<start> एक भूरे रंग की लकड़ी की कैबिनेट दरवाजा <end>',
#  '<start> बंदूक चमकदार है <end>',
#  '<start> एक पहाड़ के ऊपर स्पष्ट नीला आकाश <end>',
#  '<start> एक अपार्टमेंट इमारत में एक खिड़की <end>',
#  '<start> एक काली स्ट्रीट लाइट <end>',
#  '<start> एक काली कुर्सी <end>',
#  '<start> एक डेस्क पर दो आदमी बैठे थे <end>',
#  '<start> मुड़ कॉर्ड के साथ फोन <end>',
#  '<start> एक सफेद कार सड़क पर खड़ी थी <end>',
#  '<start> सफेद कार बाड़ के पास खड़ी है <end>',
#  '<start> भवन की खिड़की का किनारा <end>',
#  '<start> यह एक महिला है <end>',
#  '<start> क्षेत्र हरा है <end>',
#  '<start> सड़क पर पीली लाइनें <end>',
#  '<start> सड़क पर काली कार पार्क <end>',
#  '<start> सड़क <end>',
#  '<start> यह एक कार है <end>',
#  '<start> पानी का रंग हरा है <end>',
#  '<start> कार पर लगी लाइसेंस प्लेट <end>',
#  '<start> एक सड़क पर काली कार <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> खिड़की पर फलक <end>',
#  '<start> लंबा आउटडोर लैंप पोस्ट <end>',
#  '<start> गाड़ी का टायर <end>',
#  '<start> भूरे रंग का डिलीवरी ट्रक <end>',
#  '<start> कार का टायर काला रबर और चांदी की धातु से बना है <end>',
#  '<start> खड़ी सफेद कार <end>',
#  '<start> एक उज्ज्वल जला हुआ रियर ब्रेक लाइट <end>',
#  '<start> एक बड़े कार्यालय भवन में खिड़की <end>',
#  '<start> भवन के सामने की खिड़की <end>',
#  '<start> हल्के भूरे रंग की छत वाला नीला घर <end>',
#  '<start> फुटपाथ पर चलने वाली वृद्ध महिला <end>',
#  '<start> एक बड़े काले ट्रैशकैन <end>',
#  '<start> स्ट्रीट संकेत कहते हैं एम्स <end>',
#  '<start> फुटपाथ पर खड़ी महिला <end>',
#  '<start> इमारत पर वर्ग खिड़की <end>',
#  '<start> भूरी लकड़ी की बुकशेल्फ़ पर किताब <end>',
#  '<start> डेस्क के शीर्ष पर पेपर कप <end>',
#  '<start> दीवार पर घड़ी <end>',
#  '<start> मेज पर फूलदान <end>',
#  '<start> एक चमकदार नीली कॉफी मग <end>',
#  '<start> रसोई के सिंक पर चांदी का नल <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> जींस और काले रंग की शर्ट में महिला <end>',
#  '<start> एक नीले और सफेद पार्किंग साइन <end>',
#  '<start> शौचालय पर संयंत्र <end>',
#  '<start> काले लेखन के साथ सफेद किताब <end>',
#  '<start> एक टैन कार खड़ी थी <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> स्त्री के काले बाल है <end>',
#  '<start> फुटपाथ पर चलने वाला आदमी <end>',
#  '<start> पोस्ट पर बैनर <end>',
#  '<start> दुकान की खिड़की पर प्रतिबिंब <end>',
#  '<start> बेंच लंबा है <end>',
#  '<start> पोर्च पर लकड़ी प्लांक <end>',
#  '<start> एक पेड़ से गिरने वाला कुरकुरा भूरा पत्ता <end>',
#  '<start> पत्ती से भरे खेत में एक पत्थर <end>',
#  '<start> चांदी एसयूवी सड़क पर खड़ी है <end>',
#  '<start> मेलबॉक्स पर पेंट <end>',
#  '<start> सफेद इमारत के सामने की खिड़की <end>',
#  '<start> दीवार पर घड़ी <end>',
#  '<start> चाँदी की कार <end>',
#  '<start> एक महिला खड़ी है <end>',
#  '<start> ईंट निर्माण के सामने की खिड़की <end>',
#  '<start> सड़क चिह्न नहीं दाखिल करें <end>',
#  '<start> लाल बालों वाली औरत सड़्क पर चलते हुए <end>',
#  '<start> भवन के सामने की खिड़की <end>',
#  '<start> मैरून कार कर्ब पर खड़ी <end>',
#  '<start> सड़क पर खड़ा नीला वाहन <end>',
#  '<start> जीप एसयूवी पर अंकुश लगा दिया <end>',
#  '<start> एक धातु के खंभे पर एक स्ट्रीट लाइट <end>',
#  '<start> शेल्फ का रंग भूरा है <end>',
#  '<start> एक कंप्यूटर एक कीबोर्ड पर होता है <end>',
#  '<start> नीला और सफेद कॉफी कि जग <end>',
#  '<start> दीवार पर एक खाली पोस्टर बोर्ड <end>',
#  '<start> स्नैक बिस्कुट का पीला बक्सा <end>',
#  '<start> ब्लैक मॉनिटर ऑन डेस्क <end>',
#  '<start> ब्लैक एंड व्हाइट डेस्क लैंप <end>',
#  '<start> डेस्क के नीचे ग्रे प्लास्टिक कचरा हो सकता है <end>',
#  '<start> माइक्रोवेव ओवन <end>',
#  '<start> कंप्यूटर मॉनिटर के सामने कार्यालय की कुर्सी <end>',
#  '<start> नीली कुर्सी पर नीला कार्डिगन लिपटा हुआ <end>',
#  '<start> एक शेल्फ पर बाँधने की एक पंक्ति <end>',
#  '<start> कागज का एक सफेद टुकड़ा <end>',
#  '<start> डेस्क के ऊपर सफेद कीबोर्ड <end>',
#  '<start> एक पुरानी काली टायर <end>',
#  '<start> सड़क के नीचे जाती लाल रंग की एसयूवी <end>',
#  '<start> दीवार पर लटका एक नक्शा <end>',
#  '<start> फ्लोरोसेंट छत रोशनी <end>',
#  '<start> एक लकड़ी की मेज <end>',
#  '<start> नीली दीवारों <end>',
#  '<start> सफेद खिड़की के साथ बड़ी खिड़की <end>',
#  '<start> लाल स्ट्रीट लाल चिह्न सफेद पट्टी के साथ <end>',
#  '<start> एक सफेद पट्टी के साथ एक लाल संकेत <end>',
#  '<start> सड़क पर कार चलाना <end>',
#  '<start> सफेद सजावट के साथ नीला बैनर <end>',
#  '<start> काला रेलिंगोन सिडीचलन <end>',
#  '<start> सर्फ़बोर्ड पर व्यक्ति <end>',
#  '<start> पानी में नाव <end>',
#  '<start> खड़ी कारों की एक पंक्ति <end>',
#  '<start> एक काला कंप्यूटर मॉनीटर <end>',
#  '<start> पानी के ऊपर बहु रंगीन इंद्रधनुष <end>',
#  '<start> हेज करने के लिए सही है <end>',
#  '<start> एक मेज पर एक कॉफी कप <end>',
#  '<start> स्ट्रीट लाइट बंद है <end>',
#  '<start> एक काले सूट और नीली शर्ट में खड़ा आदमी <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> पीले और काले पैदल यात्री क्रॉसिंग सिग्नल <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> काला टैंक टॉप में व्यक्ति <end>',
#  '<start> एक काला शर्ट पहनने हुए लड़का <end>',
#  '<start> एक छोटी ग्रे मोटरसाइकिल <end>',
#  '<start> बड़ी इमारत पर खिड़की <end>',
#  '<start> यह एक मोटर वाहन है <end>',
#  '<start> सीढ़ियों के नीचे बात कर रहे हैं दो लोग | <end>',
#  '<start> वैन नीले सफेद और हरे रंग की है <end>',
#  '<start> किसी व्यापार का दरवाज़ा <end>',
#  '<start> वाहन का पहिया <end>',
#  '<start> चार द्वारों के साथ एक कार <end>',
#  '<start> आदमी सड़क पर चल रहा है <end>',
#  '<start> सफेद कार खड़ी है <end>',
#  '<start> एक पोल की लाल टिप <end>',
#  '<start> कोका कोला चिह्न <end>',
#  '<start> इमारत पर खिड़्की <end>',
#  '<start> एक लाल और सफेद छाता <end>',
#  '<start> एक आदमी का सिर <end>',
#  '<start> यह तस्वीर रंग में सोना है | <end>',
#  '<start> प्रवेश द्वार की ओर जाने वाली सीढ़ियाँ <end>',
#  '<start> इमारत पर विंडो <end>',
#  '<start> यह एक टैक्सी कैब है <end>',
#  '<start> बिना पत्तों वाला बड़ा पेड़ <end>',
#  '<start> कार्य ट्रक सफेद है <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> एक सड़क के किनारे खड़ी एक सफेद कार <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> काली कार सड़क पर खड़ी <end>',
#  '<start> लाल ईंट विंडो पर विंडो <end>',
#  '<start> कार लाल है और गली में खड़ी है <end>',
#  '<start> इमारत पर खिड़कियाँ <end>',
#  '<start> भवन के किनारे की खिड़की <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> भूरे रंग का पेड़ का तना <end>',
#  '<start> घर का रंग पीला होता है <end>',
#  '<start> खड़ी कारों की एक पंक्ति <end>',
#  '<start> एक इमारत की तरफ खिड़की <end>',
#  '<start> नारंगी नारंगी जीवन धारण किए हुए आदमी खड़ा है <end>',
#  '<start> सीढ़ियों पर एक घड़ा <end>',
#  '<start> घास पर लंबा हरा पेड़ <end>',
#  '<start> पानी का एक विशाल स्थान <end>',
#  '<start> दीवार पर काई <end>',
#  '<start> शहर के चारों ओर घने पेड़ <end>',
#  '<start> पृष्ठभूमि में पर्वत <end>',
#  '<start> पानी में बड़ी सफेद नाव यात्रा <end>',
#  '<start> एक पहिया <end>',
#  '<start> की दूरी पर एक लाल अग्नि हाइड्रेंट दिखाई देता है <end>',
#  '<start> लड़की भूरे बाल | <end>',
#  '<start> ईंट इमारत के सामने खिड़की <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> भूरे रंग का पेड़ का तना <end>',
#  '<start> झील के निकट पक्षी <end>',
#  '<start> एक धातु की छत के साथ पुराना शेड <end>',
#  '<start> लंबा और भूरा पर्वत <end>',
#  '<start> ग्रे और भूरी चट्टानों का ढेर <end>',
#  '<start> लोग चल रहे हैं <end>',
#  '<start> जमीन पर डाक <end>',
#  '<start> एक गोल शीर्ष के साथ एक खिड़की <end>',
#  '<start> साथ में खड़ा एक जोड़ा <end>',
#  '<start> यह एक बिस्तर है <end>',
#  '<start> कोठरी पर सफेद दरवाजा <end>',
#  '<start> एक काला साबुन पकवान <end>',
#  '<start> एक लंबी रोशनी चालू है <end>',
#  '<start> दीपक पर बड़ा छाया <end>',
#  '<start> एक नाइटस्टैंड पर रेडियो <end>',
#  '<start> डेस्क पर टेलीविजन <end>',
#  '<start> हेडबोर्ड पर वर्ग <end>',
#  '<start> एक सफेद कॉफी मग <end>',
#  '<start> सफेद कागजात के पतले ढेर <end>',
#  '<start> दीवार पर दीपक रंग <end>',
#  '<start> ड्रेसर भूरे रंग का है <end>',
#  '<start> बेज रंग का कॉर्डेड फोन <end>',
#  '<start> हेडबोर्ड के ऊपर चित्र <end>',
#  '<start> एक नारंगी कुर्सी <end>',
#  '<start> चौखट सफेद रंग की होती है <end>',
#  '<start> स्पॉटलेस डाइनिंग रूम <end>',
#  '<start> एक सफेद पेंट फ्रेम के साथ खिड़की <end>',
#  '<start> गंदगी के बगल में उगी घास का एक हिस्सा <end>',
#  '<start> धातु दरवाजा घुंडी <end>',
#  '<start> यह एक जीप है <end>',
#  '<start> चाय की केतली चांदी है <end>',
#  '<start> दरवाज़ा अंकुर और रिक्टेंगुलर है <end>',
#  '<start> कमरे के कोने में सोफा <end>',
#  '<start> यह एक धूसर टेलीविजन है <end>',
#  '<start> तस्वीर दीवार पर है <end>',
#  '<start> नल चांदी है <end>',
#  '<start> चांदी की बनी कैनिस्टर <end>',
#  '<start> फर्श पर खाली टोकरी <end>',
#  '<start> नाइटस्टैंड पर सफेद और काले दीपक <end>',
#  '<start> एक मोटा धूसर तकिया <end>',
#  '<start> शौचालय सफेद है <end>',
#  '<start> रसोई में कैबिनेट <end>',
#  '<start> एक सीढ़ी में ग्रे कालीन वाली सीढ़ी <end>',
#  '<start> कमरे में भूरे रंग का दरवाजा <end>',
#  '<start> फर्श पर धूप <end>',
#  '<start> यह एक सिंक है <end>',
#  '<start> ग्रे और सफेद साइडिंग <end>',
#  '<start> दिलासा देनेवाला और तकिया मामलों का मिलान होता है <end>',
#  '<start> सफेद लकड़ी की बालकनी <end>',
#  '<start> ब्लैक एंड सिल्वर रेंज <end>',
#  '<start> दिन के आकाश का प्रकाश <end>',
#  '<start> कांच की खिड़की पारदर्शी है <end>',
#  '<start> प्रकाश लटका हुआ है <end>',
#  '<start> एक कमरे के कोने में एक पौधा <end>',
#  '<start> सफेद ओवन पर कांच की खिड़की <end>',
#  '<start> हरा और पीला घर <end>',
#  '<start> एक फुटपाथ पर पेड़ <end>',
#  '<start> सजावटी हरे कांच के फूलदान <end>',
#  '<start> एक पेड़ के सामने एक कार <end>',
#  '<start> एक बड़ा तकिया सफेद आवरण मे <end>',
#  '<start> भूरे रंग की पेंटिंग के साथ सामने का लकड़ी का दरवाजा <end>',
#  '<start> आवासीय भवन के पिछवाड़े <end>',
#  '<start> बेडरूम की दीवार पर प्रकाश स्विच <end>',
#  '<start> दीवार पर टंगी एक फंसी हुई पेंटिंग <end>',
#  '<start> हल्के रंग का दरवाज़ा <end>',
#  '<start> सीट ऊपर है <end>',
#  '<start> पुराना और छोटा टेलीविजन सेट <end>',
#  '<start> बड़े नीले फूलों के साथ रंगीन आड़ू पीच <end>',
#  '<start> मेज पर ब्रोशर <end>',
#  '<start> पंखा काला है <end>',
#  '<start> आवासीय कमरे का इंटीरियर <end>',
#  '<start> खिड़की में वर्ग फलक <end>',
#  '<start> लाइट चालू है <end>',
#  '<start> बार कुर्सियां \u200b\u200bभूरे रंग के हैं <end>',
#  '<start> तस्वीर के निकट सफेद दीवार <end>',
#  '<start> प्लेट पर खाना <end>',
#  '<start> भोजन क्षेत्र का इंटीरियर <end>',
#  '<start> कुर्सी लकड़ी से बना है और चार पैर हैं <end>',
#  '<start> एक चिड़िया के मुँह में एक मछली <end>',
#  '<start> चिड़िया की बेक <end>',
#  '<start> लटका पॉट में गुलाबी फूल <end>',
#  '<start> एक छोटी ग्रे कार <end>',
#  '<start> सफेद कार पार्क की गई <end>',
#  '<start> वाहन सफेद है <end>',
#  '<start> क्षेत्र को कवर शामियाना <end>',
#  '<start> वाहन पर लाल और स्पष्ट पूंछ <end>',
#  '<start> एक सड़क पर एक सफेद तीर <end>',
#  '<start> एक सफेद वाहन <end>',
#  '<start> कार का रंग सिल्वर <end>',
#  '<start> काले और सोने के हाइड्रेंट <end>',
#  '<start> काला और सफेद चिह्न <end>',
#  '<start> पोल पर हरी चौकोर गली का चिन्ह <end>',
#  '<start> रेड वैन दाहिनी ओर खड़ी थी <end>',
#  '<start> सड़क पर एक काली कार <end>',
#  '<start> सफेद और लाल वान छत के साथ <end>',
#  '<start> हरे और सफेद संकेत <end>',
#  '<start> आदमी नीचे सड़क पर चल रहा है <end>',
#  '<start> एक गुलाबी शीर्ष के साथ महिला <end>',
#  '<start> सड़क पर पीली टैक्सी टैक्सी <end>',
#  '<start> ग्रे इमारत में एक विंडो है <end>',
#  '<start> व्यक्ति बाहर चल रहा है <end>',
#  '<start> घुमावदार पोल पर ट्रैफिक लाइट <end>',
#  '<start> एक शहर में इमारत <end>',
#  '<start> वह आदमी लाल जैकेट पहने हुए हैं <end>',
#  '<start> ग्रे पैंट में व्यक्ति खड़ा है <end>',
#  '<start> नारंगी और पीले फूलों का एक पैच <end>',
#  '<start> एक लंबी सफेद लीमोज्या <end>',
#  '<start> एक इमारत पर बड़ी खिड़की <end>',
#  '<start> गली में खड़ा अंधेरा <end>',
#  '<start> वैन पर श्वेत लिखावट <end>',
#  '<start> एक पोल पर तीन लाइट <end>',
#  '<start> सड़क पर चांदी की कार <end>',
#  '<start> एक पुराना पत्थर गिरजाघर <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> लाल और सफेद जैकेट आदमी पहने हुए है <end>',
#  '<start> एक महिला के सिर पर काला छाता <end>',
#  '<start> एक नीला और सोने का झंडा <end>',
#  '<start> टैक्सी टैक्सी एक बड़े शहर की सड़कों पर यात्रा करती है <end>',
#  '<start> कंधे पर एक लाल रंग का पर्स <end>',
#  '<start> एक पीली टैक्सी टैक्सी <end>',
#  '<start> सड़क पर कई टैक्सी टैक्सी <end>',
#  '<start> लाल बस एक सड़क पर यात्रा कर रही है <end>',
#  '<start> एक बड़े शहर में एक पार्क के चारों ओर बाड़ <end>',
#  '<start> घास में कंक्रीट ब्लॉक <end>',
#  '<start> दिन दिन का आकाश का प्रकाश <end>',
#  '<start> सफेद अक्षरों के साथ काला संकेत <end>',
#  '<start> गली में खड़ी की गई हरे रंग की कार <end>',
#  '<start> सड़क पर खड़ी सिल्वर कार <end>',
#  '<start> काले और सफेद जैकेट पहने हुए आदमी <end>',
#  '<start> एक नीली वैन <end>',
#  '<start> फुटपाथ पर चलते दो लोग <end>',
#  '<start> साइकिल को खंभे से जकड़ा जाता है <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> सड़क पर चित्रित सफेद लाइनें <end>',
#  '<start> एक लाल पार्किंग संकेत <end>',
#  '<start> पानी का पोखर <end>',
#  '<start> लोग सड़क के पार चल रहा <end>',
#  '<start> एक लाल यातायात प्रकाश <end>',
#  '<start> एक पीले टैक्सी कैब <end>',
#  '<start> सड़क पर एक कार <end>',
#  '<start> काले और हरे रंग का चिन्ह <end>',
#  '<start> फुटपाथ पर दो पीले पोस्ट <end>',
#  '<start> धातु डाक बॉक्स <end>',
#  '<start> काला कोट पहने आदमी <end>',
#  '<start> अमेरिकी ध्वज उड़ान भूमि के ऊपर <end>',
#  '<start> सड़क पर दौड़ती पीली टैक्सी <end>',
#  '<start> धूसर और सफेद आकाश <end>',
#  '<start> भवन में एक खिड़की है <end>',
#  '<start> धातु की बालकनी <end>',
#  '<start> बालकनी की रेलिंग <end>',
#  '<start> सबसे आगे मशीन आर्म <end>',
#  '<start> सड़क पर चलने वाला व्यक्ति <end>',
#  '<start> एक अमेरिकी डाक वान <end>',
#  '<start> आदमी एक कला के टुकड़े के सामने खड़ा है <end>',
#  '<start> पेंटिंग पर फूल <end>',
#  '<start> दीवार पर चित्रकारी <end>',
#  '<start> काली कुर्सी लकड़ी की है <end>',
#  '<start> नारंगी वस्तु <end>',
#  '<start> एक बड़े हवाई जहाज की पूंछ स्टेबलाइजर <end>',
#  '<start> काले अक्षर के साथ हस्ताक्षर करें <end>',
#  '<start> सड़क पर पीले आग हाइड्रेंट <end>',
#  '<start> एक नदी के सामने एक महिला <end>',
#  '<start> चौराहे से होकर निकलती सिल्वर वैन <end>',
#  '<start> एक लाल और सफेद संकेत <end>',
#  '<start> ग्रे छत के साथ सफेद घर <end>',
#  '<start> दूरी में एक बड़ी इमारत <end>',
#  '<start> एक सफेद बादल <end>',
#  '<start> इमारत पर ईंट चिमनी <end>',
#  '<start> क्षितिज में नारंगी आकाश <end>',
#  '<start> समुद्र तट के बगल में शोरलाइन <end>',
#  '<start> यह एक शहर है <end>',
#  '<start> नीला और सफेद आसमान <end>',
#  '<start> एक ट्रेन पर एक सफेद सर्कल <end>',
#  '<start> बादल सफेद होते हैं <end>',
#  '<start> एक ग्रे विस्तारित टैक्सी ट्रक <end>',
#  '<start> पर्वत की चोटी पर बढ़ रही झाड़ियों <end>',
#  '<start> काला चमकदार मीनिवान <end>',
#  '<start> दूरी में पहाड़ <end>',
#  '<start> एक खेत में एक पेड़ <end>',
#  '<start> भूरी लकड़ी की बेंच <end>',
#  '<start> सड़क से हरा पेड़ <end>',
#  '<start> हरी पत्तियों वाला विशाल वृक्ष <end>',
#  '<start> एक इमारत द्वारा सफेद ट्रक <end>',
#  '<start> एक सफेद वाणिज्यिक ट्रक <end>',
#  '<start> पानी में पीले रोशनी <end>',
#  '<start> खाने की मेज सेट <end>',
#  '<start> एक धनुषाकार शीर्ष के साथ अलंकृत खिड़की <end>',
#  '<start> एक पहाड़ी पर नारंगी इमारत <end>',
#  '<start> कुत्ता फुटपाथ पर चल रहा है <end>',
#  '<start> सीढ़ियों के नीचे चलने वाला आदमी <end>',
#  '<start> इमारत पर खिड़कियाँ <end>',
#  '<start> एक खेत में एक पेड़ <end>',
#  '<start> एक लंबा काला प्रकाश पोल <end>',
#  '<start> एक खेत में एक पेड़ <end>',
#  '<start> एक इमारत पर नीले शब्द <end>',
#  '<start> गुब्बारा लाल है <end>',
#  '<start> घर के बाहर एक संकेत <end>',
#  '<start> एक शाखा पर माता अंहिंगा चिड़िया <end>',
#  '<start> पक्षी की चोंच <end>',
#  '<start> भूरे और सफेद पफर मछली तैराकी <end>',
#  '<start> शाखा पर पक्षी <end>',
#  '<start> एक डाल पर पझी <end>',
#  '<start> पेड़ पर छोड़ देता है <end>',
#  '<start> ग्रे चट्टान से बना क्लिफ फेस <end>',
#  '<start> ज़ेबरा पर पट्टी <end>',
#  '<start> पशु के सिर पर बाँया सींग <end>',
#  '<start> सूरज पीला है <end>',
#  '<start> खेत पर झेब्रा <end>',
#  '<start> ब्लैक एंड व्हाइट ज़ेबरा <end>',
#  '<start> एक संकीर्ण शरीर वाला पक्षी <end>',
#  '<start> एक बच्चा हाथी <end>',
#  '<start> एक रिज पर उपयोगी मुर्गियाँ <end>',
#  '<start> एक रस्सी संलग्न <end>',
#  '<start> भवन की छत <end>',
#  '<start> सड़क पर काली कार <end>',
#  '<start> एक ध्रुव पर चिह्न <end>',
#  '<start> सड़क के दाईं ओर धातु की रेलिंग <end>',
#  '<start> पीला कंटेनर करीब है <end>',
#  '<start> एक साफ और नीला आकाश <end>',
#  '<start> सड़क पर सफेद ट्रक <end>',
#  '<start> सड़क के बगल में पेड़ <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> आसमान नीला है <end>',
#  '<start> एक लंबी काली पोस्ट पर स्ट्रीट लाइट <end>',
#  '<start> नाव में सफेद पाल हैं <end>',
#  '<start> लाल शर्ट पहने आदमी <end>',
#  '<start> दिन के दौरान एक दृश्य <end>',
#  '<start> उज्ज्वल सफेद पालकी अंकुश के पास खड़ी <end>',
#  '<start> लंबा और गोल झाड़ियों <end>',
#  '<start> सड़क से हरा पेड़ <end>',
#  '<start> दिन के समय एक दृश्य <end>',
#  '<start> घर के बगल में सफेद पिकनिक तालिका <end>',
#  '<start> वॉकवे के बाईं ओर घास <end>',
#  '<start> घर की नाव पर खिड़की <end>',
#  '<start> एक शहर की सड़क पर सफेद इमारत <end>',
#  '<start> यह एक आदमी है <end>',
#  '<start> बाहर एक दृश्य <end>',
#  '<start> कार सड़क पर खड़ी है <end>',
#  '<start> काली पैंट की एक जोड़ी <end>',
#  '<start> एक सफेद वाणिज्यिक वैन <end>',
#  '<start> सड़क पर रोशनी कम है <end>',
#  '<start> सड़क के द्वारा चमकीला प्रकाश <end>',
#  '<start> सड़क पर चलने वाला व्यक्ति <end>',
#  '<start> रात में एक लंबा लैंप पोस्ट जलाया गया <end>',
#  '<start> यह एक कोर्ट यार्ड है <end>',
#  '<start> फुटपाथ पर चलने वाला व्यक्ति <end>',
#  '<start> सफेद हैचबैक <end>',
#  '<start> एक सड़क पर एक कार <end>',
#  '<start> फुटपाथ पर कई लोग <end>',
#  '<start> एक लाल चार दरवाजे वाला वाहन <end>',
#  '<start> रास्ता काला और सफेद रंग में है <end>',
#  '<start> तोरण अलंकृत है <end>',
#  '<start> बड़ी भड़कीली जीन्स पहने महिला <end>',
#  '<start> एक लंबा काला कचरे का डब्बा <end>',
#  '<start> भवन पर कांच की खिड़की <end>',
#  '<start> एक बास्केट के साथ एक बाइक <end>',
#  '<start> छत पर चिमनी <end>',
#  '<start> पानी में प्रतिबिंब <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> काले खत्म के साथ दीपक <end>',
#  '<start> हरे रंग की पोशाक में महिला <end>',
#  '<start> एक पोल के खिलाफ लाल साइकिल झुकाव <end>',
#  '<start> दूरी में भवन <end>',
#  '<start> एक स्त्री नीले जीन्स पहने हुए <end>',
#  '<start> एक सफेद फ्रेम के साथ एक खिड़की <end>',
#  '<start> एक समानांतर खड़ी कार <end>',
#  '<start> लंबा पतला पाइन पेड़ <end>',
#  '<start> एक रबर कार टायर <end>',
#  '<start> कई खिड़कियों के ऊर्ध्वाधर स्तंभ <end>',
#  '<start> एक पीले रंग की लाइसेंस प्लेट <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> एक चाँदी का सूव <end>',
#  '<start> आकाश में कई बादल <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> कचरा पत्थर और धातु से बना हो सकता है <end>',
#  '<start> कारों से भरपूर <end>',
#  '<start> इमारत पर विंडो <end>',
#  '<start> एक इमारत के ऊपर दो ताड़ के पेड़ <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> एक बंद सफेद मिनीवैन <end>',
#  '<start> यह एक इमारत है <end>',
#  '<start> पीठ के ऊपर मूर्ति <end>',
#  '<start> यह एक शहरी क्षेत्र है <end>',
#  '<start> गहरे भूरे रंग की लकड़ी से बनी बेंच <end>',
#  '<start> एक आदमी दुकान से पीछे चल रहा है <end>',
#  '<start> इमारत पर कांच की खिड़्की <end>',
#  '<start> एक इमारत पर लाल निशान <end>',
#  '<start> यह वॉच टॉवर है <end>',
#  '<start> सड़क पर नीली कार ड्राइविंग <end>',
#  '<start> तीर के साथ नीला चिह्न <end>',
#  '<start> एक लाल इमारत पर खिड़कियों की पंक्ति <end>',
#  '<start> सफेद स्तंभों वाला लाल भवन <end>',
#  '<start> एक छोटी सफेद कार <end>',
#  '<start> एक सड़क पर एक कार <end>',
#  '<start> एक महिला एक बच्चे को घुमक्कड़ धक्का <end>',
#  '<start> गंदगी पर कार <end>',
#  '<start> इमारत के शीर्ष पर धातु का निर्माण <end>',
#  '<start> छत पर टाइल लगाई गई है <end>',
#  '<start> दूरी में पहाड़ी पहाड़ियों <end>',
#  '<start> कार पार्क किया जाता है <end>',
#  '<start> तीन कहानी पत्थर की इमारत <end>',
#  '<start> एक पंक्ति में दो लाल कारें <end>',
#  '<start> गली में सफेद कार पार्क <end>',
#  '<start> नीला और सफेद आसमान <end>',
#  '<start> चौराहे पर एक काली कार <end>',
#  '<start> इमारत पर खिड़्की <end>',
#  '<start> एक लाल जैकेट पहनने वाला आदमी <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> इमारत पर कांच की खिड़्की <end>',
#  '<start> एक सफेद पार्क कार <end>',
#  '<start> पोल के खिलाफ साइकिल झुकाव <end>',
#  '<start> घर हरा है <end>',
#  '<start> व्यक्ति चल रहा है <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> इमारत पर खिड़्की <end>',
#  '<start> भवन पर कांच की खिड़की <end>',
#  '<start> लंबा वक्र वाल्केम <end>',
#  '<start> एक महिला का नीला बैग <end>',
#  '<start> यह एक बड़ी इमारत है <end>',
#  '<start> बड़े सफेद बादलों के साथ एक हल्का नीला आकाश <end>',
#  '<start> हरे रंग की सड़क का संकेत जो कांग्रेस को सेंट कहता है <end>',
#  '<start> लाल और ग्रे एसयूवी <end>',
#  '<start> इमारत का सामना करना पड़ सड़क पर खिड़की <end>',
#  '<start> बर्फ में कुछ गहरे टायर ट्रैक <end>',
#  '<start> बर्फ से ढकी एक सड़क <end>',
#  '<start> कारें बर्फ में ढकी हुई हैं <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> अंधेरे लाल इमारत पर विचलित <end>',
#  '<start> जमीन पर सफेद बर्फ <end>',
#  '<start> सफेद इमारत की ऊपरी मंजिल पर खिड़की <end>',
#  '<start> एक पीला और नीला चिह्न <end>',
#  '<start> फुटपाथ पर चलने वाला व्यक्ति <end>',
#  '<start> विंडो में लाल ड्रेस <end>',
#  '<start> यह एक शहर की सड़क है <end>',
#  '<start> लाल बल्री चिह्न <end>',
#  '<start> कपड़े पहने महिला <end>',
#  '<start> इमारत पर हस्ताक्षर <end>',
#  '<start> भवन पर कांच की खिड़की <end>',
#  '<start> एक अलंकृत काली स्ट्रीट लाइट <end>',
#  '<start> भवन पर कांच की खिड़की <end>',
#  '<start> बाड़ पर नारंगी पट्टी <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> फुटपाथ पर पोल <end>',
#  '<start> ये इमारतों का एक समूह हैं <end>',
#  '<start> गाड़ी <end>',
#  '<start> व्यक्ति खड़ा है <end>',
#  '<start> व्यक्ति चल रहा है <end>',
#  '<start> कोने के निर्माण पर खिड़की <end>',
#  '<start> इमारत पर कांच की खिड़्की <end>',
#  '<start> ट्रैक्टर फुटपाथ पर खड़ा था <end>',
#  '<start> बेंच का पैर <end>',
#  '<start> एक व्यक्ति जो फ़ुटपाथ पर चलता है <end>',
#  '<start> एक सड़क पर एक कार <end>',
#  '<start> पोल पर प्रकाश <end>',
#  '<start> कार पर गोल काला टायर <end>',
#  '<start> सड़क में एक सफेद रेखा <end>',
#  '<start> कार पर अंकुश लगाया <end>',
#  '<start> आकाश ग्रे और सफेद है <end>',
#  '<start> एक सड़क के पास लैंप पोल <end>',
#  '<start> यह एक कार है <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> कार सोना है <end>',
#  '<start> सड़क पर ग्रे कार चला रहा है <end>',
#  '<start> एक लाल और सफेद संकेत <end>',
#  '<start> एक पहाड़ी में सेट दो अर्ध गोलाकार ट्यूनेल <end>',
#  '<start> सड़क में सिल्वर कार पार्क किया <end>',
#  '<start> यह एक आदमी है <end>',
#  '<start> वाहन <end>',
#  '<start> फुटपाथ के सामने खड़ी सफेद वैन <end>',
#  '<start> कार सफेद है <end>',
#  '<start> सड़क पर वाहन <end>',
#  '<start> सड़क के अतिरिक्त धातु रेल <end>',
#  '<start> इमारत पर विंडो <end>',
#  '<start> सड़क में फूलों का बिस्तर <end>',
#  '<start> गली में खड़ी लाल कार <end>',
#  '<start> पत्र के साथ गोल गेंद <end>',
#  '<start> कार काली है <end>',
#  '<start> एक गोल नीला और सफेद निशान <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> सड़क के किनारे पर छोटी पत्थर दीवार <end>',
#  '<start> एक राजमार्ग पर एक लाल वाहन <end>',
#  '<start> कार पर खिड़की <end>',
#  '<start> एक सड़क पर एक कार <end>',
#  '<start> काले एंटेंना वह हूड पर था <end>',
#  '<start> इमारत पर बोर्ड <end>',
#  '<start> कार चांदी है <end>',
#  '<start> पेड़ पर छोड़ देता है <end>',
#  '<start> फुटपाथ पर लकड़ी के बेंच <end>',
#  '<start> पेड़ का तना <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> पेड़ नंगे और पार्क में है <end>',
#  '<start> पानी में पत्ती <end>',
#  '<start> काले शॉर्ट्स में व्यक्ति <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> एक शहर में एक वृक्ष <end>',
#  '<start> एक सड़क पर बैठने की व्यवस्था <end>',
#  '<start> दरवाजे के ऊपर की संख्या <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> प्लेट का रंग काला है <end>',
#  '<start> ट्रक पर नारंगी रंग <end>',
#  '<start> सड़क पर सफेद लाइनें <end>',
#  '<start> कार चाँदी है <end>',
#  '<start> सड़क के किनारे खड़ी चांदी की कार <end>',
#  '<start> कार के सामने गगनचुंबी इमारत <end>',
#  '<start> पार्क की गई सिल्वर <end>',
#  '<start> लैंप पोस्ट के शीर्ष पर गोल सफेद दीपक <end>',
#  '<start> इमारत पर हरे शटर | <end>',
#  '<start> दरवाजा भूरा है <end>',
#  '<start> तीन फाउंटेन हेड्स वाला उथला पूल <end>',
#  '<start> सफेद और लाल शर्ट में महिला <end>',
#  '<start> फुटपाथ की सीमा पर मोटी हेज <end>',
#  '<start> आकाश चमक रहा है और नीला है <end>',
#  '<start> पेड़ पर छोड़ देता है <end>',
#  '<start> दो सड़क रोशनी <end>',
#  '<start> लाल जैकेट में व्यक्ति <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> बाहर खाने वाले लोग <end>',
#  '<start> दो यातायात रोशनी लाल जलाया <end>',
#  '<start> एक काले रंग की खड़ी कार <end>',
#  '<start> एक खड़ी कार <end>',
#  '<start> गहरा हरा सुव <end>',
#  '<start> एक इमारत पर पक्षियों का भित्ति चित्र <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> दीवार के सामने खड़ा आदमी <end>',
#  '<start> भूरे बालों वाला आदमी <end>',
#  '<start> एक ग्रे स्टेपलर <end>',
#  '<start> महिला की एक आंख है <end>',
#  '<start> बेंच पर बैठे और प्रतीक्षा करता आदमी <end>',
#  '<start> उसने नीली जींस पहनी हुई है <end>',
#  '<start> ट्रक लाल है <end>',
#  '<start> शर्ट पहने व्यक्ति <end>',
#  '<start> एक सफेद शर्ट में आदमी <end>',
#  '<start> सफेद जूते पहने हुए आदमी <end>',
#  '<start> मैदान मे लम्बा कुत्ते <end>',
#  '<start> आदमी के सफेद दांत हैं <end>',
#  '<start> कैमरे को देख रहे व्यक्ति <end>',
#  '<start> पहाड़ पर खड़ा व्यक्ति <end>',
#  '<start> ब्लॉक पैटर्न के साथ साइडवॉक <end>',
#  '<start> भवन लंबा है <end>',
#  '<start> छोटे बाल और एक बकरी के साथ एक आदमी <end>',
#  '<start> एक पेड़ का तना <end>',
#  '<start> कुत्ता घास में बैठा है <end>',
#  '<start> पीला स्वेटर पहने व्यक्ति <end>',
#  '<start> दिन के समय एक दृश्य <end>',
#  '<start> हाथ मेज पर है | <end>',
#  '<start> मंजिल पर रखे स्टेपलर <end>',
#  '<start> पानी में चट्टान <end>',
#  '<start> होटल प्रवेश के मार्च में कार <end>',
#  '<start> पानी के किनारे नाव <end>',
#  '<start> एक युवा श्वेत व्यक्ति के सिर में गोली लगी <end>',
#  '<start> दिन के समय एक दृश्य <end>',
#  '<start> विमान रनवे पर बैठा <end>',
#  '<start> कोने की मेज पर एक ग्रे स्टेपलर <end>',
#  '<start> लाल रंग का व्यक्ति <end>',
#  '<start> युवती के सिर में गोली लगी <end>',
#  '<start> दिन के दौरान लिया गया फोटो <end>',
#  '<start> कार की लाइसेंस प्लेट <end>',
#  '<start> लकड़ी के दरवाजे पर घेरा <end>',
#  '<start> राजमार्ग के निकट भूरी चट्टान <end>',
#  '<start> आदमी रसोई में <end>',
#  '<start> लेन राजमार्ग के नीचे <end>',
#  '<start> मनुष्य के बाल छोटे है <end>',
#  '<start> व्यक्ति हरे रंग की शर्ट पहनता है <end>',
#  '<start> एक हरा पारोट <end>',
#  '<start> हरे पेड़ पर हरे पत्ते <end>',
#  '<start> खिड़की लाल इमारत का सामना करना पड़ <end>',
#  '<start> शीर्ष स्तर पर विंडोज <end>',
#  '<start> किसी व्यक्ति का दाहिना कान <end>',
#  '<start> घाट पर पत्थर ब्लॉक <end>',
#  '<start> एक व्यक्ति के पीछे हरी दीवार <end>',
#  '<start> बैकग्राउंड नीला है <end>',
#  '<start> छोटे भूरे बालों के साथ लड़का <end>',
#  '<start> एक तालिका के आसपास चार काले कुर्सियाँ <end>',
#  '<start> गंदगी सड़क पर बड़ा हरा ट्रक <end>',
#  '<start> पीला स्वेटर पहने हुए आदमी <end>',
#  '<start> फुटपाथ पर चलने वाला व्यक्ति <end>',
#  '<start> लैपटॉप कंप्यूटर डेस्क पर बैठे <end>',
#  '<start> मेज पर कॉफी कप <end>',
#  '<start> सफेद अक्षरों के साथ काला हस्ताक्षर <end>',
#  '<start> पेड़ का ट्रंक | <end>',
#  '<start> पानी में एक चट्टान <end>',
#  '<start> पार्किंग में सफेद वैन <end>',
#  '<start> तोता एक पेड़ शाखा पर बैठे हुए <end>',
#  ...]

# %%
# input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(padded_tensor_hin, padded_tensor_eng, test_size=0.2, random_state = 42)
input_train , input_val, target_train, target_val = train_test_split(clean_english , clean_hindi, test_size = 0.2, random_state = 42)

# %%
hin_lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='', oov_token='<OOV>')
hin_lang_tokenizer.fit_on_texts(clean_hindi)
hin_dict = hin_lang_tokenizer.word_index
tensor_hin = hin_lang_tokenizer.texts_to_sequences(target_train) 
padded_tensor_hin = tf.keras.preprocessing.sequence.pad_sequences(tensor_hin, padding='post')
# print(tensor)
# len(hin_dict)
target_tensor_train =  padded_tensor_hin
print(len(padded_tensor_hin))
print(len(hin_dict))
# Out:
# 23144
# 7013

# %%
eng_lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='', oov_token='<OOV>')
eng_lang_tokenizer.fit_on_texts(clean_english)
eng_dict = eng_lang_tokenizer.word_index
tensor_eng = eng_lang_tokenizer.texts_to_sequences(input_train) 
padded_tensor_eng = tf.keras.preprocessing.sequence.pad_sequences(tensor_eng, padding='post')
input_tensor_train = padded_tensor_eng
# print(tensor)
# len(hin_dict)
print(len(padded_tensor_eng))
print(len(eng_dict))
# Out:
# 23144
# 5553

# %%
# train test split
# input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(padded_tensor_eng, padded_tensor_hin, test_size=0.2, random_state = 42)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train))
train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
# val_dataset = tf.data.Dataset.from_tensor_slices((input_tensor_val, target_tensor_val))
# val_dataset = val_dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
train_dataset
# Out:
# <BatchDataset shapes: ((64, 26), (64, 34)), types: (tf.int32, tf.int32)>

# %%
len(target_tensor_train[0])
# Out:
# 34

# %%
example_input_batch, example_target_batch = next(iter(train_dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 26]), TensorShape([64, 34]))

# %%
# some important parameters
vocab_inp_size = len(eng_lang_tokenizer.word_index)+1
vocab_tar_size = len(hin_lang_tokenizer.word_index)+1
max_length_input = len(input_tensor_train[0])
max_length_output = len(target_tensor_train[0])

embedding_dim = 100
units = 1024
steps_per_epoch = num_examples//BATCH_SIZE

# %%
print("max_length_english, max_length_hindi, vocab_size_english, vocab_size_hindi")
max_length_input, max_length_output, vocab_inp_size, vocab_tar_size
# Out:
# max_length_english, max_length_hindi, vocab_size_english, vocab_size_hindi
# (26, 34, 5554, 7014)

# %%
# hindi embedding word2vec
# Load pre-trained Word2Vec model.
model = gensim.models.Word2Vec.load("hi-d100-m2-cbow.model")

# %%
embeddings_dictionary_h = {}
for word in hin_lang_tokenizer.word_index:
    try:
        embeddings_dictionary_h[word] = model.wv.get_vector(word)
    except:
        pass
    
print("the no of key-value pairs:"  , len(embeddings_dictionary_h))
embeddings_dictionary_h
# Out:
# the no of key-value pairs: 6380
# {'एक': array([ 1.3761369e+00,  3.1895986e-01,  5.5161637e-01,  3.3454773e+00,
#          7.5480199e-01, -4.1311855e+00,  3.6096673e+00,  3.1984558e-03,
#          1.1114923e+00,  1.8430928e+00, -1.6482291e+00, -2.6384809e+00,
#         -2.3330653e+00, -1.3789964e+00,  2.8163950e+00,  2.2858524e+00,
#          2.9680107e+00,  7.1689091e+00,  1.8727484e+00, -3.0235820e+00,
#          2.2039354e+00, -1.5322008e+00,  4.8508924e-01,  1.1078984e+00,
#         -3.8863792e+00, -1.7010270e-01, -2.9873648e-01, -1.1823559e+00,
#         -3.1249235e+00,  2.6842210e-01,  2.3926444e-01, -2.8258526e+00,
#         -7.1746130e+00, -8.4229892e-01, -2.8898644e+00,  3.0856481e-01,
#         -2.0823562e+00,  5.0447965e-01, -7.3356193e-01,  2.7815120e+00,
#          7.8827173e-01,  8.9215755e-01, -1.7951288e+00,  1.1564068e+00,
#          5.7838392e-02,  3.4770534e+00, -1.4091858e+00, -2.1184385e+00,
#         -3.9627492e+00, -3.0346465e-01, -1.0447567e+00, -1.7222787e+00,
#         -1.6216998e+00, -2.7504045e-01,  2.9573914e-02, -2.9421761e+00,
#          2.8321271e+00,  1.9808888e-01,  1.5485544e+00, -2.8636867e-01,
#         -1.0328695e+00, -2.5888300e+00,  5.7153893e-01, -3.1999829e+00,
#          5.1437903e-02, -2.1033065e-02, -1.7443717e+00, -2.6947918e+00,
#          4.7135930e+00, -5.4315410e+00,  3.4110937e+00,  1.1088907e+00,
#          4.5006957e+00, -3.7303171e+00, -4.1978226e+00,  5.8969676e-01,
#         -9.9670500e-01, -1.0953360e+00, -3.4796746e+00,  4.9944811e+00,
#         -1.2789642e+00,  1.9872626e+00, -4.9728665e+00, -7.8077334e-01,
#         -1.7952199e+00, -3.5770461e-01,  1.3398908e+00,  4.9144187e+00,
#          2.4485564e+00,  1.3914986e-01,  3.3863883e+00, -2.6943727e+00,
#          1.3312377e+00,  2.2891474e+00,  2.1819160e+00,  5.4744953e-01,
#          2.2928278e+00,  4.0853071e-01, -1.8449888e+00, -1.7304156e+00],
#        dtype=float32),
#  'पर': array([-3.3044293 , -1.3145294 , -0.7232973 ,  0.21802267, -2.1870637 ,
#         -5.746351  ,  2.7953105 ,  0.5053639 , -2.8808918 ,  1.2741377 ,
#         -2.4771163 ,  3.1502488 , -2.1485426 , -2.641312  ,  2.9359946 ,
#          1.1017172 , -0.29627723, -0.14307576,  4.9145494 , -3.2949557 ,
#          3.669713  , -4.2107077 , -4.1986256 , -2.498907  ,  4.2814136 ,
#         -1.1040734 ,  0.08708091, -1.6665468 , -1.3068985 ,  1.8084799 ,
#          7.6816316 , -5.8815775 ,  0.81472105,  2.1834614 , -0.5101271 ,
#          1.7007353 , -1.4511521 , -2.4448924 , -1.4489822 ,  7.981665  ,
#          4.4390225 , -4.264753  , -4.494165  ,  4.123554  ,  2.5648403 ,
#          0.95914525, -2.2028463 ,  1.4262921 , -1.4913447 ,  2.1867378 ,
#         -1.3558561 , -1.5863646 , -2.2579434 ,  2.0570972 ,  2.6481872 ,
#          1.2272114 ,  3.922615  , -2.0813189 , -2.2641933 , -4.606299  ,
#          0.28208068,  3.0947113 ,  7.5112185 ,  2.783326  , -0.7714574 ,
#         -1.9853909 , -1.8852324 ,  0.55501956,  0.8632461 ,  0.03367032,
#         -1.5261909 , -1.8067557 ,  1.7757623 ,  4.154413  , -3.65061   ,
#          2.4247801 , -1.8740631 , -1.3971901 , -0.676448  ,  4.244612  ,
#          1.9781619 ,  3.119292  ,  2.1021185 ,  1.254323  , -0.71345896,
#          2.765526  , -3.9601839 ,  4.6259017 , -0.50608337, -0.03787288,
#          1.3905419 , -0.66497386,  2.9293013 ,  2.0447965 ,  2.586218  ,
#         -3.6043963 , -1.9655095 ,  3.7443814 , -0.7280021 , -0.30268982],
#        dtype=float32),
#  'है': array([ 3.7498531e+00,  1.0238100e+00,  2.7376151e+00,  1.4873642e+00,
#         -4.1935863e+00, -2.1634009e+00,  3.5540419e+00,  2.9961362e-01,
#         -8.3493692e-01,  6.6317267e+00, -5.0229154e+00,  1.1002189e+00,
#          2.1843557e-01,  6.5404624e-01,  1.3291318e+00,  1.4277987e+00,
#          4.8580513e+00,  2.3615768e+00,  3.7097266e+00, -1.0212153e+00,
#         -3.3991878e+00,  4.0628549e-01,  8.3741957e-01,  2.4949176e+00,
#         -5.5173159e+00,  2.6970921e+00,  5.8946091e-01, -2.8775826e+00,
#          1.8133938e+00,  1.8623674e+00,  6.6099730e+00, -2.6443646e+00,
#         -3.2069299e+00,  1.5792850e+00, -2.7611299e+00, -2.1000562e+00,
#         -2.0238771e+00,  5.8276367e-01, -4.3471990e+00, -5.1565737e-01,
#          8.7125874e+00, -2.4525239e+00, -1.8604842e+00,  4.6053395e-01,
#         -2.1808555e+00,  3.5951567e+00,  7.1116394e-01, -1.2121749e+00,
#         -1.5652798e-01, -9.8399216e-01,  1.7046940e+00, -3.1939173e+00,
#         -5.5776315e+00,  1.7884470e+00,  1.7685294e+00,  1.1278030e+00,
#          1.0841892e+01, -3.0976379e+00, -4.3341179e+00, -2.4870074e+00,
#         -2.0574131e+00, -6.9052821e-01,  5.2605815e+00, -6.8394089e-01,
#          6.7722878e+00,  2.8787854e-01,  3.4330049e+00, -1.3496988e+00,
#         -2.4619048e+00, -7.4551463e+00, -2.8984824e-01,  2.9573998e+00,
#         -2.0521286e+00,  1.1879865e+00, -3.4039340e+00, -5.8628118e-01,
#         -1.0427538e-02, -3.7400105e+00, -2.2635391e+00,  2.8988435e+00,
#         -8.5756165e-01, -3.8654339e-01, -3.7159359e-01,  1.8382518e+00,
#         -8.1078804e-01, -2.4878883e+00,  3.7713792e+00,  1.5899055e+00,
#         -1.7353257e+00,  5.7867283e-01, -1.8313140e+00, -2.2003491e+00,
#         -7.2775054e-01,  3.2396796e+00,  3.4051774e+00, -2.7156417e+00,
#          1.8043040e+00,  1.8456335e-01, -6.9717150e+00, -2.2643681e-01],
#        dtype=float32),
#  'के': array([-1.1147534 , -0.8008088 ,  1.4726522 , -1.7794173 ,  2.9393954 ,
#         -3.7685812 ,  5.4594607 ,  1.5140761 , -0.7912337 ,  3.1839173 ,
#          1.2732108 , -6.448388  , -7.0743165 , -1.6807414 ,  2.1503668 ,
#          1.3005325 ,  8.517192  ,  4.8888073 ,  6.5288343 , -5.5686917 ,
#          1.4279556 , -1.645845  , -4.560192  , -0.20215695,  1.2434579 ,
#          0.11532015,  1.2389287 , -1.0011069 , -5.1924605 ,  0.10695625,
#          4.543739  , -2.2269278 , -4.45839   , -0.62602013,  0.4829247 ,
#          0.24309215, -0.33450037,  5.0008545 , -0.22395453,  4.425056  ,
#         -0.90123796, -6.1270504 ,  0.95782256, -0.5360148 , -5.836163  ,
#          3.95337   ,  2.802324  , -6.2749486 , -7.554181  ,  1.750824  ,
#         -2.371332  , -7.296257  ,  1.2633606 ,  1.9556265 ,  1.6164327 ,
#         -1.4600568 ,  3.260799  , -0.9869296 , -0.05001744, -1.8724312 ,
#         -2.3717792 , -0.35159466,  2.085773  , -2.1296499 , -1.1144828 ,
#         -1.1878214 , -1.6552626 ,  3.775754  ,  0.62966067, -2.163027  ,
#          0.62489825,  0.34768414,  1.252773  ,  4.2777667 , -1.9395553 ,
#          5.909966  , -1.3091896 , -1.2789099 , -1.6084284 ,  2.5075762 ,
#          2.3116984 ,  1.360208  ,  0.1955456 ,  0.6628974 , -3.046061  ,
#          4.986743  ,  0.3759243 , -0.3238166 ,  2.1824002 ,  3.6929114 ,
#          2.8964293 , -2.78443   ,  2.9253442 ,  5.634128  ,  0.9341646 ,
#          0.26867384,  3.47518   ,  3.9729443 ,  3.1951602 , -2.4142003 ],
#        dtype=float32),
#  'में': array([-0.8859824 ,  0.64330894,  0.90421456, -0.6946147 ,  4.157618  ,
#         -2.1044867 ,  5.0981264 , -0.48843065, -1.6250441 ,  2.5460114 ,
#          1.3290131 , -4.163343  , -4.450903  , -0.806661  ,  2.1136332 ,
#          4.399762  ,  0.6588886 ,  1.3553021 ,  2.6501923 , -0.9174531 ,
#          2.2766714 , -1.1571323 , -1.2434915 ,  0.13349251,  0.99902165,
#          2.2615085 , -2.8270962 , -0.8960276 , -1.8466963 , -0.7761993 ,
#          4.4493656 , -8.164801  , -1.083843  , -0.44801283, -2.2026765 ,
#          0.98357755,  0.7327746 ,  2.050408  , -0.45183173,  4.267441  ,
#          3.7979062 , -3.8166428 , -0.72217643, -0.8002708 , -0.11267823,
#          1.3980875 ,  0.8309402 , -2.8426898 , -3.9329672 , -0.06005977,
#         -1.4090124 , -3.7005997 , -0.7686836 ,  1.5241886 ,  4.0276675 ,
#         -0.8408839 ,  5.9451656 , -1.1319827 , -3.5141304 , -2.5745976 ,
#          1.7439151 ,  2.2720945 ,  3.832202  ,  3.022444  , -1.8596338 ,
#         -2.2894194 , -2.4378603 ,  3.3224773 ,  0.5841267 ,  0.20167358,
#          1.0535985 ,  0.6071092 ,  4.896126  ,  3.4499385 , -0.97193736,
#          2.6785967 , -0.6615797 , -1.3785131 , -4.509024  ,  2.6322346 ,
#          0.6546845 ,  0.41274396,  0.48127848, -1.4976057 , -3.6581788 ,
#          0.714687  , -1.7670755 ,  1.4687423 ,  2.6314752 , -0.03213599,
#         -0.73892945, -4.2899384 , -1.8003154 ,  3.3094954 ,  2.9783604 ,
#         -1.3694355 , -0.05121637,  4.698106  , -6.36366   , -2.3274505 ],
#        dtype=float32),
#  'का': array([ 2.396464  ,  3.6283486 ,  2.1469378 , -0.2092023 , -0.13748501,
#         -1.5241648 ,  2.703529  ,  1.0546759 , -3.8534088 ,  5.2396517 ,
#         -1.4936585 , -1.4299816 , -3.1675603 , -0.72366834,  3.933882  ,
#          7.101204  ,  4.4237313 ,  0.10232748,  4.000158  ,  0.9981775 ,
#         -2.0169923 , -3.4550724 , -1.9989917 , -0.97299695, -0.635524  ,
#         -0.49788073, -1.4860649 , -4.8124113 , -3.4779053 ,  1.6404369 ,
#          4.051275  , -4.661651  ,  0.5480456 ,  1.7953055 ,  3.1804988 ,
#          2.4652479 , -3.4747174 ,  5.103821  , -1.9357737 ,  3.2603755 ,
#          1.4484714 , -4.5123286 ,  1.1084586 , -1.1176076 ,  0.15180172,
#          4.52053   ,  1.0755677 , -4.73171   , -1.8841261 ,  0.08457972,
#         -1.1686057 , -7.6723723 ,  0.5109432 , -1.2039771 ,  1.8460643 ,
#          0.99159914,  2.7618606 ,  0.02967967,  1.9451845 , -2.2783127 ,
#         -6.324301  ,  2.3305185 ,  5.252024  ,  0.86758673, -1.7982605 ,
#         -3.6758573 , -1.628298  , -1.8731215 ,  0.44976696, -0.40952608,
#         -2.0077925 , -4.3012533 ,  1.0922852 ,  3.8334963 , -3.6350126 ,
#          0.56583774,  1.3737226 ,  0.23866268, -1.7200038 ,  2.8775012 ,
#          0.26350966,  1.723708  , -1.4711989 ,  1.2393719 , -2.2390301 ,
#          2.3290117 , -0.77379066,  1.9222614 , -4.2423415 ,  2.253125  ,
#          3.8658483 , -6.6059847 ,  5.121994  ,  1.0287235 ,  2.4764671 ,
#         -0.16919197, -1.0261422 ,  4.0497684 , -2.5978892 , -0.00897079],
#        dtype=float32),
#  'सफेद': array([-3.2041824e-01,  1.1052412e+00,  6.3725239e-01,  2.8152204e+00,
#          1.4383808e+00, -5.0299277e+00, -3.2511823e+00,  2.2358305e+00,
#         -3.2888153e-01,  1.0395113e+00,  3.5587928e+00,  2.1535833e+00,
#         -1.0365874e+00, -1.9866505e+00,  2.4995232e-01,  1.4407078e+00,
#         -1.2381254e+00,  3.0199604e+00,  2.4767821e+00,  5.6400925e-01,
#         -3.7155893e+00, -1.5066445e+00,  1.3884245e-01,  1.6159283e+00,
#         -4.0757391e-01, -3.8219302e+00, -1.8042256e+00, -7.8749669e-01,
#         -1.1378530e+00,  2.4953008e-01,  3.3609838e+00, -3.5437758e+00,
#         -4.9324479e+00,  1.6024548e+00, -2.0585344e+00, -4.1692600e-01,
#         -2.4334124e-01,  2.3150270e+00, -3.8640749e+00,  1.7185503e+00,
#         -3.0379614e-01, -9.4758071e-02, -3.4021369e-01,  2.6529009e+00,
#         -1.3080206e+00,  2.8876408e-03, -2.5280517e-01, -2.4300732e-01,
#         -3.0118353e+00,  2.8447607e+00, -1.7822809e+00,  1.7658968e-01,
#          1.4897596e+00,  5.1431572e-01, -1.5763615e+00,  9.0330601e-01,
#          5.0830297e+00, -4.3698702e+00, -1.4802179e+00, -1.5669479e+00,
#         -1.3098217e+00,  1.2094389e+00,  2.8035185e+00, -4.7810450e+00,
#          6.7019659e-01,  1.3998606e+00,  8.4624255e-01,  1.4814977e-01,
#          1.8220534e+00,  1.5560795e+00, -6.1588484e-01, -2.3559709e+00,
#         -6.7153317e-01, -5.6547487e-01, -1.5309040e-01,  2.2399583e+00,
#          4.4220144e-01,  3.3350422e+00, -5.4546733e+00,  2.0935974e+00,
#          2.3470306e+00, -7.6251280e-01, -2.1493316e+00, -1.2180216e-01,
#         -6.2044114e-01, -3.1439805e+00,  6.2493891e-01,  2.7974946e+00,
#          1.6924055e+00,  2.9321086e+00,  1.4664648e+00,  1.3794612e+00,
#          2.1755223e-01, -6.4638358e-01,  6.5272763e-02,  9.3698323e-01,
#         -4.0727478e-01,  2.4121189e+00, -2.3571971e-01,  1.8466444e+00],
#        dtype=float32),
#  'की': array([-5.5312133 , -3.3909912 ,  3.8681316 ,  0.74457973,  2.376638  ,
#         -1.919564  ,  3.5479887 ,  0.5370202 ,  0.06681232,  6.458265  ,
#         -3.772286  , -0.8583018 , -1.1107216 , -0.48623344,  1.960078  ,
#          0.6856631 ,  1.1799278 ,  5.0489154 ,  5.6593895 ,  0.8896882 ,
#         -1.8959903 , -0.10630604, -0.6378666 , -0.8980473 ,  0.5018549 ,
#          2.5215292 ,  0.07927464, -4.212474  , -2.5246346 , -4.2350345 ,
#          3.2636046 , -0.40384665, -0.41892704,  0.30760098, -4.2908444 ,
#          1.8403895 , -1.0113462 ,  2.285848  , -4.0768394 ,  6.131057  ,
#          2.5669634 , -4.77443   , -1.7844887 , -0.8095309 , -1.1207592 ,
#         -1.1238248 ,  3.3076868 , -1.2179564 ,  1.893422  ,  1.0295638 ,
#          1.5735888 , -4.1350393 , -0.24173988,  4.6465163 ,  3.1127393 ,
#          1.1421424 ,  1.5817901 , -2.9161348 ,  1.864569  ,  2.9731448 ,
#          1.8915511 , -1.6824685 ,  0.8531277 , -4.5723896 , -2.7100317 ,
#         -1.6142659 , -0.23165825,  0.39497375,  2.2834787 , -1.579575  ,
#          1.6861051 , -2.8988752 , -0.1948814 ,  1.9763732 ,  1.1691931 ,
#         -0.47425145, -3.9507928 , -0.8660599 , -5.5515285 ,  4.5446    ,
#         -0.6788066 ,  2.2503207 ,  3.0622811 ,  0.34112957, -5.339365  ,
#          1.8582659 , -2.8093836 , -0.4068401 ,  3.8183684 ,  0.5270202 ,
#         -1.834634  , -6.2511997 , -0.9432992 , -0.2246597 ,  3.128184  ,
#          0.8155086 ,  2.1418848 ,  3.5063298 ,  0.1592471 , -4.5985327 ],
#        dtype=float32),
#  'आदमी': array([ 2.295127  ,  0.575647  ,  2.5537786 ,  7.0069585 , -0.7989863 ,
#         -0.19126405,  3.7753072 , -2.8049135 , -2.5131834 , -2.442657  ,
#         -2.2408106 ,  0.20385456, -1.3915633 ,  3.2298164 , -0.4810947 ,
#         -1.4457029 , -0.27503332, -1.1958281 , -0.9365716 ,  0.16105844,
#         -5.2762947 , -1.9873706 , -0.13374414,  0.5696606 , -3.2619538 ,
#          0.67671067,  2.0164118 , -1.1987107 ,  2.0306664 ,  1.2963793 ,
#         -2.0778809 , -1.607226  , -5.1819777 , -3.5917122 ,  0.08819691,
#         -0.90961957,  0.49355277, -2.7787275 ,  2.2898214 ,  1.4360697 ,
#          7.106487  , -1.0474567 ,  0.62335944, -1.4036978 , -2.9879448 ,
#          3.2088916 ,  0.33574346,  2.4535449 ,  0.22969238,  4.735742  ,
#          2.415887  ,  4.8909826 ,  2.0657442 ,  1.0969276 ,  3.1245842 ,
#         -5.0441537 ,  8.096686  , -0.32878965, -1.9491864 ,  0.7574512 ,
#         -3.4605534 , -0.52200603,  5.5252037 , -2.2663732 ,  3.3587513 ,
#         -0.9088188 ,  2.0325062 , -1.2591354 ,  2.400398  , -2.7037404 ,
#         -4.8215823 ,  3.3530264 ,  1.8018025 , -1.3256668 , -4.716686  ,
#          0.07449557,  2.1431818 , -0.75209486,  2.7132747 ,  1.6377596 ,
#         -1.5159028 , -0.93005437, -0.5322245 , -0.3188675 ,  0.2483017 ,
#         -2.6922228 , -3.7132478 ,  3.7813044 ,  3.868959  , -0.6564744 ,
#         -1.3304273 , -0.9365578 ,  3.549994  , -1.2766621 ,  0.8241298 ,
#          4.724797  , -0.50001603,  0.9569434 , -4.4519377 , -1.3293332 ],
#        dtype=float32),
#  'और': array([-0.86426157, -0.0391418 ,  1.7655063 ,  0.8367936 , -0.03114397,
#         -1.1428055 ,  3.157202  ,  1.5909976 , -0.99562204,  1.4754667 ,
#         -1.4146142 ,  0.37200564, -3.5111372 ,  1.737083  ,  1.7088226 ,
#          2.8018796 ,  0.6852833 ,  2.9261873 ,  0.38825497, -2.4353833 ,
#         -0.5396456 , -1.8493313 , -0.7998935 ,  0.7578609 ,  0.9136186 ,
#          0.47247833, -2.0145192 , -0.08254636, -1.3003657 ,  0.45660618,
#          3.686435  , -3.311002  , -1.5695758 ,  1.9515709 , -1.2239845 ,
#         -0.7135368 , -2.7587273 ,  1.4286908 , -1.2927718 ,  2.9678755 ,
#          4.0413055 , -3.7775934 , -0.48511258,  1.0286435 , -0.29009145,
#         -0.08823872,  1.6560557 , -0.62687004, -2.2094042 , -1.618271  ,
#         -0.34723788, -2.857722  ,  1.4018662 ,  4.8419127 , -0.68409616,
#          0.47963795,  3.363499  , -1.3403945 , -0.5448327 , -2.6133947 ,
#         -1.9068017 , -0.6739222 ,  3.3732915 ,  0.2033523 ,  1.5944588 ,
#         -1.0906626 , -1.7911307 ,  0.8282922 ,  3.1554713 , -1.9686826 ,
#          1.7492328 ,  1.25735   ,  1.2486773 ,  2.323693  , -0.10349599,
#          4.236469  ,  1.6956497 , -0.6452475 , -0.5232657 ,  2.520356  ,
#         -0.5824942 ,  1.6936435 , -0.74875355, -0.38334048,  1.0730382 ,
#          0.04034882, -1.8278263 ,  0.8279445 ,  2.364937  , -1.1652304 ,
#         -0.41202635, -1.4950728 ,  1.9078907 ,  1.1577544 ,  2.0665998 ,
#         -0.650232  ,  3.7267423 ,  1.687504  , -1.4622437 , -2.460008  ],
#        dtype=float32),
#  'लाल': array([-4.51438606e-01,  1.80104524e-01, -4.07287925e-01,  2.27478385e+00,
#          2.19353938e+00, -2.66946292e+00, -3.13937426e+00,  2.60492587e+00,
#          1.03997028e+00,  3.73566061e-01,  3.78813267e+00,  1.74864757e+00,
#          1.74157906e+00, -1.23205766e-01,  3.45296574e+00,  1.45299506e+00,
#         -2.84003705e-01,  1.36217868e+00,  2.81282842e-01,  3.25244164e+00,
#         -1.98174930e+00,  1.20915329e+00, -3.53400111e+00,  8.22537720e-01,
#          3.58999103e-01, -3.45530438e+00, -8.15120280e-01, -8.30199182e-01,
#         -2.33142662e+00, -1.01445317e+00,  1.67017090e+00, -3.00378299e+00,
#         -3.49132752e+00,  2.50797105e+00, -5.56055427e-01,  7.10164011e-01,
#         -3.88151705e-02,  3.43255353e+00, -1.52108169e+00,  2.83903098e+00,
#         -1.88941979e+00,  8.47095773e-02,  5.51704931e+00,  1.80605853e+00,
#         -2.56392431e+00,  1.81588387e+00, -3.67645526e+00, -6.23579323e-01,
#         -2.02863455e+00,  7.31670111e-02, -6.25393569e-01,  7.38429725e-01,
#         -3.62624240e+00,  2.08680892e+00, -1.39575636e+00,  1.11101151e+00,
#          1.85246205e+00, -3.49858403e+00, -5.59647894e-03,  3.92197445e-02,
#         -3.47414553e-01,  1.37347019e+00,  1.68884456e+00, -5.82781410e+00,
#          2.38610458e+00,  1.13148737e+00,  9.89945352e-01,  1.58049107e-01,
#          3.94464445e+00,  3.75867653e+00,  1.46134764e-01,  1.85145959e-01,
#         -9.41580951e-01,  2.25060296e+00,  5.00387192e-01,  3.10533190e+00,
#         -6.04835510e-01,  3.35765147e+00, -5.95555210e+00, -7.06694201e-02,
#         -1.70916462e+00, -1.56767273e+00, -5.10083735e-01, -4.41667414e+00,
#          1.53900874e+00, -1.00085545e+00,  3.19224691e+00,  3.81961036e+00,
#          3.12296033e+00,  1.17420638e+00, -2.65070248e+00,  4.81139868e-01,
#          3.58054757e+00, -9.13216114e-01, -7.19314337e-01,  1.53006613e-01,
#         -4.04366159e+00,  3.66849244e-01,  1.27354109e+00, -1.60883749e+00],
#        dtype=float32),
#  'साथ': array([-2.745758  ,  4.207892  ,  0.3192129 , -0.10154583, -0.673554  ,
#         -2.4697075 ,  5.824443  ,  0.70194095, -0.84625465, -0.12170942,
#         -2.4677212 ,  2.3848963 , -2.0550947 ,  1.5574689 ,  3.5702808 ,
#          6.1189966 , -2.367874  ,  4.1671743 , -0.15378153,  0.39269388,
#          3.665571  , -0.2580835 ,  1.4928787 , -0.55361474,  4.7179694 ,
#          1.2183902 ,  2.127845  , -0.71278924, -0.642237  ,  3.904133  ,
#          0.04470028, -5.1357417 ,  0.24313836, -1.1376601 , -3.9386292 ,
#          0.84307885, -1.1015317 ,  0.76127636, -1.0864155 ,  0.36624545,
#          1.515857  , -3.180836  , -2.541118  , -0.45853326,  3.1134374 ,
#         -5.4774823 ,  1.3282777 , -2.087971  , -0.6188946 , -0.6118095 ,
#         -2.2216942 , -2.524216  ,  1.7710634 ,  4.0848594 ,  0.7736601 ,
#          3.0890014 , -0.04807042, -1.6488479 , -0.34789458, -4.358073  ,
#         -1.8290758 , -0.8065183 ,  4.779924  , -2.5040152 , -2.3117423 ,
#         -4.925323  , -1.7463225 ,  1.3192508 ,  2.4518452 ,  0.8813577 ,
#          0.46091032, -2.3089733 ,  4.273754  ,  0.24390027,  1.3952599 ,
#          1.0917938 ,  2.1112504 , -2.0753942 , -4.6088533 ,  0.962059  ,
#          3.0783958 , -0.7386288 ,  2.9694233 , -0.8442994 ,  1.4306563 ,
#         -0.46703485,  2.0545516 ,  3.8967588 ,  4.178153  , -3.3653755 ,
#          1.3671978 , -3.1485066 ,  3.404632  ,  3.1424608 ,  5.1235414 ,
#         -4.7289505 ,  4.1970406 , -0.90404594, -5.9779587 ,  2.9326284 ],
#        dtype=float32),
#  'यह': array([-1.4518698 , -3.5975971 ,  2.5046191 ,  6.572565  ,  0.18125305,
#         -1.2957147 ,  0.189808  ,  1.3793994 , -1.0188992 ,  1.2447819 ,
#         -2.8106024 , -5.3211217 ,  0.3661699 ,  0.2643096 ,  0.6854879 ,
#         -1.3452879 ,  2.6505303 ,  3.2466114 ,  0.08261713, -0.40461895,
#         -0.97248036, -3.6144612 ,  4.3447824 ,  3.5884087 , -5.4891253 ,
#          3.5942338 ,  1.1270262 ,  0.43714195,  1.3476728 ,  1.3565986 ,
#          3.3247678 , -1.7614471 ,  0.04540356,  3.206626  , -0.58161587,
#          2.0828748 , -1.309207  ,  1.6798612 , -2.7749755 ,  0.9421383 ,
#          4.046961  ,  3.3955016 ,  0.3139717 , -1.0995816 ,  0.3634118 ,
#          4.5404887 ,  0.32066798, -3.1808527 ,  1.1736087 , -0.84084064,
#         -1.580536  , -3.5247023 , -1.542873  ,  0.27959988, -0.31371316,
#          1.2893497 ,  4.0103316 ,  0.74793535,  0.27509445,  0.5039131 ,
#         -1.982673  , -0.25233024,  4.320802  ,  3.5990293 ,  3.7985594 ,
#          1.3878412 ,  0.16506347, -2.635831  , -0.01866348, -4.011089  ,
#         -1.1438781 , -1.4573928 ,  1.5090319 , -0.43167448, -3.344939  ,
#          0.1729299 , -1.0024893 , -2.1717482 , -3.9032414 ,  2.2664838 ,
#          0.25939915, -0.76202524, -3.6260936 , -2.2130013 , -1.6613973 ,
#         -4.0503893 ,  1.5882782 ,  4.347606  , -2.5047474 ,  2.3788238 ,
#          0.99175334, -1.6753976 ,  1.043115  ,  1.4625063 ,  0.4873528 ,
#         -0.11442688, -1.4097433 ,  0.794009  , -5.7076764 , -3.9388275 ],
#        dtype=float32),
#  'व्यक्ति': array([ 1.808807  ,  0.7182141 ,  2.389498  ,  2.1879058 ,  1.5393745 ,
#         -0.9420401 ,  2.9845755 , -2.8921542 , -2.6758661 , -3.7473755 ,
#         -2.596415  ,  0.5124464 , -5.647149  ,  3.7915947 ,  0.83861005,
#          1.5499855 ,  6.391056  ,  1.1312916 ,  0.6545338 , -4.9537477 ,
#         -2.499249  , -4.1341014 , -0.22124586, -2.3455899 , -5.3521876 ,
#          1.3771541 ,  1.2555896 , -3.5686598 ,  1.1381044 , -1.0676033 ,
#         -3.4652247 , -2.0453734 , -4.2349524 , -3.2135444 ,  0.48741868,
#         -1.2897894 ,  0.7660662 , -3.1939356 , -1.1821791 ,  2.912992  ,
#          6.893921  , -3.3669147 , -0.49361417,  0.9498318 ,  0.0930496 ,
#          0.9520876 ,  0.66455245,  1.1409225 , -0.53453135,  4.321728  ,
#          1.4570506 ,  4.2772846 ,  2.6870506 ,  1.1720079 ,  3.5503469 ,
#         -4.2784705 ,  6.3305078 , -2.0378165 , -2.4268858 , -0.10966416,
#         -3.6635673 , -1.0567269 ,  4.686252  ,  0.9332555 ,  3.563349  ,
#         -2.5968509 ,  0.50490296,  0.08082014,  1.6682189 , -2.793012  ,
#         -3.7337139 ,  2.5062664 , -1.2146509 , -1.3596437 , -2.2365499 ,
#         -3.156216  ,  2.0876877 , -5.5016575 ,  0.2774224 ,  2.0121436 ,
#          1.8747739 ,  1.8415586 , -1.629349  ,  0.1202198 , -0.33150846,
#         -2.8644364 , -0.65902674, -1.2206749 ,  4.5693693 ,  2.225585  ,
#         -0.36685687, -6.3320036 ,  2.5315096 ,  2.8557584 , -1.1845378 ,
#         -0.7826558 , -2.824056  , -1.2022758 , -1.4542009 , -1.4174092 ],
#        dtype=float32),
#  'हैं': array([ 1.3017032 ,  1.8849665 ,  2.0311294 , -0.22506747,  3.964518  ,
#         -3.162572  ,  6.488435  ,  1.1786889 , -1.8071667 ,  4.679546  ,
#         -2.3477418 ,  8.092288  , -2.2296424 ,  0.27735698,  1.6997727 ,
#          3.656257  ,  3.6890604 ,  4.919875  ,  4.650249  , -3.4055226 ,
#          1.0442699 ,  1.231259  ,  0.9895082 ,  4.447911  , -1.2766556 ,
#         -2.3223479 ,  0.7622812 ,  1.6155956 ,  3.4868371 , -2.7611105 ,
#         10.448621  ,  2.7203307 , -3.6728544 ,  0.5612804 ,  2.2257106 ,
#         -0.8289259 , -5.738098  ,  0.28769735,  0.7645994 , -5.4813094 ,
#         10.099946  , -3.9421601 , -0.7913038 , -1.4391836 , -4.596213  ,
#          0.2846602 ,  1.7751651 , -0.95860803, -3.3044508 ,  2.6613965 ,
#          0.4441158 ,  1.7398547 , -2.7284927 ,  7.531834  ,  2.179438  ,
#         -1.4764698 ,  7.73517   , -1.4725643 ,  0.7757875 , -0.7842713 ,
#          0.8175457 , -0.8293849 ,  7.292565  ,  0.16426991,  0.09919125,
#          3.0790331 ,  5.379717  , -0.40703553,  0.7341175 , -4.941429  ,
#         -1.5713238 ,  2.3647447 , -4.798531  ,  3.8027804 , -0.88424796,
#          0.5249858 , -5.0425086 , -6.2707715 , -1.2942047 ,  1.4788007 ,
#          1.3304137 ,  0.58186233,  2.4774427 , -4.371927  ,  1.051378  ,
#         -1.7176783 ,  2.8397036 , -1.6278609 , -2.1403694 ,  0.04308238,
#         -0.13549988,  0.67081296,  0.26347798,  7.971489  , -3.0864186 ,
#         -1.1258105 ,  3.122144  ,  3.5935857 , -7.7613773 ,  3.4622753 ],
#        dtype=float32),
#  'रंग': array([-4.9534220e-01,  2.3842788e+00, -8.6075252e-01, -4.7778508e-01,
#          1.5567709e+00, -2.7759519e+00,  1.5253813e+00,  1.6895108e+00,
#         -2.4586892e+00, -2.3366568e+00,  1.6795619e+00,  1.6222979e+00,
#          1.9057816e+00,  3.4493167e+00, -1.2125829e+00,  3.9861321e+00,
#         -3.7363245e+00,  2.4837384e+00,  1.6856896e+00, -1.0554013e+00,
#         -3.5299006e+00,  2.1127540e-01,  2.1721559e+00,  2.3044529e+00,
#         -5.1465712e+00, -6.6139638e-01, -1.8598821e+00, -3.7137456e+00,
#          2.1580729e+00,  8.8596159e-01,  5.7967186e+00, -3.7026844e+00,
#         -4.2782493e+00,  1.9143410e+00, -3.7883408e+00, -2.8785512e+00,
#         -6.1056638e-01,  1.4974425e+00, -3.6194189e+00,  4.8797493e+00,
#         -1.6286315e+00,  5.0935340e-01, -1.4837626e+00,  1.5047967e+00,
#         -3.5619173e+00, -2.3631084e+00, -5.1590061e+00,  2.9194193e+00,
#         -2.7861261e-01,  9.4486517e-01, -2.6171324e+00, -2.7037385e+00,
#         -1.1051092e+00,  1.2453303e+00, -5.7918757e-01, -2.6781709e+00,
#          4.7431626e+00, -4.8955169e+00, -1.0394454e+00, -2.0287764e+00,
#          6.8849933e-01, -1.0358343e+00,  4.4088345e+00, -2.9528005e+00,
#          4.0104032e+00,  2.3198171e-01,  4.0227389e-03,  1.4650248e+00,
#          3.8943682e+00,  2.1225936e+00, -1.8524264e+00, -1.6212906e+00,
#          2.5061398e+00, -1.3930418e+00,  2.0227664e+00,  3.5847905e+00,
#          1.1402040e+00,  4.8025256e-01, -5.6275806e+00, -2.1634388e-01,
#          1.3234392e+00, -1.5654441e+00,  2.3951402e+00, -1.1816802e+00,
#          4.1042995e+00, -4.8346581e+00,  4.7058336e-02,  1.5019791e+00,
#          1.5827569e+00,  3.2323699e+00, -1.2723342e+00, -7.0385963e-02,
#          4.4824388e-02, -4.9113351e-01, -1.3704913e+00,  3.3347287e+00,
#          2.4763927e+00,  4.2583045e-01, -3.0791733e+00,  1.2287774e+00],
#        dtype=float32),
#  'महिला': array([ 3.7397907 ,  0.4840149 , -0.02977228,  0.17145939, -0.54729885,
#         -1.0069675 , -1.0257508 , -5.6258445 , -0.07320905, -1.9771667 ,
#          1.7626368 , -2.8653688 , -2.6324122 ,  1.1033746 ,  1.8775445 ,
#          3.387205  ,  5.7880745 ,  3.5032685 , -0.77550656, -1.6383395 ,
#          2.4121315 , -0.6720737 , -3.5568237 , -0.84589916,  3.444455  ,
#          1.6997834 , -1.4135109 ,  0.23316044,  0.25097972, -0.01614872,
#         -3.4572666 , -3.4026384 , -2.1854856 , -4.355202  ,  2.3401504 ,
#         -1.699308  ,  2.1525786 , -2.2354271 , -3.4481304 ,  2.3059063 ,
#          0.77633435, -2.9300604 , -0.11053038,  3.6136196 , -1.5418776 ,
#          0.44585577,  2.3740513 ,  1.5297221 , -4.7437096 ,  1.1371553 ,
#         -0.20042467,  5.135226  ,  2.0475397 ,  2.2479005 ,  0.9072543 ,
#          1.4626309 , -0.1622002 , -1.1543308 , -0.6830544 , -0.05781215,
#         -3.478248  , -3.3324094 ,  3.5396228 , -3.162123  , -0.96463645,
#          2.1437118 , -1.2191751 ,  0.87652045, -2.7116907 , -0.8302657 ,
#          2.3237216 , -2.339765  , -0.42082226,  3.2538624 , -6.377021  ,
#         -1.6401445 , -1.1745771 , -2.8137877 , -1.6935209 ,  0.63608646,
#          2.0052056 , -1.1300634 ,  1.5526347 ,  1.3733441 , -3.6774085 ,
#         -0.71354115,  0.09652858,  2.0601487 ,  1.0543683 , -0.09702004,
#          1.411974  , -2.1791828 ,  2.0454893 ,  2.0992167 ,  2.3080127 ,
#          0.6615611 , -1.8642193 ,  0.18105546,  0.02800772, -6.2393184 ],
#        dtype=float32),
#  'रहा': array([ 4.905259  ,  3.2334664 ,  9.569559  , -2.7170427 ,  1.6540363 ,
#         -0.5629758 , -3.882093  ,  5.304728  , -4.781329  ,  5.6961417 ,
#          0.33254576, -2.9701812 ,  3.3784897 ,  3.9353158 , -1.8867328 ,
#         -2.6292431 ,  5.7261844 , -7.0540333 , -3.7861347 ,  3.828112  ,
#          0.11530117, -0.343029  ,  2.1382215 ,  1.9167613 , -2.7053719 ,
#          4.6806793 ,  3.1796365 , -3.8359487 , -4.8456764 , -3.207564  ,
#         -1.0526161 , -5.988754  , -3.2326326 , -4.120357  ,  0.21957424,
#          3.9371252 , -7.166742  , -2.3823318 , -1.8138965 , -2.647219  ,
#         -3.0355592 ,  3.6953583 , -8.729637  , -5.8546505 ,  1.7184381 ,
#          7.697923  , -5.6950817 ,  1.4400473 , -6.29294   ,  7.33434   ,
#          2.5732212 ,  1.127936  , -3.6667783 , -4.26352   , -2.3572183 ,
#          1.9888484 ,  3.3799298 ,  6.2495904 , -3.6275558 ,  3.3202715 ,
#         -1.1370217 , -4.875668  ,  8.390942  ,  3.4906898 ,  3.7511146 ,
#         -6.256735  ,  1.1869531 ,  2.1972015 , -8.834186  ,  0.51777166,
#         -3.4170184 , -3.6343646 ,  2.904968  , -6.0715246 , -1.3590331 ,
#         -2.6863403 , -2.2470448 ,  9.7511425 , -0.8168316 ,  2.533824  ,
#         -1.940903  ,  0.03326494, -0.20458736,  0.12103258,  9.529744  ,
#          0.72826964, -2.4509547 , -4.171008  ,  1.6523002 , -4.9777436 ,
#          7.655767  ,  3.5230436 ,  2.4573429 , -2.4297495 , -2.423919  ,
#          0.57482004,  2.0841877 , -1.7670665 ,  2.2520072 ,  1.7206866 ],
#        dtype=float32),
#  'दो': array([ 1.7907032 ,  0.07586073, -1.0676218 , -1.0671659 ,  0.10586044,
#         -1.3778225 , -0.285378  ,  1.4369395 ,  3.0697174 ,  0.35814804,
#         -0.26314646, -0.64880705, -1.4567076 , -1.6280563 , -0.593302  ,
#          5.268531  ,  5.2202573 ,  5.1495914 ,  7.0902195 , -0.5584588 ,
#          3.8160613 ,  1.3825552 , -1.0187039 , -1.5315318 ,  2.0608275 ,
#         -4.0435333 , -2.1096272 ,  1.6881056 , -4.022537  , -1.3237338 ,
#         -1.2337409 , -2.80035   , -4.1330953 ,  0.71359855, -4.517337  ,
#          3.6641889 , -2.593669  , -4.057495  ,  4.0646186 ,  0.53916717,
#          0.0530649 , -0.33141863, -0.05994234,  0.43674847, -0.98145527,
#          4.0644083 ,  1.0266594 ,  0.48609397, -2.5868196 ,  1.8893888 ,
#         -1.6839125 , -2.8882992 ,  0.6592497 ,  1.5072795 ,  0.18976758,
#         -3.4113436 ,  1.8123641 ,  0.5704495 ,  0.11052574, -2.9554462 ,
#          5.6014805 , -1.2451537 , -1.0248225 , -4.463151  , -4.1237364 ,
#         -0.45273188, -0.44884786, -2.0492113 ,  1.3700467 , -1.715876  ,
#          2.9102361 , -3.577377  ,  3.894881  ,  0.04420166, -3.922215  ,
#          2.4904807 , -1.169672  ,  3.889628  , -4.8213286 ,  2.9324863 ,
#          0.5016974 ,  0.19459711, -2.0626574 , -0.32050496,  0.96289533,
#          2.994569  , -0.5880348 ,  3.1270926 ,  3.4748623 ,  0.16511653,
#          2.0086436 , -2.2257707 , -1.6186875 ,  2.459061  ,  1.6850659 ,
#          0.40606263,  0.5155062 ,  3.7505546 , -3.363924  , -0.20614824],
#        dtype=float32),
#  'सड़क': array([ 0.58161825, -1.1950061 ,  2.7285802 ,  1.6357312 ,  4.3478355 ,
#          0.3005145 ,  1.8107176 ,  0.54845786,  2.3469794 , -3.225522  ,
#          4.7615895 ,  2.0698178 ,  1.5959362 , -3.1327915 ,  0.9153108 ,
#          2.6148884 ,  1.708524  , -0.9497656 ,  4.7570786 ,  0.04632336,
#         -1.0603286 ,  2.1033387 , -3.7649767 , -0.52976483,  3.7482147 ,
#         -0.7011757 ,  2.3970273 ,  0.40503132, -0.32476664,  2.6429157 ,
#         -1.9637023 , -2.5518174 , -5.812559  ,  0.20663077, -2.0946934 ,
#         -3.2190502 ,  2.3956203 ,  4.917338  ,  1.5677338 ,  0.44431534,
#          5.2570925 , -1.9579047 , -6.0978413 , -1.3126938 , -0.1206366 ,
#          2.3476663 ,  2.2456648 ,  0.24232826, -2.140293  ,  0.27610764,
#         -0.08322553,  1.419007  ,  1.409797  ,  0.11850185, -2.2703788 ,
#          2.575418  , -0.47831082,  4.560316  , -1.143448  , -0.5220157 ,
#          1.5488096 , -0.6533191 ,  3.154386  , -4.4972215 ,  0.45309588,
#          1.8869332 ,  0.4278394 , -1.819809  , -0.53057474, -1.2529814 ,
#         -1.3861815 ,  6.913271  , -1.2335937 , -5.60745   , -2.9307265 ,
#          1.0634068 ,  0.15684956,  3.4072483 , -3.2598958 , -2.1815884 ,
#          0.8327051 , -3.8519228 ,  0.20764759,  5.230716  , -4.0857396 ,
#          3.5066392 , -2.1679883 ,  0.7630694 , -0.52730286,  2.492166  ,
#          2.5966482 , -0.46099982, -0.86644214, -0.3774435 ,  2.0653355 ,
#          3.2841468 , -1.7101073 ,  4.7055025 , -1.066778  , -2.8566139 ],
#        dtype=float32),
#  'से': array([-0.9076704 ,  2.9957955 ,  4.8754964 ,  1.5531266 ,  1.176642  ,
#         -1.573969  ,  7.182844  ,  3.1409798 , -0.52355206,  0.89171416,
#         -1.1805612 , -0.01912663, -1.8688109 , -0.5920736 , -0.50654614,
#          5.7369742 ,  3.9999626 ,  3.2645288 ,  3.0592446 , -1.454291  ,
#          0.8641815 ,  0.0468661 ,  0.67253286, -3.188594  ,  0.8459225 ,
#          1.6793514 ,  0.95869005, -3.0285811 , -1.544138  ,  1.7664748 ,
#          7.1440163 , -3.8312192 , -5.161435  ,  2.544789  , -4.2718887 ,
#          2.0052714 , -1.1751046 , -1.1042498 ,  0.64017797,  5.5123386 ,
#          3.043473  , -5.8672028 , -1.7505373 ,  0.26276758,  0.30638853,
#          0.05471061,  2.639764  , -0.6493419 ,  0.60485506, -0.01350238,
#          0.39729574, -1.2573605 ,  2.4211829 ,  0.64763737,  0.05293939,
#         -0.9055724 ,  4.6501627 , -1.6206013 , -2.464116  , -6.5292654 ,
#         -0.45668924,  0.51592153,  1.9098743 , -0.33107942, -0.02092323,
#         -2.2517061 , -0.28390628,  1.1746832 ,  0.9842206 , -0.9875341 ,
#          1.6926306 , -0.36104736,  1.684292  ,  3.7666347 , -2.1948774 ,
#          4.2984166 , -4.2980523 , -0.31373805, -1.6159546 ,  1.2938138 ,
#          0.69143724, -1.0932491 ,  0.26378015, -0.07319805, -2.903001  ,
#          0.19748995, -3.3018217 , -1.8516338 ,  1.376     ,  2.173343  ,
#         -0.75478256, -4.4388623 ,  5.399537  , -2.5401325 ,  0.36013997,
#         -4.1173906 ,  3.023371  ,  5.17825   , -5.3658547 , -2.623775  ],
#        dtype=float32),
#  'हुए': array([-1.7249821 ,  2.7536154 ,  5.5933156 ,  1.0516943 ,  8.363424  ,
#         -0.9232913 ,  2.5347872 ,  2.425045  ,  3.4716063 , -4.4248147 ,
#         -2.3723083 ,  7.2844844 , -1.3437288 , -0.8149865 ,  0.7243118 ,
#          3.3089108 ,  5.4873834 ,  2.674696  , -3.9147694 , -2.4696143 ,
#          7.6769967 , -2.0049572 , -3.4829612 ,  4.7068086 ,  3.551263  ,
#          1.6311234 , -2.6237974 , -1.1449714 ,  0.28888297, -4.7056437 ,
#          5.4523635 ,  3.1000886 , -1.7514709 ,  3.559183  ,  2.671123  ,
#          1.9492832 , -6.020952  ,  2.9668381 , -1.3349988 , -0.47872776,
#          3.2534525 , -6.250664  , -1.6124318 , -2.259584  , -3.2567406 ,
#         -2.09385   ,  4.034261  , -5.8874636 , -3.4223561 ,  1.6958008 ,
#          4.8675456 ,  3.9273355 , -0.9595066 ,  3.4797366 , -0.51994246,
#         -1.5167619 ,  2.3460453 , -4.2217617 ,  0.8169729 ,  6.130201  ,
#          2.5621715 , -0.68176836,  4.4354873 ,  2.5465868 ,  1.1643075 ,
#          7.3820906 ,  1.9901502 ,  3.4265778 ,  1.2169733 , -3.697937  ,
#         -2.9735115 ,  2.3490648 , -1.471583  ,  3.8303068 , -5.3021536 ,
#          6.346936  ,  3.8519742 , -2.9973273 , -0.93451935,  4.2253275 ,
#          2.5049703 ,  4.6702523 ,  1.3233287 , -7.8626866 ,  2.4987135 ,
#          3.3270898 , -1.8653255 ,  0.74764943, -1.2247143 ,  0.570474  ,
#          0.29725787,  0.8075905 , -0.7230686 ,  2.8941689 , -8.35033   ,
#          3.741777  ,  2.048117  ,  5.2972856 , -3.911778  , -4.0043654 ],
#        dtype=float32),
#  'काले': array([ 0.62299854,  1.6472456 , -0.14279729,  3.616037  ,  3.287076  ,
#         -2.8845708 , -0.71374804,  0.6842751 ,  0.4136105 , -0.07287993,
#          3.054851  ,  1.1686335 , -0.25317332, -2.8425071 , -1.9651222 ,
#         -1.4139941 , -0.3883423 ,  0.31900603,  1.089467  ,  0.18168832,
#         -2.5796282 , -1.9740456 , -0.6175144 ,  3.0250618 ,  0.77892154,
#         -2.728492  , -1.9972181 , -0.04853112, -0.7479385 , -0.21627083,
#          3.6126957 , -2.3709555 , -4.6585436 ,  1.7261304 ,  0.10086463,
#         -1.1725385 , -1.7138782 ,  2.7163708 , -3.8714504 ,  0.49556473,
#         -0.9115752 , -1.7954972 , -0.18179181,  1.3290771 , -4.2420416 ,
#         -0.49125537,  0.8787554 ,  0.04296876, -3.86932   ,  3.200616  ,
#         -1.3113961 , -0.50662065,  1.9836704 , -0.16535726,  0.5530589 ,
#          0.53719014,  1.2619712 , -4.9509106 , -3.607614  , -2.0586832 ,
#         -0.2198431 ,  4.617565  ,  2.400038  , -4.0963497 , -2.210736  ,
#         -0.21868189, -0.6587725 ,  2.1105883 ,  2.157249  ,  4.922259  ,
#         -0.7302713 , -3.575711  , -0.1829889 ,  1.7777667 ,  0.38868943,
#          0.29587507,  0.6008729 ,  2.8647246 , -3.5942945 ,  1.1611472 ,
#          0.2838244 ,  0.08950096, -3.5728192 ,  0.9197888 ,  1.4069021 ,
#         -0.45597717,  0.21087421,  2.1078134 ,  1.3903015 ,  3.0656157 ,
#         -0.5525135 ,  2.9132273 ,  1.8072004 ,  1.098331  , -2.9316275 ,
#          0.849367  , -0.4959352 ,  0.6894923 , -0.06606321,  2.033233  ],
#        dtype=float32),
#  'काला': array([ 2.617316  ,  0.80413246,  0.7902217 ,  4.6223774 ,  1.2819633 ,
#         -3.415465  , -2.3291206 ,  1.5416332 ,  0.0820369 ,  1.978058  ,
#          3.2561665 , -0.5973636 ,  1.2207198 , -0.31171256,  0.3580039 ,
#         -0.87925553,  0.6344019 , -2.968179  , -0.503575  ,  2.0814488 ,
#         -4.1887727 , -1.2434678 , -1.0645602 ,  1.3235055 , -2.0700412 ,
#         -1.6271645 , -4.019828  , -0.5703258 , -2.472389  ,  1.2820251 ,
#          3.2044547 , -4.2557273 , -2.5513694 ,  1.9757829 ,  2.0183976 ,
#         -0.45161745, -2.6699924 ,  1.8117595 , -2.5011957 , -0.23559439,
#         -1.8532866 ,  0.41931948, -0.9213617 ,  0.39856   , -1.2088903 ,
#          0.6041346 , -2.1105952 ,  0.73732346, -3.24703   ,  1.5474583 ,
#         -0.8367208 ,  0.27533257, -1.4384087 , -1.5435134 , -0.68401724,
#         -2.2667317 ,  2.7076619 , -3.1796834 , -3.2835987 , -2.9777138 ,
#         -2.8258002 ,  2.926318  ,  0.8502807 , -4.936093  ,  1.4300458 ,
#          0.73649323, -1.6783497 ,  0.5208774 ,  0.49028823,  2.9370718 ,
#         -0.62271714, -3.760926  , -2.4122365 ,  1.4350631 ,  1.2906398 ,
#         -0.16229951,  1.4128702 ,  3.6861966 , -2.5388284 ,  1.7187601 ,
#         -0.6486026 , -1.396771  , -4.157122  ,  1.6402462 , -0.11817835,
#         -0.4789409 ,  0.13074094,  3.7052836 ,  0.09011677,  2.1264248 ,
#         -1.112649  ,  1.5939416 ,  1.7394211 ,  0.42382604, -1.2461753 ,
#          2.3101504 , -2.9066923 , -0.87249964, -2.0014567 ,  2.149115  ],
#        dtype=float32),
#  'ट्रेन': array([ 4.3405333 ,  3.064651  ,  3.1101587 , -1.9388924 , -1.3881924 ,
#          1.7970842 , -0.8638153 ,  1.1357085 ,  3.063268  , -2.2684793 ,
#          1.6180272 , -0.22611892, -0.38952973, -4.4359117 ,  4.860675  ,
#          4.538285  , -3.4868407 ,  0.37690508,  3.9122896 ,  0.82313466,
#          1.3733274 ,  4.0843997 , -5.1857433 ,  0.14081097,  0.40157688,
#          2.8737485 ,  3.6924093 ,  4.358993  ,  1.7257307 ,  1.5661716 ,
#          1.1477594 , -0.39669657, -3.847696  , -1.2635747 , -3.5696704 ,
#          1.9728497 ,  2.3094885 , -4.673531  ,  0.5862878 , -2.6535976 ,
#          4.106119  , -2.5531878 , -5.6429963 ,  0.8917149 ,  2.435968  ,
#          0.51520824,  1.8942668 , -1.9412959 , -1.856411  , -1.6855837 ,
#          2.3806062 ,  2.155467  ,  3.5183692 ,  2.4122136 , -1.0659432 ,
#          0.67727584,  1.1839681 ,  4.672578  ,  0.09061049, -1.2768909 ,
#          3.2815013 , -0.3824657 ,  5.7342596 ,  0.6392673 ,  1.8780636 ,
#          4.117282  , -0.8168237 , -2.009784  ,  0.28770998, -3.55626   ,
#         -1.5175362 ,  3.4502447 ,  0.6491283 , -5.2860446 , -4.51862   ,
#          1.1469167 , -3.01529   , -1.7508653 , -2.8591785 ,  0.25332704,
#          1.5429901 , -5.469468  ,  3.927553  ,  1.2754699 , -0.20172285,
#          2.0433311 , -3.9793909 ,  3.8933797 ,  0.39331564,  5.248954  ,
#          2.8381326 , -1.0043765 , -1.9955852 , -0.5861142 ,  2.8637998 ,
#          0.43108812, -3.5295525 ,  1.5669518 ,  5.177309  , -5.2018185 ],
#        dtype=float32),
#  'दीवार': array([ 0.5980918 , -1.062589  , -0.12272928,  1.891705  ,  2.1197348 ,
#         -0.7791947 ,  1.0880264 ,  2.179595  ,  1.3061856 , -3.5482697 ,
#          0.07284295,  1.8957039 , -2.200534  , -0.28405923, -3.4210742 ,
#          1.747295  , -1.746499  , -0.4536716 ,  1.0219011 , -2.275232  ,
#         -4.0846205 ,  1.2827599 , -5.427572  , -0.61380947,  3.7538183 ,
#          1.6429149 ,  0.19433257, -3.7393591 , -2.6893978 ,  0.31980646,
#          1.7095524 , -4.925068  , -5.1700087 ,  1.3704374 , -0.6910427 ,
#         -4.696767  ,  0.5425313 ,  0.8428292 , -2.8136454 ,  0.23569047,
#          2.8343117 ,  0.12479665, -2.5229466 ,  1.0529683 , -1.8117651 ,
#          1.2092144 ,  1.2338824 , -0.873902  , -4.0034013 , -1.2196331 ,
#         -0.70042986,  1.4604708 ,  1.0462692 ,  0.2653725 , -0.46362752,
#         -0.15955094,  3.769515  ,  4.6036444 , -0.86533064, -1.9879426 ,
#          1.9578669 ,  0.52510333,  3.6452017 , -4.358468  ,  1.4127406 ,
#         -0.12347483,  0.47253078, -2.4247088 ,  2.4314272 , -2.1170714 ,
#         -1.9058009 ,  4.689957  ,  1.5600487 , -1.0379518 , -4.3690753 ,
#         -1.3980975 , -0.5452992 ,  3.3344803 , -4.160821  ,  0.98136693,
#          1.2622207 ,  2.144744  ,  1.2066    ,  2.037455  , -2.8132987 ,
#         -2.0826776 ,  5.4060287 ,  0.7011478 ,  0.18270703, -0.91578436,
#          0.92502016,  2.8014581 , -1.1688665 , -3.043787  ,  0.41149485,
#          4.203467  , -1.9674801 ,  3.9161265 ,  0.3081637 , -1.1553551 ],
#        dtype=float32),
#  'पानी': array([ 1.7364832 , -2.3014421 , -1.5272459 , -0.09427347, -2.802177  ,
#         -1.6209843 ,  1.8691852 ,  3.8819244 ,  2.2171824 ,  0.21718006,
#          3.7154913 ,  3.9091015 ,  4.2363544 , -2.3754504 ,  1.6943697 ,
#         -0.49839333,  3.324021  , -1.0076429 ,  5.7503905 , -0.95233494,
#         -3.2055364 ,  0.05196124,  3.4580498 ,  0.04500976,  0.19656494,
#         -0.44445094,  1.8032346 ,  0.0363606 , -0.81971085,  2.37149   ,
#          8.157783  , -3.2844481 , -7.4275594 ,  3.0072064 , -5.179762  ,
#         -2.1815953 , -1.397625  ,  1.6128145 ,  2.430406  , -2.1083927 ,
#          2.3687432 ,  0.9583008 , -8.837937  , -1.3672438 ,  2.0936036 ,
#         -1.0220495 , -1.2763189 ,  0.5955425 ,  1.3524014 ,  8.365625  ,
#         -1.1821725 , -0.66787744, -0.9275118 , -0.89481115, -3.2899745 ,
#         -1.9410902 ,  3.8141806 ,  1.5131682 , -1.0693405 , -4.604339  ,
#          1.0100361 ,  3.4093318 , -0.5011522 , -2.987537  ,  1.9183733 ,
#          1.775135  , -0.78518283,  1.2693293 ,  1.8761239 , -1.1660355 ,
#         -9.242144  ,  3.7012794 ,  2.7764206 , -4.249006  ,  1.2913314 ,
#          6.2162776 ,  2.825308  ,  3.2409687 , -2.5503268 , -1.2995023 ,
#          0.0891363 ,  0.7901979 ,  2.3760002 ,  0.20250368, -2.639507  ,
#          0.28717962, -3.332212  , -1.0707821 ,  1.7897052 ,  4.3659344 ,
#         -0.96393067, -2.7588532 , -2.399083  ,  0.05875054,  4.3293047 ,
#          5.320422  ,  0.03974545, -0.04595603, -4.5054293 , -3.1005607 ],
#        dtype=float32),
#  'पहने': array([ 1.5013239 ,  1.8960814 ,  1.0044401 ,  2.7084403 ,  2.9862478 ,
#         -6.109399  , -1.9070487 , -4.207056  , -0.833596  , -2.3457112 ,
#          5.923235  ,  1.3914411 ,  0.04828779, -2.687076  ,  1.545336  ,
#          0.10457192, -0.34508625,  2.9111583 ,  2.1413004 ,  2.9204035 ,
#         -1.9904422 , -3.459304  , -2.7609267 ,  0.8442783 , -1.7979734 ,
#         -2.0528772 , -1.6316748 ,  2.888114  , -1.5032144 ,  0.88438666,
#          2.2257178 , -0.5011965 , -3.564204  , -4.7147274 ,  0.36853313,
#         -0.5535976 ,  2.4630094 , -1.5751675 , -4.400499  ,  2.4078333 ,
#         -1.2829821 , -1.3875831 ,  3.8315814 ,  6.527944  , -1.628626  ,
#         -1.9875767 , -0.9023486 ,  2.892151  , -1.0909264 , -1.3733985 ,
#         -2.9704063 , -0.9780625 ,  5.517213  ,  0.5416057 , -3.9107208 ,
#          1.9434329 ,  3.5931447 ,  0.3043826 , -2.7984717 , -2.9364946 ,
#          0.1194958 ,  2.077909  ,  1.3434494 , -3.6840324 ,  3.4598641 ,
#         -1.9614314 ,  2.6656692 , -0.5116923 ,  2.917612  ,  4.2589645 ,
#          1.0937779 ,  0.71591794,  2.318716  , -2.0716155 , -1.2388158 ,
#         -0.528531  , -3.7703853 ,  0.46065834, -4.6953955 ,  2.8801446 ,
#          2.3133838 , -0.3798742 ,  0.9325898 , -1.002891  ,  4.047773  ,
#         -1.4679341 , -3.457642  ,  5.338127  ,  3.1395648 ,  3.1688836 ,
#         -1.5603927 ,  3.5031226 ,  2.2739193 , -1.5735418 ,  5.2893257 ,
#          3.0663605 , -2.0074189 ,  2.4498594 , -0.47014225,  3.190259  ],
#        dtype=float32),
#  'आकाश': array([ 0.21356176, -1.156883  ,  0.33083794, -1.3550112 ,  3.8728619 ,
#          0.34109265, -1.3077117 ,  5.6515403 ,  3.6321645 ,  1.1014912 ,
#         -2.5250354 ,  2.6739264 ,  3.583457  ,  0.10540946, -2.3357782 ,
#         -1.0579097 , -2.591658  , -1.0269843 ,  0.6911041 , -0.8227    ,
#          0.2003089 , -0.4033313 , -2.066888  , -2.5609782 , -4.012328  ,
#         -0.17051706,  1.9663174 , -1.4822595 ,  0.42018288, -1.0196861 ,
#          5.9773264 , -3.5580933 , -3.4516    ,  3.2829547 ,  0.60549605,
#         -1.5391674 , -0.7027464 , -0.26584408,  0.64912105,  3.0163481 ,
#          1.209534  ,  1.0626082 , -1.9423788 , -0.4156869 , -0.57582873,
#         -0.92317086, -0.5651882 , -1.9541218 , -1.7597449 , -0.49606773,
#          0.6104687 , -1.5413069 , -0.7672917 , -0.5351881 , -1.4625218 ,
#          0.7090559 ,  1.0601043 , -0.49491853, -0.02172711, -1.9704534 ,
#         -1.5091583 , -0.6340235 ,  2.5419405 , -2.9814773 ,  1.146087  ,
#          3.1218734 , -0.01909576, -3.9242053 ,  4.6252227 , -0.24053417,
#         -3.4496253 , -1.0664465 ,  0.4527536 , -3.0526366 , -0.64708555,
#          2.8090415 , -1.2825284 ,  2.2207417 , -2.7257721 ,  0.14214219,
#         -0.6898354 ,  2.682083  , -0.46732825,  1.1174792 ,  5.1501822 ,
#         -1.0116892 ,  1.403277  ,  0.21998301,  3.6610584 ,  5.0949845 ,
#         -2.943996  , -3.4211035 ,  0.8867604 , -0.10048696, -1.8823851 ,
#          0.38878632, -0.68295366,  0.85056525, -1.4003787 , -1.3448685 ],
#        dtype=float32),
#  'नीला': array([ 1.7665005 ,  1.2663028 ,  0.58525294, -0.21035463,  2.098895  ,
#         -2.0606923 , -2.9860032 ,  4.3574243 , -0.2756076 ,  1.1028222 ,
#          1.9180231 ,  1.8413806 ,  1.2541295 ,  1.1256337 ,  0.2808022 ,
#         -0.2668175 , -1.0269092 ,  0.55990654,  1.743114  ,  1.8183362 ,
#         -1.7645229 ,  0.36163858, -0.3491824 ,  0.7254293 , -3.2037446 ,
#         -2.3830225 , -2.8824506 , -2.594397  , -2.657095  , -0.91646063,
#          3.728347  , -4.708219  , -1.9737102 ,  2.5889692 ,  1.5806342 ,
#         -1.3861556 , -0.17721458,  2.1814592 , -1.4031457 ,  1.4476737 ,
#         -0.95537573,  1.2583002 , -0.13374527,  1.4002959 ,  0.6633912 ,
#          0.14224897, -4.0042615 , -0.95574874, -1.5204412 , -0.20887233,
#         -1.1307417 , -0.5485489 , -2.3667371 , -1.5237905 , -3.02027   ,
#         -2.157036  ,  4.565162  , -2.6618364 , -0.7199806 , -2.290009  ,
#         -1.3324753 , -2.7771535 ,  2.061369  , -2.4804275 ,  1.528757  ,
#          2.231149  ,  0.39734495, -0.6067597 ,  1.9991325 ,  0.98908186,
#         -2.0091538 , -1.8651881 ,  0.08440843, -0.25051054,  0.40037432,
#          0.77582717,  1.9886506 ,  2.3731089 , -4.0103216 ,  1.0726445 ,
#          0.63455516, -0.8976831 , -2.2289279 , -0.17891021,  1.7301724 ,
#         -2.3340242 ,  0.5685251 ,  1.796885  ,  0.8701281 ,  3.344342  ,
#         -1.5621951 ,  1.0357106 ,  3.655398  , -0.09073924, -0.5426469 ,
#         -0.7117171 , -0.9451636 ,  2.666372  , -0.5976599 ,  0.42476094],
#        dtype=float32),
#  'टेनिस': array([ 8.77497792e-01,  3.11130822e-01, -2.93550920e+00, -2.09663391e+00,
#          3.61656594e+00, -2.09143972e+00,  6.71639681e-01, -2.11958027e+00,
#          6.39374182e-02,  3.44578505e+00,  5.77118814e-01, -3.57659268e+00,
#         -1.97515726e-01, -4.83284521e+00, -3.59430146e+00,  2.81526995e+00,
#         -3.80322069e-01,  1.75768650e+00, -1.40817440e+00, -2.39884353e+00,
#         -3.23825061e-01,  3.66066480e+00, -2.32782102e+00,  1.64263177e+00,
#          3.40526581e+00,  7.38382161e-01, -2.21720457e+00,  3.75736856e+00,
#         -6.79854810e-01,  2.20938706e+00, -6.02107167e-01, -1.07090935e-01,
#         -2.44230580e+00, -3.99712896e+00, -2.07354617e+00, -9.40112829e-01,
#         -5.68964243e-01, -2.61062169e+00, -5.44835806e+00,  2.87375808e+00,
#          2.19194248e-01,  1.10144258e+00, -4.12500191e+00,  7.37402380e-01,
#          4.75775093e-01, -4.06717920e+00,  2.94649386e+00, -2.50015998e+00,
#         -5.53392231e-01, -2.74855685e+00, -4.02057219e+00, -6.22294322e-02,
#          3.79902273e-01, -2.29715991e+00,  5.81779540e-01,  1.20131707e+00,
#          2.68469882e+00,  9.27364588e-01,  1.54665613e+00,  3.03708649e+00,
#         -2.81944966e+00, -9.12872255e-01,  1.36927021e+00,  1.68200278e+00,
#         -3.50154668e-01,  2.54398346e+00,  3.20946169e+00,  2.10603535e-01,
#         -2.84679621e-01, -1.77707827e+00,  2.67879176e+00, -3.52274323e+00,
# ...
#          6.1754966e-01,  1.0725585e+00, -2.2368026e+00, -3.2729998e+00,
#          1.2128949e+00, -1.3615781e+00,  1.6120269e+00,  7.6761949e-01,
#          1.7145286e+00, -4.3186030e-01, -1.0290973e+00, -3.2274061e-01,
#         -2.3383517e+00, -6.2300009e-01, -2.9753687e+00, -3.0367310e+00,
#         -2.3214030e+00,  1.4572341e+00, -1.9828087e+00,  4.7119576e-01],
#        dtype=float32),
#  'बाहरी': array([-2.3371005e+00,  1.4619280e+00,  1.2177459e+00, -3.9665375e+00,
#          1.6071389e+00, -2.9541006e+00,  2.3625913e+00,  3.2507799e+00,
#         -7.4064088e-01,  8.0372721e-01,  1.1804502e+00,  1.8227667e-01,
#         -1.3777026e+00, -1.0327970e+00, -7.0591229e-01, -2.7851748e+00,
#          9.2976052e-01,  1.0561513e+00,  3.6236482e+00,  7.7861524e-01,
#          4.9724588e-01, -1.8900001e+00, -6.8258530e-01, -7.3799473e-01,
#          1.6216736e+00, -2.4337854e+00, -2.7425429e-01, -1.5959257e-01,
#         -3.1675630e+00, -2.6364464e-01,  2.2699699e+00, -3.7768440e+00,
#         -3.8572459e+00,  3.1051922e-01, -2.2934630e+00,  1.0090710e+00,
#         -1.7631756e-01,  4.1412765e-01, -7.7439561e+00,  2.9745071e+00,
#         -9.6034436e-03, -8.6329263e-01, -9.7758543e-01, -8.5448635e-01,
#         -3.1900708e-02,  3.2605793e+00,  1.3817456e+00, -2.3481588e+00,
#         -1.2869089e+00,  8.5053664e-01, -2.1487672e-03, -1.7722664e+00,
#          1.9365935e+00,  1.6343234e-01,  2.1257500e-01, -4.1086200e-01,
#          2.2722130e+00, -1.7903320e+00,  1.4581773e+00,  5.5084825e-01,
#          2.0755262e+00,  2.9195935e-02, -1.5105816e+00,  9.1385424e-01,
#         -2.7462592e+00, -3.4958212e+00, -3.8559406e+00, -3.4900994e+00,
#          3.1855989e-02,  2.0997462e+00, -1.3847742e+00,  1.1691892e+00,
#         -1.7494047e+00,  8.0168468e-01, -8.2170570e-01, -1.3499609e-01,
#         -2.3401923e-01, -1.0036621e+00, -1.8493134e+00, -1.0341346e+00,
#          9.4186389e-01, -9.8659563e-01, -4.4914261e-01,  3.4202709e+00,
#         -1.9268991e+00,  1.4125672e-01,  2.0295103e+00, -1.6176530e+00,
#          1.9338720e+00,  4.6806481e-01, -2.1797714e-01,  7.5693138e-02,
#         -2.5335616e-01,  4.4374318e+00, -3.5090208e-01,  1.0522393e+00,
#          1.2234006e+00, -1.0020254e-01, -2.6612358e+00,  7.6673239e-01],
#        dtype=float32),
#  'ट्रिम': array([-2.071891  , -0.66310936, -1.3073572 , -0.5714758 , -0.72318184,
#         -1.7258908 , -1.4879661 ,  1.4423122 , -2.1497645 ,  0.25999635,
#          2.3171456 ,  1.3092277 , -1.5926043 , -3.2102988 ,  1.4852517 ,
#          2.4289207 , -1.8148499 ,  0.79611963,  2.8145385 ,  0.11087565,
#         -0.7365988 , -1.2510134 , -0.58958036,  0.11774085,  0.80905324,
#         -1.5625085 , -1.3151668 ,  0.42573917,  0.7938394 ,  0.8896977 ,
#          0.3725914 ,  0.30135944, -3.2854605 , -0.60561055, -1.1024973 ,
#          0.02900967,  1.4405669 ,  1.7893873 , -2.7212117 , -0.35367984,
#         -0.53800464, -0.16257106, -0.92399246,  0.4545218 ,  1.6114041 ,
#         -0.40619   , -1.048755  ,  1.3429387 , -2.0830173 , -0.90922505,
#         -2.3019714 ,  1.00136   ,  1.6437385 , -0.7475444 , -1.1264617 ,
#         -0.46547046,  4.5464225 , -1.4044181 ,  0.80273396, -1.0474797 ,
#         -0.8015957 , -1.6047995 ,  2.611863  , -2.2821636 , -0.816952  ,
#         -0.5509302 ,  1.5342783 ,  0.52120036,  0.10960356, -1.1028733 ,
#         -0.8178969 , -0.60348403,  0.7674318 ,  1.786327  , -0.02886179,
#          1.8808719 , -0.75864613,  0.49972337, -2.4969687 ,  1.4700174 ,
#          2.0795968 ,  1.1833843 , -0.33630565,  0.085189  , -1.8418802 ,
#         -0.28590968, -0.10767824, -1.215167  , -0.3580219 , -0.96966255,
#          0.2940185 ,  0.98821175,  0.6375817 , -0.2508855 , -0.14512242,
#          0.7816807 ,  1.7405744 ,  0.31364724,  1.0091571 ,  1.6877842 ],
#        dtype=float32),
#  'पत्तियां': array([ 1.4469668e+00,  7.3104806e-02, -7.0566934e-01,  4.4562134e-01,
#         -4.3650231e-01, -2.1445024e+00, -5.5272359e-01,  3.5200233e+00,
#         -1.4666442e+00,  1.2816025e+00,  2.9477301e+00,  2.3710914e+00,
#         -2.0784423e+00,  2.7744124e+00, -5.5276394e+00,  2.6740093e+00,
#         -2.3929806e-01,  3.1121871e+00, -8.8433141e-01, -3.0461097e+00,
#         -4.7321849e+00,  1.6039045e+00,  9.2703760e-01,  7.3678869e-01,
#          6.8176663e-01, -2.4391594e+00, -1.8084328e-01,  2.2216411e+00,
#          2.0127325e+00,  4.7610772e-01,  3.9889293e+00, -5.9073739e+00,
#         -5.9019151e+00,  2.1008551e+00, -4.6942154e-01,  5.4079533e-01,
#          5.6214148e-01,  1.6924537e+00,  3.5574293e+00,  1.6522430e+00,
#          3.4760542e+00, -1.2208505e+00, -1.7312711e+00,  3.3065333e+00,
#         -3.9231300e+00, -2.6731844e+00, -2.1359236e+00,  1.7231575e+00,
#          1.2094277e-01,  4.2468619e+00, -1.0208955e+00,  4.0280488e-03,
#          8.9009738e-01,  1.4558342e+00, -1.7661989e+00,  2.3982884e-01,
#          4.9162531e+00,  7.7901816e-01,  2.8165126e-01, -3.2332242e-01,
#         -2.5507310e-01, -6.0519612e-01,  2.7634901e-01, -1.2262771e+00,
#         -5.5785056e-02, -1.0130805e+00, -4.5697573e-01,  7.6557386e-01,
#         -1.6061498e-01, -2.9291921e+00, -2.4378393e+00,  1.7245452e+00,
#          1.2957158e+00, -2.3953643e-01, -3.1876457e+00,  3.6235526e+00,
#          5.0525373e-01,  2.9343941e+00, -2.2939763e+00,  1.1760732e+00,
#          6.0294223e-01,  1.0848370e+00,  2.3477483e+00, -4.2543507e-01,
#         -2.4435635e+00, -9.7029090e-01,  1.6812216e+00,  9.0295601e-01,
#         -2.8015296e+00, -8.3453141e-02,  2.9052157e+00, -2.8393784e-01,
#         -2.1089518e-02, -7.8966141e-01,  2.0992460e+00, -1.2072902e+00,
#          5.1472205e-01,  4.1786928e+00, -2.4733081e+00,  1.2762414e+00],
#        dtype=float32),
#  'पदार्थ': array([ 3.2060697 ,  0.07112441,  0.7182482 , -2.5438404 , -0.27519488,
#         -1.224278  ,  1.9208635 ,  0.36763063, -0.47420815, -1.8919568 ,
#         -2.3616395 ,  0.7620483 , -2.0379856 ,  1.0633337 , -0.8705132 ,
#          2.590012  ,  1.9783864 , -0.9946499 ,  3.8132327 , -3.115351  ,
#         -4.8798213 , -4.845978  ,  3.9077294 , -2.8412838 , -2.9502134 ,
#         -1.3330692 ,  0.70970815,  0.38706788, -0.20226109, -4.8276563 ,
#          3.3609734 , -7.491511  , -4.8944826 , -3.008992  , -1.5314842 ,
#         -0.7887822 , -5.382891  ,  2.1779969 , -2.0118434 , -1.1449271 ,
#          3.3134556 , -0.911183  , -3.8058927 ,  3.2531655 , -3.2135682 ,
#         -5.3606496 , -3.6147625 ,  1.5862191 ,  1.4990067 ,  3.2834332 ,
#          0.2793098 , -2.534118  ,  5.465645  , -0.19580962, -2.6177967 ,
#         -1.4406167 ,  6.8377    , -1.4627897 , -3.1863334 , -0.47988534,
#         -1.861398  , -0.3304078 , -0.68309975,  1.7207674 ,  2.7990065 ,
#         -0.7543402 , -0.8422396 ,  0.06370518,  1.6012145 , -1.5860527 ,
#         -5.2657456 ,  3.8246999 , -1.7535312 , -2.7178595 ,  0.58946294,
#          1.3363521 ,  4.3126373 , -2.886909  , -2.6332326 ,  2.0952795 ,
#          0.8538505 ,  2.0335429 , -2.4990523 , -3.638711  , -1.3223069 ,
#         -4.7855077 ,  0.5532779 , -1.360022  , -0.07086359,  3.4923408 ,
#          0.8837128 , -8.313735  , -0.7669905 ,  2.68366   , -2.9158566 ,
#         -0.8202017 ,  2.3138928 , -2.8354156 , -2.118726  , -3.1274931 ],
#        dtype=float32),
#  'गिर': array([-3.8691292 , -2.8120754 , -2.6470752 ,  5.7055235 , -0.24911156,
#         -0.31455275,  0.4830003 , -0.02697154,  5.9731374 ,  3.4256377 ,
#          0.5614387 ,  1.6004627 ,  2.646344  ,  0.50127727,  1.8845452 ,
#         -1.5169035 , -2.2032287 , -1.0619413 ,  5.758079  , -2.614296  ,
#         -0.58410066, -1.0719653 , -4.191632  , -1.0764498 ,  0.88713336,
#         -2.8850873 , -1.4024793 ,  4.3424697 , -2.1738966 ,  3.4016278 ,
#          2.2364528 ,  0.5930397 ,  1.6911377 ,  3.8736856 ,  5.590355  ,
#         -0.48400748,  2.3589256 , -5.4655786 ,  0.8656242 , -6.376199  ,
#          2.0814102 ,  2.6833177 , -5.3452315 , -0.2917931 , -2.8894544 ,
#         -2.200398  , -0.30371842, -1.1191174 , -0.78540903,  2.9169621 ,
#         -4.92039   ,  1.6554083 ,  2.977519  ,  0.24780396, -2.440032  ,
#         -3.1759887 ,  2.236049  , -3.961285  , -0.5026878 , -6.6260867 ,
#          2.5613601 ,  4.047723  ,  0.16650523, -6.027468  ,  4.710467  ,
#          1.0180223 , -1.7548465 , -4.357078  ,  6.2700825 ,  2.1156728 ,
#         -0.8992703 ,  5.6740003 , -3.9383764 , -1.0337129 , -0.49863106,
#         -0.12445754, -2.1850822 ,  2.9429312 , -0.11001848,  3.0561297 ,
#          3.6995277 ,  1.4655583 , -2.204653  ,  4.9086905 , -3.9392757 ,
#         -3.44732   ,  0.39407188,  1.0045727 , -0.48978   ,  0.86274165,
#         -3.6492748 ,  2.2651658 , -2.1542404 , -0.7245671 ,  7.2319636 ,
#         -3.812454  ,  0.50464106,  8.836715  , -1.3917435 , -1.790422  ],
#        dtype=float32),
#  'मामला': array([ 1.4896024 ,  0.7447372 , -0.30120417,  0.5513961 , -3.316826  ,
#          5.021417  , -0.24083798, -2.1797116 , -1.6124623 ,  0.21305601,
#          3.0922868 , -0.58182335,  1.5012177 , -3.8323038 , -0.2349076 ,
#         -1.0546868 ,  5.950843  , -4.731315  ,  0.84330314, -5.3930335 ,
#         -1.0629824 ,  0.77144724, -0.9004783 , -1.0661871 , -0.7350328 ,
#          3.6287804 ,  1.8743997 ,  0.2097998 , -2.8136268 ,  2.0351899 ,
#         -2.396405  , -6.1875076 ,  5.304064  , -0.68222684, -3.3418815 ,
#          1.5762556 , -2.8134172 , -0.6443919 , -0.13885912, -3.5363817 ,
#         -1.6679024 ,  0.7520096 , -5.114896  , -1.0391775 , -0.09225838,
#          1.282521  , -0.8258279 ,  2.4259522 ,  0.8223609 ,  0.74854857,
#          4.0196476 ,  1.4925313 ,  0.5452971 , -2.2718794 ,  3.0027437 ,
#          1.0456383 ,  2.6824803 ,  0.51403433, -6.1623516 , -3.1255636 ,
#         -1.080323  , -3.5475364 , -1.7157618 , -4.3154335 ,  0.4897335 ,
#          3.0026379 , -2.8470194 ,  1.7276905 ,  2.4885733 , -3.5949554 ,
#          3.6734695 , -2.1628013 , -7.80812   , -1.6501855 , -4.562498  ,
#         -2.0670724 ,  5.0417647 , -1.0738577 ,  0.3788301 ,  4.714266  ,
#         -1.6127099 , -5.056498  ,  3.6127417 , -0.88586694, -1.3900577 ,
#         -1.4619915 , -2.0699098 , -0.07429237,  1.8188736 ,  2.622045  ,
#         -2.2787433 ,  0.75415224,  3.5908287 , -0.08456846, -3.111921  ,
#          3.2618704 ,  0.56374145, -3.7521276 , -2.0560367 , -2.0872176 ],
#        dtype=float32),
#  'सैन्य': array([-1.9771438 , -0.980199  ,  2.7158747 , -4.6557593 , -2.3022044 ,
#          0.51149493,  0.7982937 , -2.7985003 , -0.1986393 , -1.5734838 ,
#         -0.10965467, -2.217953  ,  4.505212  , -1.8996998 ,  0.15077227,
#         -1.5216833 ,  1.4071251 ,  0.974494  ,  1.8970742 , -2.2631063 ,
#          0.5142041 , -4.9661574 ,  1.0726745 , -0.5242233 ,  2.5595696 ,
#         -0.88354796,  2.9490097 , -2.0150623 , -0.57221466,  0.20876332,
#         -5.8863525 ,  0.26810443, -5.3540783 ,  2.1800041 ,  0.9344172 ,
#          1.9510723 , -1.3431196 ,  1.160364  , -7.8620157 ,  3.6865077 ,
#          0.17764351, -5.3174114 , -0.2368257 , -1.5884074 , -0.23608974,
#          0.8680585 ,  5.1676383 , -3.3432648 , -4.244095  , -1.6161045 ,
#          3.4211318 , -4.56701   , -1.4744067 ,  1.0510544 , -1.7711978 ,
#          1.7435777 , -0.79472095,  0.9327642 ,  0.20103842, -0.73726207,
#          1.4218569 , -0.78329   ,  0.16391546,  3.0640476 , -4.1200576 ,
#          0.92984176, -4.17339   ,  3.3394864 , -1.1980032 ,  0.62891   ,
#          0.57289326,  3.4693782 , -0.78866416,  4.0463862 ,  1.3700746 ,
#         -2.7767725 , -1.7029577 , -4.1283736 , -1.2188286 ,  2.0422542 ,
#          1.0799191 , -2.7890086 , -3.102404  ,  0.64517754, -1.3215494 ,
#          0.8289926 , -0.99450076,  1.3773713 ,  5.06538   ,  0.98387575,
#          3.238496  ,  2.0500786 ,  0.9873964 ,  0.66071635, -2.0530503 ,
#         -0.22342005,  0.03054802,  1.63502   , -0.790844  ,  2.300539  ],
#        dtype=float32),
#  'सोडा': array([ 0.9520877 ,  0.30658033, -2.9982483 ,  1.373532  , -3.117285  ,
#         -2.100777  ,  0.64615726,  0.03107523, -1.1421307 ,  0.18077274,
#          1.7816066 ,  0.0499314 ,  0.9826443 , -2.3098664 ,  3.209497  ,
#          2.5440598 ,  3.127675  , -0.02649398,  1.7981253 , -0.1024495 ,
#         -2.9191055 , -0.46627778,  3.2137945 ,  1.6313093 ,  0.17671162,
#          1.2644219 , -1.6815505 ,  1.2709758 , -2.222561  , -0.19599213,
#          3.0412755 , -1.9673036 , -5.374071  , -0.36200288, -3.9903374 ,
#         -1.5681454 , -2.3808575 ,  2.078791  , -0.3593456 , -3.7204006 ,
#         -0.4562547 ,  0.17128009, -2.2463334 , -0.05162186,  1.424701  ,
#         -2.2438843 , -4.2536664 ,  0.5636845 , -0.392976  ,  1.0667651 ,
#         -1.4285494 , -1.0659844 ,  0.4991358 ,  0.7669736 , -0.45633823,
#         -0.78203326,  7.0101485 ,  2.3113933 ,  2.3712933 , -0.94345504,
#          0.18165502, -0.3625374 , -1.6833303 ,  0.06492298, -0.20593053,
#          2.1582425 ,  0.01101091,  1.1697216 , -1.0887703 , -1.6919643 ,
#         -3.9937558 ,  0.28863916,  0.43669736, -0.5908278 ,  1.7248971 ,
#          1.1277868 ,  2.323776  ,  0.628592  , -2.2256935 ,  0.8420766 ,
#          4.262999  , -0.08814134, -0.19324097, -2.568967  , -2.662797  ,
#          0.9951319 , -1.4414775 ,  1.6099534 , -1.1522707 , -1.4499936 ,
#          1.1745163 , -2.655849  , -0.48575196, -0.32704705,  0.6161673 ,
#         -0.88403165,  2.0805063 , -1.0239898 , -1.2462137 , -0.7192283 ],
#        dtype=float32),
#  'पहनें': array([-0.33918458,  1.9215784 , -1.261427  ,  1.0993335 ,  3.9311712 ,
#         -1.8114872 , -2.6670973 , -2.9701703 , -2.0376375 , -1.3885268 ,
#          6.1797514 ,  3.251923  , -4.3130074 , -2.1559677 , -0.9780252 ,
#          1.0020896 ,  1.7572445 ,  1.2194458 ,  3.0294147 ,  2.281873  ,
#         -2.3866906 ,  0.5143876 ,  0.29406488, -0.19656652, -3.0667408 ,
#         -4.284137  , -2.4330928 ,  1.5904907 , -1.4184672 ,  2.2157323 ,
#          1.0012277 ,  0.86709213, -4.653399  , -2.656222  , -0.67043066,
#          0.0502424 , -0.22026096,  0.71691364, -2.8150878 ,  1.8157616 ,
#         -0.4384628 ,  1.8518682 ,  0.2973369 ,  1.6587857 ,  2.388573  ,
#          0.34925196, -2.545002  ,  2.3218837 , -0.8893374 ,  0.19588193,
#         -3.3632371 , -1.8423904 ,  3.76727   ,  0.9061579 , -5.9811087 ,
#         -0.5471447 ,  4.384642  , -1.6136826 ,  0.29475456, -1.217791  ,
#         -0.32844573,  0.2627005 ,  2.436041  , -1.0776906 ,  0.35141587,
#          1.3168534 ,  0.9258277 ,  3.5939248 , -1.3911756 ,  0.39226073,
#         -2.3536043 , -1.7951175 , -0.98123944,  2.2979069 , -0.00989141,
#         -4.317901  , -3.5089478 , -2.11475   , -2.750025  ,  2.4676602 ,
#          2.4579027 , -0.2728436 ,  2.0085678 ,  1.3000079 ,  2.5713084 ,
#         -3.4360116 , -1.7021989 ,  0.5194072 ,  1.8353508 ,  0.6270286 ,
#         -1.1037757 , -0.06756812,  0.39391854, -0.57699656,  1.0725005 ,
#          1.0134995 , -1.1755494 ,  0.36864895,  1.8047984 ,  3.9796631 ],
#        dtype=float32),
#  'पुआल': array([-0.3146555 , -0.23329656, -0.16507801,  2.0079212 ,  0.69495213,
#         -1.9024736 ,  2.1518657 ,  0.33029288, -1.5597334 , -0.16501418,
#          1.6835233 ,  2.6212363 , -0.92886496, -0.72275275, -0.5203591 ,
#          1.8512726 , -2.464898  , -0.42186096,  3.0892198 , -0.27829352,
#         -2.7757275 , -2.502506  ,  0.79099035,  0.52778566,  0.85237694,
#         -0.8953044 ,  1.5997324 , -0.19310535, -2.042244  ,  0.5953077 ,
#         -0.48829192, -0.7102472 , -4.744565  ,  1.0928681 , -1.7438093 ,
#         -0.8427055 , -1.533529  ,  2.3976953 , -0.10847332, -0.7572896 ,
#          1.40455   ,  2.3784056 , -3.0703797 ,  0.36351812, -1.1924821 ,
#         -1.6587893 , -0.8783892 ,  1.8500843 , -2.718894  ,  2.6060376 ,
#         -0.70009965,  0.17388384,  1.9947242 ,  1.1856613 ,  0.04877815,
#         -0.8915838 ,  2.8551035 , -0.7608396 , -1.0901202 ,  0.5362925 ,
#         -0.8412531 ,  0.15334412,  1.0644733 ,  0.06802899, -0.11922994,
#         -0.9795342 ,  0.8018391 , -0.094846  ,  0.675352  , -2.1710017 ,
#         -3.3322952 ,  0.8195452 ,  2.0258663 , -0.22505865, -0.7666598 ,
#          2.705078  ,  1.2299477 ,  3.9316974 , -2.4367604 ,  1.7844067 ,
#         -0.91019744,  0.5394832 ,  1.8908281 ,  1.0603278 , -2.8324285 ,
#          1.2061125 ,  3.9602783 , -0.72690696,  1.9024708 ,  0.4849704 ,
#         -0.13702707,  1.4588943 , -3.006444  , -1.3256018 ,  1.332387  ,
#          0.32611024, -1.4830612 ,  2.0182452 , -1.2422862 ,  0.90478045],
#        dtype=float32),
#  ...}

# %%
num_words = vocab_tar_size
embedding_matrix_h = zeros((vocab_tar_size, 100))
for word, index in hin_lang_tokenizer.word_index.items(): #input_lang_word2idx=1847
    embedding_vector = embeddings_dictionary_h.get(word)
    if embedding_vector is not None:
        embedding_matrix_h[index] = embedding_vector

# %%
len(embedding_matrix_h)
# Out:
# 7014

# %%
# preparing english lines for w2v
eng = []
for line in clean_english_lines:
    for l in line:
        l = l.split(" ")
    eng.append(l)

eng
# Out:
# [['<start>', 'it', 'is', 'an', 'indoor', 'scene', '<end>'],
#  ['<start>', 'computer', 'screens', 'turned', 'on', '<end>'],
#  ['<start>', 'man', 'has', 'short', 'hair', '<end>'],
#  ['<start>', 'photo', 'album', 'open', 'on', 'an', 'adults', 'lap', '<end>'],
#  ['<start>',
#   'there',
#   'is',
#   'a',
#   'group',
#   'of',
#   'girls',
#   'beside',
#   'the',
#   'black',
#   'car',
#   '<end>'],
#  ['<start>', 'child', 'in', 'a', 'stroller', '<end>'],
#  ['<start>', 'tall', 'metal', 'lightpost', '<end>'],
#  ['<start>', 'wall', 'is', 'painted', 'white', '<end>'],
#  ['<start>',
#   'there',
#   'are',
#   'several',
#   'pictures',
#   'on',
#   'the',
#   'wall',
#   '<end>'],
#  ['<start>', 'woman', 'facing', 'the', 'ocean', '<end>'],
#  ['<start>', 'this', 'is', 'an', 'office', 'layout', '<end>'],
#  ['<start>', 'four', 'metallic', 'chairs', '<end>'],
#  ['<start>', 'clutter', 'is', 'on', 'a', 'table', '<end>'],
#  ['<start>', 'a', 'white', 'microwave', 'oven', '<end>'],
#  ['<start>', 'white', 'suv', 'driving', 'through', 'intersection', '<end>'],
#  ['<start>', 'person', 'crossing', 'street', 'with', 'umbrella', '<end>'],
#  ['<start>',
#   'man',
#   'in',
#   'gray',
#   'pants',
#   'leaning',
#   'on',
#   'building',
#   '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'a', 'man', 'standing', 'in', 'between', 'cars', '<end>'],
#  ['<start>', 'painting', 'hanging', 'on', 'wall', '<end>'],
#  ['<start>', 'leg', 'of', 'the', 'chair', '<end>'],
#  ['<start>', 'window', 'of', 'a', 'boat', '<end>'],
#  ['<start>', 'the', 'cabinet', 'is', 'wood', '<end>'],
#  ['<start>', 'a', 'man', 'reading', 'a', 'book', '<end>'],
#  ['<start>', 'a', 'person', 'swimming', 'in', 'water', '<end>'],
#  ['<start>', 'lamp', 'with', 'glowing', 'shade', '<end>'],
#  ['<start>', 'fruit', 'on', 'the', 'plate', '<end>'],
#  ['<start>', 'a', 'porcelain', 'white', 'plate', '<end>'],
#  ['<start>', 'black', 'game', 'controller', '<end>'],
#  ['<start>',
#   'a',
#   'person',
#   'putting',
#   'something',
#   'in',
#   'the',
#   'trunk',
#   'of',
#   'the',
#   'car',
#   '<end>'],
#  ['<start>', 'green', 'car', 'parked', 'along', 'a', 'street', '<end>'],
#  ['<start>', 'car', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'construction', 'worker', 'wearing', 'coveralls', '<end>'],
#  ['<start>', 'a', 'black', 'car', 'with', 'a', 'yellow', 'door', '<end>'],
#  ['<start>', 'chair', 'at', 'the', 'table', '<end>'],
#  ['<start>', 'a', 'navel', 'orange', 'on', 'a', 'counter', '<end>'],
#  ['<start>', 'three', 'windows', 'of', 'a', 'building', '<end>'],
#  ['<start>', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>',
#   'brown',
#   'table',
#   'standing',
#   'on',
#   'top',
#   'of',
#   'a',
#   'floor',
#   '<end>'],
#  ['<start>', 'floor', 'lamp', 'is', 'on', '<end>'],
#  ['<start>', 'a', 'yellow', 'bus', '<end>'],
#  ['<start>', 'branch', 'of', 'the', 'tree', '<end>'],
#  ['<start>', 'cement', 'bench', 'outside', 'the', 'building', '<end>'],
#  ['<start>',
#   'thick',
#   'black',
#   'pole',
#   'with',
#   'a',
#   'white',
#   'stripe',
#   '<end>'],
#  ['<start>', 'a', 'wooden', 'park', 'bench', '<end>'],
#  ['<start>', 'a', 'cup', '<end>'],
#  ['<start>', 'man', 'has', 'brown', 'hair', '<end>'],
#  ['<start>', 'grass', 'in', 'a', 'field', '<end>'],
#  ['<start>', 'a', 'large', 'brown', 'tree', 'trunk', '<end>'],
#  ['<start>', 'silver', 'car', 'in', 'front', 'of', 'a', 'building', '<end>'],
#  ['<start>', 'man', 'sits', 'at', 'counter', '<end>'],
#  ['<start>', 'woman', 'standing', 'at', 'a', 'book', 'cart', '<end>'],
#  ['<start>', 'two', 'story', 'blue', 'bus', '<end>'],
#  ['<start>', 'a', 'gray', 'laundry', 'basket', '<end>'],
#  ['<start>', 'the', 'yellow', 'construction', 'hats', '<end>'],
#  ['<start>', 'wooden', 'floor', 'in', 'the', 'room', '<end>'],
#  ['<start>', 'a', 'tall', 'palm', 'tree', 'above', 'the', 'horizon', '<end>'],
#  ['<start>', 'chair', 'inside', 'an', 'auditorium', '<end>'],
#  ['<start>', 'a', 'tall', 'leafy', 'tree', '<end>'],
#  ['<start>', 'mirror', 'is', 'on', 'far', 'wall', '<end>'],
#  ['<start>', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'the', 'drivers', 'side', 'door', 'is', 'open', '<end>'],
#  ['<start>', 'a', 'plate', 'full', 'of', 'food', '<end>'],
#  ['<start>', 'the', 'building', 'is', 'white', '<end>'],
#  ['<start>', 'small', 'picture', 'on', 'wall', '<end>'],
#  ['<start>', 'intersection', 'of', 'wooden', 'logs', '<end>'],
#  ['<start>', 'light', 'attached', 'to', 'building', '<end>'],
#  ['<start>', 'do', 'not', 'enter', 'sign', '<end>'],
#  ['<start>',
#   'colorful',
#   'pillow',
#   'of',
#   'blues',
#   'and',
#   'reds',
#   'on',
#   'a',
#   'white',
#   'striped',
#   'couch',
#   '<end>'],
#  ['<start>', 'dent', 'is', 'in', 'the', 'vehicle', '<end>'],
#  ['<start>', 'the', 'roof', 'is', 'grey', '<end>'],
#  ['<start>', 'brown', 'frame', 'on', 'mirror', '<end>'],
#  ['<start>', 'white', 'flowers', 'beneath', 'tree', '<end>'],
#  ['<start>', 'white', 'ambulance', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'green', 'trees', 'in', 'distance', '<end>'],
#  ['<start>', 'the', 'sign', 'is', 'blue', '<end>'],
#  ['<start>', 'man', 'sitting', 'off', 'to', 'side', 'of', 'road', '<end>'],
#  ['<start>', 'a', 'man', 'crossing', 'the', 'street', '<end>'],
#  ['<start>', 'sign', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'window', 'in', 'a', 'brick', 'house', '<end>'],
#  ['<start>', 'the', 'computer', 'screen', 'is', 'blue', '<end>'],
#  ['<start>', 'bike', 'route', 'sign', '<end>'],
#  ['<start>', 'grey', 'beard', 'hair', 'on', 'a', 'man', '<end>'],
#  ['<start>', 'the', 'rear', 'view', 'of', 'a', 'car', '<end>'],
#  ['<start>', 'burger', 'with', 'cheese', 'sauce', '<end>'],
#  ['<start>', 'side', 'of', 'thee', 'silver', 'suv', '<end>'],
#  ['<start>', 'woman', 'walking', 'across', 'street', '<end>'],
#  ['<start>', 'woman', 'wearing', 'pink', 'jacket', '<end>'],
#  ['<start>', 'red', 'car', 'parked', 'by', 'street', 'light', '<end>'],
#  ['<start>', 'the', 'traffic', 'lights', 'are', 'yellow', '<end>'],
#  ['<start>', 'white', 'painted', 'line', 'on', 'pavement', '<end>'],
#  ['<start>', 'the', 'black', 'tipped', 'pen', 'on', 'the', 'desk', '<end>'],
#  ['<start>',
#   'man',
#   'in',
#   'white',
#   'shirt',
#   'walking',
#   'down',
#   'the',
#   'sidewalk',
#   '<end>'],
#  ['<start>', 'large', 'light', 'fixture', 'in', 'ceiling', '<end>'],
#  ['<start>', 'white', 'monitor', 'on', 'desk', '<end>'],
#  ['<start>', 'black', 'computer', 'monitor', 'on', 'desk', '<end>'],
#  ['<start>', 'handle', 'on', 'the', 'mug', '<end>'],
#  ['<start>',
#   'a',
#   'man',
#   'sitting',
#   'in',
#   'front',
#   'of',
#   'a',
#   'computer',
#   'monitor',
#   '<end>'],
#  ['<start>', 'turned', 'on', 'black', 'monitor', '<end>'],
#  ['<start>', 'man', 'wearing', 'brown', 'sunglasses', '<end>'],
#  ['<start>', 'brick', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'silver', 'metal', 'table', 'on', 'ground', '<end>'],
#  ['<start>', 'a', 'grey', 'trash', 'bin', '<end>'],
#  ['<start>', 'boy', 'holding', 'ball', '<end>'],
#  ['<start>', 'projection', 'screen', 'is', 'white', '<end>'],
#  ['<start>',
#   'yellow',
#   'traffic',
#   'signal',
#   'attached',
#   'to',
#   'a',
#   'gray',
#   'pole',
#   '<end>'],
#  ['<start>', 'red', 'truck', 'behind', 'silver', 'car', '<end>'],
#  ['<start>', 'two', 'mopeds', 'are', 'parked', '<end>'],
#  ['<start>', 'a', 'blue', 'car', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'black', 'car', 'with', 'yellow', 'doors', '<end>'],
#  ['<start>', 'a', 'car', 'with', 'four', 'doors', '<end>'],
#  ['<start>', 'bike', 'parked', 'on', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'red', 'motorcycle', 'on', 'sidewalk', '<end>'],
#  ['<start>', 'man', 'wearing', 'blue', 'shirt', '<end>'],
#  ['<start>',
#   'group',
#   'of',
#   'scooters',
#   'parked',
#   'next',
#   'to',
#   'each',
#   'other',
#   '<end>'],
#  ['<start>', 'yellow', 'vw', 'leaving', 'parking', 'lot', '<end>'],
#  ['<start>', 'bag', 'of', 'oranges', '<end>'],
#  ['<start>', 'there', 'is', 'a', 'band', 'on', 'stage', '<end>'],
#  ['<start>', 'window', 'on', 'white', 'house', '<end>'],
#  ['<start>', 'these', 'are', 'tall', 'buildings', '<end>'],
#  ['<start>', 'small', 'car', 'beside', 'curb', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'person', '<end>'],
#  ['<start>', 'bull', 'on', 'the', 'sand', '<end>'],
#  ['<start>', 'the', 'building', 'with', 'a', 'yellow', 'roof', '<end>'],
#  ['<start>', 'the', 'cup', 'is', 'upside', 'down', '<end>'],
#  ['<start>', 'light', 'in', 'the', 'ceiling', '<end>'],
#  ['<start>', 'black', 'truck', 'is', 'parked', '<end>'],
#  ['<start>', 'the', 'man', 'in', 'the', 'light', 'blue', 'coat', '<end>'],
#  ['<start>', 'bike', 'leaning', 'against', 'black', 'gate', '<end>'],
#  ['<start>', 'white', 'curtain', 'on', 'window', '<end>'],
#  ['<start>', 'the', 'alarm', 'clock', 'is', 'off', '<end>'],
#  ['<start>', 'a', 'medium', 'sized', 'picture', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'a', 'bottle', 'of', 'water', 'on', 'the', 'table', '<end>'],
#  ['<start>', 'wired', 'telephone', 'connected', 'to', 'the', 'wall', '<end>'],
#  ['<start>', 'chair', 'next', 'to', 'wood', 'desk', '<end>'],
#  ['<start>', 'lamppost', 'next', 'to', 'television', '<end>'],
#  ['<start>', 'black', 'backpack', 'beside', 'a', 'bed', '<end>'],
#  ['<start>', 'a', 'silver', 'faucet', 'in', 'a', 'bathroom', '<end>'],
#  ['<start>', 'small', 'plant', 'on', 'porch', '<end>'],
#  ['<start>', 'cedar', 'shingles', 'on', 'the', 'house', '<end>'],
#  ['<start>', 'a', 'white', 'and', 'tan', 'hotel', 'room', '<end>'],
#  ['<start>', 'five', 'knobs', 'on', 'a', 'stove', '<end>'],
#  ['<start>', 'the', 'sink', 'is', 'stainless', 'steel', '<end>'],
#  ['<start>', 'a', 'wooden', 'floor', '<end>'],
#  ['<start>', 'the', 'window', 'is', 'shut', '<end>'],
#  ['<start>', 'black', 'car', 'tire', 'with', 'silver', 'rim', '<end>'],
#  ['<start>', 'a', 'four', 'legged', 'steel', 'chair', '<end>'],
#  ['<start>', 'red', 'desk', 'lamp', 'sitting', 'on', 'desk', '<end>'],
#  ['<start>', 'the', 'wooden', 'night', 'stand', '<end>'],
#  ['<start>', 'tall', 'grassy', 'plants', '<end>'],
#  ['<start>', 'part', 'of', 'a', 'house', 'plant', '<end>'],
#  ['<start>', 'red', 'and', 'green', 'plaid', 'sofa', '<end>'],
#  ['<start>', 'large', 'kitchen', 'area', '<end>'],
#  ['<start>', 'boat', 'on', 'the', 'water', '<end>'],
#  ['<start>',
#   'vehicles',
#   'parked',
#   'on',
#   'the',
#   'side',
#   'of',
#   'the',
#   'road',
#   '<end>'],
#  ['<start>', 'a', 'woman', 'standing', 'on', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'man', 'standing', 'on', 'the', 'phone', '<end>'],
#  ['<start>', 'a', 'woman', 'wearing', 'a', 'rain', 'jacket', '<end>'],
#  ['<start>', 'taxi', 'cab', 'driving', 'on', 'street', '<end>'],
#  ['<start>', 'yellow', 'taxi', 'driving', 'on', 'a', 'street', '<end>'],
#  ['<start>',
#   'person',
#   'walking',
#   'down',
#   'the',
#   'sidewalk',
#   'in',
#   'a',
#   'busy',
#   'city',
#   '<end>'],
#  ['<start>', 'person', 'walks', 'on', 'sidewalk', '<end>'],
#  ['<start>', 'group', 'of', 'people', 'is', 'standing', '<end>'],
#  ['<start>', 'black', 'car', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'window', 'of', 'a', 'car', '<end>'],
#  ['<start>', 'flowers', 'next', 'to', 'water', '<end>'],
#  ['<start>', 'a', 'food', 'stand', 'on', 'a', 'sidewalk', '<end>'],
#  ['<start>', 'person', 'crossing', 'on', 'crosswalk', '<end>'],
#  ['<start>', 'van', 'driving', 'under', 'light', '<end>'],
#  ['<start>', 'yellow', 'taxi', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'women', 'is', 'wearing', 'a', 'pink', 'shirt', '<end>'],
#  ['<start>', 'tan', 'hat', 'hanging', 'on', 'a', 'post', '<end>'],
#  ['<start>', 'a', 'white', 'plane', 'on', 'a', 'tarmac', '<end>'],
#  ['<start>', 'planes', 'parked', 'on', 'the', 'tarmac', '<end>'],
#  ['<start>', 'small', 'window', 'on', 'airplane', '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'small', 'rocks', '<end>'],
#  ['<start>', 'tree', 'trunk', 'is', 'broken', '<end>'],
#  ['<start>', 'person', 'in', 'red', 'shorts', '<end>'],
#  ['<start>', 'the', 'shrub', 'is', 'very', 'short', '<end>'],
#  ['<start>', 'clouds', 'in', 'the', 'sky', '<end>'],
#  ['<start>', 'a', 'buffalo', 'near', 'a', 'road', '<end>'],
#  ['<start>', 'cloud', 'in', 'the', 'sky', '<end>'],
#  ['<start>', 'white', 'moving', 'through', 'the', 'water', '<end>'],
#  ['<start>', 'parrot', 'is', 'on', 'top', 'of', 'cage', '<end>'],
#  ['<start>', 'a', 'bird', 'standing', 'in', 'water', '<end>'],
#  ['<start>', 'right', 'eye', '<end>'],
#  ['<start>', 'light', 'on', 'the', 'pole', '<end>'],
#  ['<start>', 'highway', 'in', 'a', 'quiet', 'area', '<end>'],
#  ['<start>', 'white', 'cloud', 'in', 'sky', '<end>'],
#  ['<start>', 'white', 'boat', 'next', 'to', 'the', 'dock', '<end>'],
#  ['<start>', 'boat', 'in', 'the', 'water', '<end>'],
#  ['<start>', 'boat', 'is', 'orange', '<end>'],
#  ['<start>', 'bikes', 'in', 'line', 'by', 'sidewalk', '<end>'],
#  ['<start>', 'small', 'green', 'minivan', '<end>'],
#  ['<start>',
#   'american',
#   'flag',
#   'hanging',
#   'on',
#   'side',
#   'of',
#   'building',
#   '<end>'],
#  ['<start>', 'tree', 'behind', 'building', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'orange', 'beak', 'on', 'white', 'duck', '<end>'],
#  ['<start>', 'grey', 'and', 'white', 'sky', '<end>'],
#  ['<start>', 'man', 'holding', 'long', 'yellow', 'skis', '<end>'],
#  ['<start>', 'the', 'red', 'flag', 'in', 'the', 'snow', '<end>'],
#  ['<start>', 'black', 'scooter', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'black', 'metal', 'lock', 'box', '<end>'],
#  ['<start>', 'glass', 'window', 'on', 'building', '<end>'],
#  ['<start>', 'sidewalk', 'is', 'light', 'grey', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'paved', 'road', 'with', 'parked', 'cars', '<end>'],
#  ['<start>', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>',
#   'white',
#   'lines',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'the',
#   'road',
#   '<end>'],
#  ['<start>', 'car', 'parked', 'on', 'a', 'narrow', 'road', '<end>'],
#  ['<start>', 'red', 'helmet', 'on', 'his', 'head', '<end>'],
#  ['<start>', 'boat', 'on', 'the', 'water', '<end>'],
#  ['<start>', 'the', 'boat', 'is', 'at', 'a', 'dock', '<end>'],
#  ['<start>', 'pink', 'pants', '<end>'],
#  ['<start>', 'blue', 'parking', 'lines', 'on', 'the', 'pavement', '<end>'],
#  ['<start>', 'the', 'man', 'is', 'walking', '<end>'],
#  ['<start>', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'green', 'palm', 'on', 'radio', '<end>'],
#  ['<start>', 'hole', 'in', 'silver', 'hubcap', '<end>'],
#  ['<start>', 'girl', 'in', 'blue', 'jean', 'skirt', '<end>'],
#  ['<start>', 'the', 'electrical', 'box', 'on', 'the', 'post', '<end>'],
#  ['<start>', 'sign', 'on', 'side', 'of', 'road', '<end>'],
#  ['<start>', 'green', 'grass', 'in', 'a', 'field', '<end>'],
#  ['<start>', 'blue', 'sign', 'with', 'large', 'black', 'base', '<end>'],
#  ['<start>', 'green', 'palm', 'on', 'tree', '<end>'],
#  ['<start>', 'picture', 'in', 'a', 'frame', '<end>'],
#  ['<start>', 'the', 'car', 'is', 'black', '<end>'],
#  ['<start>', 'red', 'car', 'near', 'plant', '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'white', 'bus', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'a', 'decorated', 'christmas', 'tree', '<end>'],
#  ['<start>', 'yellow', 'dump', 'truck', 'by', 'the', 'mountain', '<end>'],
#  ['<start>', 'green', 'palm', 'on', 'tree', '<end>'],
#  ['<start>', 'sun', 'in', 'the', 'sky', '<end>'],
#  ['<start>', 'white', 'print', 'style', 'letter', '<end>'],
#  ['<start>', 'the', 'light', 'is', 'on', 'the', 'ceiling', '<end>'],
#  ['<start>', 'light', 'brown', 'wooden', 'step', '<end>'],
#  ['<start>', 'womens', 'lips', '<end>'],
#  ['<start>', 'brick', 'with', 'grass', 'around', 'it', '<end>'],
#  ['<start>', 'a', 'seagull', 'is', 'standing', '<end>'],
#  ['<start>', 'the', 'building', 'is', 'large', '<end>'],
#  ['<start>', 'a', 'dark', 'colored', 'van', '<end>'],
#  ['<start>',
#   'a',
#   'dark',
#   'haired',
#   'woman',
#   'in',
#   'a',
#   'colorful',
#   'top',
#   '<end>'],
#  ['<start>', 'ear', 'of', 'the', 'cat', '<end>'],
#  ['<start>', 'the', 'woman', 'is', 'next', 'to', 'the', 'man', '<end>'],
#  ['<start>', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'grey', 'colored', 'sidewalk', 'brick', '<end>'],
#  ['<start>', 'the', 'man', 'is', 'standing', '<end>'],
#  ['<start>', 'three', 'men', 'standing', 'in', 'a', 'group', '<end>'],
#  ['<start>', 'a', 'luggage', 'cart', 'on', 'a', 'tarmac', '<end>'],
#  ['<start>', 'the', 'tail', 'of', 'an', 'airplane', '<end>'],
#  ['<start>',
#   'black',
#   'restroom',
#   'sign',
#   'attached',
#   'to',
#   'the',
#   'wall',
#   '<end>'],
#  ['<start>', 'a', 'long', 'metal', 'rack', '<end>'],
#  ['<start>', 'light', 'on', 'a', 'machine', '<end>'],
#  ['<start>', 'child', 'wearing', 'striped', 'shirt', '<end>'],
#  ['<start>', 'cameras', 'on', 'the', 'ceiling', 'of', 'the', 'room', '<end>'],
#  ['<start>', 'vase', 'on', 'the', 'mantel', '<end>'],
#  ['<start>', 'the', 'man', 'has', 'a', 'goatee', '<end>'],
#  ['<start>', 'man', 'painting', 'on', 'canvas', '<end>'],
#  ['<start>', 'a', 'row', 'of', 'red', 'chairs', '<end>'],
#  ['<start>', 'two', 'police', 'officers', '<end>'],
#  ['<start>', 'houseboat', 'in', 'the', 'water', '<end>'],
#  ['<start>', 'bread', 'in', 'a', 'basket', '<end>'],
#  ['<start>', 'man', 'with', 'short', 'black', 'hair', '<end>'],
#  ['<start>', 'a', 'big', 'grey', 'ball', '<end>'],
#  ['<start>', 'white', 'table', 'cloth', 'on', 'the', 'table', '<end>'],
#  ['<start>', 'a', 'person', 'sitting', 'in', 'the', 'baptism', 'tub', '<end>'],
#  ['<start>',
#   'horizontal',
#   'venetian',
#   'blinds',
#   'on',
#   'the',
#   'window',
#   '<end>'],
#  ['<start>', 'flatscreen', 'television', 'on', 'the', 'dresser', '<end>'],
#  ['<start>', 'lights', 'suspended', 'from', 'ceiling', '<end>'],
#  ['<start>', 'the', 'man', 'has', 'gray', 'hair', '<end>'],
#  ['<start>', 'man', 'wearing', 'white', 'shirt', '<end>'],
#  ['<start>', 'people', 'sitting', 'in', 'a', 'bus', '<end>'],
#  ['<start>', 'man', 'and', 'woman', 'in', 'a', 'candy', 'store', '<end>'],
#  ['<start>', 'chair', 'desk', 'combo', 'in', 'the', 'room', '<end>'],
#  ['<start>', 'the', 'man', 'is', 'wearing', 'glasses', '<end>'],
#  ['<start>', 'a', 'man', 'with', 'no', 'shirt', 'in', 'the', 'snow', '<end>'],
#  ['<start>', 'grey', 'dividers', 'for', 'cubicles', '<end>'],
#  ['<start>', 'windown', 'pane', 'on', 'door', '<end>'],
#  ['<start>', 'truck', 'has', 'white', 'cargo', 'holder', '<end>'],
#  ['<start>', 'the', 'chair', 'has', 'no', 'arms', '<end>'],
#  ['<start>', 'man', 'has', 'head', 'turned', '<end>'],
#  ['<start>', 'child', 'walking', 'into', 'plane', '<end>'],
#  ['<start>', 'purple', 'tissue', 'paper', 'around', 'bouquet', '<end>'],
#  ['<start>', 'pool', 'table', 'in', 'a', 'large', 'room', '<end>'],
#  ['<start>', 'paddle', 'on', 'a', 'table', '<end>'],
#  ['<start>', 'man', 'standing', 'in', 'a', 'room', '<end>'],
#  ['<start>', 'man', 'relaxing', 'in', 'the', 'water', '<end>'],
#  ['<start>', 'man', 'is', 'in', 'a', 'pool', '<end>'],
#  ['<start>', 'boy', 'has', 'brown', 'hair', '<end>'],
#  ['<start>', 'a', 'brown', 'and', 'white', 'staircase', '<end>'],
#  ['<start>', 'building', 'is', 'painted', 'green', '<end>'],
#  ['<start>', 'many', 'people', 'in', 'snow', '<end>'],
#  ['<start>', 'the', 'silver', 'toilet', '<end>'],
#  ['<start>', 'yellow', 'slide', 'in', 'the', 'room', '<end>'],
#  ['<start>',
#   'child',
#   'shopping',
#   'cart',
#   'filled',
#   'with',
#   'fake',
#   'food',
#   '<end>'],
#  ['<start>', 'this', 'is', 'a', 'kitchen', '<end>'],
#  ['<start>', 'a', 'faucet', 'on', 'the', 'sink', '<end>'],
#  ['<start>', 'assorted', 'cereals', 'on', 'a', 'kitchen', 'shelf', '<end>'],
#  ['<start>', 'white', 'microwave', 'oven', 'in', 'corner', '<end>'],
#  ['<start>', 'wall', 'papered', 'wall', 'in', 'a', 'kitchen', '<end>'],
#  ['<start>', 'a', 'wall', 'of', 'orange', 'dryers', '<end>'],
#  ['<start>', 'white', 'pipe', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'dolphin', 'statue', 'near', 'the', 'pool', '<end>'],
#  ['<start>', 'microwave', 'on', 'top', 'of', 'counter', '<end>'],
#  ['<start>', 'logo', 'on', 'the', 'hat', '<end>'],
#  ['<start>', 'a', 'person', 'kneeling', 'down', '<end>'],
#  ['<start>', 'person', 'wearing', 'black', 'pants', '<end>'],
#  ['<start>', 'people', 'sitting', 'on', 'a', 'couch', '<end>'],
#  ['<start>', 'light', 'hanging', 'from', 'the', 'ceiling', '<end>'],
#  ['<start>', 'square', 'hole', 'in', 'chair', '<end>'],
#  ['<start>', 'arms', 'up', 'in', 'the', 'air', '<end>'],
#  ['<start>', 'orange', 'pail', 'hanging', 'from', 'wall', '<end>'],
#  ['<start>', 'white', 'washer', 'situated', 'under', 'a', 'counter', '<end>'],
#  ['<start>', 'person', 'sitting', 'in', 'front', 'of', 'window', '<end>'],
#  ['<start>', 'light', 'of', 'daytime', 'sky', '<end>'],
#  ['<start>', 'brown', 'lounge', 'chair', 'next', 'to', 'the', 'pool', '<end>'],
#  ['<start>', 'a', 'group', 'of', 'umbrellas', 'at', 'a', 'pool', '<end>'],
#  ['<start>', 'red', 'bench', 'near', 'elegant', 'chair', '<end>'],
#  ['<start>', 'green', 'turtle', 'pool', 'in', 'stack', '<end>'],
#  ['<start>', 'many', 'people', 'in', 'a', 'room', '<end>'],
#  ['<start>',
#   'man',
#   'with',
#   'a',
#   'blue',
#   'and',
#   'black',
#   'plaid',
#   'shirt',
#   '<end>'],
#  ['<start>', 'the', 'word', 'polar', 'on', 'the', 'truck', '<end>'],
#  ['<start>', 'a', 'black', 'and', 'brown', 'area', 'rug', '<end>'],
#  ['<start>',
#   'black',
#   'chair',
#   'to',
#   'the',
#   'left',
#   'of',
#   'brown',
#   'table',
#   '<end>'],
#  ['<start>', 'brown', 'colored', 'wooden', 'stair', '<end>'],
#  ['<start>', 'a', 'yellow', 'and', 'black', 'tie', 'on', 'a', 'man', '<end>'],
#  ['<start>', 'person', 'walking', 'on', 'trail', '<end>'],
#  ['<start>', 'woman', 'wearing', 'red', 'scarf', '<end>'],
#  ['<start>', 'pigeon', 'on', 'ground', '<end>'],
#  ['<start>', 'back', 'of', 'docked', 'houseboat', '<end>'],
#  ['<start>', 'a', 'yellow', 'skirt', '<end>'],
#  ['<start>', 'black', 'tv', 'in', 'room', '<end>'],
#  ['<start>',
#   'television',
#   'remote',
#   'sitting',
#   'on',
#   'a',
#   'red',
#   'tablecloth',
#   '<end>'],
#  ['<start>', 'mirror', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'picture', 'hanging', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'a', 'large', 'painting', 'on', 'a', 'wall', '<end>'],
#  ['<start>', 'photo', 'taken', 'during', 'the', 'day', '<end>'],
#  ['<start>', 'people', 'walking', 'on', 'the', 'bridge', '<end>'],
#  ['<start>', 'tower', 'with', 'pointed', 'top', '<end>'],
#  ['<start>', 'these', 'are', 'old', 'structures', '<end>'],
#  ['<start>', 'grey', 'steps', 'on', 'stairs', '<end>'],
#  ['<start>', 'person', 'walking', 'on', 'spiral', 'stairs', '<end>'],
#  ['<start>', 'window', 'on', 'a', 'residential', 'building', '<end>'],
#  ['<start>', 'the', 'silver', 'butter', 'knives', '<end>'],
#  ['<start>', 'utensil', 'to', 'the', 'left', 'of', 'plate', '<end>'],
#  ['<start>', 'black', 'letters', 'on', 'paper', '<end>'],
#  ['<start>', 'coffee', 'cup', 'full', 'of', 'frothy', 'coffee', '<end>'],
#  ['<start>', 'cut', 'banana', 'in', 'bowl', '<end>'],
#  ['<start>', 'juice', 'in', 'glass', 'bottle', '<end>'],
#  ['<start>', 'a', 'vase', 'full', 'of', 'red', 'flowers', '<end>'],
#  ['<start>', 'the', 'rainbow', 'looks', 'like', 'a', 'half', 'moon', '<end>'],
#  ['<start>', 'wooden', 'slat', 'on', 'chair', '<end>'],
#  ['<start>', 'a', 'brown', 'wooden', 'cabinet', 'door', '<end>'],
#  ['<start>', 'the', 'gun', 'is', 'shiny', '<end>'],
#  ['<start>', 'clear', 'blue', 'sky', 'above', 'a', 'mountaintop', '<end>'],
#  ['<start>', 'a', 'window', 'in', 'an', 'apartment', 'building', '<end>'],
#  ['<start>', 'a', 'black', 'street', 'light', '<end>'],
#  ['<start>', 'a', 'black', 'chair', '<end>'],
#  ['<start>', 'two', 'men', 'sitting', 'at', 'a', 'desk', '<end>'],
#  ['<start>', 'phone', 'with', 'twisted', 'cord', '<end>'],
#  ['<start>', 'a', 'white', 'car', 'parked', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'white', 'car', 'parked', 'near', 'the', 'fence', '<end>'],
#  ['<start>', 'window', 'side', 'of', 'building', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'woman', '<end>'],
#  ['<start>', 'the', 'field', 'is', 'green', '<end>'],
#  ['<start>', 'yellow', 'lines', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'black', 'car', 'parked', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'the', 'street', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'car', '<end>'],
#  ['<start>', 'the', 'water', 'is', 'green', 'in', 'color', '<end>'],
#  ['<start>', 'license', 'plate', 'on', 'the', 'car', '<end>'],
#  ['<start>', 'black', 'car', 'on', 'a', 'road', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'pane', 'on', 'the', 'window', '<end>'],
#  ['<start>', 'tall', 'outdoor', 'lamp', 'post', '<end>'],
#  ['<start>', 'tire', 'of', 'the', 'car', '<end>'],
#  ['<start>', 'the', 'brown', 'delivery', 'truck', '<end>'],
#  ['<start>',
#   'car',
#   'tire',
#   'made',
#   'of',
#   'black',
#   'rubber',
#   'and',
#   'silver',
#   'metal',
#   '<end>'],
#  ['<start>', 'the', 'parked', 'white', 'car', '<end>'],
#  ['<start>', 'a', 'brightly', 'lit', 'rear', 'brake', 'light', '<end>'],
#  ['<start>', 'window', 'in', 'a', 'large', 'office', 'building', '<end>'],
#  ['<start>', 'window', 'in', 'front', 'of', 'building', '<end>'],
#  ['<start>', 'blue', 'house', 'with', 'light', 'brown', 'roof', '<end>'],
#  ['<start>',
#   'the',
#   'older',
#   'woman',
#   'walking',
#   'on',
#   'the',
#   'sidewalk',
#   '<end>'],
#  ['<start>', 'a', 'large', 'black', 'trashcan', '<end>'],
#  ['<start>', 'street', 'signs', 'says', 'ames', '<end>'],
#  ['<start>', 'woman', 'standing', 'on', 'sidewalk', '<end>'],
#  ['<start>', 'square', 'window', 'on', 'building', '<end>'],
#  ['<start>', 'book', 'on', 'brown', 'wooden', 'bookshelf', '<end>'],
#  ['<start>', 'paper', 'cup', 'on', 'top', 'of', 'desk', '<end>'],
#  ['<start>', 'clock', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'vase', 'on', 'the', 'table', '<end>'],
#  ['<start>', 'a', 'glossy', 'blue', 'coffee', 'mug', '<end>'],
#  ['<start>', 'silver', 'faucet', 'on', 'kitchen', 'sink', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>',
#   'the',
#   'woman',
#   'in',
#   'jeans',
#   'and',
#   'a',
#   'black',
#   'shirt',
#   '<end>'],
#  ['<start>', 'a', 'blue', 'and', 'white', 'parking', 'sign', '<end>'],
#  ['<start>', 'the', 'plant', 'on', 'the', 'toilet', '<end>'],
#  ['<start>', 'white', 'book', 'with', 'black', 'writing', '<end>'],
#  ['<start>', 'a', 'tan', 'car', 'parked', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'woman', 'has', 'black', 'hair', '<end>'],
#  ['<start>', 'man', 'walking', 'on', 'sidewalk', '<end>'],
#  ['<start>', 'banners', 'on', 'the', 'post', '<end>'],
#  ['<start>', 'reflection', 'on', 'store', 'window', '<end>'],
#  ['<start>', 'the', 'bench', 'is', 'long', '<end>'],
#  ['<start>', 'wood', 'plank', 'on', 'porch', '<end>'],
#  ['<start>',
#   'crisp',
#   'brown',
#   'leaf',
#   'fallen',
#   'off',
#   'of',
#   'a',
#   'tree',
#   '<end>'],
#  ['<start>', 'a', 'stone', 'in', 'a', 'leaf', 'filled', 'field', '<end>'],
#  ['<start>', 'silver', 'suv', 'parked', 'on', 'road', '<end>'],
#  ['<start>', 'paint', 'on', 'a', 'mailbox', '<end>'],
#  ['<start>', 'window', 'in', 'front', 'of', 'white', 'building', '<end>'],
#  ['<start>', 'clock', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'the', 'silver', 'car', '<end>'],
#  ['<start>', 'a', 'women', 'standing', '<end>'],
#  ['<start>', 'window', 'in', 'front', 'of', 'brick', 'building', '<end>'],
#  ['<start>', 'do', 'not', 'enter', 'street', 'sign', '<end>'],
#  ['<start>',
#   'the',
#   'red',
#   'headed',
#   'woman',
#   'wlaking',
#   'on',
#   'the',
#   'sidewalk',
#   '<end>'],
#  ['<start>', 'window', 'in', 'front', 'of', 'building', '<end>'],
#  ['<start>', 'maroon', 'car', 'parked', 'at', 'the', 'curb', '<end>'],
#  ['<start>', 'blue', 'vehicle', 'parked', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'jeep', 'suv', 'parked', 'on', 'curb', '<end>'],
#  ['<start>', 'a', 'street', 'light', 'on', 'a', 'metal', 'pole', '<end>'],
#  ['<start>', 'the', 'shelf', 'is', 'color', 'brown', '<end>'],
#  ['<start>', 'a', 'computer', 'is', 'on', 'front', 'a', 'keyboard', '<end>'],
#  ['<start>', 'blue', 'and', 'white', 'coffee', 'mug', '<end>'],
#  ['<start>', 'an', 'empty', 'poster', 'board', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'yellow', 'box', 'of', 'snack', 'crackers', '<end>'],
#  ['<start>', 'black', 'monitor', 'on', 'desk', '<end>'],
#  ['<start>', 'black', 'and', 'white', 'desk', 'lamp', '<end>'],
#  ['<start>', 'gray', 'plastic', 'trash', 'can', 'under', 'desk', '<end>'],
#  ['<start>', 'whtie', 'microwave', 'oven', '<end>'],
#  ['<start>',
#   'office',
#   'chair',
#   'in',
#   'front',
#   'of',
#   'computer',
#   'monitor',
#   '<end>'],
#  ['<start>', 'blue', 'cardigan', 'draped', 'over', 'blue', 'chair', '<end>'],
#  ['<start>', 'a', 'row', 'of', 'binders', 'on', 'a', 'shelf', '<end>'],
#  ['<start>', 'a', 'white', 'piece', 'of', 'paper', '<end>'],
#  ['<start>', 'white', 'keyboard', 'on', 'top', 'of', 'desk', '<end>'],
#  ['<start>', 'an', 'old', 'black', 'tire', '<end>'],
#  ['<start>', 'maroon', 'suv', 'driving', 'down', 'the', 'road', '<end>'],
#  ['<start>', 'a', 'map', 'hanging', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'fluorescent', 'ceiling', 'lights', '<end>'],
#  ['<start>', 'a', 'tan', 'wooden', 'desk', '<end>'],
#  ['<start>', 'the', 'blue', 'walls', '<end>'],
#  ['<start>', 'large', 'window', 'with', 'white', 'sill', '<end>'],
#  ['<start>', 'red', 'street', 'sign', 'with', 'white', 'lettering', '<end>'],
#  ['<start>', 'a', 'red', 'sign', 'with', 'a', 'white', 'stripe', '<end>'],
#  ['<start>', 'car', 'driving', 'on', 'road', '<end>'],
#  ['<start>', 'blue', 'banner', 'with', 'white', 'decorations', '<end>'],
#  ['<start>', 'black', 'railingon', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'person', 'on', 'the', 'surfboard', '<end>'],
#  ['<start>', 'boat', 'in', 'the', 'water', '<end>'],
#  ['<start>', 'a', 'row', 'of', 'parked', 'cars', '<end>'],
#  ['<start>', 'a', 'black', 'computer', 'monitor', '<end>'],
#  ['<start>', 'multicolored', 'rainbow', 'over', 'water', '<end>'],
#  ['<start>', 'the', 'hedges', 'to', 'the', 'right', '<end>'],
#  ['<start>', 'a', 'coffee', 'cup', 'on', 'a', 'table', '<end>'],
#  ['<start>', 'street', 'light', 'is', 'off', '<end>'],
#  ['<start>',
#   'man',
#   'standing',
#   'in',
#   'a',
#   'black',
#   'suit',
#   'and',
#   'blue',
#   'shirt',
#   '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>',
#   'yellow',
#   'and',
#   'black',
#   'pedestrian',
#   'crossing',
#   'signal',
#   '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'person', 'in', 'black', 'tank', 'top', '<end>'],
#  ['<start>', 'boy', 'wearing', 'a', 'black', 'shirt', '<end>'],
#  ['<start>', 'a', 'small', 'gray', 'motorcycle', '<end>'],
#  ['<start>', 'window', 'on', 'large', 'building', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'motor', 'vehicle', '<end>'],
#  ['<start>',
#   'two',
#   'people',
#   'talking',
#   'at',
#   'the',
#   'bottom',
#   'of',
#   'the',
#   'stairs',
#   '<end>'],
#  ['<start>', 'the', 'van', 'is', 'blue', 'white', 'and', 'green', '<end>'],
#  ['<start>', 'a', 'door', 'way', 'to', 'a', 'business', '<end>'],
#  ['<start>', 'wheel', 'of', 'the', 'vehicle', '<end>'],
#  ['<start>', 'a', 'car', 'with', 'four', 'doors', '<end>'],
#  ['<start>', 'man', 'walking', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'the', 'white', 'car', 'is', 'parked', '<end>'],
#  ['<start>', 'the', 'red', 'tip', 'of', 'a', 'pole', '<end>'],
#  ['<start>', 'a', 'coca', 'cola', 'sign', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'a', 'red', 'and', 'white', 'umbrella', '<end>'],
#  ['<start>', 'the', 'head', 'of', 'a', 'man', '<end>'],
#  ['<start>', 'the', 'picture', 'frame', 'is', 'gold', 'in', 'color', '<end>'],
#  ['<start>', 'the', 'stairs', 'leading', 'to', 'entrance', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'taxi', 'cab', '<end>'],
#  ['<start>', 'large', 'tree', 'with', 'no', 'leaves', '<end>'],
#  ['<start>', 'work', 'truck', 'is', 'white', '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>',
#   'a',
#   'white',
#   'car',
#   'parked',
#   'on',
#   'the',
#   'side',
#   'of',
#   'a',
#   'street',
#   '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'black', 'car', 'parked', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'window', 'on', 'red', 'brick', 'window', '<end>'],
#  ['<start>',
#   'the',
#   'car',
#   'is',
#   'red',
#   'and',
#   'parked',
#   'in',
#   'the',
#   'street',
#   '<end>'],
#  ['<start>', 'windows', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'window', 'on', 'side', 'of', 'building', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'brown', 'tree', 'trunk', '<end>'],
#  ['<start>', 'townhouse', 'is', 'painted', 'yellow', '<end>'],
#  ['<start>', 'a', 'row', 'of', 'parked', 'cars', '<end>'],
#  ['<start>', 'window', 'on', 'side', 'of', 'a', 'building', '<end>'],
#  ['<start>', 'man', 'standing', 'wearing', 'orange', 'lifesaving', '<end>'],
#  ['<start>', 'a', 'pot', 'on', 'the', 'stairs', '<end>'],
#  ['<start>', 'tall', 'green', 'tree', 'on', 'grass', '<end>'],
#  ['<start>', 'a', 'vast', 'space', 'of', 'water', '<end>'],
#  ['<start>', 'moss', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'thick', 'trees', 'surrounding', 'the', 'town', '<end>'],
#  ['<start>', 'mountains', 'in', 'the', 'background', '<end>'],
#  ['<start>', 'big', 'white', 'boat', 'traveling', 'in', 'water', '<end>'],
#  ['<start>', 'a', 'wheel', '<end>'],
#  ['<start>',
#   'a',
#   'red',
#   'fire',
#   'hydrant',
#   'is',
#   'visible',
#   'at',
#   'a',
#   'distance',
#   '<end>'],
#  ['<start>', 'the', 'girls', 'brown', 'hair', '<end>'],
#  ['<start>', 'window', 'on', 'front', 'of', 'brick', 'building', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'brown', 'tree', 'trunk', '<end>'],
#  ['<start>', 'bird', 'near', 'a', 'lake', '<end>'],
#  ['<start>', 'old', 'shed', 'with', 'a', 'metal', 'roof', '<end>'],
#  ['<start>', 'tall', 'and', 'brown', 'mountain', '<end>'],
#  ['<start>', 'the', 'pile', 'of', 'gray', 'and', 'brown', 'rocks', '<end>'],
#  ['<start>', 'the', 'people', 'are', 'walking', '<end>'],
#  ['<start>', 'post', 'in', 'the', 'ground', '<end>'],
#  ['<start>', 'a', 'window', 'with', 'a', 'rounded', 'top', '<end>'],
#  ['<start>', 'a', 'couple', 'standing', 'together', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'bed', '<end>'],
#  ['<start>', 'white', 'door', 'on', 'closet', '<end>'],
#  ['<start>', 'a', 'black', 'soap', 'dish', '<end>'],
#  ['<start>', 'a', 'long', 'light', 'is', 'on', '<end>'],
#  ['<start>', 'big', 'lampshade', 'on', 'the', 'lamp', '<end>'],
#  ['<start>', 'radio', 'on', 'a', 'nightstand', '<end>'],
#  ['<start>', 'television', 'on', 'the', 'desk', '<end>'],
#  ['<start>', 'square', 'on', 'the', 'headboard', '<end>'],
#  ['<start>', 'a', 'white', 'coffee', 'mug', '<end>'],
#  ['<start>', 'thin', 'pile', 'of', 'white', 'papers', '<end>'],
#  ['<start>', 'lamp', 'shades', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'the', 'dresser', 'is', 'brown', '<end>'],
#  ['<start>', 'beige', 'colored', 'corded', 'phone', '<end>'],
#  ['<start>', 'picture', 'above', 'the', 'headboard', '<end>'],
#  ['<start>', 'a', 'orange', 'desk', 'chair', '<end>'],
#  ['<start>', 'the', 'door', 'frame', 'is', 'white', 'in', 'color', '<end>'],
#  ['<start>', 'spotlessly', 'clean', 'dining', 'room', '<end>'],
#  ['<start>', 'window', 'with', 'a', 'white', 'painted', 'frame', '<end>'],
#  ['<start>',
#   'a',
#   'portion',
#   'of',
#   'grass',
#   'grown',
#   'beside',
#   'the',
#   'dirt',
#   '<end>'],
#  ['<start>', 'metal', 'door', 'knob', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'jeep', '<end>'],
#  ['<start>', 'the', 'tea', 'kettle', 'is', 'silver', '<end>'],
#  ['<start>', 'the', 'door', 'is', 'whit', 'and', 'rectangular', '<end>'],
#  ['<start>', 'sofa', 'in', 'the', 'corner', 'of', 'the', 'room', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'grey', 'television', '<end>'],
#  ['<start>', 'the', 'picture', 'is', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'the', 'faucet', 'is', 'silver', '<end>'],
#  ['<start>', 'cannister', 'made', 'of', 'silver', 'metal', '<end>'],
#  ['<start>', 'empty', 'basket', 'on', 'the', 'floor', '<end>'],
#  ['<start>',
#   'white',
#   'and',
#   'black',
#   'lamp',
#   'on',
#   'the',
#   'nightstand',
#   '<end>'],
#  ['<start>', 'a', 'plump', 'gray', 'pillow', '<end>'],
#  ['<start>', 'the', 'toilet', 'is', 'white', '<end>'],
#  ['<start>', 'cabinet', 'in', 'the', 'kitchen', '<end>'],
#  ['<start>', 'grey', 'carpeted', 'stair', 'in', 'a', 'stairwell', '<end>'],
#  ['<start>', 'brown', 'door', 'in', 'the', 'room', '<end>'],
#  ['<start>', 'sunlight', 'on', 'the', 'floor', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'sink', '<end>'],
#  ['<start>', 'grey', 'and', 'white', 'siding', '<end>'],
#  ['<start>', 'the', 'comforter', 'and', 'pillow', 'cases', 'match', '<end>'],
#  ['<start>', 'white', 'wooden', 'balcony', '<end>'],
#  ['<start>', 'black', 'and', 'silver', 'range', '<end>'],
#  ['<start>', 'light', 'of', 'daytime', 'sky', '<end>'],
#  ['<start>', 'the', 'glass', 'window', 'is', 'transparent', '<end>'],
#  ['<start>', 'the', 'light', 'is', 'hanging', '<end>'],
#  ['<start>', 'a', 'plant', 'in', 'the', 'corner', 'of', 'a', 'room', '<end>'],
#  ['<start>', 'glass', 'window', 'on', 'white', 'oven', '<end>'],
#  ['<start>', 'green', 'and', 'yellow', 'house', '<end>'],
#  ['<start>', 'tree', 'on', 'a', 'sidewalk', '<end>'],
#  ['<start>', 'decorative', 'green', 'glass', 'vase', '<end>'],
#  ['<start>', 'a', 'car', 'on', 'front', 'a', 'tree', '<end>'],
#  ['<start>', 'large', 'pillow', 'in', 'a', 'white', 'case', '<end>'],
#  ['<start>', 'front', 'wooden', 'door', 'with', 'brown', 'painting', '<end>'],
#  ['<start>', 'backyard', 'of', 'residential', 'building', '<end>'],
#  ['<start>', 'light', 'switch', 'on', 'bedroom', 'wall', '<end>'],
#  ['<start>',
#   'a',
#   'framed',
#   'painting',
#   'hanging',
#   'on',
#   'the',
#   'wall',
#   '<end>'],
#  ['<start>', 'door', 'made', 'of', 'light', 'colored', 'wood', '<end>'],
#  ['<start>', 'the', 'toilet', 'seat', 'is', 'up', '<end>'],
#  ['<start>', 'old', 'and', 'small', 'television', 'set', '<end>'],
#  ['<start>',
#   'peach',
#   'colored',
#   'couch',
#   'with',
#   'large',
#   'blue',
#   'flowers',
#   '<end>'],
#  ['<start>', 'the', 'brochures', 'on', 'the', 'table', '<end>'],
#  ['<start>', 'the', 'fan', 'is', 'black', '<end>'],
#  ['<start>', 'interior', 'of', 'residential', 'living', 'room', '<end>'],
#  ['<start>', 'square', 'pane', 'in', 'window', '<end>'],
#  ['<start>', 'the', 'light', 'is', 'on', '<end>'],
#  ['<start>', 'the', 'bar', 'chairs', 'are', 'brown', '<end>'],
#  ['<start>', 'white', 'wall', 'near', 'picture', '<end>'],
#  ['<start>', 'food', 'on', 'a', 'plate', '<end>'],
#  ['<start>', 'interior', 'of', 'dining', 'area', '<end>'],
#  ['<start>',
#   'the',
#   'chair',
#   'is',
#   'made',
#   'of',
#   'wood',
#   'and',
#   'has',
#   'four',
#   'legs',
#   '<end>'],
#  ['<start>', 'a', 'fish', 'in', 'a', 'birds', 'mouth', '<end>'],
#  ['<start>', 'beak', 'of', 'a', 'bird', '<end>'],
#  ['<start>', 'pink', 'flowers', 'in', 'hanging', 'pot', '<end>'],
#  ['<start>', 'a', 'small', 'grey', 'car', '<end>'],
#  ['<start>', 'white', 'parked', 'car', '<end>'],
#  ['<start>', 'the', 'vehicle', 'is', 'white', '<end>'],
#  ['<start>', 'awning', 'covering', 'the', 'area', '<end>'],
#  ['<start>',
#   'red',
#   'and',
#   'clear',
#   'tail',
#   'light',
#   'on',
#   'a',
#   'vehicle',
#   '<end>'],
#  ['<start>', 'a', 'white', 'arrow', 'on', 'a', 'road', '<end>'],
#  ['<start>', 'a', 'white', 'vehicle', '<end>'],
#  ['<start>', 'a', 'car', 'color', 'silver', '<end>'],
#  ['<start>', 'black', 'and', 'gold', 'hydrant', '<end>'],
#  ['<start>', 'black', 'and', 'white', 'sign', '<end>'],
#  ['<start>',
#   'the',
#   'green',
#   'square',
#   'street',
#   'sign',
#   'on',
#   'the',
#   'pole',
#   '<end>'],
#  ['<start>', 'red', 'van', 'parked', 'on', 'the', 'right', '<end>'],
#  ['<start>', 'a', 'black', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>',
#   'white',
#   'and',
#   'red',
#   'van',
#   'with',
#   'a',
#   'roof',
#   'rack',
#   '<end>'],
#  ['<start>', 'green', 'and', 'white', 'signs', '<end>'],
#  ['<start>', 'man', 'walking', 'down', 'the', 'street', '<end>'],
#  ['<start>', 'woman', 'with', 'a', 'pink', 'top', '<end>'],
#  ['<start>', 'yellow', 'taxi', 'cab', 'on', 'street', '<end>'],
#  ['<start>', 'gray', 'building', 'has', 'a', 'window', '<end>'],
#  ['<start>', 'person', 'is', 'walking', 'outside', '<end>'],
#  ['<start>', 'traffic', 'light', 'on', 'curved', 'pole', '<end>'],
#  ['<start>', 'tall', 'building', 'in', 'a', 'city', '<end>'],
#  ['<start>', 'the', 'red', 'jacket', 'the', 'man', 'is', 'wearing', '<end>'],
#  ['<start>',
#   'the',
#   'person',
#   'in',
#   'gray',
#   'pants',
#   'is',
#   'standing',
#   '<end>'],
#  ['<start>',
#   'a',
#   'patch',
#   'of',
#   'orange',
#   'and',
#   'yellow',
#   'flowers',
#   '<end>'],
#  ['<start>', 'a', 'long', 'white', 'limosine', '<end>'],
#  ['<start>', 'large', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'dark', 'wagon', 'parked', 'in', 'street', '<end>'],
#  ['<start>', 'the', 'white', 'writing', 'on', 'the', 'van', '<end>'],
#  ['<start>', 'three', 'lights', 'on', 'a', 'pole', '<end>'],
#  ['<start>', 'silver', 'car', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'an', 'old', 'stone', 'church', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>',
#   'the',
#   'red',
#   'and',
#   'white',
#   'jacket',
#   'the',
#   'man',
#   'is',
#   'wearing',
#   '<end>'],
#  ['<start>', 'a', 'black', 'umbrella', 'over', 'a', 'womans', 'head', '<end>'],
#  ['<start>', 'a', 'blue', 'and', 'gold', 'flag', '<end>'],
#  ['<start>',
#   'taxi',
#   'cab',
#   'traveling',
#   'the',
#   'roads',
#   'of',
#   'a',
#   'large',
#   'city',
#   '<end>'],
#  ['<start>', 'a', 'red', 'purse', 'on', 'the', 'shoulder', '<end>'],
#  ['<start>', 'a', 'yellow', 'taxi', 'cab', '<end>'],
#  ['<start>', 'numerous', 'taxi', 'cabs', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'red', 'bus', 'is', 'travelling', 'on', 'a', 'road', '<end>'],
#  ['<start>',
#   'fence',
#   'around',
#   'a',
#   'park',
#   'in',
#   'a',
#   'large',
#   'city',
#   '<end>'],
#  ['<start>', 'concrete', 'block', 'in', 'the', 'grass', '<end>'],
#  ['<start>', 'light', 'of', 'daytime', 'sky', '<end>'],
#  ['<start>', 'black', 'sign', 'with', 'white', 'letters', '<end>'],
#  ['<start>', 'green', 'car', 'parked', 'in', 'the', 'street', '<end>'],
#  ['<start>', 'silver', 'car', 'parked', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'man', 'wearing', 'black', 'and', 'white', 'jacket', '<end>'],
#  ['<start>', 'a', 'blue', 'van', '<end>'],
#  ['<start>', 'two', 'people', 'walking', 'on', 'sidewalk', '<end>'],
#  ['<start>', 'the', 'bicycle', 'is', 'chained', 'to', 'the', 'pole', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'white', 'lines', 'painted', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'a', 'red', 'parking', 'sign', '<end>'],
#  ['<start>', 'a', 'puddle', 'of', 'water', '<end>'],
#  ['<start>', 'people', 'walking', 'across', 'the', 'street', '<end>'],
#  ['<start>', 'a', 'red', 'traffic', 'light', '<end>'],
#  ['<start>', 'a', 'yellow', 'taxi', 'cab', '<end>'],
#  ['<start>', 'a', 'car', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'black', 'and', 'green', 'sign', '<end>'],
#  ['<start>', 'two', 'yellow', 'posts', 'on', 'sidewalk', '<end>'],
#  ['<start>', 'metal', 'postal', 'box', '<end>'],
#  ['<start>', 'man', 'wearing', 'a', 'black', 'coat', '<end>'],
#  ['<start>', 'american', 'flag', 'flying', 'overhead', '<end>'],
#  ['<start>', 'yellow', 'taxi', 'driving', 'on', 'road', '<end>'],
#  ['<start>', 'grey', 'and', 'white', 'sky', '<end>'],
#  ['<start>', 'building', 'has', 'a', 'window', '<end>'],
#  ['<start>', 'the', 'metal', 'balcony', '<end>'],
#  ['<start>', 'the', 'railing', 'of', 'balcony', '<end>'],
#  ['<start>', 'machine', 'arm', 'in', 'the', 'forefront', '<end>'],
#  ['<start>', 'a', 'person', 'walking', 'on', 'a', 'street', '<end>'],
#  ['<start>', 'a', 'us', 'mail', 'van', '<end>'],
#  ['<start>',
#   'man',
#   'standing',
#   'in',
#   'front',
#   'of',
#   'an',
#   'art',
#   'piece',
#   '<end>'],
#  ['<start>', 'flower', 'on', 'the', 'painting', '<end>'],
#  ['<start>', 'painting', 'on', 'the', 'wall', '<end>'],
#  ['<start>', 'black', 'chair', 'is', 'wooden', '<end>'],
#  ['<start>', 'the', 'orange', 'object', '<end>'],
#  ['<start>', 'tail', 'stabilizer', 'of', 'a', 'large', 'airplane', '<end>'],
#  ['<start>', 'sign', 'with', 'black', 'lettering', '<end>'],
#  ['<start>', 'yellow', 'fire', 'hydrant', 'at', 'the', 'road', '<end>'],
#  ['<start>', 'a', 'woman', 'in', 'front', 'a', 'river', '<end>'],
#  ['<start>', 'silver', 'van', 'driving', 'through', 'intersection', '<end>'],
#  ['<start>', 'a', 'red', 'and', 'white', 'sign', '<end>'],
#  ['<start>', 'white', 'house', 'with', 'gray', 'roof', '<end>'],
#  ['<start>', 'a', 'large', 'building', 'in', 'the', 'distance', '<end>'],
#  ['<start>', 'a', 'white', 'cloud', '<end>'],
#  ['<start>', 'brick', 'chimney', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'orange', 'sky', 'in', 'the', 'horizon', '<end>'],
#  ['<start>', 'shoreline', 'next', 'to', 'the', 'beach', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'city', '<end>'],
#  ['<start>', 'blue', 'and', 'white', 'sky', '<end>'],
#  ['<start>', 'a', 'white', 'circle', 'on', 'a', 'train', '<end>'],
#  ['<start>', 'clouds', 'are', 'bright', 'white', '<end>'],
#  ['<start>', 'a', 'grey', 'extended', 'cab', 'truck', '<end>'],
#  ['<start>', 'bushes', 'growing', 'on', 'the', 'mountain', 'top', '<end>'],
#  ['<start>', 'black', 'shiny', 'parked', 'minivan', '<end>'],
#  ['<start>', 'mountain', 'in', 'the', 'distance', '<end>'],
#  ['<start>', 'a', 'tree', 'in', 'a', 'field', '<end>'],
#  ['<start>', 'brown', 'wooden', 'bench', '<end>'],
#  ['<start>', 'green', 'tree', 'by', 'the', 'road', '<end>'],
#  ['<start>', 'large', 'tree', 'with', 'green', 'leaves', '<end>'],
#  ['<start>', 'white', 'truck', 'by', 'a', 'building', '<end>'],
#  ['<start>', 'a', 'white', 'commercial', 'truck', '<end>'],
#  ['<start>', 'yellow', 'lights', 'glowing', 'in', 'the', 'water', '<end>'],
#  ['<start>', 'a', 'dinner', 'table', 'set', '<end>'],
#  ['<start>', 'ornate', 'window', 'with', 'an', 'arched', 'top', '<end>'],
#  ['<start>', 'orange', 'building', 'on', 'a', 'hill', '<end>'],
#  ['<start>', 'the', 'dog', 'is', 'walking', 'on', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'a', 'man', 'walking', 'down', 'the', 'stairs', '<end>'],
#  ['<start>', 'windows', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'a', 'tree', 'in', 'a', 'field', '<end>'],
#  ['<start>', 'a', 'tall', 'black', 'light', 'pole', '<end>'],
#  ['<start>', 'a', 'tree', 'in', 'a', 'field', '<end>'],
#  ['<start>', 'blue', 'words', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'the', 'balloon', 'is', 'red', '<end>'],
#  ['<start>', 'a', 'sign', 'standing', 'outside', 'the', 'house', '<end>'],
#  ['<start>', 'mother', 'anhinga', 'bird', 'on', 'a', 'branch', '<end>'],
#  ['<start>', 'beak', 'of', 'the', 'bird', '<end>'],
#  ['<start>', 'brown', 'and', 'white', 'puffer', 'fish', 'swimming', '<end>'],
#  ['<start>', 'bird', 'on', 'the', 'branch', '<end>'],
#  ['<start>', 'bird', 'on', 'a', 'branch', '<end>'],
#  ['<start>', 'leaves', 'on', 'the', 'tree', '<end>'],
#  ['<start>', 'cliff', 'face', 'made', 'of', 'grey', 'rock', '<end>'],
#  ['<start>', 'stripe', 'on', 'the', 'zebra', '<end>'],
#  ['<start>', 'the', 'left', 'horn', 'on', 'the', 'animals', 'head', '<end>'],
#  ['<start>', 'the', 'sun', 'is', 'yellow', '<end>'],
#  ['<start>', 'zebra', 'on', 'the', 'field', '<end>'],
#  ['<start>', 'black', 'and', 'white', 'zebra', '<end>'],
#  ['<start>', 'a', 'bird', 'with', 'a', 'narrow', 'body', '<end>'],
#  ['<start>', 'a', 'baby', 'elephant', '<end>'],
#  ['<start>', 'utility', 'towers', 'on', 'a', 'ridge', '<end>'],
#  ['<start>', 'a', 'rope', 'attached', '<end>'],
#  ['<start>', 'roof', 'of', 'the', 'building', '<end>'],
#  ['<start>', 'black', 'car', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'a', 'street', 'sign', 'on', 'a', 'pole', '<end>'],
#  ['<start>',
#   'metal',
#   'railing',
#   'on',
#   'the',
#   'right',
#   'side',
#   'of',
#   'the',
#   'road',
#   '<end>'],
#  ['<start>', 'the', 'yellow', 'container', 'is', 'close', '<end>'],
#  ['<start>', 'a', 'clear', 'and', 'blue', 'sky', '<end>'],
#  ['<start>', 'white', 'truck', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'tree', 'next', 'to', 'the', 'road', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'the', 'sky', 'is', 'blue', '<end>'],
#  ['<start>', 'street', 'light', 'on', 'a', 'long', 'black', 'post', '<end>'],
#  ['<start>', 'the', 'boat', 'has', 'white', 'sails', '<end>'],
#  ['<start>', 'man', 'wearing', 'red', 'shirt', '<end>'],
#  ['<start>', 'a', 'scene', 'during', 'the', 'day', 'time', '<end>'],
# ...
#   'the',
#   'walkway',
#   '<end>'],
#  ['<start>', 'window', 'on', 'house', 'boat', '<end>'],
#  ['<start>',
#   'a',
#   'tall',
#   'white',
#   'building',
#   'on',
#   'a',
#   'city',
#   'street',
#   '<end>'],
#  ['<start>', 'this', 'is', 'a', 'man', '<end>'],
#  ['<start>', 'a', 'scene', 'outside', '<end>'],
#  ['<start>', 'car', 'parked', 'on', 'street', '<end>'],
#  ['<start>', 'a', 'pair', 'of', 'black', 'pants', '<end>'],
#  ['<start>', 'a', 'white', 'commercial', 'van', '<end>'],
#  ['<start>', 'the', 'street', 'is', 'dimly', 'lit', '<end>'],
#  ['<start>', 'bright', 'light', 'by', 'the', 'street', '<end>'],
#  ['<start>', 'a', 'person', 'walking', 'on', 'a', 'street', '<end>'],
#  ['<start>', 'a', 'tall', 'lamp', 'post', 'lit', 'up', 'at', 'night', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'courtyard', '<end>'],
#  ['<start>', 'a', 'person', 'walking', 'on', 'a', 'sidewalk', '<end>'],
#  ['<start>', 'white', 'hatchback', '<end>'],
#  ['<start>', 'a', 'car', 'on', 'a', 'street', '<end>'],
#  ['<start>', 'several', 'people', 'on', 'a', 'sidewalk', '<end>'],
#  ['<start>', 'a', 'red', 'fourdoor', 'vehicle', '<end>'],
#  ['<start>',
#   'the',
#   'road',
#   'is',
#   'black',
#   'and',
#   'white',
#   'in',
#   'color',
#   '<end>'],
#  ['<start>', 'the', 'archway', 'is', 'ornate', '<end>'],
#  ['<start>', 'woman', 'wearing', 'large', 'flare', 'jeans', '<end>'],
#  ['<start>', 'a', 'tall', 'black', 'trash', 'can', '<end>'],
#  ['<start>', 'glass', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'a', 'bike', 'with', 'a', 'basket', '<end>'],
#  ['<start>', 'the', 'chimney', 'on', 'the', 'roof', '<end>'],
#  ['<start>', 'reflection', 'in', 'the', 'water', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'lamp', 'with', 'black', 'finish', '<end>'],
#  ['<start>', 'woman', 'in', 'a', 'green', 'dress', '<end>'],
#  ['<start>', 'red', 'bicycle', 'leaning', 'against', 'a', 'pole', '<end>'],
#  ['<start>', 'building', 'in', 'the', 'distance', '<end>'],
#  ['<start>', 'a', 'lady', 'wearing', 'blue', 'jeans', '<end>'],
#  ['<start>', 'a', 'window', 'with', 'a', 'white', 'frame', '<end>'],
#  ['<start>', 'a', 'parallel', 'parked', 'car', '<end>'],
#  ['<start>', 'tall', 'skinny', 'pine', 'tree', '<end>'],
#  ['<start>', 'a', 'rubber', 'car', 'tire', '<end>'],
#  ['<start>', 'vertical', 'column', 'of', 'several', 'windows', '<end>'],
#  ['<start>', 'a', 'yellow', 'license', 'plate', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'a', 'silver', 'suv', '<end>'],
#  ['<start>', 'many', 'clouds', 'in', 'the', 'sky', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'trash', 'can', 'made', 'of', 'stone', 'and', 'metal', '<end>'],
#  ['<start>', 'lot', 'full', 'of', 'cars', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>',
#   'two',
#   'palm',
#   'trees',
#   'on',
#   'top',
#   'of',
#   'a',
#   'building',
#   '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'a', 'stopped', 'white', 'minivan', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'buliding', '<end>'],
#  ['<start>', 'statue', 'on', 'top', 'of', 'a', 'pedestal', '<end>'],
#  ['<start>', 'this', 'is', 'an', 'urban', 'area', '<end>'],
#  ['<start>', 'bench', 'made', 'of', 'dark', 'brown', 'wood', '<end>'],
#  ['<start>', 'a', 'man', 'walking', 'past', 'the', 'store', '<end>'],
#  ['<start>', 'glass', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'red', 'sign', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'this', 'is', 'watch', 'tower', '<end>'],
#  ['<start>', 'blue', 'car', 'driving', 'on', 'road', '<end>'],
#  ['<start>', 'blue', 'sign', 'with', 'the', 'arrow', '<end>'],
#  ['<start>', 'row', 'of', 'windows', 'on', 'a', 'red', 'building', '<end>'],
#  ['<start>', 'red', 'building', 'with', 'white', 'columns', '<end>'],
#  ['<start>', 'a', 'small', 'white', 'car', '<end>'],
#  ['<start>', 'a', 'car', 'on', 'a', 'street', '<end>'],
#  ['<start>', 'a', 'woman', 'pushing', 'a', 'baby', 'stroller', '<end>'],
#  ['<start>', 'car', 'on', 'the', 'dirt', '<end>'],
#  ['<start>', 'metal', 'railing', 'on', 'top', 'of', 'building', '<end>'],
#  ['<start>', 'the', 'roof', 'is', 'tiled', '<end>'],
#  ['<start>', 'treed', 'hilltops', 'in', 'the', 'distance', '<end>'],
#  ['<start>', 'the', 'car', 'is', 'parked', '<end>'],
#  ['<start>', 'three', 'story', 'stone', 'building', '<end>'],
#  ['<start>', 'two', 'red', 'cars', 'in', 'a', 'row', '<end>'],
#  ['<start>', 'white', 'car', 'parked', 'in', 'street', '<end>'],
#  ['<start>', 'blue', 'and', 'white', 'sky', '<end>'],
#  ['<start>', 'a', 'black', 'car', 'in', 'intersection', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'man', 'wearing', 'a', 'red', 'jacket', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'glass', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'a', 'white', 'parked', 'car', '<end>'],
#  ['<start>', 'bicycle', 'leaning', 'against', 'pole', '<end>'],
#  ['<start>', 'the', 'house', 'is', 'green', '<end>'],
#  ['<start>', 'the', 'person', 'is', 'walking', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'glass', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'a', 'long', 'curve', 'walkway', '<end>'],
#  ['<start>', 'a', 'womans', 'blue', 'bag', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'large', 'building', '<end>'],
#  ['<start>',
#   'a',
#   'light',
#   'blue',
#   'sky',
#   'with',
#   'large',
#   'white',
#   'clouds',
#   '<end>'],
#  ['<start>',
#   'green',
#   'street',
#   'sign',
#   'that',
#   'says',
#   'congress',
#   'st',
#   '<end>'],
#  ['<start>', 'red', 'and', 'grey', 'suv', '<end>'],
#  ['<start>', 'window', 'on', 'building', 'facing', 'street', '<end>'],
#  ['<start>', 'some', 'deep', 'tire', 'tracks', 'in', 'the', 'snow', '<end>'],
#  ['<start>', 'a', 'street', 'covered', 'with', 'snow', '<end>'],
#  ['<start>', 'the', 'cars', 'are', 'covered', 'in', 'snow', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'windown', 'on', 'dark', 'red', 'building', '<end>'],
#  ['<start>', 'white', 'snow', 'on', 'the', 'ground', '<end>'],
#  ['<start>',
#   'window',
#   'on',
#   'top',
#   'floor',
#   'of',
#   'white',
#   'building',
#   '<end>'],
#  ['<start>', 'a', 'yellow', 'and', 'blue', 'sign', '<end>'],
#  ['<start>', 'person', 'walking', 'on', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'red', 'dresses', 'in', 'the', 'window', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'city', 'street', '<end>'],
#  ['<start>', 'the', 'red', 'blurry', 'sign', '<end>'],
#  ['<start>', 'woman', 'in', 'dress', 'walking', '<end>'],
#  ['<start>', 'sign', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'glass', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'an', 'ornate', 'black', 'street', 'light', '<end>'],
#  ['<start>', 'glass', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'orange', 'bar', 'on', 'fence', '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'pole', 'on', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'these', 'are', 'a', 'bunch', 'of', 'buildings', '<end>'],
#  ['<start>', 'car', '<end>'],
#  ['<start>', 'the', 'person', 'is', 'standing', '<end>'],
#  ['<start>', 'the', 'person', 'is', 'walking', '<end>'],
#  ['<start>', 'window', 'on', 'corner', 'building', '<end>'],
#  ['<start>', 'glass', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'tractor', 'parked', 'on', 'sidewalk', '<end>'],
#  ['<start>', 'leg', 'of', 'the', 'bench', '<end>'],
#  ['<start>', 'a', 'person', 'walking', 'on', 'a', 'sidewalk', '<end>'],
#  ['<start>', 'a', 'car', 'on', 'a', 'street', '<end>'],
#  ['<start>', 'light', 'on', 'the', 'pole', '<end>'],
#  ['<start>', 'round', 'black', 'tire', 'on', 'car', '<end>'],
#  ['<start>', 'a', 'white', 'line', 'in', 'the', 'street', '<end>'],
#  ['<start>', 'car', 'parked', 'at', 'the', 'curb', '<end>'],
#  ['<start>', 'the', 'sky', 'is', 'grey', 'and', 'white', '<end>'],
#  ['<start>', 'lamp', 'pole', 'near', 'a', 'road', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'car', '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'the', 'car', 'is', 'gold', '<end>'],
#  ['<start>', 'the', 'grey', 'car', 'driving', 'on', 'the', 'street', '<end>'],
#  ['<start>', 'a', 'red', 'and', 'white', 'sign', '<end>'],
#  ['<start>',
#   'two',
#   'semicircular',
#   'tunnels',
#   'set',
#   'in',
#   'a',
#   'hill',
#   '<end>'],
#  ['<start>', 'silver', 'car', 'parked', 'in', 'the', 'street', '<end>'],
#  ['<start>', 'this', 'is', 'a', 'man', '<end>'],
#  ['<start>', 'taillight', 'of', 'a', 'vehicle', '<end>'],
#  ['<start>',
#   'white',
#   'van',
#   'parked',
#   'in',
#   'front',
#   'of',
#   'sidewalk',
#   '<end>'],
#  ['<start>', 'the', 'car', 'is', 'white', '<end>'],
#  ['<start>', 'the', 'vehicles', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'metal', 'guard', 'rail', 'beside', 'of', 'road', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'flower', 'bed', 'in', 'street', '<end>'],
#  ['<start>', 'red', 'car', 'parked', 'in', 'the', 'street', '<end>'],
#  ['<start>', 'round', 'ball', 'with', 'letters', 'airis', '<end>'],
#  ['<start>', 'the', 'car', 'is', 'black', '<end>'],
#  ['<start>', 'a', 'round', 'blue', 'and', 'white', 'sign', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>',
#   'the',
#   'small',
#   'stone',
#   'wall',
#   'on',
#   'the',
#   'side',
#   'of',
#   'the',
#   'road',
#   '<end>'],
#  ['<start>', 'a', 'red', 'vehicle', 'on', 'a', 'highway', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'car', '<end>'],
#  ['<start>', 'a', 'car', 'on', 'a', 'street', '<end>'],
#  ['<start>', 'the', 'black', 'aentenna', 'ont', 'he', 'hood', '<end>'],
#  ['<start>', 'board', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'the', 'car', 'is', 'silver', '<end>'],
#  ['<start>', 'leaves', 'on', 'the', 'tree', '<end>'],
#  ['<start>', 'the', 'wooden', 'bench', 'on', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'trunk', 'of', 'the', 'tree', '<end>'],
#  ['<start>', 'window', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'tree', 'is', 'bare', 'and', 'in', 'the', 'park', '<end>'],
#  ['<start>', 'leaf', 'in', 'the', 'water', '<end>'],
#  ['<start>', 'person', 'in', 'black', 'shorts', '<end>'],
#  ['<start>', 'car', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'a', 'tree', 'in', 'a', 'city', '<end>'],
#  ['<start>', 'the', 'sitting', 'arrangement', 'on', 'a', 'street', '<end>'],
#  ['<start>', 'the', 'numbers', 'above', 'the', 'door', '<end>'],
#  ['<start>', 'a', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'the', 'plate', 'is', 'black', 'in', 'color', '<end>'],
#  ['<start>', 'orange', 'color', 'on', 'truck', '<end>'],
#  ['<start>', 'white', 'lines', 'on', 'the', 'road', '<end>'],
#  ['<start>', 'the', 'car', 'is', 'silver', '<end>'],
#  ['<start>', 'silver', 'car', 'parked', 'along', 'the', 'street', '<end>'],
#  ['<start>', 'skyscraper', 'in', 'front', 'of', 'car', '<end>'],
#  ['<start>', 'parked', 'silver', 'suv', '<end>'],
#  ['<start>',
#   'round',
#   'white',
#   'lamp',
#   'on',
#   'top',
#   'of',
#   'lamp',
#   'post',
#   '<end>'],
#  ['<start>', 'green', 'shutters', 'on', 'the', 'building', '<end>'],
#  ['<start>', 'the', 'door', 'is', 'brown', '<end>'],
#  ['<start>', 'shallow', 'pool', 'with', 'three', 'fountain', 'heads', '<end>'],
#  ['<start>', 'woman', 'in', 'white', 'and', 'red', 'shirt', '<end>'],
#  ['<start>', 'thick', 'hedge', 'bordering', 'the', 'sidewalk', '<end>'],
#  ['<start>', 'the', 'sky', 'is', 'shining', 'and', 'blue', '<end>'],
#  ['<start>', 'leaves', 'on', 'the', 'tree', '<end>'],
#  ['<start>', 'two', 'street', 'lights', '<end>'],
#  ['<start>', 'person', 'in', 'red', 'jacket', '<end>'],
#  ['<start>', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'people', 'eating', 'outside', '<end>'],
#  ['<start>', 'two', 'traffic', 'lights', 'lit', 'up', 'red', '<end>'],
#  ['<start>', 'a', 'black', 'parked', 'car', '<end>'],
#  ['<start>', 'a', 'parked', 'black', 'car', '<end>'],
#  ['<start>', 'dark', 'green', 'suv', '<end>'],
#  ['<start>', 'mural', 'of', 'bird', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'window', 'on', 'a', 'building', '<end>'],
#  ['<start>', 'man', 'standing', 'in', 'front', 'of', 'wall', '<end>'],
#  ['<start>', 'man', 'with', 'brown', 'hair', '<end>'],
#  ['<start>', 'one', 'grey', 'stapler', '<end>'],
#  ['<start>', 'woman', 'has', 'an', 'eye', '<end>'],
#  ['<start>', 'bench', 'with', 'person', 'sitting', 'and', 'waiting', '<end>'],
#  ['<start>', 'he', 'is', 'wearing', 'blue', 'jeans', '<end>'],
#  ['<start>', 'the', 'truck', 'is', 'red', '<end>'],
#  ['<start>', 'person', 'wearing', 'shirt', '<end>'],
#  ['<start>', 'man', 'in', 'a', 'white', 'shirt', '<end>'],
#  ['<start>', 'man', 'walking', 'wearing', 'white', 'shoes', '<end>'],
#  ['<start>', 'tall', 'dog', 'in', 'a', 'field', '<end>'],
#  ['<start>', 'man', 'has', 'white', 'teeth', '<end>'],
#  ['<start>', 'person', 'looking', 'at', 'the', 'camera', '<end>'],
#  ['<start>', 'person', 'standing', 'on', 'mountain', '<end>'],
#  ['<start>', 'sidewalk', 'with', 'block', 'pattern', '<end>'],
#  ['<start>', 'the', 'building', 'is', 'tall', '<end>'],
#  ['<start>',
#   'a',
#   'man',
#   'with',
#   'short',
#   'hair',
#   'and',
#   'a',
#   'goatee',
#   '<end>'],
#  ['<start>', 'the', 'trunk', 'of', 'a', 'tree', '<end>'],
#  ['<start>', 'dog', 'is', 'sitting', 'in', 'grass', '<end>'],
#  ['<start>', 'man', 'wearing', 'a', 'yellow', 'sweater', '<end>'],
#  ['<start>', 'a', 'scene', 'during', 'the', 'day', 'time', '<end>'],
#  ['<start>', 'the', 'hand', 'is', 'on', 'table', '<end>'],
#  ['<start>', 'the', 'stapler', 'laying', 'on', 'the', 'floor', '<end>'],
#  ['<start>', 'cliff', 'in', 'the', 'water', '<end>'],
#  ['<start>',
#   'car',
#   'in',
#   'the',
#   'arch',
#   'of',
#   'the',
#   'hotel',
#   'entrance',
#   '<end>'],
#  ['<start>', 'boat', 'at', 'the', 'edge', 'of', 'water', '<end>'],
#  ['<start>', 'head', 'shot', 'of', 'a', 'young', 'white', 'man', '<end>'],
#  ['<start>', 'a', 'scene', 'during', 'the', 'day', 'time', '<end>'],
#  ['<start>', 'plane', 'sitting', 'on', 'the', 'runway', '<end>'],
#  ['<start>', 'a', 'gray', 'stapler', 'on', 'the', 'corner', 'desk', '<end>'],
#  ['<start>', 'the', 'person', 'wearing', 'red', '<end>'],
#  ['<start>', 'head', 'shot', 'of', 'a', 'young', 'woman', '<end>'],
#  ['<start>', 'photo', 'taken', 'during', 'the', 'day', '<end>'],
#  ['<start>', 'license', 'plate', 'of', 'a', 'car', '<end>'],
#  ['<start>', 'circle', 'on', 'the', 'wood', 'door', '<end>'],
#  ['<start>', 'brown', 'rock', 'near', 'highway', '<end>'],
#  ['<start>', 'man', 'in', 'the', 'kitchen', '<end>'],
#  ['<start>', 'underside', 'of', 'the', 'lane', 'highway', '<end>'],
#  ['<start>', 'man', 'has', 'short', 'hair', '<end>'],
#  ['<start>', 'person', 'wears', 'a', 'green', 'shirt', '<end>'],
#  ['<start>', 'a', 'green', 'parrot', '<end>'],
#  ['<start>', 'green', 'leaves', 'on', 'brown', 'tree', '<end>'],
#  ['<start>', 'window', 'facing', 'red', 'building', '<end>'],
#  ['<start>', 'windows', 'on', 'the', 'top', 'level', '<end>'],
#  ['<start>', 'right', 'ear', 'of', 'a', 'man', '<end>'],
#  ['<start>', 'stone', 'block', 'on', 'pier', '<end>'],
#  ['<start>', 'green', 'wall', 'behind', 'a', 'man', '<end>'],
#  ['<start>', 'the', 'background', 'is', 'blue', '<end>'],
#  ['<start>', 'guy', 'with', 'short', 'brown', 'hair', '<end>'],
#  ['<start>', 'four', 'black', 'chairs', 'around', 'a', 'table', '<end>'],
#  ['<start>', 'big', 'green', 'truck', 'on', 'dirt', 'road', '<end>'],
#  ['<start>', 'man', 'wearing', 'yellow', 'sweater', '<end>'],
#  ['<start>', 'a', 'person', 'walking', 'on', 'a', 'sidewalk', '<end>'],
#  ['<start>', 'laptop', 'computer', 'sitting', 'on', 'desk', '<end>'],
#  ['<start>', 'coffee', 'cup', 'on', 'the', 'table', '<end>'],
#  ['<start>', 'black', 'sign', 'with', 'white', 'letters', '<end>'],
#  ['<start>', 'trunk', 'of', 'tree', '<end>'],
#  ['<start>', 'a', 'rock', 'in', 'water', '<end>'],
#  ['<start>', 'white', 'van', 'in', 'the', 'parking', 'lot', '<end>'],
#  ['<start>', 'parrot', 'sitting', 'on', 'a', 'tree', 'branch', '<end>'],
#  ...]

# %%
### english word embeddings
model_e = gensim.models.Word2Vec(eng , vector_size = 100 , min_count = 1 , window = 2)

# %%
model_e.train(eng , epochs = 50 , total_examples = len(clean_english_lines))
# Out:
# (5122391, 10040650)

# %%
model_e.wv.get_vector('<start>')
# Out:
# array([ 0.63226235,  0.07326045,  0.08264413, -0.28418985, -1.4862686 ,
#         0.54313266,  0.8832349 ,  0.16667123, -0.9001615 , -0.42769414,
#         1.0355892 ,  0.2561295 ,  0.39911753,  0.38124356, -0.3462795 ,
#        -1.0242969 ,  0.7896572 ,  0.69668746,  0.3062607 , -0.6927859 ,
#        -0.39012143, -1.0796406 , -0.20258614,  0.198911  ,  1.5238084 ,
#        -0.2047223 ,  0.0508874 ,  0.07792722,  0.63066685, -0.33229363,
#         0.9738102 ,  0.17071792, -0.14397371, -0.38410005, -1.09202   ,
#        -0.3555798 ,  0.00577452,  0.06813556, -0.9186177 , -0.203931  ,
#         0.33113986, -1.5539758 ,  0.16176265, -0.34438342,  0.08331409,
#        -0.6060499 , -0.24326384,  0.3220264 , -0.6458316 ,  0.20457365,
#         0.76374245, -0.00802057,  1.038     , -0.5834782 , -0.4885547 ,
#        -0.7826476 , -0.0912772 ,  0.6912189 ,  0.3581428 , -0.5622137 ,
#        -0.14659312, -0.47453663,  0.59545213, -0.18514645,  0.60075104,
#         0.21430406, -0.59236604, -0.27423164, -0.20341146, -0.44386077,
#        -0.15016216,  0.96869874, -0.24447131,  0.4626523 ,  0.0574465 ,
#         0.9840721 , -0.7090386 , -1.2090533 , -1.8191223 ,  1.9815693 ,
#         1.0370226 , -0.74057376,  0.7442725 ,  0.19982818,  0.71689427,
#         0.64018375,  0.51513255, -0.07365946, -0.48345557, -0.6650146 ,
#         1.0284637 , -0.04287209,  0.6067313 , -0.29983214, -0.04543184,
#         0.9716999 ,  1.3668853 , -0.7821592 ,  0.46444386,  0.4712549 ],
#       dtype=float32)

# %%
embeddings_dictionary = {}
for word in eng_lang_tokenizer.word_index:
    try:
        embeddings_dictionary[word] = model_e.wv.get_vector(word)
    except:
        pass
    
print("the no of key-value pairs:"  , len(embeddings_dictionary))
embeddings_dictionary
# Out:
# the no of key-value pairs: 5552
# {'<start>': array([ 0.63226235,  0.07326045,  0.08264413, -0.28418985, -1.4862686 ,
#          0.54313266,  0.8832349 ,  0.16667123, -0.9001615 , -0.42769414,
#          1.0355892 ,  0.2561295 ,  0.39911753,  0.38124356, -0.3462795 ,
#         -1.0242969 ,  0.7896572 ,  0.69668746,  0.3062607 , -0.6927859 ,
#         -0.39012143, -1.0796406 , -0.20258614,  0.198911  ,  1.5238084 ,
#         -0.2047223 ,  0.0508874 ,  0.07792722,  0.63066685, -0.33229363,
#          0.9738102 ,  0.17071792, -0.14397371, -0.38410005, -1.09202   ,
#         -0.3555798 ,  0.00577452,  0.06813556, -0.9186177 , -0.203931  ,
#          0.33113986, -1.5539758 ,  0.16176265, -0.34438342,  0.08331409,
#         -0.6060499 , -0.24326384,  0.3220264 , -0.6458316 ,  0.20457365,
#          0.76374245, -0.00802057,  1.038     , -0.5834782 , -0.4885547 ,
#         -0.7826476 , -0.0912772 ,  0.6912189 ,  0.3581428 , -0.5622137 ,
#         -0.14659312, -0.47453663,  0.59545213, -0.18514645,  0.60075104,
#          0.21430406, -0.59236604, -0.27423164, -0.20341146, -0.44386077,
#         -0.15016216,  0.96869874, -0.24447131,  0.4626523 ,  0.0574465 ,
#          0.9840721 , -0.7090386 , -1.2090533 , -1.8191223 ,  1.9815693 ,
#          1.0370226 , -0.74057376,  0.7442725 ,  0.19982818,  0.71689427,
#          0.64018375,  0.51513255, -0.07365946, -0.48345557, -0.6650146 ,
#          1.0284637 , -0.04287209,  0.6067313 , -0.29983214, -0.04543184,
#          0.9716999 ,  1.3668853 , -0.7821592 ,  0.46444386,  0.4712549 ],
#        dtype=float32),
#  '<end>': array([ 0.08991314, -0.29862863,  0.69085556,  0.04588427, -0.19975008,
#          0.3772354 ,  1.0204172 ,  0.04979562, -0.76941895, -0.4010687 ,
#          0.33390862,  0.22723536, -0.25789645, -0.44104418,  0.7329719 ,
#         -0.35427547,  0.76418304,  0.59232783, -0.6437687 ,  0.0619822 ,
#         -0.14181502, -1.0236597 ,  0.6814196 ,  0.6452524 , -0.15211447,
#          0.468878  ,  0.69025254,  0.15266216,  0.6887991 ,  0.6387    ,
#          0.3871666 ,  0.99139106, -0.4419733 , -0.3909822 , -0.4461238 ,
#         -0.27109   , -0.25359273,  0.27854732, -0.6616017 , -0.04812932,
#          0.66313785, -0.85244316, -0.30823195,  0.3884991 ,  0.4569325 ,
#          0.553106  ,  0.30238685, -0.35399437, -0.10469494, -0.6280128 ,
#          0.14754918, -0.07520694,  0.60396785, -1.1703948 , -0.3696781 ,
#          0.06879368,  0.10530614,  0.70190907,  0.49472982,  0.6289351 ,
#         -0.5004221 ,  0.07149117,  0.07003516, -0.13868545,  1.2111616 ,
#         -0.30484992, -0.2008972 , -0.13694508, -0.0420935 ,  0.16357523,
#         -0.23895608,  0.22485885,  0.04084651,  0.18824476, -0.0302205 ,
#          0.2153778 , -1.5000113 ,  0.23106693, -0.41077524,  1.260022  ,
#         -0.11198821, -0.49516156, -0.22788745,  0.07819074,  0.33153734,
#         -0.12339689,  0.04207347, -0.76842946,  0.02895813, -1.4698756 ,
#          0.48826456,  0.44783932,  0.02796503,  0.4850154 , -0.41459447,
#          0.4899197 ,  1.0228295 ,  0.13111468,  0.12542826,  0.8378847 ],
#        dtype=float32),
#  'a': array([-2.6811382e-02,  2.8736845e-01,  8.5076433e-01, -1.0334774e+00,
#         -3.2508960e-01, -1.3408132e-04, -2.0006749e-01, -7.4038261e-01,
#         -1.1150527e+00,  6.0249329e-01,  1.0472191e-01,  4.6500134e-01,
#         -2.6816761e-02, -1.2413483e-01, -8.2551765e-01, -8.1147772e-01,
#          1.3188659e+00,  7.1321881e-01, -1.4349062e+00, -5.6429392e-01,
#         -7.1323180e-01, -1.0628532e+00,  3.4511304e-01, -3.0386737e-02,
#          7.4611330e-01,  3.1686630e-02, -3.1428313e-01, -3.7086728e-01,
#          5.6384271e-01,  1.1145232e+00, -1.6824302e-01,  1.2752550e+00,
#         -4.5266235e-01, -8.5613526e-02, -6.4078867e-01, -2.6603529e-01,
#         -1.4381962e-02, -8.4461272e-02,  9.6222423e-02, -4.0541893e-01,
#          5.4899162e-01, -8.3049536e-01, -1.0233015e-01, -2.8675380e-01,
#          3.1818295e-01,  7.9327136e-01, -1.8118697e-01,  3.8435161e-01,
#         -1.0980735e+00,  4.3653375e-01, -5.9751689e-01, -5.7412881e-01,
#         -2.8155053e-02, -9.5196795e-01, -9.3975782e-01, -7.7136314e-01,
#         -5.6155002e-01,  3.8137849e-02,  9.9076521e-01, -8.4499478e-02,
#         -1.4548075e-01, -7.3108089e-01,  1.7318420e-01, -1.4340584e-01,
#          7.3560798e-01,  2.8488374e-01, -1.0164717e+00,  6.8451172e-01,
#         -7.0669955e-01,  5.8408952e-01,  2.5243750e-01,  4.9402660e-01,
#         -5.5339473e-01,  2.7854416e-01,  1.7601198e-01,  9.1334790e-01,
#         -7.5877416e-01,  4.0644786e-01, -1.4518967e+00,  1.6027895e+00,
#          1.9019288e-01, -1.5153941e+00,  1.3345331e-02, -2.5739557e-01,
#          5.0586224e-01, -4.0752582e-02, -5.2799529e-01, -1.1385220e+00,
#         -9.9010773e-02, -6.7212218e-01,  1.3192883e+00,  6.9872838e-01,
#          1.3097696e-01,  7.4066758e-02,  5.2312791e-01,  7.2759461e-01,
#          1.6210009e+00, -6.1462736e-01,  5.6372941e-01,  1.0348783e+00],
#        dtype=float32),
#  'the': array([-0.08702428,  0.34598207,  0.5266292 , -0.43660745,  0.06039118,
#          0.8376086 ,  0.5753228 , -0.18376733, -0.7773342 ,  1.0145638 ,
#         -0.23738472, -0.34427893,  0.5160181 ,  0.02071146,  0.4871574 ,
#          0.06158355,  0.4069083 , -1.080491  , -1.6400673 ,  0.683115  ,
#         -0.06961195, -1.1280012 ,  0.04764223,  1.3264222 , -0.19665109,
#          0.23138887, -0.766538  ,  0.22798786,  0.95802945,  0.83922297,
#         -0.197866  ,  0.36059383, -0.5525673 ,  0.20884395,  0.1133775 ,
#         -1.0222038 ,  0.3756991 , -0.42336476,  0.78413224,  0.660316  ,
#         -0.27409226, -0.60823405,  0.5456828 ,  0.9581359 ,  0.2445456 ,
#          1.1996627 ,  0.23473588, -0.26752716, -0.23501301,  0.05987066,
#         -0.04784374, -0.7642956 , -0.12513453, -1.477049  , -1.1136765 ,
#         -0.75802994,  0.19896987,  0.673232  ,  1.4658544 ,  0.5245929 ,
#         -0.6302057 ,  0.31900656, -0.2681686 , -0.92552775,  1.0061688 ,
#         -0.7603865 ,  0.07504468,  0.6567825 , -0.7332588 , -0.38864356,
#          0.13650289, -0.25594932, -0.3319262 , -0.37569785,  0.2637154 ,
#          0.4910165 , -1.4922161 ,  1.0442472 , -0.4521401 ,  1.2854713 ,
#         -0.39255825, -0.5627359 , -0.42542386,  0.65896016,  0.5663234 ,
#          0.45806202, -0.26931074, -0.338701  , -0.18183829, -0.6824107 ,
#          0.44043365,  1.1547712 , -0.5159285 ,  0.2169447 , -0.23800641,
#          0.21076348,  0.9482644 , -0.41157532,  0.3324444 ,  0.56103075],
#        dtype=float32),
#  'on': array([ 0.70666885, -0.2448649 , -0.81459343,  0.01772177, -0.24253365,
#         -0.5576853 ,  0.4672948 , -0.5524543 , -0.8381201 , -0.6184153 ,
#          1.4029294 , -0.774071  , -0.4948911 ,  0.4983293 ,  0.4388104 ,
#          0.03656977,  0.22989725, -0.22222486,  0.3307283 , -1.2680225 ,
#          1.0843109 , -0.18712008, -0.12364447,  0.543174  ,  0.7180166 ,
#          1.2231237 , -1.2966092 ,  0.8547246 , -0.7146506 , -0.56722003,
#          0.11744371,  0.9096333 , -0.01542065, -0.50742364,  1.1023889 ,
#          0.14766762, -0.57445997, -0.8856087 , -0.07954672, -0.3819913 ,
#          0.43866462, -0.52911663,  0.8014778 ,  0.05575191,  0.29450613,
#         -1.2275958 ,  0.12877864,  0.9202174 ,  0.02526405,  0.25509873,
#          0.0958619 ,  0.8825366 ,  0.6121087 ,  0.13362923,  1.0578341 ,
#         -0.37943882, -0.75133586,  0.356976  ,  0.28794685, -1.2271323 ,
#          0.79833853,  0.24170598,  1.1573482 , -1.4438381 , -1.0940048 ,
#         -0.28577617,  1.8496349 ,  0.49385494,  0.3671778 ,  0.46115822,
#         -0.7989661 ,  1.4618195 ,  0.37770107, -0.79325694,  0.05732323,
#          0.0848037 , -0.5386044 ,  0.728131  , -0.66358346, -1.0567012 ,
#          1.1409612 , -0.02249917, -0.2135833 , -0.15852056, -0.35542393,
#          1.0957196 ,  0.07622936,  0.30285844, -1.8026277 ,  0.10271613,
#          0.17330486, -0.4265392 ,  0.20443809, -0.41821525, -0.0251114 ,
#          0.08660094, -0.14929014, -0.42313528, -0.23388453, -0.22846916],
#        dtype=float32),
#  'of': array([-0.8467128 , -0.5321929 , -0.3571554 , -0.76131326, -0.37958694,
#          0.5616005 ,  0.21328834, -1.323929  , -1.6621873 , -2.3713963 ,
#          0.4679981 , -0.735362  ,  0.3089105 , -0.20299418,  1.1624231 ,
#         -0.6676977 ,  0.70423526, -1.3775718 , -0.5818833 , -1.0230867 ,
#          0.22359481,  0.8084413 ,  0.97882587,  1.4858872 , -0.2324627 ,
#         -0.42068908,  0.11435311,  0.7282782 , -0.12401379,  0.17261042,
#         -0.3846708 , -0.5974123 , -0.62923867, -0.27744564,  0.25511745,
#          0.86067706,  0.47558618,  0.71419036,  1.3709764 , -0.8957954 ,
#          0.35446388, -1.4489794 ,  0.24782278,  0.8022401 ,  1.2507538 ,
#         -1.2416219 , -0.77402383,  0.9961071 ,  0.13008988,  0.14418302,
#          1.3041155 ,  0.6504604 ,  0.32580262,  0.7398056 , -0.8368182 ,
#          0.6764659 ,  0.8293999 , -0.13097075,  0.3612825 , -1.6810174 ,
#          0.1827943 ,  0.5585194 ,  1.1484541 , -0.7340267 , -0.68339944,
#          0.08027605, -0.10122461, -0.2932893 , -1.5846497 , -1.0032481 ,
#          0.94339484,  1.2158841 ,  1.4303774 , -0.19513614, -1.3652847 ,
#          1.0002162 ,  0.39483568,  0.43136987,  0.21373549,  1.0531776 ,
#          1.320464  , -0.52536803,  0.89532155, -0.90876764,  1.3981655 ,
#          0.08154325, -0.0833348 ,  0.5037256 , -0.03416619,  0.69962347,
#         -0.3558341 ,  0.29566   , -0.96153075,  0.24145664,  0.9419526 ,
#          0.99777424, -0.96925867, -1.2876167 , -1.1662468 , -0.75458914],
#        dtype=float32),
#  'is': array([-3.15401673e-01, -9.17929411e-01, -4.83926803e-01,  2.89631695e-01,
#         -3.81205440e-03,  1.94643699e-02,  4.42958385e-01, -2.80140430e-01,
#         -2.64357954e-01, -9.33974385e-01,  8.22184235e-02,  3.70477706e-01,
#          7.39177763e-01,  6.13678515e-01, -3.84879857e-01,  5.52042663e-01,
#          1.79962707e+00,  9.45222557e-01,  1.56070078e-02, -1.58043504e+00,
#          1.09289765e+00,  5.67074001e-01,  1.05372727e+00,  5.18008292e-01,
#         -2.83404529e-01, -2.31482565e-01, -9.72874388e-02,  3.69490236e-02,
#         -1.36925471e+00, -8.14542115e-01,  1.27314734e+00,  2.62490511e-01,
#          1.05624497e-01, -2.44674236e-01, -6.77711487e-01,  6.94456875e-01,
#          6.66094795e-02, -5.50821662e-01, -1.28108704e+00,  2.80268431e-01,
#          7.44875431e-01,  8.71495605e-01,  1.47242773e+00, -1.28183544e+00,
#          6.95783556e-01,  1.61327744e+00, -7.10094571e-01, -3.77548367e-01,
#         -5.47934413e-01, -9.65172276e-02,  1.25867105e+00, -1.30640042e+00,
#         -1.43319583e+00, -2.99692035e-01,  8.23733956e-02,  2.75971055e-01,
#          4.08479929e-01, -8.33096266e-01, -1.27148837e-01, -3.03147227e-01,
#          6.09967887e-01, -4.82000560e-01,  8.97185326e-01,  7.79875815e-02,
#          5.17877162e-01,  6.83137417e-01, -1.46559656e-01,  1.21926535e-02,
#          6.39296472e-02, -2.34312296e-01, -5.10598063e-01,  3.27587277e-01,
#         -1.74707100e-01,  5.54798961e-01,  1.01584840e+00, -3.11187863e-01,
#          4.67828304e-01,  8.95880256e-03, -1.41894424e+00,  8.89015794e-01,
#          4.65954542e-01, -1.08678365e+00, -7.33860672e-01, -7.14874029e-01,
#          7.10506916e-01,  4.03665304e-01,  3.15470308e-01, -1.59303451e+00,
#         -1.16354428e-01, -1.10119879e+00, -1.14886418e-01,  8.19718182e-01,
#          1.04047656e+00, -3.13844085e-01,  1.03295612e+00, -9.27722305e-02,
#          1.05411410e+00, -6.87153459e-01,  1.66734192e-03,  7.42478073e-01],
#        dtype=float32),
#  'in': array([ 2.4688292 , -1.0194608 ,  0.70686847,  1.6649066 , -0.1953947 ,
#         -0.05904278,  0.08389457,  0.42625105, -0.6771285 , -0.5092844 ,
#          1.3076062 , -0.16060795, -0.5344994 ,  0.8322733 ,  0.5057971 ,
#         -0.08335502,  0.64937806,  0.585869  , -0.8217993 , -0.8135186 ,
#          0.2412716 ,  1.4198589 ,  0.57519364, -1.2063097 ,  0.21490854,
#          1.4845586 , -0.59806365,  0.09136032, -1.4891893 ,  0.08601983,
#         -0.22415242,  0.21265936,  1.2334191 ,  0.32454762,  0.4694564 ,
#         -0.43776914, -0.66122955,  0.42159688, -1.7764287 , -0.23507115,
#          0.8621291 ,  0.21417142,  0.03286127, -0.3033552 ,  0.7740602 ,
#         -0.5256181 , -0.13726786, -0.00561965,  0.5172453 , -0.45980296,
#          0.194295  ,  0.16027756,  0.32837173, -0.8232149 , -0.1089287 ,
#         -0.19007649, -0.9771244 ,  0.66405034,  0.2949346 ,  0.03276219,
#          0.26396766,  0.655524  ,  1.3190008 , -0.6759792 , -0.3671591 ,
#          1.3333719 ,  0.4495313 ,  0.5751445 , -0.30201632, -0.95050687,
#         -0.7184182 ,  0.43600777, -0.37816116, -0.73737025, -0.7309156 ,
#          1.2521086 , -0.11415526, -1.14753   ,  0.37298694,  0.44843182,
#          1.8840007 ,  0.30281386, -0.37738502, -0.29239747,  0.9090361 ,
#          1.2308873 ,  0.9188705 ,  1.0022651 , -0.84191716, -0.6502259 ,
#         -0.04942235, -1.3321674 ,  0.8811735 , -0.08128269, -0.05835595,
#          0.693705  , -0.6944935 , -1.6674328 ,  0.6291503 , -0.8358004 ],
#        dtype=float32),
#  'white': array([-1.452288  ,  1.7989149 ,  2.2339723 ,  0.3360873 , -0.8378532 ,
#          0.07674756,  0.849188  , -0.30644903, -0.9974654 , -0.4629876 ,
#         -0.13236374, -0.40796202,  0.34416652, -0.6670818 ,  1.1143115 ,
#         -0.15700838, -0.36351123, -0.44871497, -1.888034  , -0.3973815 ,
#          0.6840488 , -0.46199885,  0.2156747 , -0.76751286,  0.45523617,
#         -0.9551133 , -0.45148543,  0.6715095 ,  1.0348928 ,  0.23704632,
#          1.5638245 , -0.05533553, -0.39251077,  0.43031868,  0.39713934,
#         -1.4163941 ,  0.8293801 ,  0.43623224, -1.691035  , -0.19249886,
#         -0.86040074, -1.0475864 ,  1.6570823 ,  0.03781161, -0.15728426,
#         -0.24317817, -0.5610916 , -0.01501389, -1.9412118 , -0.42856738,
#          0.05484988, -0.57035154,  0.8866485 , -2.2631269 , -0.5678427 ,
#          0.47601482, -0.7040653 ,  0.11529785,  0.25373504, -0.58206457,
#         -0.27189416, -0.54739374,  1.3366942 ,  0.31008092, -0.29487342,
#         -0.03826429,  0.52069247,  0.14017749, -0.43408418,  0.29073545,
#         -0.40990826,  0.18609084,  0.4649147 ,  1.095371  ,  0.49219078,
#         -0.7705103 , -1.7155755 , -1.3630666 , -0.7117074 , -0.8922072 ,
#         -0.27456433,  0.22054236,  2.208716  , -0.01582837,  0.07388157,
#          0.05936436,  0.20730983, -1.2116784 , -0.73774636, -0.66564506,
#          0.05734411, -0.54647034,  0.24102874,  0.5393246 ,  0.07752454,
#          0.86332244,  1.5975192 , -0.46599808,  0.33171794,  0.32961565],
#        dtype=float32),
#  'man': array([ 0.07616788, -0.44790205, -1.5655744 ,  0.58441234,  0.41645545,
#          0.40386486,  0.9510823 ,  0.95551044, -0.18502392,  1.1323885 ,
#          0.01337765,  0.5588359 , -0.32824546,  0.33885995, -0.9585324 ,
#         -0.27472493, -0.4706723 , -0.46100676, -0.5935915 , -1.5047238 ,
#          0.9462141 , -0.15714513, -1.505145  ,  0.6048683 ,  0.03690054,
#         -1.0958034 ,  1.3352208 , -2.4907727 , -0.2021522 , -0.66663283,
#          2.707876  ,  1.8730128 ,  0.17493547,  1.2735623 , -0.6228458 ,
#         -0.17057182, -0.9103032 , -0.3433952 , -2.4102855 ,  0.2907869 ,
#          0.855022  , -1.0729502 , -1.0208089 ,  1.1278378 ,  0.11426157,
#          1.7278335 , -1.7288373 , -0.5132296 , -0.4405424 ,  0.93008584,
#         -1.265492  , -1.175939  ,  0.52649385,  0.47602984, -0.40225014,
#         -0.42935055, -1.7190974 ,  0.5858351 , -0.4986206 ,  1.2563217 ,
#          1.4186682 ,  1.0813934 ,  0.26679832, -0.6495752 , -0.663542  ,
#         -1.4530348 , -0.05888731, -1.0594761 ,  0.6036429 , -0.9466601 ,
#         -0.14397518, -1.407317  , -0.51398754, -0.23278154,  0.6668968 ,
#          0.44159144, -1.2338346 , -0.80458003, -0.2799078 ,  0.7645271 ,
#          0.46863967, -0.68005544, -0.75551856, -0.1966784 ,  0.78631854,
#         -0.98314154, -0.9402249 , -1.0466902 ,  1.0142453 , -1.2901746 ,
#         -0.4033512 ,  1.7993653 ,  0.63740885,  1.4601486 , -0.525256  ,
#         -0.00833266,  0.8027011 , -0.796858  ,  1.6561306 ,  0.41711807],
#        dtype=float32),
#  'and': array([ 1.3321211 , -1.0945815 , -0.45015147, -1.1754762 , -0.63371706,
#         -1.1630538 , -0.9203934 , -0.45084026, -0.78942466, -1.1392071 ,
#         -0.06746951, -1.4647264 ,  1.0649096 ,  1.536388  ,  0.4275039 ,
#          0.00853474,  1.3310603 , -0.23978895,  0.13063109,  0.5177662 ,
#          0.587993  , -0.07797654,  2.5934627 ,  1.2224438 ,  0.35175633,
#          1.1130146 ,  0.09484667, -0.12463432,  0.60437   ,  1.0216267 ,
#          0.8132254 ,  0.7877913 ,  1.7353805 ,  0.94038844,  0.18774994,
#          0.40983367, -0.48694554,  0.24601002, -1.1759958 , -0.49967197,
#          0.7844945 , -1.0554574 , -1.3287506 , -0.3540724 ,  0.1861384 ,
#          0.62638885, -0.75345033,  0.9869434 , -0.2189412 , -0.48134533,
#         -0.27966157,  1.336623  , -0.7754672 , -0.89553845,  0.8087873 ,
#         -1.1689069 , -1.7813542 ,  0.8554058 ,  1.0778781 ,  0.60460657,
#         -1.7308948 , -0.0062356 ,  0.07764719,  0.5114026 , -0.22820053,
#          1.0410112 , -1.731607  , -0.46188587,  1.2160354 , -0.5306783 ,
#         -0.27612305,  0.7976252 , -0.78611064,  0.7720866 ,  0.69562024,
#          1.4886055 ,  0.40835264, -2.1904573 , -1.8236084 ,  2.168741  ,
#          1.3451691 , -0.66098917,  1.0076528 ,  1.6629598 , -1.1669967 ,
#          0.00431003,  1.7401136 , -1.4283986 ,  0.867159  ,  0.5321394 ,
#          1.4033258 , -0.16067763,  1.2960595 ,  0.21684961, -0.21215881,
#         -0.74150217,  1.4363031 , -1.2694349 ,  1.330863  , -0.2735855 ],
#        dtype=float32),
#  'black': array([ 0.34357575,  0.75790787,  1.8780779 , -0.33658698, -1.5857403 ,
#         -1.0373508 ,  0.49370363,  0.596221  , -0.3213989 , -0.12243471,
#          0.37279484, -0.3202947 , -0.19936115,  0.3927651 , -0.48230875,
#         -1.2798427 ,  0.82703894, -1.2495944 ,  0.6253406 , -0.87275153,
#         -0.99259734, -1.3995885 , -0.31755528, -1.0069441 , -0.732099  ,
#         -1.3174446 ,  0.01833213,  0.33387488,  1.232505  , -0.22889158,
#          2.4738588 ,  0.8676553 , -0.61240655,  1.3630483 ,  0.0955058 ,
#         -0.9381617 , -0.03176446,  0.36764637, -1.2009066 , -1.4409003 ,
#          0.44695875, -0.35462356,  0.05067281,  0.79966956,  1.4033492 ,
#          0.7844338 ,  0.0676366 ,  1.2387121 , -1.2054816 , -1.4200085 ,
#          0.23994012, -1.2733232 ,  0.8967176 , -1.3308952 , -0.5908884 ,
#          0.3460398 ,  0.38351724,  2.2022383 ,  0.13718954, -1.1638305 ,
#         -0.88560134,  0.2323764 ,  0.91748226,  0.65022725,  0.25235137,
#         -0.07148056, -0.0455923 ,  1.4446851 , -0.34409583,  1.7192571 ,
#         -0.8196693 ,  1.6784315 , -1.1883802 ,  0.19141565,  0.5060083 ,
#          0.16549177, -0.23395617, -0.15262282, -0.98118234,  0.13985763,
#         -0.11623377,  0.22742932,  1.913418  , -0.46604246,  1.0151151 ,
#         -0.75410384, -0.5807207 , -2.0650482 , -1.5193802 , -0.6046267 ,
#          0.43536508, -1.08731   , -0.58988106,  1.3870658 ,  0.7835557 ,
#         -0.3920082 ,  0.96450007, -0.43581668, -1.1868459 ,  2.8177483 ],
#        dtype=float32),
#  'with': array([ 0.7711347 ,  0.7387166 ,  2.309963  , -0.82653207, -0.6798388 ,
#          0.41128862,  0.8434749 , -0.42708346, -1.615549  , -2.898526  ,
#          0.1566491 ,  0.52157134, -0.4704996 , -0.7494067 ,  0.4048325 ,
#         -0.03211578,  1.2744129 ,  0.82404846,  1.6337522 , -1.2045872 ,
#          0.81148547,  0.07483788,  2.1218426 ,  0.46062383, -0.4499558 ,
#          1.401297  ,  0.41598895,  0.07439221, -0.04963678,  0.70009863,
#         -0.65945137,  0.76270616,  1.5245231 , -0.12885852,  0.97034717,
#          0.26641774, -1.0413768 , -0.00319405,  0.33856723, -2.009164  ,
#          0.52665997,  0.9226816 ,  0.2718572 , -0.46733642, -0.12148593,
#         -0.5924747 ,  0.7946204 , -0.15180014,  0.3420222 , -0.23798029,
#          0.9381911 , -0.21544315, -0.24904722, -0.75156677,  1.8676381 ,
#         -1.060253  , -1.3503231 ,  0.36468488,  2.1956737 ,  0.9215853 ,
#         -1.6307397 , -1.0634977 ,  0.09513029,  0.83466923, -1.4184663 ,
#          0.6371162 , -0.11314765,  0.39817646, -0.25724238, -1.3943406 ,
#         -0.05544139, -0.09229725,  1.2391584 , -0.8244864 , -0.40771967,
#         -0.72864544,  1.0414691 , -2.0059414 , -1.418764  , -0.92970186,
#         -1.0318412 , -0.2721319 , -1.0672568 ,  1.4583431 , -0.65774214,
#         -1.3531806 ,  1.3175597 , -1.1683867 , -0.05524714,  0.49134025,
#          0.55609834, -0.6061551 ,  0.43423837, -0.05825011,  1.6788197 ,
#          0.05553262,  0.437197  , -0.6201284 ,  0.15224896, -0.5683707 ],
#        dtype=float32),
#  'red': array([ 0.47398493,  1.2227861 ,  0.967059  , -1.453549  , -0.9396684 ,
#         -2.4514365 , -0.08391408, -0.25362355, -0.46532214, -0.6854802 ,
#         -0.0565733 ,  0.12387618, -0.6013878 , -1.6557444 ,  1.2732711 ,
#          0.13201381,  1.3469877 , -0.00600981,  0.20512368, -1.0946318 ,
#          0.35729116, -1.0994766 , -0.60289216, -0.21177064,  1.244995  ,
#         -0.6065233 , -0.70688736, -0.72694564,  0.77716905, -0.48714614,
#          1.8099052 ,  0.50493836,  0.14192171,  0.20911795,  0.68927974,
#         -1.8946884 , -0.6306662 ,  0.68048507, -0.61589354, -0.5418965 ,
#          0.0196769 , -1.6265864 ,  1.5482693 ,  0.69327015, -0.65180254,
#          1.152566  , -0.92801535,  0.5050058 , -0.5547162 ,  0.58486485,
#          0.6657964 , -0.08627659,  0.43780595, -1.1008424 , -0.74453413,
#          1.327731  ,  0.5488109 ,  1.1012295 , -0.29380828,  0.35314193,
#          0.24781196,  0.10114134,  1.6836332 ,  1.546916  ,  1.5231991 ,
#          0.8120086 ,  0.21866238,  0.698353  ,  0.6866534 ,  1.5396906 ,
#          0.01498024, -0.05401939,  0.16414192,  0.48108715,  0.38220465,
#          1.7122573 ,  0.24584888, -1.4081159 ,  0.39734265,  0.49740556,
#          0.42358324,  0.49769816,  1.7160181 ,  0.12157117,  0.63985133,
#         -0.9030632 , -0.09970689, -0.6474988 , -0.19768362, -1.006789  ,
#          0.8301042 , -0.19767964,  0.75923926,  1.2567294 , -0.07124758,
#          0.4568703 ,  0.9891751 , -0.29485133,  0.80143213,  2.976821  ],
#        dtype=float32),
#  'blue': array([ 3.5041729e-01,  2.0398018e+00,  1.5757405e+00,  1.1152702e-03,
#          5.1531905e-01, -1.4051837e+00,  3.9308774e-01,  1.9562306e-01,
#          3.2438189e-01, -1.2798213e+00,  7.3526484e-01, -7.8972852e-01,
#         -9.2825085e-01,  5.5202335e-01, -1.2345238e+00,  9.5917936e-03,
#          5.9850138e-01, -6.4057255e-01, -1.0290097e+00, -2.5606036e-01,
#          1.1884866e+00, -5.6704098e-01, -7.5958449e-01, -2.3106907e-01,
#         -4.9537787e-01, -2.5968015e-01,  4.4879031e-01, -7.4061328e-01,
#          1.7599646e+00, -1.0236361e+00,  1.6910678e+00,  8.2544172e-01,
#         -1.3584288e+00,  2.0420532e-01, -4.2493102e-01, -1.8699083e+00,
#          5.0285280e-01, -1.2660360e-01, -8.4192687e-01, -5.7384297e-02,
#          4.5047724e-01, -1.6042293e+00,  2.6378143e-01,  5.2893120e-01,
#          1.2352457e-03,  1.0197340e+00, -4.8789251e-01,  4.8161337e-01,
#         -1.3938171e+00, -3.3197570e-01,  8.5614449e-01, -1.0979427e+00,
#          1.0453140e+00, -9.6160460e-01, -1.3938167e+00, -3.3284771e-01,
#          1.2005751e+00,  1.8097264e+00, -1.9469662e-01, -9.4203156e-01,
#         -9.1211069e-01,  2.7576890e-02,  1.5606502e+00,  1.0249262e+00,
#          1.0859843e+00,  3.8301548e-01, -2.8304380e-01,  1.3360645e+00,
#         -6.5536904e-01,  1.2999549e+00, -3.4416553e-01, -5.0183225e-01,
#          7.0280284e-01,  8.9866662e-01,  2.6771709e-01, -4.8280141e-01,
#          3.3595228e-01, -2.5156472e+00,  1.0704457e-01, -5.7444979e-02,
#         -7.9476166e-01,  1.3809876e-01,  2.1988926e+00,  3.2162517e-01,
#         -1.1188368e+00,  6.4495936e-02,  7.3423553e-01, -6.6092527e-01,
#         -6.5888208e-01, -7.5264341e-01,  1.1978968e+00, -3.9413813e-01,
#          2.6366183e-01,  1.7403189e+00,  4.9578750e-01, -9.9479061e-01,
#          3.6491832e-01,  5.6455088e-01, -2.3767668e-01,  2.3790302e+00],
#        dtype=float32),
#  'this': array([-0.3792632 ,  0.57200986,  0.6143529 ,  1.8355922 ,  0.25721973,
#         -0.14728144, -0.07447589,  1.8590826 , -1.0099646 ,  1.2021574 ,
#         -1.4466555 , -0.7848701 ,  0.53244007,  2.954664  ,  1.6740004 ,
#         -1.1384972 , -0.6019912 ,  0.5314095 , -0.35206935, -0.7154662 ,
#         -0.838307  ,  1.1060331 , -1.9206017 , -0.7102473 ,  1.7435882 ,
#         -0.83556825, -1.0319687 ,  0.6489977 ,  1.0199432 , -1.1637063 ,
#         -1.2411058 , -1.3322785 , -1.3472245 ,  0.08695968, -1.0249903 ,
#          0.6541502 , -0.16766784, -0.3777459 , -0.8799485 ,  0.54017544,
#         -1.4797997 , -1.1664482 , -0.5501456 ,  0.6277896 ,  0.344886  ,
#          1.1266403 , -0.94507957, -0.06112575,  0.1201372 , -1.8399364 ,
#         -0.3621093 ,  0.89495313, -0.58788055, -0.1695027 ,  0.6003289 ,
#          0.40927997,  0.4869489 , -0.07545482,  0.4944155 , -0.08926813,
#          0.6057641 , -2.7248204 ,  0.94123524,  0.1635217 , -1.0104558 ,
#          0.5394137 ,  1.4807487 ,  0.15568145,  0.26428065,  0.18147719,
#         -2.2579412 ,  0.26507846,  0.17101593, -0.6806029 ,  0.32907373,
#          0.5230127 ,  1.3236811 , -0.79614216,  0.81599647, -0.2551503 ,
#          0.18922062,  1.5379286 ,  0.5652823 ,  0.41795808, -0.9289308 ,
#          0.24361505,  0.32829753, -2.2578726 ,  0.6779447 ,  1.0491937 ,
#          0.22755316, -1.884244  ,  0.24026889, -0.34075567, -0.08456433,
#          1.0923468 , -1.6295444 ,  0.9303648 ,  1.4171078 , -0.53997755],
#        dtype=float32),
#  'woman': array([-3.70827615e-01, -4.83989447e-01, -1.38376164e+00,  1.19169161e-01,
#          1.21020997e+00,  2.67447680e-01,  1.19633770e+00,  1.54060259e-01,
#         -2.73588719e-03,  1.46367252e+00, -8.82883519e-02, -3.13490182e-01,
#         -2.62435228e-01,  6.49343431e-01, -7.06609309e-01,  8.16368237e-02,
#         -5.15319645e-01, -1.12068844e+00,  2.07241774e-01, -9.63937819e-01,
#          7.67018259e-01, -4.04140204e-01, -1.18885410e+00,  3.81968712e-04,
#          5.06556127e-03, -2.30848834e-01,  1.34014797e+00, -2.73546743e+00,
#         -9.71525460e-02, -1.14844358e+00,  2.66325188e+00,  1.04256308e+00,
#         -4.85680133e-01,  3.05313855e-01, -1.06464827e+00, -4.63915765e-01,
#         -5.18448949e-01, -2.39064284e-02, -2.66138554e+00, -1.21118987e+00,
#          1.34044552e+00, -1.62713003e+00, -9.01898265e-01,  1.39383328e+00,
#         -1.15912333e-01,  2.58308947e-01, -1.39388812e+00, -1.23065150e+00,
#         -4.04313743e-01,  1.06170702e+00, -8.01024020e-01, -1.94107151e+00,
#         -7.37412944e-02,  6.35493770e-02, -5.77621996e-01,  1.32069290e+00,
#         -1.24454951e+00,  1.17871022e+00,  2.45108739e-01,  3.58502924e-01,
#          1.04536116e+00,  1.49333596e+00,  2.43969917e-01, -3.00295055e-01,
#         -3.68219763e-01, -1.26306605e+00, -2.09000334e-01, -5.99700570e-01,
#          3.81774038e-01, -1.56433737e+00, -5.37421629e-02, -1.46509814e+00,
#         -7.35278904e-01, -9.27507043e-01, -1.14763133e-01,  1.12704439e-02,
#         -4.73385543e-01, -4.26000118e-01, -1.25752664e+00,  7.08983719e-01,
#          1.51891220e+00, -1.07342362e+00, -1.50396657e+00, -5.38010061e-01,
#          9.60025191e-01, -9.05233622e-01, -2.50474524e+00, -2.57077456e+00,
#          4.90266860e-01, -6.45668149e-01, -1.27736395e-02,  2.05077672e+00,
#          9.83996570e-01,  1.79089880e+00, -1.25884724e+00,  6.91366017e-01,
#          7.97969401e-01, -1.29159141e+00,  1.39005160e+00,  6.23177290e-01],
#        dtype=float32),
#  'green': array([ 0.66357297,  2.1218777 ,  0.9285532 , -1.1589298 ,  1.0483955 ,
#         -0.6628537 ,  1.3282274 ,  0.9109252 , -0.4104051 ,  0.42745078,
#         -0.21552622, -0.29105306,  0.04817744,  0.1569328 , -0.10258111,
#         -1.2068747 ,  0.8165943 ,  0.49424785,  0.4266438 , -0.61215097,
#         -0.19511653,  0.10234505, -0.97129434, -0.25763372,  0.82239074,
#         -2.6240175 , -1.0800476 , -0.6514998 ,  0.99219495, -0.11465389,
#          0.49713948,  0.7585941 , -1.5270295 , -0.91359025,  0.5213785 ,
#         -0.77001506, -1.814491  ,  1.2160854 ,  0.26149952, -0.45364523,
#          1.5198252 , -1.6442252 ,  0.4106742 ,  0.30984703,  0.07068203,
#         -0.03741037, -0.52903295, -0.7082273 , -1.5801169 ,  0.78786236,
#          0.51750857, -1.5811224 ,  2.699812  , -1.1676774 ,  0.23481783,
#          1.0168453 , -0.07860377,  1.5037816 ,  0.22974691,  0.71456504,
#         -0.7000923 , -0.07436187,  0.17394999,  0.75581115,  1.8114924 ,
#         -0.959863  ,  1.4282926 ,  1.2830187 ,  0.4646244 ,  0.6046051 ,
#          0.44341117,  0.23069641,  0.984519  ,  1.2035509 ,  1.4619405 ,
#          0.7195433 , -1.0439571 ,  0.22974746,  1.0611329 , -0.3677798 ,
#          0.43332276,  1.4129025 ,  2.2486517 , -0.16099823, -0.04915597,
#          1.0536616 ,  0.98403275, -1.6123949 ,  0.54205877, -1.0873173 ,
#          1.8751259 ,  0.42637366,  1.7140672 ,  0.22222835,  1.2010092 ,
#         -0.63617235,  0.43520296, -1.03122   ,  0.40437698,  1.0020018 ],
#        dtype=float32),
#  'brown': array([ 1.1547713 , -1.2183414 ,  0.91815716, -0.39751473,  0.19278978,
#          0.46499196,  1.2188643 ,  0.04191042, -1.164488  ,  0.04591964,
#         -0.8146369 ,  0.44096455,  0.92649245,  2.2295883 ,  0.1624323 ,
#         -1.6767167 , -1.0180383 ,  1.0130464 ,  1.3249384 ,  0.15315534,
#         -0.20318905, -1.090664  , -1.1027961 , -0.0764761 ,  1.1643506 ,
#         -1.3697029 , -0.6750041 ,  0.05649183,  1.1755328 , -0.601749  ,
#          1.639258  , -0.0593791 , -1.0231919 ,  0.27666184, -0.2358306 ,
#         -0.9449445 ,  0.37095857,  0.15865077,  1.0816245 , -1.6418111 ,
#         -0.6599689 , -1.0813676 ,  1.1899114 ,  1.244735  , -0.11879105,
#          1.5792093 , -1.2607076 ,  0.57108593,  0.05615035, -1.8023835 ,
#         -0.411953  , -1.9684213 ,  0.7929938 , -1.4442497 ,  0.9062035 ,
#          1.1494979 , -1.0098633 ,  2.1404498 ,  0.48798552, -0.87880963,
#          0.33801994,  0.7992299 ,  2.1636417 ,  1.5300305 ,  0.82942545,
#          0.04821637,  1.1598626 ,  1.5796067 , -1.913406  ,  0.02100224,
#          0.44257408,  0.26357716,  1.6673675 , -0.22527663,  1.2966213 ,
#         -0.23790121, -1.716995  , -0.15643266, -1.6985384 , -0.6114137 ,
#         -0.49408054, -0.5477528 ,  1.6128002 ,  0.20053774,  0.8520837 ,
#         -1.8152608 , -0.72176147, -0.19648312, -1.3389504 , -1.6183436 ,
#          0.21112864, -0.54383844, -0.17128783,  1.5787383 ,  0.8066494 ,
#         -0.76417124,  1.0765086 , -1.5982631 ,  1.2646667 ,  0.06039014],
#        dtype=float32),
#  'person': array([-4.42133904e-01,  8.60309880e-03, -1.34644926e+00, -5.87537251e-02,
#          5.00465147e-02, -1.04480498e-01,  6.37267113e-01,  1.37664831e+00,
#          9.58230138e-01,  8.24244320e-01,  2.72833258e-01,  3.76931816e-01,
#          5.71472049e-01, -3.03750813e-01, -2.10655883e-01,  1.64628804e-01,
#         -5.07369936e-01, -1.23017406e+00,  1.47261813e-01, -1.88457990e+00,
#          5.69007874e-01, -3.79228950e-01, -1.71922553e+00, -2.67561436e-01,
#          3.52924138e-01, -1.06163692e+00,  1.46547031e+00, -2.17326236e+00,
#         -2.42450416e-01,  7.86438137e-02,  2.07700825e+00,  1.11977935e+00,
#          2.44419323e-03,  6.55009866e-01, -5.43448329e-01,  5.01389623e-01,
#         -2.83431679e-01, -5.99423885e-01, -2.21494365e+00,  6.00863636e-01,
#          3.80775124e-01, -1.14713776e+00, -8.77493918e-01,  1.27550650e+00,
#          4.04237807e-01,  1.29687703e+00, -1.38979936e+00, -1.23928261e+00,
#         -4.08412486e-01,  7.27785587e-01, -1.66275811e+00, -1.24678588e+00,
#         -3.96645755e-01,  6.95897877e-01, -1.05014704e-01,  7.24225342e-01,
#         -8.45808625e-01,  1.59180963e+00, -1.58697814e-01,  6.37917042e-01,
#          7.71571040e-01,  4.91853029e-01,  6.48894787e-01, -2.45997381e+00,
#         -7.23101258e-01, -1.33568501e+00,  3.27018112e-01, -4.68762368e-01,
#          7.83685744e-01, -1.32098722e+00, -9.25809085e-01, -2.04753971e+00,
#         -2.30866879e-01, -7.42431343e-01, -1.47946224e-01,  1.29754341e+00,
#         -1.04887152e+00, -2.46120408e-01, -6.20518625e-01, -4.76242036e-01,
#          9.56068933e-01, -9.52234328e-01, -8.38361144e-01,  5.64964861e-02,
#          1.73654020e+00, -7.77154207e-01, -1.85852158e+00, -1.36631238e+00,
#          8.55957568e-01, -1.45258009e+00, -8.51846635e-01,  2.85333419e+00,
#          1.09873450e+00,  8.33718061e-01, -6.76907897e-01, -4.41426367e-01,
#          6.47196054e-01, -3.97624940e-01,  1.51978779e+00,  4.67405990e-02],
#        dtype=float32),
#  'two': array([ 1.6568757 , -0.63169914,  1.1636143 , -0.4001033 , -0.08908319,
#          0.61959255,  0.9128532 , -0.04095508,  0.2761517 , -0.8616619 ,
#         -0.01596587, -0.9289945 , -1.5037947 ,  1.3854365 , -0.7310112 ,
#         -1.203799  , -1.3653753 , -1.0608736 , -0.7418816 ,  1.1526663 ,
#          1.7431747 , -1.1714333 ,  0.8517822 ,  2.9128873 ,  1.1034495 ,
#          0.3305161 ,  0.39195564, -1.191763  , -0.6392485 ,  1.396212  ,
#          0.8696251 ,  0.62083167,  0.37439033, -0.5882643 , -0.4097857 ,
#          0.7484594 ,  0.5685871 ,  0.6978571 , -0.27024436, -0.3203905 ,
#         -0.36119398, -1.093652  , -0.60493624,  0.64626104, -0.29887846,
#         -1.6797261 ,  0.01277942,  0.33106163,  1.6533026 ,  1.6533977 ,
#          0.49510127, -1.4621271 ,  1.489018  , -1.637173  , -1.5690782 ,
#          1.1202319 , -1.7210081 ,  0.37167928, -1.4508535 ,  0.7743676 ,
#         -1.2070578 ,  2.2185326 , -0.5615126 , -2.6087024 , -0.0350872 ,
#          0.588357  , -1.3449687 , -0.0882711 ,  0.1258687 ,  0.5133208 ,
#         -0.5030969 ,  0.9112106 , -1.4989116 , -0.98486435,  1.0485601 ,
#          0.9551886 , -0.27225614, -1.101332  , -1.6969651 ,  1.0820767 ,
#          2.0912697 , -2.0862725 ,  0.28060675, -0.70156384, -1.7712116 ,
#          0.8346524 ,  0.607555  ,  1.5848415 , -0.3098357 , -0.05383676,
#          0.830881  , -0.40109926, -1.2493333 ,  0.6053909 , -1.056642  ,
#          1.0351676 ,  2.1917934 , -3.108092  ,  0.78152996,  1.6666213 ],
#        dtype=float32),
#  'wearing': array([ 1.613897  , -0.96855223,  1.220002  ,  1.3373735 , -1.5945574 ,
#         -1.3822626 , -0.5998379 ,  1.4219807 ,  0.15583573,  0.22317375,
#          1.041086  , -0.3044163 ,  2.9293234 ,  2.0951054 , -0.08285889,
#          0.7714827 ,  1.631641  , -0.74028134,  0.275681  , -1.7327119 ,
#         -0.2231344 ,  1.5382526 , -1.1668055 ,  0.59576184,  1.183909  ,
#          1.2174541 , -0.9101714 ,  0.2387035 , -0.08525913,  0.11598955,
#         -0.02309968,  0.32185763,  1.3505841 ,  0.92386353, -0.623688  ,
#          1.1121265 ,  0.6813275 , -1.1011775 , -1.6237015 , -2.3138044 ,
#         -1.4979641 , -0.34386414, -0.42510176, -0.23529665,  0.18348671,
#         -0.05079918, -2.6567264 ,  0.22506982, -1.027251  ,  0.02800008,
#          1.5756557 ,  1.5019941 , -1.5083824 , -0.7842358 ,  3.3753555 ,
#         -0.39865237, -0.6196686 ,  0.6966589 , -0.69002473, -0.95455116,
#         -0.45457828,  0.18241595, -0.51596665,  0.84461176, -1.6091579 ,
#         -0.22334467, -1.6500533 ,  0.27587786,  0.03901827,  0.10883294,
#          0.83071494,  1.4731472 ,  0.3087301 , -0.67991644,  0.5730465 ,
#         -1.2116637 ,  1.4622836 , -1.0903027 ,  0.04650702,  1.0082948 ,
#          0.22640404,  0.23198223,  1.4368355 ,  2.141973  , -1.1398066 ,
#          0.641804  ,  1.8162081 , -0.72988373,  0.34415078,  1.7602661 ,
#          1.6365182 , -1.006807  ,  0.33086145,  2.1459281 , -0.80154175,
#          0.4808583 , -1.6067672 ,  1.6007054 ,  1.3789394 ,  0.29513574],
#        dtype=float32),
#  'yellow': array([-0.6308252 ,  2.028574  ,  1.5665348 ,  0.61598116, -0.15770428,
#         -2.1623273 , -0.16363361,  0.52078074, -1.2448618 , -0.53836465,
#          0.0441553 , -0.99896413,  0.39090243, -1.4456002 ,  1.5244882 ,
#          1.0368471 ,  0.690019  ,  0.6657145 , -0.31033918, -0.2195939 ,
#          0.08290935, -0.46283436, -1.1569409 , -0.24454494,  1.5151911 ,
#         -0.7646914 , -0.70701563, -2.188262  , -0.27899948,  0.50526065,
#          1.337428  ,  1.2695143 , -1.9199607 , -0.70227486,  0.41107142,
#         -2.0638807 , -0.21039137,  0.28467542, -0.03530627,  0.40819797,
#         -0.41567507, -2.0899615 ,  0.4347896 , -1.3188279 ,  0.07475989,
#         -0.10592072, -0.46809745,  0.6278889 , -0.5718381 ,  0.62562233,
#          1.7079003 , -1.0749089 ,  0.29880914, -0.95233494,  0.8177709 ,
#          0.07524627,  0.5466603 ,  1.0509614 ,  0.95397073, -1.8825479 ,
#         -0.5081862 ,  0.6268939 ,  1.202044  ,  1.3745761 ,  1.1895412 ,
#         -0.12249519, -1.379231  ,  0.45399764, -0.47242704,  0.9950827 ,
#         -1.1366181 , -0.03835637, -0.6829668 ,  1.1538402 , -0.25218076,
#          0.5930291 , -2.6518555 , -1.1301941 ,  0.5523507 , -1.2754037 ,
#         -0.6940336 ,  1.3143504 ,  2.8932412 , -1.4337853 ,  0.7848836 ,
#          0.18515448,  0.39487243, -0.38280252,  0.06421563, -0.8298957 ,
#          1.2211851 , -1.1714927 ,  0.19299932,  1.3089864 ,  0.19265586,
#          1.2528965 ,  0.39215207, -0.4140341 ,  0.9566143 ,  1.7162464 ],
#        dtype=float32),
#  'sign': array([-0.6779094 ,  0.45625398, -0.00786207, -2.1746004 , -0.02008764,
#         -0.82411325, -2.4824288 ,  1.6240456 ,  0.41731298, -0.58005744,
#         -1.8637681 ,  0.79923296,  0.5525588 ,  0.24649325,  2.6130812 ,
#          0.54320145,  1.0170486 , -1.7421068 ,  0.97201097, -0.71279836,
#         -0.06055298, -0.63063896, -0.6669388 , -0.93426704, -2.1092224 ,
#          0.77081084,  1.7503748 , -1.0977904 ,  0.21810187, -0.49530882,
#          2.2822835 ,  0.08688615, -1.4879305 , -0.5964802 , -0.5420867 ,
#         -2.0489907 ,  0.18079922,  1.8896214 , -1.7088186 ,  1.3146392 ,
#          2.241257  ,  1.4262656 ,  0.1752675 , -1.1772768 , -1.0225275 ,
#         -1.579219  , -0.81830424, -0.3698751 ,  0.29264602,  1.3466488 ,
#          0.25360492, -0.01606997,  0.3771454 , -0.24297574, -0.7597582 ,
#          1.4030973 ,  0.33564743,  2.2126427 ,  0.44166636,  0.13703114,
#          1.4021664 ,  0.95134944, -0.5657449 , -0.03446051, -0.7109704 ,
#         -0.5544596 , -0.51445204, -2.2493339 ,  1.8136511 ,  2.0972843 ,
#          0.8069928 , -1.3413377 , -2.4545412 , -0.3363998 ,  2.4656754 ,
#         -1.4934485 ,  0.8267975 , -1.2718152 , -0.10615134,  0.7182703 ,
#          0.5610476 , -0.7734994 , -0.04014281,  0.51112556,  0.502656  ,
#         -1.5514736 , -1.5070236 ,  0.00393391, -0.2979996 ,  1.2048701 ,
#         -0.00263323,  0.3290787 , -0.30215806, -0.7950201 , -1.5872766 ,
#          1.8298764 ,  0.80711305, -1.4007596 , -0.4915205 , -0.63319397],
#        dtype=float32),
#  'train': array([-0.27686337, -1.3184514 , -0.84548527, -1.0663315 , -0.05396254,
#         -0.14904003, -0.80057234,  0.75973284,  0.5779412 , -0.27500173,
#         -0.17079116,  0.9551905 ,  0.324591  ,  0.4666322 , -0.53872776,
#          0.5882242 ,  0.8560702 , -0.10135631, -1.7296075 , -1.1198608 ,
#         -1.1087904 , -0.5561264 , -2.538678  ,  1.0609666 ,  0.36677912,
#         -2.5806947 ,  1.7852061 , -0.4190785 ,  0.8566531 , -1.1723952 ,
#          2.0394216 ,  1.9733176 , -0.94165534,  1.5629873 , -0.36345425,
#         -0.9749189 ,  1.3791014 , -1.2744656 ,  0.69917476,  1.2922506 ,
#         -1.1580236 , -1.0056676 ,  1.182579  , -0.56684023,  0.98439354,
#         -1.2112445 ,  0.1606945 , -0.38709703,  0.4113037 , -0.10734151,
#          0.54566586,  1.4293206 ,  0.83795106, -0.19312425,  0.7918254 ,
#          1.0364558 , -0.08596288,  2.2975705 ,  0.842879  ,  0.3696508 ,
#          1.8642129 ,  0.11339089, -0.4995932 , -0.16825645, -0.21558128,
#         -0.73461074, -1.3797512 , -1.5767919 ,  0.09339688,  1.9668002 ,
#          1.1633786 , -2.342537  , -0.70756584,  0.73622835,  0.6438471 ,
#          0.61921144,  0.05250356,  0.64250195, -0.21734843,  1.2303137 ,
#          1.0278352 ,  0.51317406, -0.31774053,  0.84940517,  1.7426579 ,
#          0.75440943, -1.8514533 ,  1.3556832 ,  1.3651801 ,  0.52862334,
#         -0.23308164,  0.03548819, -0.71466744,  0.41137815,  0.32848313,
#         -0.7681229 ,  1.3220875 , -1.3803272 , -0.16148283, -1.9484915 ],
#        dtype=float32),
#  'sky': array([-3.98660898e-02, -9.39300478e-01, -7.02376425e-01,  1.00508833e+00,
#          3.68658423e-01, -4.98186350e-01, -9.16634142e-01,  1.15473676e+00,
#          2.26473427e+00, -1.92767411e-01, -2.32444501e+00, -2.44324237e-01,
#         -1.35381103e-01, -8.83012176e-01, -2.60346055e-01,  9.49154794e-01,
#          1.58064365e+00, -1.48722100e+00, -1.19138479e+00,  5.80145478e-01,
#         -3.92206013e-01,  1.87875316e-01, -2.03969646e+00, -7.41886914e-01,
#          2.15445951e-01, -1.53366446e+00,  5.61812639e-01,  1.31096840e+00,
#         -1.66782737e+00,  3.83506000e-01,  3.10411930e+00, -4.71526325e-01,
#          4.04529452e-01,  3.32627296e-01, -1.36135805e+00,  9.26627696e-01,
#          1.17832983e+00, -1.72409844e+00, -5.20172119e-01, -2.96144262e-02,
#         -3.59446317e-01, -8.75083685e-01, -2.88174361e-01, -3.37856084e-01,
#          6.44737124e-01, -1.10678613e+00, -1.77211475e+00,  5.21270260e-02,
#         -4.81056282e-03, -1.57713816e-01,  1.61701038e-01, -2.95990205e+00,
#          5.41920438e-02, -2.67576844e-01, -1.69014835e+00,  1.06438172e+00,
#          3.98575991e-01, -6.37338638e-01, -3.67670327e-01,  6.46882176e-01,
#         -5.39926231e-01,  1.72014117e+00,  2.24133110e+00,  8.18542719e-01,
#          1.62711930e+00,  1.43881238e+00,  1.51383173e+00, -1.78316617e+00,
#         -1.55816168e-01, -6.57906175e-01, -3.36926103e-01, -3.84220195e+00,
#         -1.54001522e+00,  2.57454085e+00,  3.47653955e-01, -1.28993261e+00,
#         -2.05114818e+00,  5.85925221e-01,  5.52731566e-02,  8.07375968e-01,
#          1.93229601e-01,  2.38805890e+00,  1.36615229e+00,  2.32924271e+00,
#         -9.21434402e-01,  6.53268516e-01, -1.63655090e+00,  1.52581131e+00,
#          7.27283120e-01, -3.69474874e-03,  2.28241205e+00,  3.21473092e-01,
#          2.45852327e+00,  1.01029485e-01,  5.44836640e-01, -4.21946138e-01,
#          2.48987317e-01,  1.89378202e+00,  1.23982918e+00, -5.01096435e-02],
#        dtype=float32),
#  'wall': array([ 2.02847525e-01, -5.23467362e-01, -1.85198438e+00,  7.63540864e-01,
#          1.97980225e+00,  1.71700001e+00,  3.93573791e-01,  1.51353970e-01,
#          1.18132567e+00,  9.37276304e-01, -9.29056942e-01,  5.00007689e-01,
#          2.42665410e+00, -2.60436088e-01, -4.66664881e-01, -8.78268331e-02,
#          1.20225871e+00, -1.54964817e+00,  4.07087207e-01,  1.74282305e-02,
#          1.26391447e+00, -4.55060065e-01,  6.25103354e-01, -1.79888213e+00,
#          2.16051310e-01, -1.56505179e+00, -6.78331912e-01,  1.50595319e+00,
#          1.21151173e+00,  3.62331927e-01, -5.06060898e-01,  4.62500930e-01,
#         -2.36395860e+00,  1.77601397e+00,  9.59594026e-02, -4.93347079e-01,
#         -1.70315588e+00,  5.54926515e-01, -7.69271478e-02,  4.22738492e-01,
#          7.89555162e-02, -1.01906824e+00,  1.19851194e-01, -6.09957814e-01,
#          9.15829092e-02, -6.45664036e-01,  9.44873273e-01,  1.36733532e+00,
#         -3.82319301e-01,  2.36940831e-01,  7.22695813e-02, -4.27760221e-02,
#          3.56271982e-01, -6.32844120e-02, -4.89778310e-01,  5.53101122e-01,
#          9.90137696e-01,  9.40809965e-01, -5.12302458e-01, -1.97493291e+00,
#          1.24280751e+00,  5.47790647e-01,  1.65930182e-01,  1.47884190e+00,
#          3.52410465e-01, -4.99886245e-01,  1.42870748e+00, -1.01693261e+00,
#          4.47884589e-01,  1.07256675e+00,  1.59414816e+00, -9.87402499e-01,
#         -1.68952525e+00, -5.40622830e-01,  5.90803683e-01, -1.59449661e+00,
#         -7.22901106e-01, -1.37432769e-03, -9.19398889e-02,  2.63065886e+00,
#          3.92420560e-01,  1.65731740e+00, -2.32057452e+00,  7.51178682e-01,
#          6.25904799e-01,  6.76187515e-01, -3.49942017e+00,  2.38624620e+00,
#          8.28509480e-02, -1.91959351e-01, -2.43762419e-01, -3.04287910e-01,
#         -1.84906352e+00, -5.09824038e-01,  8.11745703e-01, -1.74597144e+00,
#          1.55997026e+00,  5.36233664e-01, -5.31655014e-01, -9.00721014e-01],
#        dtype=float32),
#  'water': array([ 0.60018355, -1.4121077 , -1.6654068 , -0.6867569 ,  1.2164755 ,
#          1.493143  , -0.302251  ,  0.23901205,  2.3662994 ,  1.778543  ,
#         -0.4290095 , -1.0592285 , -0.28318584,  0.08822899, -1.9573185 ,
#         -0.6790217 ,  1.342089  , -2.3054757 , -1.4912204 ,  2.6952329 ,
#         -1.5980515 , -0.70111173, -1.9810301 ,  1.1001437 ,  0.00556467,
#          0.22373281,  0.06252089, -1.0900273 , -1.787195  , -0.6776842 ,
#          2.0013754 , -0.52802896, -0.34566784, -1.1066467 , -1.761859  ,
#          0.05284534,  0.59992284,  0.6716502 ,  0.06990211,  0.01354293,
#         -2.3253987 , -0.9027116 , -0.22084926, -0.01734335,  0.82318175,
#          1.2737434 , -1.7609518 ,  0.05157472,  1.0074766 , -0.13985124,
#          0.32012385, -1.1702666 ,  1.0003479 , -2.2883003 , -0.32305104,
#         -0.37902743,  0.23258702,  0.02586903,  0.675617  ,  0.3433189 ,
#         -0.33049822, -0.45215142,  0.42379484, -0.3157885 ,  0.3661972 ,
#          0.21540971,  0.6548764 , -1.743233  , -0.5432686 ,  0.0117859 ,
#          0.23515408, -1.9555972 , -0.7537326 ,  0.3899066 , -0.55473495,
#         -0.9363082 , -2.8999314 ,  0.5278385 , -0.0187131 ,  0.06052059,
#          0.08284771, -1.045984  ,  0.25996557,  1.2331504 ,  1.1463063 ,
#         -1.0673975 , -1.9844084 ,  0.25833347,  1.6893631 , -0.07008451,
#         -0.36930296,  1.1794647 ,  1.6085644 , -3.4586916 ,  1.7122371 ,
#          0.5189321 ,  0.87581044,  1.9988863 , -0.39073285, -0.8147181 ],
#        dtype=float32),
#  'are': array([ 0.9843248 , -0.8576842 , -1.5846475 ,  0.79894376, -1.504349  ,
#          1.9816402 ,  1.3409082 , -0.7686004 ,  0.82634544, -0.64883757,
#         -0.71887016, -0.5431806 , -0.4225911 ,  2.0992162 , -0.04951378,
#          2.2763975 ,  2.1784337 , -1.131735  ,  0.67147714, -0.3895809 ,
#          1.9302318 ,  0.736576  ,  2.1940472 ,  2.0912914 ,  1.056879  ,
#         -0.32708475,  1.7255156 , -0.66184145,  0.03415609,  1.197218  ,
#          0.91853505,  0.8362808 ,  1.0374789 , -2.3884313 ,  0.66763806,
#          0.64470243, -0.6223232 ,  0.43301806, -0.7157134 , -0.03443271,
#         -0.740916  ,  1.3115144 , -0.41682574, -0.7721115 ,  1.398347  ,
#         -0.20335859,  0.04553017,  0.04066744, -0.37654036,  1.524462  ,
#          0.8316278 , -2.3265371 , -0.16661733, -0.38515675, -0.4254235 ,
#          0.63768846,  0.36659265, -0.43502575, -1.3464067 ,  2.4220912 ,
#         -0.34721017,  0.19218333, -0.06691071, -0.17366077, -1.477438  ,
#          0.08428951, -1.2207518 , -0.12723291,  0.617402  ,  0.96896785,
#         -0.00949287, -2.256079  ,  1.5479796 ,  0.4365075 ,  0.4735911 ,
#         -0.05110418, -2.1412058 ,  0.75002843, -1.5663073 ,  0.34218565,
#          0.44182402, -2.6297157 , -0.6174504 ,  0.02068493, -1.1835337 ,
#          1.7506685 ,  2.0317187 ,  1.6886116 , -1.0303679 , -0.8928894 ,
#          0.12730956,  0.63744175, -1.0262799 , -0.8810893 ,  0.88331395,
#         -0.36360642, -0.34327516, -2.588034  ,  1.7188058 ,  1.8550959 ],
#        dtype=float32),
#  'building': array([ 0.35794622, -0.43597835, -0.6524609 , -1.6328253 ,  1.6296995 ,
#         -0.83216244, -1.6086894 , -0.08422867,  0.6185482 ,  0.11782748,
#         -0.5262922 ,  0.06711689,  0.8426942 , -0.10021343,  1.0634556 ,
#         -1.1883204 , -0.0366454 , -1.9808064 ,  0.0262398 , -0.12690906,
#          0.44085455, -0.8052439 , -2.237802  ,  0.33749342,  1.0144083 ,
#         -2.055394  ,  0.21831115,  1.5350922 ,  1.3599548 , -0.7746039 ,
#         -1.0529478 ,  0.53422385, -1.2567229 ,  0.5537432 , -0.86775416,
#         -0.23121119, -0.4348806 , -1.0724223 ,  1.2770233 ,  2.4178233 ,
#         -1.7768553 , -0.18231085,  0.6288941 ,  0.19706966,  0.3085193 ,
#         -1.5900409 , -0.8392171 , -0.9026634 ,  0.7862743 ,  0.72131324,
#         -0.7459301 , -0.07516764,  0.12066637,  1.0068023 ,  0.36844647,
#          1.1549166 , -0.61173964,  2.2266126 , -0.17322525, -0.746934  ,
#          0.21083498,  0.04302054,  0.45608997,  1.7877274 ,  0.63022697,
#         -2.3390746 , -0.30004406, -1.2574694 ,  0.3540821 ,  0.46039903,
#          1.4526325 , -1.3744421 , -0.92521787,  0.15131913, -1.4212968 ,
#         -1.0763763 , -0.23355477, -0.29925326, -2.1419725 ,  2.0815003 ,
#         -0.97428286,  1.0413077 , -1.4228462 ,  0.9542267 ,  3.2967875 ,
#          1.4705013 , -2.0561252 ,  2.1732097 ,  0.882724  , -0.45207378,
#         -1.6258907 ,  2.3405116 , -0.37889287,  0.8497705 ,  0.90042996,
#          0.36131606,  0.05722499, -0.73642653, -2.500985  , -0.88683516],
#        dtype=float32),
#  'an': array([ 0.45734122,  1.4948908 ,  1.581568  ,  0.8688613 , -1.8583341 ,
#          0.33558518,  1.5846003 ,  0.36193952,  1.4025077 ,  1.2890968 ,
#         -0.16265   , -2.1933465 ,  0.41951245, -1.4530787 , -1.7913754 ,
#         -3.0229464 ,  0.82968754, -1.3057423 , -0.36317423, -0.7359012 ,
# ...
#          2.13596195e-01, -4.61899877e-01,  1.77965790e-01, -2.37711161e-01,
#          3.37928832e-01, -4.17876840e-01, -4.73606646e-01,  2.45462999e-01],
#        dtype=float32),
#  'candle': array([-1.40089214e-01,  3.40835392e-01, -8.50840211e-02, -2.23459035e-01,
#          4.82604504e-01, -4.33740228e-01, -1.20352432e-01,  2.47332275e-01,
#          4.12868261e-01, -1.80392057e-01, -4.74533439e-01, -3.00490856e-01,
#          1.39147267e-01, -7.39755109e-02,  1.17523968e-01,  2.23047212e-01,
#         -2.23620594e-01, -1.60007417e-01, -1.86944425e-01, -1.39862776e-01,
#          2.55337924e-01, -1.33541897e-01, -1.96802810e-01, -2.54574448e-01,
#          6.01939484e-02,  2.20109392e-02,  7.73710534e-02, -1.89670362e-02,
#         -7.63197616e-02, -2.23956376e-01,  7.87928775e-02, -3.69714618e-01,
#         -3.57146263e-02, -6.12877570e-02, -1.63482770e-01,  7.29350448e-01,
#          2.59915680e-01, -1.53349503e-03, -1.14430048e-01, -2.08328795e-02,
#         -1.34170964e-01, -1.20574206e-01, -2.32682660e-01,  1.40121445e-01,
#          6.60204440e-02, -4.00488228e-01, -3.17391992e-01,  8.20655376e-02,
#          4.44737047e-01,  5.87721430e-02,  1.44785255e-01, -4.56782192e-01,
#          4.09563705e-02,  2.94866115e-02, -1.61737189e-01,  5.45219541e-01,
#          2.34674007e-01, -2.38090230e-04, -1.78312287e-02,  1.80917844e-01,
#         -3.66127640e-02, -1.04534619e-01, -1.02923801e-02, -8.14944357e-02,
#          2.00026751e-01,  3.42915148e-01,  8.71484429e-02, -3.46571282e-02,
#          1.63326681e-01,  1.09352045e-01, -1.07994854e-01, -1.53670475e-01,
#         -4.55919728e-02,  6.00927174e-01, -1.78092010e-02, -5.75027466e-02,
#          6.81686625e-02, -1.69768929e-01, -1.04877628e-01,  3.98203760e-01,
#         -3.55799079e-01,  1.39753565e-01, -6.19139150e-02,  3.65203679e-01,
#          2.05284387e-01,  1.60194933e-01, -4.49744537e-02,  4.77338165e-01,
#          1.03044465e-01,  1.04370922e-01,  4.04230505e-01,  2.21059248e-01,
#          3.56732041e-01, -1.80032268e-01,  4.52438384e-01, -1.28746361e-01,
#          2.82489397e-02, -8.89605805e-02,  1.28708472e-02,  8.61748755e-02],
#        dtype=float32),
#  'stuff': array([-0.2860573 ,  0.34789035,  0.10685522, -0.7479078 ,  0.23194148,
#         -0.03209852, -0.23524924,  0.16979735, -0.04326905, -0.03959962,
#          0.10316199, -0.02526891,  0.1342481 , -0.48243877,  0.3074641 ,
#         -0.47769558, -0.08071568, -0.8016837 , -0.04873015, -0.21019535,
#          0.14398664,  0.06006232,  0.5752431 ,  0.248218  , -0.494465  ,
#         -0.04064408,  0.4613328 ,  0.00225867,  0.01333677, -0.15824404,
#         -0.22744161,  0.27773565,  0.13188046,  0.11427573, -0.01941971,
#          0.12610959, -0.21575749, -0.10252737, -0.04537626,  0.07506406,
#         -0.02602869,  0.13386232, -0.838776  ,  0.1054167 ,  0.23635058,
#          0.11050658,  0.2900937 ,  0.45129937,  0.1378882 ,  0.39421296,
#          0.6062078 ,  0.00676326,  0.11101128, -0.54055166, -0.14643335,
#          0.6286144 ,  0.24735405,  0.23119153, -0.13904469, -0.45036736,
#         -0.2769454 , -0.25674438,  0.26960447, -0.58555484,  0.2459678 ,
#         -0.2668678 , -0.036394  ,  0.5602008 , -0.36820644,  0.00246702,
#         -0.2877565 , -0.29445738,  0.46121493,  0.9105642 ,  0.06003245,
#          0.7253553 , -0.09165313,  0.21138753,  0.1066805 ,  0.46628234,
#         -0.13694903, -0.11896744, -0.08052171, -0.3944907 ,  0.5768307 ,
#         -0.25357696,  0.03536759,  0.21982485,  0.56402844, -0.38633928,
#          0.26577953,  0.26490465, -0.1289343 , -0.29232678,  0.10569784,
#          0.16140975,  0.0584552 , -0.06116036,  0.37188092, -0.05399613],
#        dtype=float32),
#  'aircraft': array([-0.5899358 ,  0.19261846, -0.10157175, -0.29186717,  0.11668661,
#         -0.81140924, -0.10465468, -0.10286477,  0.38823646,  0.25131086,
#          0.25796902, -0.03880534, -0.2842336 , -0.4936586 ,  0.09015629,
#          0.3506231 ,  0.38906884, -0.04429675, -0.36194003, -0.5902375 ,
#          0.23946323, -0.31994945, -0.5165379 ,  0.52079153, -0.28546777,
#         -0.5722155 , -0.15601264,  0.12001814,  0.6248756 ,  0.07959937,
#         -0.10410511,  0.38380262, -0.14873844,  0.6832735 , -0.26185858,
#          0.2805215 ,  0.6428794 , -0.7378043 , -0.30524108,  0.02854154,
#          0.59461963, -0.1792431 , -0.34058833, -0.05618982,  0.75574243,
#         -0.5615478 , -0.30576116, -0.1376133 ,  1.3864052 ,  0.01632816,
#         -0.31457368,  0.05230296, -0.04435738,  0.23810174, -0.48203886,
#          0.3846755 ,  0.32002258, -0.11878344, -0.05928664,  0.41361898,
#          0.50508934,  0.32526305, -0.46045682,  0.3320555 ,  0.19565727,
#          0.56128913,  0.1199443 , -0.1023737 , -0.6321545 ,  0.17751162,
#         -0.3432776 ,  0.15768941,  0.0022948 ,  0.0452316 ,  0.00949775,
#          0.01329548,  0.41183627,  0.20009157, -0.39064544, -0.42287636,
#         -0.4299113 ,  0.14016478, -0.26780856,  0.43873024,  0.24666099,
#          0.3221246 , -0.16984265,  0.8112751 ,  0.640426  ,  0.13645707,
#          0.27413175, -0.14711802, -0.05641475,  0.11327904,  1.1073157 ,
#          0.30024862,  0.41958725, -0.18939796, -0.20600994,  0.26517555],
#        dtype=float32),
#  'hard': array([ 2.14603588e-01, -1.02077171e-01,  3.77105057e-01,  1.71888351e-01,
#         -1.18600331e-01,  8.63644332e-02, -1.17355376e-01,  4.74884123e-01,
#         -5.61660826e-01, -3.48367959e-01,  3.84636939e-01,  2.26265222e-01,
#          2.03654572e-01, -4.52545017e-01, -7.45981932e-02,  4.36768159e-02,
#          4.15287971e-01, -1.44206598e-01,  1.89564347e-01, -6.56985760e-01,
#          3.41242611e-01,  3.08420770e-02,  1.87968910e-01,  6.86426312e-02,
#         -1.02527291e-01,  1.96449677e-04, -3.84371042e-01, -9.80760872e-01,
#         -3.71329747e-02, -3.38077635e-01,  1.84623972e-01,  6.07407689e-01,
#          6.12143159e-01,  3.73762965e-01, -1.23955004e-01, -8.62972438e-02,
#          6.21870756e-01,  4.09837574e-01, -1.08754432e+00, -3.13254625e-01,
#         -3.49448234e-01, -2.16795951e-01, -4.41026166e-02,  6.41317129e-01,
#         -6.12133026e-01, -2.91893575e-02, -9.20308292e-01,  2.75390595e-01,
#         -5.08830309e-01, -1.22426264e-01,  2.99719602e-01,  1.22381553e-01,
#         -2.34843701e-01, -8.55106175e-01,  3.05710733e-01, -5.05508482e-01,
#         -3.74017924e-01,  2.24639252e-01,  9.09596384e-02,  1.83392465e-01,
#         -2.34059095e-01, -1.91428885e-01,  6.98566809e-02,  1.58539549e-01,
#         -9.99676108e-01,  1.44279778e-01, -3.79192412e-01,  3.36339742e-01,
#         -1.40038744e-01,  4.04285252e-01, -5.22692680e-01,  4.26107854e-01,
#          3.40338200e-01,  7.51032382e-02,  3.78438801e-01, -2.58557796e-01,
#         -3.06779772e-01, -3.46136987e-01, -2.35664714e-02,  3.97806078e-01,
#         -2.10602991e-02, -3.15358847e-01,  4.42215711e-01, -5.34572124e-01,
#         -4.92836177e-01, -6.18360221e-01, -1.25363097e-02, -2.82810062e-01,
#          6.13152564e-01,  9.42396186e-03,  5.48495412e-01,  8.90062094e-01,
#          6.68574989e-01,  5.11048913e-01,  2.48969242e-01,  1.20300427e-01,
#         -2.23542415e-02,  1.11598395e-01,  2.32393280e-01,  3.75937462e-01],
#        dtype=float32),
#  'trolley': array([-0.30936068, -0.1949546 ,  0.2068916 , -0.3976349 ,  0.09380358,
#         -0.24113002, -0.06836894,  0.27733257,  0.26593632, -0.22395192,
#          0.08078489, -0.05689416,  0.06406111,  0.12871276,  0.18343024,
#          0.39939398,  0.31819022, -0.31415173, -0.39319742, -0.37185213,
#          0.16155392, -0.11006928, -0.21590552,  0.2612969 , -0.19758056,
#         -0.43866247,  0.13512714, -0.1440244 ,  0.33239543, -0.050468  ,
#          0.01937294,  0.5611209 ,  0.24874826,  0.3089607 , -0.18571506,
#          0.00082906,  0.13733298, -0.22443864, -0.07332105, -0.16234444,
#         -0.0817543 , -0.00708172,  0.6040311 , -0.63298935,  0.2485485 ,
#         -0.28240472,  0.15474685,  0.22797604,  0.3160705 ,  0.26983872,
#          0.01363433,  0.07222044, -0.12141773, -0.23493284,  0.6807437 ,
#         -0.34466773,  0.18115528,  0.5836987 ,  0.4759081 , -0.47333664,
#          0.28586376, -0.27882567,  0.11673411, -0.23412457, -0.44813514,
#          0.10014439, -0.08178402, -0.21426979, -0.06796259,  0.49126387,
#          0.04792163, -0.2826692 ,  0.06574097,  0.30695438,  0.25642124,
#         -0.17999704,  0.1105705 , -0.34043202, -0.04519647,  0.3339893 ,
#         -0.03277702,  0.31980017, -0.00675113,  0.22793984,  0.26522225,
#         -0.0172172 , -0.0586829 ,  0.14979824, -0.14760394,  0.15387112,
#          0.2508001 ,  0.1273716 ,  0.10311238,  0.05379878, -0.06433363,
#          0.01304025, -0.18907507, -0.4931762 , -0.1906696 ,  0.20828484],
#        dtype=float32),
#  'pickup': array([-0.54628736,  0.01032712,  0.6329527 , -0.3443708 ,  0.30255425,
#         -0.74897635, -0.36100614,  0.07682077,  0.31311586,  0.09745985,
#         -0.1086146 , -0.02782689,  0.8101861 , -0.10791498,  0.1430549 ,
#          0.39517578,  0.08689515,  0.3238765 , -0.42120016, -0.2446585 ,
#          0.41484168, -0.31900397,  0.26174024,  0.56868815, -0.30220443,
#         -0.1605501 ,  0.5436219 , -0.5312895 ,  0.12144231, -0.24238452,
#         -0.19375052, -0.26483116, -0.29954132,  0.09944282,  0.04731734,
#         -0.5109343 ,  0.25204077, -0.5047034 , -0.3313248 , -0.89217573,
#         -0.12074303,  0.00857922,  0.00829852, -0.2472653 ,  0.05996699,
#         -0.4145491 , -0.02619477,  0.26139867,  0.50740445, -0.36515504,
#          0.38033494,  0.3145828 , -0.23965369, -0.25357077,  0.2358149 ,
#          0.1892471 , -0.12489431,  0.24920942, -0.0138564 , -0.21488753,
#          0.19969113,  0.17948054, -0.139656  ,  0.37338948, -0.65653306,
#          0.42759615,  0.15719949,  0.23679304,  0.22169991,  0.7161719 ,
#         -0.2179951 , -0.23191935, -0.01455648,  0.50729275,  0.29222956,
#          0.8768584 , -0.47721592, -0.2631682 , -0.39725277,  0.46608633,
#         -0.3041137 ,  0.35115173,  0.01189179, -0.12599953,  0.12489578,
#         -0.1372043 ,  0.09282388,  0.43721166,  0.30642593,  0.30498037,
#          0.24212883,  0.17511967,  0.48969692, -0.32053396,  0.48693976,
#          0.6126593 ,  0.42083162, -0.4503044 , -0.08748826,  0.05595548],
#        dtype=float32),
#  'meters': array([-0.38596568, -0.3154002 ,  0.4071181 , -0.8093389 , -0.23684675,
#         -0.5675987 , -0.5750093 ,  0.7973608 ,  0.41036877,  0.5143331 ,
#         -0.33903882,  0.15449162, -0.6422883 , -0.19913702,  0.3081108 ,
#          0.06905773, -0.33053926, -0.3119597 ,  0.65282464, -0.16965254,
#          0.2977809 , -0.32635355,  0.25883567, -0.36568394, -0.51693094,
#          0.40235633,  0.181098  , -0.3648142 , -0.13746887,  0.18194705,
#         -0.58913845,  0.5481519 , -1.2517457 , -0.3165427 ,  0.6895146 ,
#         -0.6081138 , -0.18813424,  0.17409274, -0.29500416,  0.21777028,
#          0.4838344 , -0.8331986 , -0.2962131 , -0.44663516,  0.43395403,
#         -0.6298729 ,  0.8250403 ,  0.08659144,  0.05042454, -0.0730079 ,
#          0.32080257,  0.20228459,  0.59815145, -0.8645884 , -0.21139646,
#          0.7421467 ,  0.13161634,  0.861789  , -0.62743926,  1.0738025 ,
#         -0.49992296,  0.77332544, -0.41716012, -0.35198244,  0.18082339,
#         -0.30336764,  0.6829586 ,  0.5413163 , -0.01554944,  0.68831146,
#          0.3696875 , -1.3152778 , -0.38777155,  0.03708512,  0.62965006,
#          0.2798406 ,  0.1811709 , -0.61932063,  0.1805368 ,  0.03963375,
#          0.21885818, -0.25420663,  0.2052127 ,  0.10824467,  0.773607  ,
#          0.5371728 ,  0.7300183 ,  0.11546247, -0.4300487 ,  0.28019056,
#          0.9335199 , -0.00599975,  0.16568239, -0.05029701,  0.04097024,
#          1.1121386 ,  0.5780279 , -0.43813318,  0.51238376,  0.2336534 ],
#        dtype=float32),
#  'key': array([-1.3410181 ,  0.04882393, -0.40787017,  0.33835143,  0.49641085,
#          0.11896146, -0.27310124,  0.32658768, -0.4119624 ,  0.41171336,
#          0.14365608,  0.25942564,  0.90343505,  0.25549424,  0.21140544,
#         -0.6117803 , -0.13025507, -0.3296509 , -0.12274877, -0.8963303 ,
#          0.21506703,  0.07196113,  0.00829054,  0.03158732,  0.08103856,
#          0.50639474, -0.14318827,  0.24385077, -0.02412529, -0.07825297,
#          0.88160676,  0.48556948, -0.26076546,  0.36370498,  0.40795404,
#          0.0088923 , -0.3598475 ,  0.518495  , -0.3950813 , -0.7264097 ,
#         -0.09686289,  0.1629282 , -0.6924808 ,  0.19037735,  0.22259262,
#          0.29099524,  0.26865724, -0.4584007 , -0.22804229, -0.5485008 ,
#          0.37735885,  0.6162271 , -0.4445376 ,  0.16370389, -0.20772432,
#         -0.6623414 , -0.00183222,  0.7541207 , -0.48808402, -0.5227117 ,
#          0.00316052, -0.31315652, -0.06108424,  0.08731977, -0.23071398,
#         -0.1291424 ,  0.05993721, -0.27365872, -0.18404919,  0.95785713,
#         -0.20366149,  0.7247188 , -0.05126874, -0.27465096, -0.01464141,
#          0.18363844, -0.00313566, -0.19297662,  0.2696283 ,  0.00702553,
#         -0.70482296, -0.60650694, -0.50310045,  0.27269804, -0.2756281 ,
#         -0.13672702, -0.2577755 , -0.41082436,  0.04610014,  0.14131226,
#         -0.19843252, -0.02161735,  0.11832539, -0.05710781,  0.5783396 ,
#         -0.37211224,  0.21895619,  0.11602595, -0.18466824, -0.28199333],
#        dtype=float32),
#  'pulled': array([-0.00309005,  0.72340477, -0.5447868 ,  0.62220496, -0.23112279,
#         -0.2315415 , -0.34317306,  0.4101522 , -0.05269882, -0.05351401,
#         -0.38230842,  0.30545747,  0.20161456,  0.00536928,  0.11063237,
#         -0.26147282,  0.01656534, -0.13307697, -0.76256335,  0.135919  ,
#          0.01519294,  0.04181917,  0.45137936,  0.47201312, -0.7724916 ,
#         -0.3462989 , -0.07706752,  0.04090937, -0.24456158,  0.9263903 ,
#         -0.35851863, -0.86065656, -0.30342183, -0.427188  , -0.34349093,
#         -0.31150103, -0.62745386, -0.9691409 ,  0.39324346, -0.33767077,
#          0.40915528, -0.04949631, -0.3667911 ,  0.55546886, -0.13869226,
#         -0.01778295, -0.7853011 , -1.1080976 ,  0.16945803, -0.48497155,
#         -0.03121168,  0.516902  , -0.4385116 , -0.7842853 , -0.30552045,
#         -0.26043302, -0.86552197, -0.38865831, -0.7801533 ,  0.55038166,
#          0.45460805,  0.27120522, -0.83832586,  0.7959727 , -0.17596458,
#          0.30351627,  0.27156073,  0.28128204, -0.3072487 ,  0.7871448 ,
#          0.09076227, -0.9480576 ,  0.13582243, -0.87332195, -0.16994582,
#         -0.11881995, -0.68233865, -0.05415087, -0.29896957,  0.16756347,
#         -0.07514168, -0.15652741,  0.26663944, -0.5213002 ,  0.6117317 ,
#         -0.87108946,  0.18850854,  0.18589182,  0.55115587, -0.28399277,
#          0.5174054 , -0.07250957,  0.10095584,  0.37657493, -0.17757693,
#          0.6028787 ,  0.17000687,  0.24834429, -0.4598918 ,  0.15258525],
#        dtype=float32),
#  'games': array([-0.10524133,  0.26008764, -0.581541  ,  0.10216861, -0.0781232 ,
#          0.48690093,  0.45229223,  0.53446656, -0.13944182,  0.5309207 ,
#         -0.13486502, -0.46354273, -0.13328761, -0.12444605,  0.1067572 ,
#         -0.18996038, -0.01241352,  0.03554243, -0.36374187, -0.49508446,
#          0.14726907, -0.61519194, -0.20186177,  0.340769  , -0.36678904,
#          0.37113288,  0.27675202, -0.44520155, -0.5000369 ,  0.30118623,
#          0.20897114,  0.6029816 ,  0.7919282 , -0.42833063, -0.24745654,
#          0.2923284 ,  0.05234529, -0.12086456, -0.76698875, -0.1982138 ,
#         -0.36447576, -0.23780833, -0.18968505, -0.01441131,  0.32836747,
#         -0.16122505,  0.20561135,  0.45948616,  0.20308593,  0.14886239,
#         -0.09209219, -0.6750073 , -0.01227744, -0.42100492, -0.35409495,
#         -0.15405314, -0.5933283 ,  0.05356054, -0.11824765,  0.354702  ,
#          0.32863042, -0.03577095, -0.6477819 , -0.01574375,  0.08873569,
#          0.13701965, -0.07735389,  0.54221624, -0.35923406,  0.06093172,
#          0.19644983, -0.45199615, -0.04368692, -0.05098635,  0.06197377,
#         -0.29616627,  0.02708379, -0.5656111 ,  0.3628148 ,  0.17200178,
#         -0.45021856, -0.81375974, -0.5790932 , -0.07403306, -0.07134257,
#         -0.26556444, -0.15997441,  0.09703021,  0.4338093 , -0.24943168,
#          0.17799664,  0.09792312,  0.391646  , -0.05877522,  0.43381652,
#          0.23089743,  0.15651526, -0.43175542, -0.04329754, -0.22568136],
#        dtype=float32),
#  ...}

# %%
num_words = vocab_inp_size
embedding_matrix = zeros((vocab_inp_size, 100))
for word, index in eng_lang_tokenizer.word_index.items(): #input_lang_word2idx=1847
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector

# %%
class Encoder(tf.keras.Model):
    
    
    def __init__(self,embedding_matrix, vocab_size, embedding_dim, enc_units, batch_sz):
        
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        embedding_matrix = embedding_matrix
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim, weights = [embedding_matrix])

        ##-------- LSTM layer in Encoder ------- ##
        self.lstm_layer = tf.keras.layers.LSTM(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')



    def call(self, x, hidden):
        
        x = self.embedding(x)
        output, h, c = self.lstm_layer(x, initial_state = hidden)
        return output, h, c

    def initialize_hidden_state(self):
        return [tf.zeros((self.batch_sz, self.enc_units)), tf.zeros((self.batch_sz, self.enc_units))]

# %%
## Test Encoder Stack

encoder = Encoder(embedding_matrix, vocab_inp_size, embedding_dim, units, BATCH_SIZE)


# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_h, sample_c = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder h vecotr shape: (batch size, units) {}'.format(sample_h.shape))
print ('Encoder c vector shape: (batch size, units) {}'.format(sample_c.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 26, 1024)
# Encoder h vecotr shape: (batch size, units) (64, 1024)
# Encoder c vector shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, embedding_matrix_h, vocab_size_h, embedding_dim, dec_units, batch_sz, attention_type = 'luong'):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.attention_type = attention_type
        
        embedding_matrix_h = embedding_matrix_h
        
        #Embedding layer
        
        self.embedding = tf.keras.layers.Embedding(vocab_size_h, embedding_dim, weights = [embedding_matrix_h])
        
        #final dense layer on which softmax will be applied
        self.fc = tf.keras.layers.Dense(vocab_size_h)
        
        # define the fundamental cell for decoder recurrent structure
        
        self.decoder_rnn_cell = tf.keras.layers.LSTMCell(self.dec_units)
        
        # sampler 
        self.sampler = tfa.seq2seq.sampler.TrainingSampler()
        
        # create attention mechanism with memory = None
        self.attention_mechanism = self.build_attention_mechanism(self.dec_units, None, self.batch_sz*[max_length_input], self.attention_type)
        
        # wrap attention mechanism with the fundamental rnn cell
        self.rnn_cell = self.build_rnn_cell(batch_sz)
        
        # define the decoder with respect to fundamental rnn cell
        self.decoder = tfa.seq2seq.BasicDecoder(self.rnn_cell, sampler=self.sampler, output_layer=self.fc)

        
        
    def build_rnn_cell(self, batch_sz):
        rnn_cell = tfa.seq2seq.AttentionWrapper(self.decoder_rnn_cell, 
                                      self.attention_mechanism, attention_layer_size=self.dec_units)
        return rnn_cell
    
    def build_attention_mechanism(self, dec_units, memory,memory_sequence_length, attention_type = 'luong'):
         # ------------- #
        # typ: Which sort of attention (Bahdanau, Luong)
        # dec_units: final dimension of attention outputs 
        # memory: encoder hidden states of shape (batch_size, max_length_input, enc_units)
        # memory_sequence_length: 1d array of shape (batch_size) with every element set to max_length_input (for masking purpose)
        if(attention_type == 'bahdanau'):
            return tfa.seq2seq.BahdanauAttention(units=dec_units, memory=memory, memory_sequence_length=memory_sequence_length)
        
        else:
             return tfa.seq2seq.LuongAttention(units=dec_units, memory=memory, memory_sequence_length=memory_sequence_length)
            
    def build_initial_state(self, batch_sz, encoder_state, Dtype):
        decoder_initial_state = self.rnn_cell.get_initial_state(batch_size=batch_sz, dtype=Dtype)
        decoder_initial_state = decoder_initial_state.clone(cell_state=encoder_state)
        return decoder_initial_state


    def call(self, inputs, initial_state):
        x = self.embedding(inputs)
        outputs, _, _ = self.decoder(x, initial_state=initial_state, sequence_length=self.batch_sz*[max_length_output-1])
        return outputs

# %%
# Test decoder stack

decoder = Decoder(embedding_matrix_h, vocab_tar_size, embedding_dim, units, BATCH_SIZE, 'luong')
sample_x = tf.random.uniform((BATCH_SIZE, max_length_output))
decoder.attention_mechanism.setup_memory(sample_output)
initial_state = decoder.build_initial_state(BATCH_SIZE, [sample_h, sample_c], tf.float32)


sample_decoder_outputs = decoder(sample_x, initial_state)

print("Decoder Outputs Shape: ", sample_decoder_outputs.rnn_output.shape)
# Out:
# Decoder Outputs Shape:  (64, 33, 7014)

# %%
# defing optimizer and loss function

optimizer = tf.keras.optimizers.Adam()


def loss_function(real, pred):
    # real shape = (BATCH_SIZE, max_length_output)
    # pred shape = (BATCH_SIZE, max_length_output, tar_vocab_size )
    cross_entropy = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
    loss = cross_entropy(y_true=real, y_pred=pred)
    mask = tf.logical_not(tf.math.equal(real,0))   #output 0 for y=0 else output 1
    mask = tf.cast(mask, dtype=loss.dtype)  
    loss = mask* loss
    loss = tf.reduce_mean(loss)
    return loss

# %%
checkpoint_dir = './training_checkpoints_e'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0
    
    with tf.GradientTape() as tape:
        enc_output, enc_h, enc_c = encoder(inp, enc_hidden)


        dec_input = targ[ : , :-1 ] # Ignore <end> token
        real = targ[ : , 1: ]         # ignore <start> token

        # Set the AttentionMechanism object with encoder_outputs
        decoder.attention_mechanism.setup_memory(enc_output)

        # Create AttentionWrapperState as initial_state for decoder
        decoder_initial_state = decoder.build_initial_state(BATCH_SIZE, [enc_h, enc_c], tf.float32)
        pred = decoder(dec_input, decoder_initial_state)
        logits = pred.rnn_output
        loss = loss_function(real, logits)

    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return loss

# %%
# EPOCHS = 10

# for epoch in range(EPOCHS):
#     start = time.time()
#     enc_hidden = encoder.initialize_hidden_state()
#     total_loss = 0
#     # print(enc_hidden[0].shape, enc_hidden[1].shape)
    
#     for (batch, (inp, targ)) in enumerate(train_dataset.take(steps_per_epoch)):
#         batch_loss = train_step(inp, targ, enc_hidden)
#         total_loss += batch_loss
#         if batch % 100 == 0:
#             print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
#                                                    batch,
#                                                    batch_loss.numpy()))
#    # saving (checkpoint) the model every 2 epochs
#     if (epoch + 1) % 2 == 0:
#         checkpoint.save(file_prefix = checkpoint_prefix)

#     print('Epoch {} Loss {:.4f}'.format(epoch + 1,
#                                       total_loss / steps_per_epoch))
#     print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))

# %%
def evaluate_sentence(sentence):
    sentence = clean_english_data(sentence)
    string = " ".join(sentence)
    inputs = [eng_lang_tokenizer.word_index[i] for i in string.split(" ")]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                          maxlen=max_length_input,
                                                          padding='post')
    inputs = tf.convert_to_tensor(inputs)
    inference_batch_size = inputs.shape[0]
    result = ''
    enc_start_state = [tf.zeros((inference_batch_size, units)), tf.zeros((inference_batch_size,units))]
    enc_out, enc_h, enc_c = encoder(inputs, enc_start_state)
    dec_h = enc_h
    dec_c = enc_c
    start_tokens = tf.fill([inference_batch_size], hin_lang_tokenizer.word_index['<start>'])
    end_token = hin_lang_tokenizer.word_index['<end>']
    greedy_sampler = tfa.seq2seq.GreedyEmbeddingSampler()
    # Instantiate BasicDecoder object
    decoder_instance = tfa.seq2seq.BasicDecoder(cell=decoder.rnn_cell, sampler=greedy_sampler, output_layer=decoder.fc)
    # Setup Memory in decoder stack
    decoder.attention_mechanism.setup_memory(enc_out)

    # set decoder_initial_state
    decoder_initial_state = decoder.build_initial_state(inference_batch_size, [enc_h, enc_c], tf.float32)


    ### Since the BasicDecoder wraps around Decoder's rnn cell only, you have to ensure that the inputs to BasicDecoder 
    ### decoding step is output of embedding layer. tfa.seq2seq.GreedyEmbeddingSampler() takes care of this. 
    ### You only need to get the weights of embedding layer, which can be done by decoder.embedding.variables[0] and pass this callabble to BasicDecoder's call() function
    decoder_embedding_matrix = decoder.embedding.variables[0]
    outputs, _, _ = decoder_instance(decoder_embedding_matrix, start_tokens = start_tokens, end_token= end_token, initial_state=decoder_initial_state)
    return outputs.sample_id.numpy()

def translate(sentence):
    result = evaluate_sentence(sentence)
    print(result)
    result = hin_lang_tokenizer.sequences_to_texts(result)
    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))
    return result, sentence

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
# removing <start> and <end> from input_val
input_val_rem = []
for i in range(len(input_val)):
    l = input_val[i].split(" ")
    l.pop(0)
    n = len(l)-1
    l.pop(n)
    s = " ".join(l)
    input_val_rem.append(s)

# %%
input_val_rem.index('')
# Out:
# 3575

# %%
input_val_rem.pop(3575) , target_val.pop(3575)
# Out:
# ('', '<start> समुद्र तट पर बाइक <end>')

# %%
print(len(input_val_rem), len(target_val))
# Out:
# 5785 5785

# %%
input_val_rem.pop(1346)
target_val.pop(1346)
# Out:
# '<start>  <end>'

# %%
input_val_rem.pop(1655)
target_val.pop(1655)
# Out:
# '<start>  <end>'

# %%
print(len(input_val_rem) , len(target_val))
# Out:
# 5783 5783

# %%
input_val_rem.pop(258)
target_val.pop(258)
print(len(input_val_rem) , len(target_val))
# Out:
# 5782 5782

# %%
translation = []
for i in range(0,100):
    translated_sent = translate(input_val_rem[i])
    translation.append(translated_sent)
# Out:
# [[16 32  6  3]]
# Input: this is the sky
# Predicted translation: ['यह आकाश है <end>']
# [[238  13  10 231   7  15  70   3]]
# Input: boy with purple and white shoes
# Predicted translation: ['बैंगनी और सफेद जूते के साथ लड़का <end>']
# [[12 14 79 31 25  3]]
# Input: man wearing dapper red hat
# Predicted translation: ['आदमी लाल टोपी पहने हुए <end>']
# [[ 54  19   7  54 356   3]]
# Input: green colored leaves
# Predicted translation: ['हरे रंग के हरे पत्ते <end>']
# [[   4 1235  648    7  648    8    4  786  488    3]]
# Input: a runner leading off of first base
# Predicted translation: ['एक प्राचीन आधार के आधार में एक उपकरण कैमरा <end>']
# [[ 4 14 28  3]]
# Input: a red train
# Predicted translation: ['एक लाल ट्रेन <end>']
# [[507  14 125   3]]
# Input: windown on dark red building
# Predicted translation: ['गहरा लाल भवन <end>']
# [[ 12   5  46 200   9 200   3]]
# Input: black suit jacket on man
# Predicted translation: ['आदमी पर काली जैकेट का जैकेट <end>']
# [[ 119   78 1642   84    3]]
# Input: big grey indian elephant
# Predicted translation: ['बड़ी ग्रे विस्तारित भालू <end>']
# [[ 12  11   4 915   5   6   3]]
# Input: man has a ring on
# Predicted translation: ['आदमी की एक उंगली पर है <end>']
# [[  55  160 1122  565   43    6    3]]
# Input: the girl is wearing a necklace
# Predicted translation: ['लड़की ने हार रखा हुआ है <end>']
# [[ 12 259  24  30  11   3]]
# Input: man drawing water from borehole
# Predicted translation: ['आदमी कांच से पानी की <end>']
# [[ 23   5 302   3]]
# Input: street sign
# Predicted translation: ['सड़क पर हस्ताक्षर <end>']
# [[125   5   4  57   3]]
# Input: a window on the building
# Predicted translation: ['भवन पर एक खिड़की <end>']
# [[131   8 238 433   9 165   3]]
# Input: tops of purple flowers in the field
# Predicted translation: ['मैदान में बैंगनी फूलों का फूल <end>']
# [[270 123  87  20   3]]
# Input: woman holding a cell phone
# Predicted translation: ['सेल फोन पकड़े महिला <end>']
# [[  10 1846    7   15   26 2390    3]]
# Input: black ipod with white plug
# Predicted translation: ['सफेद प्लग के साथ काले नेकटाई <end>']
# [[ 81   5 754   3]]
# Input: stripes on the zebra
# Predicted translation: ['ज़ेबरा पर धारियों <end>']
# [[  26 1847    9    4  529   43  147    3]]
# Input: a sliced piece of black olive
# Predicted translation: ['काले जैतून का एक कटा हुआ टुकड़ा <end>']
# [[115 579 323   3]]
# Input: the cow lying down
# Predicted translation: ['गाय लेट गई <end>']
# [[52  7 52  7 15 52 11 52 11 69  3]]
# Input: wooden bench with wooden slats
# Predicted translation: ['लकड़ी के लकड़ी के साथ लकड़ी की लकड़ी की बेंच <end>']
# [[  16    4 6999    6    3]]
# Input: this is a buiding
# Predicted translation: ['यह एक हाफपाइप है <end>']
# [[146   5 154  20   3]]
# Input: women are sitting on the chair
# Predicted translation: ['कुर्सी पर बैठी महिला <end>']
# [[ 45   5  14 555   3]]
# Input: sliced red tomatoes on plate
# Predicted translation: ['प्लेट पर लाल टमाटर <end>']
# [[ 685    5   22 1290    3]]
# Input: two is written on the jersey
# Predicted translation: ['जर्सी पर दो व्यक्तियों <end>']
# [[  16    4  252    9 1082    6    3]]
# Input: this is a toilet bow
# Predicted translation: ['यह एक टॉयलेट का टाइलेट है <end>']
# [[185  77   6   3]]
# Input: the hydrant is yellow
# Predicted translation: ['हाइड्रेंट पीला है <end>']
# [[  4  51   5 129  41   3]]
# Input: people sitting at a table
# Predicted translation: ['एक मेज पर बैठे लोग <end>']
# [[ 47 453 124   3]]
# Input: blue surf board
# Predicted translation: ['नीले सर्फ बोर्ड <end>']
# [[ 59   7 111 126   7 800   3]]
# Input: metal cage near giraffe
# Predicted translation: ['जिराफ के पास धातु के निकट <end>']
# [[ 30   9 478   3]]
# Input: shallow body of water
# Predicted translation: ['पानी का शरीर <end>']
# [[202   9   4 139   3]]
# Input: a group of people
# Predicted translation: ['लोगों का एक समूह <end>']
# [[191   5 123   3]]
# Input: phone on table
# Predicted translation: ['टेबल पर फोन <end>']
# [[107   5 259  11  57   3]]
# Input: glass window on boat
# Predicted translation: ['नाव पर कांच की खिड़की <end>']
# [[ 28   5 678 190  25 188   3]]
# Input: train traveling on rails
# Predicted translation: ['ट्रेन पर यात्रा करते हुए साइकिल <end>']
# [[  4  51   5   4 343   3]]
# Input: a tv on a table
# Predicted translation: ['एक मेज पर एक टीवी <end>']
# [[   4 3643   47  403  227    3]]
# Input: a glossy blue coffee mug
# Predicted translation: ['एक समानांतर नीले कॉफी कप <end>']
# [[ 163    8   22 1226    3]]
# Input: two women in the bathroom
# Predicted translation: ['बाथरूम में दो महिलाएँ <end>']
# [[34 86 11 14 79  3]]
# Input: red cap of the tennis player
# Predicted translation: ['टेनिस खिलाड़ी की लाल टोपी <end>']
# [[   4   70    4  493 1240   21    6    3]]
# Input: a little boy reading a book
# Predicted translation: ['एक लड़का एक किताब पढ़ रहा है <end>']
# [[32  9 37  3]]
# Input: part of the sky
# Predicted translation: ['आकाश का हिस्सा <end>']
# [[  4 746   7 111  94   3]]
# Input: bird near a lake
# Predicted translation: ['एक झील के पास पक्षी <end>']
# [[  4 668  44  14 188   3]]
# Input: a leaning red bike
# Predicted translation: ['एक झुकाव वाला लाल साइकिल <end>']
# [[   4   12  109 1320    6    3]]
# Input: a man flying kites
# Predicted translation: ['एक आदमी पतंग उड़ाते है <end>']
# [[  4  45   5 771 531  24 879   3]]
# Input: partially eaten cookie on a plate
# Predicted translation: ['एक प्लेट पर आंशिक रूप से खाया <end>']
# [[427   5  54 356   3]]
# Input: green leaves on trees
# Predicted translation: ['पेड़ों पर हरे पत्ते <end>']
# [[232   5  10 636   3]]
# Input: white patch on screen
# Predicted translation: ['स्क्रीन पर सफेद पैच <end>']
# [[ 36   9 194   3]]
# Input: face of the cat
# Predicted translation: ['बिल्ली का चेहरा <end>']
# [[158   9  37   3]]
# Input: part of a floor
# Predicted translation: ['फर्श का हिस्सा <end>']
# [[ 64   5   4 405   6   3]]
# Input: a mouse is printed on the shirt
# Predicted translation: ['शर्ट पर एक माउस है <end>']
# [[374   7  90 374   4  69   3]]
# Input: a bench to sit on
# Predicted translation: ['पीठ के नीचे पीठ एक बेंच <end>']
# [[130 125   7  76  11   4  29   3]]
# Input: a wall on the side of a building
# Predicted translation: ['किसी भवन के किनारे की एक दीवार <end>']
# [[   4   17    4 1701   31   25    3]]
# Input: a person wearing a custom
# Predicted translation: ['एक व्यक्ति एक बागे पहने हुए <end>']
# [[142   7  15  22 142   3]]
# Input: two dogs with tongues visible
# Predicted translation: ['कुत्ते के साथ दो कुत्ते <end>']
# [[16 32  6  3]]
# Input: this is the sky
# Predicted translation: ['यह आकाश है <end>']
# [[ 51   5 397   3]]
# Input: knife on the table
# Predicted translation: ['मेज पर चाकू <end>']
# [[547   5  75 696   3]]
# Input: green leaf on plant
# Predicted translation: ['पौधे पर हरी पत्ती <end>']
# [[ 59  11 788   3]]
# Input: giraffes tail sticking out
# Predicted translation: ['जिराफ की सूंड <end>']
# [[ 392    8 1557    3]]
# Input: shot in the tray
# Predicted translation: ['ट्रे में शॉट <end>']
# [[ 12 221  58  21   6   3]]
# Input: the man is skiing
# Predicted translation: ['आदमी स्कीइंग कर रहा है <end>']
# [[ 16   4 331   6   3]]
# Input: this is a tire
# Predicted translation: ['यह एक टायर है <end>']
# [[  4  12   7 273   5 321 127   3]]
# Input: dark sunglasses on a mans face
# Predicted translation: ['एक आदमी के चेहरे पर गहरे बाल <end>']
# [[ 22  41  26 461  31  25   3]]
# Input: two people are wearing goggles
# Predicted translation: ['दो लोग काले चश्मे पहने हुए <end>']
# [[191   5 154  20   3]]
# Input: woman sitting at table
# Predicted translation: ['टेबल पर बैठी महिला <end>']
# [[ 909    8   33 4874    3]]
# Input: blue lanyard in the neck
# Predicted translation: ['गले में नीला कैनो <end>']
# [[  22  243 2453    8    3]]
# Input: picture of two mail boxes
# Predicted translation: ['दो सैंडविच बक्सों में <end>']
# [[99  7 15 12  3]]
# Input: man with a skateboard
# Predicted translation: ['स्केटबोर्ड के साथ आदमी <end>']
# [[733   7 180   8 169   3]]
# Input: sheep next to sheep
# Predicted translation: ['भेड़ों के बगल में भेड़ <end>']
# [[ 65   5 181   5  20   3]]
# Input: woman on skis on snow
# Predicted translation: ['बर्फ पर स्की पर महिला <end>']
# [[ 312 5980  211    5  129    3]]
# Input: brown teddy bear sitting on counter
# Predicted translation: ['ब्राउन स्टफ्ड बियर पर बैठे <end>']
# [[102  26 824   3]]
# Input: three black pillows
# Predicted translation: ['तीन काले तकिए <end>']
# [[  30    8  113 4073    3]]
# Input: small duckling in water
# Predicted translation: ['पानी में छोटी पिस्तौल <end>']
# [[16  4 12  6  3]]
# Input: this is a man
# Predicted translation: ['यह एक आदमी है <end>']
# [[17 67  6  3]]
# Input: the person is standing
# Predicted translation: ['व्यक्ति खड़ा है <end>']
# [[  4 191 166   3]]
# Input: a table scene
# Predicted translation: ['एक टेबल दृश्य <end>']
# [[328 295 539  44 153   3]]
# Input: man carrying a surfboard
# Predicted translation: ['सर्फबोर्ड ले जाने वाला मनुष्य <end>']
# [[245   7  82  65   3]]
# Input: snow on top of mountain
# Predicted translation: ['पहाड़ी के ऊपर बर्फ <end>']
# [[1557    8   94    3]]
# Input: birds in the shot
# Predicted translation: ['शॉट में पक्षी <end>']
# [[16  4 12  6  3]]
# Input: this is a man
# Predicted translation: ['यह एक आदमी है <end>']
# [[ 48   8  67 927   3]]
# Input: elephant standing in clearing
# Predicted translation: ['हाथी में खड़ा होना <end>']
# [[  39    5 1662  323    3]]
# Input: ud on the clock
# Predicted translation: ['घड़ी पर बनाई गई <end>']
# [[108   9   4 147 283 103  20   3]]
# Input: woman eating a slice of pizza
# Predicted translation: ['पिज्जा का एक टुकड़ा खाने वाली महिला <end>']
# [[  4 311   8  67 927   3]]
# Input: serviceman standing in a line
# Predicted translation: ['एक पंक्ति में खड़ा होना <end>']
# [[ 4 17  9 40  3]]
# Input: head of a person
# Predicted translation: ['एक व्यक्ति का सिर <end>']
# [[84  4 72  8  6  3]]
# Input: the bear is up in a tree
# Predicted translation: ['भालू एक पेड़ में है <end>']
# [[ 379   47   19    9 5678 5561    3]]
# Input: light blue pillow case
# Predicted translation: ['हल्के नीले रंग का फूला पेसा <end>']
# [[16 32  6  3]]
# Input: this is the sky
# Predicted translation: ['यह आकाश है <end>']
# [[ 64 148   6   3]]
# Input: the shirt is yellow
# Predicted translation: ['शर्ट पीली है <end>']
# [[ 16   4 104   6   3]]
# Input: this is a picture
# Predicted translation: ['यह एक तस्वीर है <end>']
# [[  77   13   10 1603    3]]
# Input: yellow and white toothbrush
# Predicted translation: ['पीला और सफेद टूथब्रुश <end>']
# [[330 102  41  18   3]]
# Input: these are three people
# Predicted translation: ['ये तीन लोग हैं <end>']
# [[114  29   5  10  57   3]]
# Input: white window sill on the pink wall
# Predicted translation: ['गुलाबी दीवार पर सफेद खिड़की <end>']
# [[  4 282 415  24 254  21   6   3]]
# Input: a vehicle is going through slush
# Predicted translation: ['एक वाहन माध्यम से जा रहा है <end>']
# [[16  4 81  6  3]]
# Input: this is a zebra
# Predicted translation: ['यह एक ज़ेबरा है <end>']
# [[ 30   8  14 115   3]]
# Input: red cow in water
# Predicted translation: ['पानी में लाल गाय <end>']
# [[ 22  52  11 894   3]]
# Input: two wooden beach chairs
# Predicted translation: ['दो लकड़ी की कुर्सियाँ <end>']
# [[230 664   9 139   3]]
# Input: gathering of brown elephants
# Predicted translation: ['भूरी हाथियों का समूह <end>']
# [[  4  78 267 348   3]]
# Input: a grey parking meter
# Predicted translation: ['एक ग्रे पार्किंग मीटर <end>']
# [[237  95 132   5   4  77 151   3]]
# Input: a yellow umbrella over some beach chairs
# Predicted translation: ['कुछ समुद्र तट पर एक पीला छाता <end>']
# [[191  47  19  11   6   3]]
# Input: the table is blue
# Predicted translation: ['टेबल नीले रंग की है <end>']

# %%
target_val_1 = target_val[:100]
for i in range(len(target_val_1)):
    target_val_1[i] = target_val_1[i].split(" ")[1:-1]
    
t = []
for i in range(len(translation)):
    t.append(translation[i][0])    

t1=[]
for i in range(len(t)):
    l = t[i][0].split(" ")[:-1]
    s = " ".join(l)
    t1.append(s)

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu
avg_1g_score = 0
for i in range(len(t1)):
    candidate = t1[i].split(" ")
    reference = [target_val_1[i]]
    score = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0))
#     print(score)
    avg_1g_score = avg_1g_score + score

avg_1g_score = avg_1g_score/len(t1)
avg_1g_score
# Out:
# C:\Users\sudha\anaconda3\envs\rtx_3060\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\sudha\anaconda3\envs\rtx_3060\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\sudha\anaconda3\envs\rtx_3060\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 0.6924838159650187

# %%
avg_2g_score = 0
for i in range(len(t1)):
    candidate = t1[i].split(" ")
    reference = [target_val_1[i]]
    score = sentence_bleu(reference, candidate, weights=(0, 1, 0, 0))
#     print(score)
    avg_2g_score = avg_2g_score + score

avg_2g_score = avg_2g_score/len(t1)
avg_2g_score
# Out:
# 0.5425592696258319

# %%
avg_ng_score = 0
for i in range(len(t1)):
    candidate = t1[i].split(" ")
    reference = [target_val_1[i]]
    score = sentence_bleu(reference, candidate, weights=(0.25, 0.25, 0.25, 0.25))
#     print(score)
    avg_ng_score = avg_ng_score + score

avg_ng_score = avg_ng_score/len(t1)
avg_ng_score
# Out:
# 0.27664548786554677
