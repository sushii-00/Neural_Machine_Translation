# %% [markdown]
# # SEQUENCE-TO-SEQUENCE NMT WITH ATTENTION MECHANISM

# %% [markdown]
# # DATA

# %%
import numpy as np
import re
import string
import unicodedata
from unicodedata import normalize
import sys
import indicnlp
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from numpy import array
from numpy import asarray
from numpy import zeros
# from keras.models import Model
# from keras.layers import Input, LSTM, GRU, Dense, Embedding
from tensorflow.keras.utils import plot_model
import numpy as np
# !pip install tensorflow-addons==0.11.2
import tensorflow_addons as tfa
from sklearn.model_selection import train_test_split

from tensorflow import keras
# !pip install indic-nlp-library : this is necessary, without this common wont be found and correct indic nlp wont get installed
import os
import io
import time
INDIC_NLP_LIB_HOME=r"C:\Users\sudha\Desktop\ALL_PROJECTS\NMT_PROJECTS\Language_Translation_Chat_Bot\LSTM_MODELS\GLOve_large_dataset\anoopkunchukuttan-indic_nlp_library-eccde81"
INDIC_NLP_RESOURCES=r"C:\Users\sudha\Desktop\ALL_PROJECTS\NMT_PROJECTS\Language_Translation_Chat_Bot\LSTM_MODELS\GLOve_large_dataset\indic_nlp_resources-master"
sys.path.append(r'{}'.format(INDIC_NLP_LIB_HOME))
from indicnlp import common
common.set_resources_path(INDIC_NLP_RESOURCES)
from indicnlp import loader
loader.load()
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
from indicnlp.tokenize import indic_tokenize

# %% [markdown]
# # LOAD DATA

# %%
def load_doc(doc):
    file = open(doc , mode = 'rt' , encoding = 'utf -8')
    text = file.read()
    file.close()
    return text

def clean_english_data(lines):
    re_print = re.compile('[^%s]' %re.escape(string.printable))
    table = str.maketrans('' , '' , string.punctuation)
    
    
    clean_eng_lines = []
    ans = list()
    ans.append(lines)
    
    for line in ans:
        line = normalize('NFD' , line).encode('ascii' , 'ignore')
        line = line.decode('UTF-8')
        line = line.split()
        line = [word.lower() for word in line]
        line = [word.translate(table) for word in line]
        line = [word for word in line if word.isalpha()]
        line = ' '.join(line)
        line = '<start> ' + line +' <end>'
        clean_eng_lines.append(line)
    return clean_eng_lines

def clean_text(line):
    text = line
    text = text.replace(u',' ,'')
    text = text.replace(u'"' ,'')
    text = text.replace(u'(' ,'')
    text = text.replace(u')' ,'')
    text = text.replace(u'"' ,'')
    text = text.replace(u':' ,'')
    text = text.replace(u"'" ,'')
    text = text.replace(u"'" ,'')
    text=text.replace(u"‘‘",'')
    text=text.replace(u"’’",'')
    text=text.replace(u"''",'')
    text=text.replace(u".",'')
    text=text.replace(u"-",'')
    text=text.replace(u"।",'')
    text=text.replace(u"?",'')
    text=text.replace(u"\\",'')
    text=text.replace(u"_",'')
    text = re.sub('[a-zA-Z]' , '' , text)
    text = re.sub('[0-9+\-*/.%&!]' , '' , text)
    return text

def clean_hindi_data(lines):
    clean_hin_lines = []
    ans = list()
    ans.append(lines)
    for line in ans:
        remove_nuktas = True
        factory = IndicNormalizerFactory()
        normalizer = factory.get_normalizer("hi" , remove_nuktas = True )
        line = clean_text(line)
        tokens = list()
        for t in indic_tokenize.trivial_tokenize(line):
            tokens.append(t)
        line = tokens
        line = [ word.lower() for word in line]
        line = [word for word in line if not re.search(r'\d', word)]
        line = ' '.join(line)
        line = '<start> ' + line +' <end>'
        clean_hin_lines.append(line)
        
    return clean_hin_lines   


def to_pairs(text):
    lines = text.strip().split('\n')
    
    eng_hin_pairs = [line.split('\t') for line in lines]
    eng_hin_pairs = np.delete(eng_hin_pairs, [0,1,2,3,4] , axis = 1)
    eng_hin_pairs = eng_hin_pairs.tolist()
    clean_data = list()
    for pair in eng_hin_pairs:
        temp_data = list()
        for i, sentence in enumerate(pair):
            if i == 0:
                x = clean_english_data(sentence)
                temp_data.append(x)
            if i == 1:
                y = clean_hindi_data(sentence)
                temp_data.append(y)
        clean_data.append(temp_data)
    return eng_hin_pairs, clean_data

doc = load_doc("hindi-visual-genome-train.txt")
pairs , clean_data = to_pairs(doc)

# %%
clean_data
# Out:
# [[['<start> it is an indoor scene <end>'],
#   ['<start> यह एक इनडोर दृश्य है <end>']],
#  [['<start> computer screens turned on <end>'],
#   ['<start> कंप्यूटर स्क्रीन चालू <end>']],
#  [['<start> man has short hair <end>'],
#   ['<start> आदमी के छोटे बाल हैं <end>']],
#  [['<start> photo album open on an adults lap <end>'],
#   ['<start> एक वयस्क की गोद में फोटो एल्बम खुला <end>']],
#  [['<start> there is a group of girls beside the black car <end>'],
#   ['<start> काली कार के पास लड़कियों का एक समूह है <end>']],
#  [['<start> child in a stroller <end>'],
#   ['<start> एक घुमक्कड़ में बच्चा <end>']],
#  [['<start> tall metal lightpost <end>'],
#   ['<start> लंबा धातु प्रकाश पोस्ट <end>']],
#  [['<start> wall is painted white <end>'],
#   ['<start> दीवार सफेद रंग की है <end>']],
#  [['<start> there are several pictures on the wall <end>'],
#   ['<start> दीवार पर कई चित्र हैं <end>']],
#  [['<start> woman facing the ocean <end>'],
#   ['<start> सागर का सामना कर रही महिला <end>']],
#  [['<start> this is an office layout <end>'],
#   ['<start> यह एक कार्यालय लेआउट है <end>']],
#  [['<start> four metallic chairs <end>'],
#   ['<start> चार धातु की कुर्सियाँ <end>']],
#  [['<start> clutter is on a table <end>'],
#   ['<start> क्लटर एक मेज पर है <end>']],
#  [['<start> a white microwave oven <end>'],
#   ['<start> एक सफेद माइक्रोवेव ओवन <end>']],
#  [['<start> white suv driving through intersection <end>'],
#   ['<start> चौराहे के माध्यम से सफेद एसयूवी ड्राइविंग <end>']],
#  [['<start> person crossing street with umbrella <end>'],
#   ['<start> छतरी के साथ सड़क पार करते व्यक्ति <end>']],
#  [['<start> man in gray pants leaning on building <end>'],
#   ['<start> इमारत पर झुकाव में आदमी ग्रे पैंट में <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> a man standing in between cars <end>'],
#   ['<start> कारों के बीच में खड़ा एक आदमी <end>']],
#  [['<start> painting hanging on wall <end>'],
#   ['<start> दीवार पर चित्रकला <end>']],
#  [['<start> leg of the chair <end>'], ['<start> कुर्सी का पैर <end>']],
#  [['<start> window of a boat <end>'], ['<start> एक नाव की खिड़की <end>']],
#  [['<start> the cabinet is wood <end>'], ['<start> कैबिनेट लकड़ी है <end>']],
#  [['<start> a man reading a book <end>'],
#   ['<start> एक आदमी एक किताब पढ़ रहा है <end>']],
#  [['<start> a person swimming in water <end>'],
#   ['<start> पानी में तैरता हुआ व्यक्ति <end>']],
#  [['<start> lamp with glowing shade <end>'],
#   ['<start> चमकती छाया के साथ दीपक <end>']],
#  [['<start> fruit on the plate <end>'], ['<start> प्लेट पर फल <end>']],
#  [['<start> a porcelain white plate <end>'],
#   ['<start> एक चीनी मिट्टी के बरतन सफ़ेद प्लेट <end>']],
#  [['<start> black game controller <end>'],
#   ['<start> काला खेल नियंत्रक <end>']],
#  [['<start> a person putting something in the trunk of the car <end>'],
#   ['<start> कार की डिक्की में कुछ डालने वाला व्यक्ति <end>']],
#  [['<start> green car parked along a street <end>'],
#   ['<start> एक सड़क के साथ ग्रीन कार पार्क किया <end>']],
#  [['<start> car on the street <end>'], ['<start> गली पर कार <end>']],
#  [['<start> construction worker wearing coveralls <end>'],
#   ['<start> निर्माण कर्मचारी कवरलेस पहनते हैं <end>']],
#  [['<start> a black car with a yellow door <end>'],
#   ['<start> पीले दरवाजे के साथ एक काली कार <end>']],
#  [['<start> chair at the table <end>'], ['<start> मेज पर कुर्सी <end>']],
#  [['<start> a navel orange on a counter <end>'],
#   ['<start> एक काउंटर पर एक नारंगी संतरा <end>']],
#  [['<start> three windows of a building <end>'],
#   ['<start> एक इमारत की तीन खिड़कियां <end>']],
#  [['<start> window on a building <end>'], ['<start> इमारत पर खिडकि <end>']],
#  [['<start> brown table standing on top of a floor <end>'],
#   ['<start> भूरे रंग की मेज एक मंजिल के ऊपर खड़ी है <end>']],
#  [['<start> floor lamp is on <end>'], ['<start> फ्लोर लैंप चालू है <end>']],
#  [['<start> a yellow bus <end>'], ['<start> एक पीली बस <end>']],
#  [['<start> branch of the tree <end>'], ['<start> वृक्ष की शाखा <end>']],
#  [['<start> cement bench outside the building <end>'],
#   ['<start> भवन के बाहर सीमेंट की बेंच <end>']],
#  [['<start> thick black pole with a white stripe <end>'],
#   ['<start> एक सफेद पट्टी के साथ मोटी काली पोल <end>']],
#  [['<start> a wooden park bench <end>'], ['<start> लकड़ी पार्क बेंच <end>']],
#  [['<start> a cup <end>'], ['<start> एक कप <end>']],
#  [['<start> man has brown hair <end>'],
#   ['<start> आदमी के भूरे बाल हैं <end>']],
#  [['<start> grass in a field <end>'], ['<start> एक खेत में घास <end>']],
#  [['<start> a large brown tree trunk <end>'],
#   ['<start> एक बड़ा भूरा पेड़ का तना <end>']],
#  [['<start> silver car in front of a building <end>'],
#   ['<start> इमारत के सामने चांदी कार <end>']],
#  [['<start> man sits at counter <end>'],
#   ['<start> आदमी काउंटर पर बैठता है <end>']],
#  [['<start> woman standing at a book cart <end>'],
#   ['<start> किताब की गाड़ी पर खड़ी महिला <end>']],
#  [['<start> two story blue bus <end>'], ['<start> दो कहानी नीली बस <end>']],
#  [['<start> a gray laundry basket <end>'],
#   ['<start> एक ग्रे कपड़े धोने की टोकरी <end>']],
#  [['<start> the yellow construction hats <end>'],
#   ['<start> पीले रंग की निर्माण टोपी <end>']],
#  [['<start> wooden floor in the room <end>'],
#   ['<start> कमरे में लकड़ी का फर्श <end>']],
#  [['<start> a tall palm tree above the horizon <end>'],
#   ['<start> क्षितिज के ऊपर एक लंबा ताड़ का पेड़ <end>']],
#  [['<start> chair inside an auditorium <end>'],
#   ['<start> एक सभागार के अंदर कुर्सी <end>']],
#  [['<start> a tall leafy tree <end>'],
#   ['<start> एक लंबा पत्ते का पेड़ <end>']],
#  [['<start> mirror is on far wall <end>'],
#   ['<start> दर्पण दूर की दीवार पर है <end>']],
#  [['<start> the sidewalk <end>'], ['<start> फ़ुटपाथ <end>']],
#  [['<start> the drivers side door is open <end>'],
#   ['<start> ड्राइवर के बगल का द्वार खुला है <end>']],
#  [['<start> a plate full of food <end>'], ['<start> भोजन से भरी थाली <end>']],
#  [['<start> the building is white <end>'], ['<start> इमारत सफेद है <end>']],
#  [['<start> small picture on wall <end>'],
#   ['<start> दीवार पर छोटी सी तस्वीर <end>']],
#  [['<start> intersection of wooden logs <end>'],
#   ['<start> लकड़ी के लॉग का चौराहे <end>']],
#  [['<start> light attached to building <end>'],
#   ['<start> इमारत से संबद्ध प्रकाश <end>']],
#  [['<start> do not enter sign <end>'], ['<start> साइन न करें <end>']],
#  [['<start> colorful pillow of blues and reds on a white striped couch <end>'],
#   ['<start> सफेद धारीदार सोफे पर ब्लूज़ और रेड्स का रंगीन तकिया <end>']],
#  [['<start> dent is in the vehicle <end>'],
#   ['<start> डेंट वाहन में है <end>']],
#  [['<start> the roof is grey <end>'], ['<start> छत ग्रे है <end>']],
#  [['<start> brown frame on mirror <end>'],
#   ['<start> दर्पण पर भूरे रंग का फ्रेम <end>']],
#  [['<start> white flowers beneath tree <end>'],
#   ['<start> पेड़ के नीचे सफेद फूल <end>']],
#  [['<start> white ambulance on the street <end>'],
#   ['<start> सड़क पर सफेद एम्बुलेंस <end>']],
#  [['<start> green trees in distance <end>'],
#   ['<start> दूरी में हरे पेड़ <end>']],
#  [['<start> the sign is blue <end>'], ['<start> यह चिह्न नीला है <end>']],
#  [['<start> man sitting off to side of road <end>'],
#   ['<start> सड़क के किनारे बैठा आदमी <end>']],
#  [['<start> a man crossing the street <end>'],
#   ['<start> सड़क पार करने वाला एक आदमी <end>']],
#  [['<start> sign on the wall <end>'], ['<start> दीवार पर साइन इन करें <end>']],
#  [['<start> window in a brick house <end>'],
#   ['<start> एक ईंट के घर में खिड़की <end>']],
#  [['<start> the computer screen is blue <end>'],
#   ['<start> कंप्यूटर की स्क्रीन नीली है <end>']],
#  [['<start> bike route sign <end>'], ['<start> बाइक मार्ग का चिह्न <end>']],
#  [['<start> grey beard hair on a man <end>'],
#   ['<start> एक आदमी पर ग्रे दाढ़ी बाल <end>']],
#  [['<start> the rear view of a car <end>'],
#   ['<start> कार का पिछला दृश्य <end>']],
#  [['<start> burger with cheese sauce <end>'],
#   ['<start> पनीर सॉस के साथ बर्गर <end>']],
#  [['<start> side of thee silver suv <end>'],
#   ['<start> रजत एसयूवी की ओर <end>']],
#  [['<start> woman walking across street <end>'],
#   ['<start> सड़क पर घूमती हुई महिला <end>']],
#  [['<start> woman wearing pink jacket <end>'],
#   ['<start> गुलाबी जैकेट पहने महिला <end>']],
#  [['<start> red car parked by street light <end>'],
#   ['<start> गली की बत्ती से के पास खड़ी लाल कार <end>']],
#  [['<start> the traffic lights are yellow <end>'],
#   ['<start> ट्रैफिक लाइट पीले हैं <end>']],
#  [['<start> white painted line on pavement <end>'],
#   ['<start> फुटपाथ पर सफेद रंग की लाइन <end>']],
#  [['<start> the black tipped pen on the desk <end>'],
#   ['<start> मेज पर काले रंग की कलम <end>']],
#  [['<start> man in white shirt walking down the sidewalk <end>'],
#   ['<start> सफेद शर्ट में आदमी फुटपाथ के नीचे चल रहा है <end>']],
#  [['<start> large light fixture in ceiling <end>'],
#   ['<start> छत में बड़ा प्रकाश आकार <end>']],
#  [['<start> white monitor on desk <end>'],
#   ['<start> सफेद मॉनिटर डेस्क पर <end>']],
#  [['<start> black computer monitor on desk <end>'],
#   ['<start> डेस्क पर ब्लैक कंप्यूटर मॉनिटर <end>']],
#  [['<start> handle on the mug <end>'], ['<start> मग पर संभाल <end>']],
#  [['<start> a man sitting in front of a computer monitor <end>'],
#   ['<start> कंप्यूटर मॉनिटर के सामने बैठा आदमी <end>']],
#  [['<start> turned on black monitor <end>'],
#   ['<start> ब्लैक मॉनीटर पर दिया <end>']],
#  [['<start> man wearing brown sunglasses <end>'],
#   ['<start> आदमी भूरा धूप का चश्मा पहने हुए <end>']],
#  [['<start> brick on the building <end>'], ['<start> इमारत पर ईंट <end>']],
#  [['<start> silver metal table on ground <end>'],
#   ['<start> जमीन पर धातु तालिका <end>']],
#  [['<start> a grey trash bin <end>'], ['<start> एक ग्रे कचरा बिन <end>']],
#  [['<start> boy holding ball <end>'], ['<start> बॉल पकड़े हुए लड़का <end>']],
#  [['<start> projection screen is white <end>'],
#   ['<start> प्रोजेक्शन स्क्रीन सफेद है <end>']],
#  [['<start> yellow traffic signal attached to a gray pole <end>'],
#   ['<start> पीले ट्रैफिक सिग्नल एक ग्रे पोल से जुड़ा हुआ है <end>']],
#  [['<start> red truck behind silver car <end>'],
#   ['<start> चांदी की कार के पीछे लाल ट्रक <end>']],
#  [['<start> two mopeds are parked <end>'],
#   ['<start> दो मोपेड खड़ी हैं <end>']],
#  [['<start> a blue car on the street <end>'],
#   ['<start> सड़क पर एक नीली कार <end>']],
#  [['<start> black car with yellow doors <end>'],
#   ['<start> पीली डोर वाली काली कार <end>']],
#  [['<start> a car with four doors <end>'],
#   ['<start> चार दरवाजों वाली एक कार <end>']],
#  [['<start> bike parked on the sidewalk <end>'],
#   ['<start> फुटपाथ पर खड़ी बाइक <end>']],
#  [['<start> red motorcycle on sidewalk <end>'],
#   ['<start> फुटपाथ पर लाल मोटरसाइकिल <end>']],
#  [['<start> man wearing blue shirt <end>'],
#   ['<start> नीली कमीज पहने आदमी <end>']],
#  [['<start> group of scooters parked next to each other <end>'],
#   ['<start> स्कूटरों का समूह एक दूसरे के बगल में खड़ा था <end>']],
#  [['<start> yellow vw leaving parking lot <end>'],
#   ['<start> पीले वीडब्ल्यू पार्किंग को छोड़कर <end>']],
#  [['<start> bag of oranges <end>'], ['<start> संतरे का बैग <end>']],
#  [['<start> there is a band on stage <end>'],
#   ['<start> मंच पर एक बैंड है <end>']],
#  [['<start> window on white house <end>'],
#   ['<start> सफेद घर पर खिड़की <end>']],
#  [['<start> these are tall buildings <end>'],
#   ['<start> ये ऊंची इमारतें हैं <end>']],
#  [['<start> small car beside curb <end>'],
#   ['<start> कर्ब के पास छोटी कार <end>']],
#  [['<start> this is a person <end>'], ['<start> यह एक व्यक्ति है <end>']],
#  [['<start> bull on the sand <end>'], ['<start> रेत पर बैल <end>']],
#  [['<start> the building with a yellow roof <end>'],
#   ['<start> एक पीले रंग की छत के साथ इमारत <end>']],
#  [['<start> the cup is upside down <end>'], ['<start> कप उल्टा है <end>']],
#  [['<start> light in the ceiling <end>'], ['<start> छत में प्रकाश <end>']],
#  [['<start> black truck is parked <end>'],
#   ['<start> काला ट्रक पार्क किया गया है <end>']],
#  [['<start> the man in the light blue coat <end>'],
#   ['<start> हल्के नीले कोट में आदमी <end>']],
#  [['<start> bike leaning against black gate <end>'],
#   ['<start> काले फाटक के खिलाफ बाइक झुकाव <end>']],
#  [['<start> white curtain on window <end>'],
#   ['<start> विंडो पर श्वेत पर्दा <end>']],
#  [['<start> the alarm clock is off <end>'],
#   ['<start> अलार्म घड़ी बंद है <end>']],
#  [['<start> a medium sized picture on the wall <end>'],
#   ['<start> दीवार पर एक मध्यम आकार का चित्र <end>']],
#  [['<start> a bottle of water on the table <end>'],
#   ['<start> टेबल पर पानी की एक बोतल <end>']],
#  [['<start> wired telephone connected to the wall <end>'],
#   ['<start> तार से जुड़ा तार <end>']],
#  [['<start> chair next to wood desk <end>'],
#   ['<start> लकड़ी के मेज़ के बगल में कुर्सी <end>']],
#  [['<start> lamppost next to television <end>'],
#   ['<start> टेलीविजन के बगल में लैम्पपोस्ट <end>']],
#  [['<start> black backpack beside a bed <end>'],
#   ['<start> एक बिस्तर के बगल में काला बैग <end>']],
#  [['<start> a silver faucet in a bathroom <end>'],
#   ['<start> एक बाथरूम में एक चांदी का नल <end>']],
#  [['<start> small plant on porch <end>'],
#   ['<start> पोर्च पर छोटा पौधा <end>']],
#  [['<start> cedar shingles on the house <end>'],
#   ['<start> देवदार घर पर दाद <end>']],
#  [['<start> a white and tan hotel room <end>'],
#   ['<start> एक सफेद और टैन होटल का कमरा <end>']],
#  [['<start> five knobs on a stove <end>'],
#   ['<start> एक डंडे पर पाँच गाँठ <end>']],
#  [['<start> the sink is stainless steel <end>'],
#   ['<start> सिंक स्टेनलेस स्टील है <end>']],
#  [['<start> a wooden floor <end>'], ['<start> एक लकड़ी के फर्श <end>']],
#  [['<start> the window is shut <end>'], ['<start> खिड़की बंद है <end>']],
#  [['<start> black car tire with silver rim <end>'],
#   ['<start> चांदी रिम के साथ काली कार टायर <end>']],
#  [['<start> a four legged steel chair <end>'],
#   ['<start> एक चार पैर वाली स्टील कुर्सी <end>']],
#  [['<start> red desk lamp sitting on desk <end>'],
#   ['<start> लाल डेस्क लैंप डेस्क पर बैठे <end>']],
#  [['<start> the wooden night stand <end>'],
#   ['<start> लकड़ी की रात स्टैंड <end>']],
#  [['<start> tall grassy plants <end>'], ['<start> लंबे घास के पौधे <end>']],
#  [['<start> part of a house plant <end>'], ['<start> मकान पौधे का भाग <end>']],
#  [['<start> red and green plaid sofa <end>'],
#   ['<start> लाल और हरे रंग का प्लेड सोफा <end>']],
#  [['<start> large kitchen area <end>'], ['<start> बड़ा रसोई क्षेत्र <end>']],
#  [['<start> boat on the water <end>'], ['<start> पानी पर नाव <end>']],
#  [['<start> vehicles parked on the side of the road <end>'],
#   ['<start> सड़क के किनारे वाहन खड़े कर दिए <end>']],
#  [['<start> a woman standing on the sidewalk <end>'],
#   ['<start> फुटपाथ पर खड़ी एक महिला <end>']],
#  [['<start> man standing on the phone <end>'],
#   ['<start> फोन पर खड़ा आदमी <end>']],
#  [['<start> a woman wearing a rain jacket <end>'],
#   ['<start> रेन जैकेट पहने एक महिला <end>']],
#  [['<start> taxi cab driving on street <end>'],
#   ['<start> सड़क पर टैक्सी टैक्सी चला रहे हैं <end>']],
#  [['<start> yellow taxi driving on a street <end>'],
#   ['<start> एक सड़क पर पीली टैक्सी चलती है <end>']],
#  [['<start> person walking down the sidewalk in a busy city <end>'],
#   ['<start> एक व्यस्त शहर में फुटपाथ के नीचे चलने वाला व्यक्ति <end>']],
#  [['<start> person walks on sidewalk <end>'],
#   ['<start> व्यक्ति फुटपाथ पर चलता है <end>']],
#  [['<start> group of people is standing <end>'],
#   ['<start> लोगों का समूह खड़ा है <end>']],
#  [['<start> black car on the street <end>'],
#   ['<start> सड़क पर काली कार <end>']],
#  [['<start> window of a car <end>'], ['<start> कार की खिड़की <end>']],
#  [['<start> flowers next to water <end>'],
#   ['<start> पानी के बगल में फूल <end>']],
#  [['<start> a food stand on a sidewalk <end>'],
#   ['<start> एक खाना फुटपाथ पर खड़ा है <end>']],
#  [['<start> person crossing on crosswalk <end>'],
#   ['<start> क्रॉसवॉक पर पार करने वाला व्यक्ति <end>']],
#  [['<start> van driving under light <end>'],
#   ['<start> प्रकाश के तहत वैन ड्राइविंग <end>']],
#  [['<start> yellow taxi on the road <end>'],
#   ['<start> सड़क पर पीली टैक्सी <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> women is wearing a pink shirt <end>'],
#   ['<start> एक ऑरत ने गुलाबी कुर्ता पहना हुआ हैं <end>']],
#  [['<start> tan hat hanging on a post <end>'],
#   ['<start> एक पोस्ट पर लटका तन टोपी <end>']],
#  [['<start> a white plane on a tarmac <end>'],
#   ['<start> एक टरमैक पर एक सफेद विमान <end>']],
#  [['<start> planes parked on the tarmac <end>'],
#   ['<start> टरमैक पर पार्क किए गए विमान <end>']],
#  [['<start> small window on airplane <end>'],
#   ['<start> हवाई जहाज पर छोटी खिड़की <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> small rocks <end>'], ['<start> छोटी चट्टानें <end>']],
#  [['<start> tree trunk is broken <end>'],
#   ['<start> पेड़ का तना टूट गया है <end>']],
#  [['<start> person in red shorts <end>'],
#   ['<start> लाल शॉर्ट्स में व्यक्ति <end>']],
#  [['<start> the shrub is very short <end>'],
#   ['<start> झाड़ी बहुत कम है <end>']],
#  [['<start> clouds in the sky <end>'], ['<start> आकाश में बादल <end>']],
#  [['<start> a buffalo near a road <end>'],
#   ['<start> एक सड़क के पास एक भैंस <end>']],
#  [['<start> cloud in the sky <end>'], ['<start> आकाश में बादल <end>']],
#  [['<start> white moving through the water <end>'],
#   ['<start> सफेद पानी के माध्यम से चलती है <end>']],
#  [['<start> parrot is on top of cage <end>'],
#   ['<start> तोता पिंजरे के ऊपर है <end>']],
#  [['<start> a bird standing in water <end>'],
#   ['<start> पानी में खड़ा एक पक्षी <end>']],
#  [['<start> right eye <end>'], ['<start> दाहिना आँख <end>']],
#  [['<start> light on the pole <end>'], ['<start> पोल पर प्रकाश <end>']],
#  [['<start> highway in a quiet area <end>'],
#   ['<start> एक शांत क्षेत्र में राजमार्ग <end>']],
#  [['<start> white cloud in sky <end>'], ['<start> आकाश में सफेद बादल <end>']],
#  [['<start> white boat next to the dock <end>'],
#   ['<start> गोदी के आगे सफेद नाव <end>']],
#  [['<start> boat in the water <end>'], ['<start> पानी में नाव <end>']],
#  [['<start> boat is orange <end>'], ['<start> नाव नारंगी है <end>']],
#  [['<start> bikes in line by sidewalk <end>'],
#   ['<start> फुटपाथ से लाइन में बाइक <end>']],
#  [['<start> small green minivan <end>'], ['<start> छोटे हरे मिनीवान <end>']],
#  [['<start> american flag hanging on side of building <end>'],
#   ['<start> इमारत के किनारे लटकता हुआ अमेरिकी झंडा <end>']],
#  [['<start> tree behind building <end>'],
#   ['<start> निर्माण के पीछे पेड़ <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> orange beak on white duck <end>'],
#   ['<start> सफेद बतख पर नारंगी चोंच <end>']],
#  [['<start> grey and white sky <end>'], ['<start> ग्रे और सफेद आकाश <end>']],
#  [['<start> man holding long yellow skis <end>'],
#   ['<start> आदमी लंबी पीली स्की पकड़े हुए <end>']],
#  [['<start> the red flag in the snow <end>'],
#   ['<start> बर्फ में लाल झंडा <end>']],
#  [['<start> black scooter on the road <end>'],
#   ['<start> सड़क पर काला स्कूटर <end>']],
#  [['<start> black metal lock box <end>'],
#   ['<start> काला धातु लॉक बक्सा <end>']],
#  [['<start> glass window on building <end>'],
#   ['<start> इमारत पर कांच विंडो <end>']],
#  [['<start> sidewalk is light grey <end>'],
#   ['<start> फुटपाथ हल्का भूरा है <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> paved road with parked cars <end>'],
#   ['<start> पार्क किए गए कारों सहित सड़क <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> window on a building <end>'], ['<start> इमारत पर खिडकि <end>']],
#  [['<start> white lines in the middle of the road <end>'],
#   ['<start> सड़क के बीच में सफेद लाइनें <end>']],
#  [['<start> car parked on a narrow road <end>'],
#   ['<start> एक संकरी सड़क पर खड़ी कार <end>']],
#  [['<start> red helmet on his head <end>'],
#   ['<start> उसके सिर पर लाल हेलमेट <end>']],
#  [['<start> boat on the water <end>'], ['<start> पानी पर नाव <end>']],
#  [['<start> the boat is at a dock <end>'],
#   ['<start> नाव एक गोदी में है <end>']],
#  [['<start> pink pants <end>'], ['<start> गुलाबी पैंट <end>']],
#  [['<start> blue parking lines on the pavement <end>'],
#   ['<start> फुटपाथ पर नीली पार्किंग लाइनें <end>']],
#  [['<start> the man is walking <end>'], ['<start> आदमी चल रहा है <end>']],
#  [['<start> the sidewalk <end>'], ['<start> फ़ुटपाथ <end>']],
#  [['<start> green palm on radio <end>'],
#   ['<start> रेडियो पर हरी हथेली <end>']],
#  [['<start> hole in silver hubcap <end>'],
#   ['<start> सिल्वर हबकैप में छेद <end>']],
#  [['<start> girl in blue jean skirt <end>'],
#   ['<start> नीली जीन स्कर्ट में लड़की <end>']],
#  [['<start> the electrical box on the post <end>'],
#   ['<start> पोस्ट पर विद्युत बॉक्स <end>']],
#  [['<start> sign on side of road <end>'],
#   ['<start> सड़क के किनारे साइन इन करें <end>']],
#  [['<start> green grass in a field <end>'],
#   ['<start> क्षेत्र में हरी घास <end>']],
#  [['<start> blue sign with large black base <end>'],
#   ['<start> बड़े काले आधार के साथ नीला चिन्ह <end>']],
#  [['<start> green palm on tree <end>'], ['<start> पेड़ पर हरा हथेली <end>']],
#  [['<start> picture in a frame <end>'], ['<start> एक फ्रेम में तस्वीर <end>']],
#  [['<start> the car is black <end>'], ['<start> कार काला है <end>']],
#  [['<start> red car near plant <end>'],
#   ['<start> संयंत्र के पास लाल कार <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> white bus on the street <end>'],
#   ['<start> सड़क पर सफेद बस <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> a decorated christmas tree <end>'],
#   ['<start> एक सजाया हुआ क्रिसमस ट्री <end>']],
#  [['<start> yellow dump truck by the mountain <end>'],
#   ['<start> पहाड़ द्वारा पीला डंप ट्रक <end>']],
#  [['<start> green palm on tree <end>'], ['<start> पेड़ पर हरा हथेली <end>']],
#  [['<start> sun in the sky <end>'], ['<start> आकाश में सूर्य <end>']],
#  [['<start> white print style letter <end>'],
#   ['<start> सफेद प्रिंट शैली <end>']],
#  [['<start> the light is on the ceiling <end>'],
#   ['<start> छत पर प्रकाश है <end>']],
#  [['<start> light brown wooden step <end>'],
#   ['<start> हल्के भूरे रंग का लकड़ी का कदम <end>']],
#  [['<start> womens lips <end>'], ['<start> महिला के होंठ <end>']],
#  [['<start> brick with grass around it <end>'],
#   ['<start> इसके चारों ओर घास के साथ ईंट <end>']],
#  [['<start> a seagull is standing <end>'], ['<start> एक सीगल खड़ा है <end>']],
#  [['<start> the building is large <end>'], ['<start> इमारत बड़ी है <end>']],
#  [['<start> a dark colored van <end>'], ['<start> गहरे रंग की एक वैन <end>']],
#  [['<start> a dark haired woman in a colorful top <end>'],
#   ['<start> एक रंगीन शीर्ष में एक काले बालों वाली महिला <end>']],
#  [['<start> ear of the cat <end>'], ['<start> बिल्ली का कान <end>']],
#  [['<start> the woman is next to the man <end>'],
#   ['<start> महिला पुरुष के बगल में है <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> grey colored sidewalk brick <end>'],
#   ['<start> धूसर रंग के ईंट फ़ुटपाथ <end>']],
#  [['<start> the man is standing <end>'], ['<start> आदमी खड़ा है <end>']],
#  [['<start> three men standing in a group <end>'],
#   ['<start> एक समूह में तीन आदमी खड़े थे <end>']],
#  [['<start> a luggage cart on a tarmac <end>'],
#   ['<start> एक टार्मेक पर एक सामान गाड़ी <end>']],
#  [['<start> the tail of an airplane <end>'],
#   ['<start> एक हवाई जहाज की पूंछ <end>']],
#  [['<start> black restroom sign attached to the wall <end>'],
#   ['<start> ब्लैक टॉयलेट साइन दीवार से जुड़ा हुआ <end>']],
#  [['<start> a long metal rack <end>'], ['<start> एक लंबा धातु रैक <end>']],
#  [['<start> light on a machine <end>'], ['<start> एक मशीन पर प्रकाश <end>']],
#  [['<start> child wearing striped shirt <end>'],
#   ['<start> धारीदार शर्ट पहने बच्चा <end>']],
#  [['<start> cameras on the ceiling of the room <end>'],
#   ['<start> कमरे की छत पर लगे कैमरे <end>']],
#  [['<start> vase on the mantel <end>'],
#   ['<start> अग्निस्थान के उप्पर ग़ुलदान <end>']],
#  [['<start> the man has a goatee <end>'],
#   ['<start> आदमी के पास एक बकरी है <end>']],
#  [['<start> man painting on canvas <end>'],
#   ['<start> कैनवास पर आदमी पेंटिंग <end>']],
#  [['<start> a row of red chairs <end>'],
#   ['<start> लाल कुर्सियों की एक पंक्ति <end>']],
#  [['<start> two police officers <end>'], ['<start> दो पुलिस अधिकारी <end>']],
#  [['<start> houseboat in the water <end>'],
#   ['<start> पानी में हाउसबोट <end>']],
#  [['<start> bread in a basket <end>'], ['<start> एक टोकरी में रोटी <end>']],
#  [['<start> man with short black hair <end>'],
#   ['<start> छोटे काले बालों वाला आदमी <end>']],
#  [['<start> a big grey ball <end>'], ['<start> एक बड़ी ग्रे बॉल <end>']],
#  [['<start> white table cloth on the table <end>'],
#   ['<start> मेज पर सफेद कपड़ा तालिका <end>']],
#  [['<start> a person sitting in the baptism tub <end>'],
#   ['<start> एक व्यक्ति दीक्षास्नान टब में बैठे व्यक्ति | <end>']],
#  [['<start> horizontal venetian blinds on the window <end>'],
#   ['<start> क्षैतिज विनीशियन खिड़की पर अंधा कर रही है <end>']],
#  [['<start> flatscreen television on the dresser <end>'],
#   ['<start> ड्रेसर पर फ्लैट स्क्रीन टेलीविजन <end>']],
#  [['<start> lights suspended from ceiling <end>'],
#   ['<start> छत से निलंबित प्रकाश <end>']],
#  [['<start> the man has gray hair <end>'],
#   ['<start> आदमी के भूरे बाल हैं <end>']],
#  [['<start> man wearing white shirt <end>'],
#   ['<start> आदमी सफेद शर्ट पहने हुए <end>']],
#  [['<start> people sitting in a bus <end>'],
#   ['<start> एक बस में बैठे लोग <end>']],
#  [['<start> man and woman in a candy store <end>'],
#   ['<start> एक कैंडी की दुकान में आदमी और औरत <end>']],
#  [['<start> chair desk combo in the room <end>'],
#   ['<start> कमरे में कुर्सी डेस्क कॉम्बो <end>']],
#  [['<start> the man is wearing glasses <end>'],
#   ['<start> आदमी चश्मा पहन रहा है | <end>']],
#  [['<start> a man with no shirt in the snow <end>'],
#   ['<start> बर्फ में कुर्ता के साथ एक व्यक्ति <end>']],
#  [['<start> grey dividers for cubicles <end>'],
#   ['<start> क्यूबिकल्स के लिए ग्रे डिवाइडर <end>']],
#  [['<start> windown pane on door <end>'],
#   ['<start> द्वार पर विन्ड फलक <end>']],
#  [['<start> truck has white cargo holder <end>'],
#   ['<start> ट्रक में सफेद कार्गो धारक है <end>']],
#  [['<start> the chair has no arms <end>'],
#   ['<start> कुर्सी के पास कोई हथियार नहीं है <end>']],
#  [['<start> man has head turned <end>'],
#   ['<start> आदमी का सिर मुड़ गया है <end>']],
#  [['<start> child walking into plane <end>'],
#   ['<start> बच्चा विमान में घूम रहा है <end>']],
#  [['<start> purple tissue paper around bouquet <end>'],
#   ['<start> गुलदस्ता के चारों ओर बैंगनी टिशू पेपर <end>']],
#  [['<start> pool table in a large room <end>'],
#   ['<start> एक बड़े कमरे में पूल टेबल <end>']],
#  [['<start> paddle on a table <end>'], ['<start> एक तालिका पर पैडल <end>']],
#  [['<start> man standing in a room <end>'],
#   ['<start> एक कमरे में खड़ा आदमी <end>']],
#  [['<start> man relaxing in the water <end>'],
#   ['<start> आदमी पानी में आराम करता है <end>']],
#  [['<start> man is in a pool <end>'], ['<start> आदमी एक कुंड में है <end>']],
#  [['<start> boy has brown hair <end>'],
#   ['<start> लड़के के भूरे बाल हैं <end>']],
#  [['<start> a brown and white staircase <end>'],
#   ['<start> एक भूरे और सफेद सीढ़ी <end>']],
#  [['<start> building is painted green <end>'],
#   ['<start> भवन को हरे रंग से रंगा गया है <end>']],
#  [['<start> many people in snow <end>'], ['<start> बर्फ में कई लोग <end>']],
#  [['<start> the silver toilet <end>'], ['<start> चाँदी का शौचालय <end>']],
#  [['<start> yellow slide in the room <end>'],
#   ['<start> कमरे में पीली स्लाइड <end>']],
#  [['<start> child shopping cart filled with fake food <end>'],
#   ['<start> बाल शॉपिंग गाड़ी से भरा हुआ भोजन <end>']],
#  [['<start> this is a kitchen <end>'], ['<start> यह एक रसोई है <end>']],
#  [['<start> a faucet on the sink <end>'], ['<start> सिंक पर एक नल <end>']],
#  [['<start> assorted cereals on a kitchen shelf <end>'],
#   ['<start> एक रसोई के शेल्फ पर अनाज रखा <end>']],
#  [['<start> white microwave oven in corner <end>'],
#   ['<start> कोने में सफेद माइक्रोवेव ओवन <end>']],
#  [['<start> wall papered wall in a kitchen <end>'],
#   ['<start> एक रसोई घर में दीवार दीवार <end>']],
#  [['<start> a wall of orange dryers <end>'],
#   ['<start> नारंगी ड्रायर्स की एक दीवार <end>']],
#  [['<start> white pipe on the wall <end>'],
#   ['<start> दीवार पर सफेद पाइप <end>']],
#  [['<start> dolphin statue near the pool <end>'],
#   ['<start> पूल के निकट डॉल्फिन <end>']],
#  [['<start> microwave on top of counter <end>'],
#   ['<start> काउंटर के ऊपर माइक्रोवेव <end>']],
#  [['<start> logo on the hat <end>'], ['<start> टोपी पर लोगो <end>']],
#  [['<start> a person kneeling down <end>'],
#   ['<start> एक व्यक्ति ने घुटने टेक दिए <end>']],
#  [['<start> person wearing black pants <end>'],
#   ['<start> व्यक्ति ने काला पैंट पहना है <end>']],
#  [['<start> people sitting on a couch <end>'],
#   ['<start> एक सोफे पर बैठे लोग <end>']],
#  [['<start> light hanging from the ceiling <end>'],
#   ['<start> छत से लटके हुए प्रकाश <end>']],
#  [['<start> square hole in chair <end>'],
#   ['<start> कुर्सी में चौकोर छेद <end>']],
#  [['<start> arms up in the air <end>'], ['<start> हवा में हथियार <end>']],
#  [['<start> orange pail hanging from wall <end>'],
#   ['<start> नारंगी की दीवार से लटकी हुई <end>']],
#  [['<start> white washer situated under a counter <end>'],
#   ['<start> एक काउंटर के नीचे स्थित सफेद वॉशर <end>']],
#  [['<start> person sitting in front of window <end>'],
#   ['<start> खिड़की के सामने बैठा व्यक्ति <end>']],
#  [['<start> light of daytime sky <end>'],
#   ['<start> दिन के आकाश का प्रकाश <end>']],
#  [['<start> brown lounge chair next to the pool <end>'],
#   ['<start> पूल के बगल में ब्राउन लाउंज कुर्सी <end>']],
#  [['<start> a group of umbrellas at a pool <end>'],
#   ['<start> एक पूल में छतरियों का एक समूह <end>']],
#  [['<start> red bench near elegant chair <end>'],
#   ['<start> सुरुचिपूर्ण कुर्सी के पास लाल बेंच <end>']],
#  [['<start> green turtle pool in stack <end>'],
#   ['<start> स्टैक में हरा कछुआ पूल <end>']],
#  [['<start> many people in a room <end>'],
#   ['<start> एक कमरे में कई लोग <end>']],
#  [['<start> man with a blue and black plaid shirt <end>'],
#   ['<start> एक नीले और काले प्लेड शर्ट के साथ आदमी <end>']],
#  [['<start> the word polar on the truck <end>'],
#   ['<start> ट्रक पर ध्रुवीय शब्द <end>']],
#  [['<start> a black and brown area rug <end>'],
#   ['<start> एक काला और भूरा क्षेत्र गलीचा <end>']],
#  [['<start> black chair to the left of brown table <end>'],
#   ['<start> भूरे रंग की मेज के बाईं ओर काली कुर्सी <end>']],
#  [['<start> brown colored wooden stair <end>'],
#   ['<start> भूरे रंग की लकड़ी की सीढ़ी <end>']],
#  [['<start> a yellow and black tie on a man <end>'],
#   ['<start> एक पीला और काला बांध आदमी पर <end>']],
#  [['<start> person walking on trail <end>'],
#   ['<start> राह पर चलते व्यक्ति <end>']],
#  [['<start> woman wearing red scarf <end>'],
#   ['<start> लाल स्कार्फ पहनने वाली महिला <end>']],
#  [['<start> pigeon on ground <end>'], ['<start> जमीन पर कबूतर <end>']],
#  [['<start> back of docked houseboat <end>'],
#   ['<start> गोदी हाउसबोट की पीठ <end>']],
#  [['<start> a yellow skirt <end>'], ['<start> एक पीला स्कर्ट <end>']],
#  [['<start> black tv in room <end>'], ['<start> कक्ष में काला टीवी <end>']],
#  [['<start> television remote sitting on a red tablecloth <end>'],
#   ['<start> टेलीविज़न रिमोट एक लाल मेज़पोश पर बैठा है <end>']],
#  [['<start> mirror on the wall <end>'], ['<start> दीवार पर लगा दर्पण <end>']],
#  [['<start> picture hanging on the wall <end>'],
#   ['<start> दीवार पर टंगी तस्वीर <end>']],
#  [['<start> a large painting on a wall <end>'],
#   ['<start> एक दीवार पर एक बड़ी पेंटिंग <end>']],
#  [['<start> photo taken during the day <end>'],
#   ['<start> दिन के दौरान लिया गया फोटो <end>']],
#  [['<start> people walking on the bridge <end>'],
#   ['<start> पुल पर चलते लोग <end>']],
#  [['<start> tower with pointed top <end>'],
#   ['<start> नुकीले शीर्ष वाला टॉवर <end>']],
#  [['<start> these are old structures <end>'],
#   ['<start> ये पुराने ढाँचे हैं <end>']],
#  [['<start> grey steps on stairs <end>'],
#   ['<start> सीढ़ियों पर ग्रे कदम <end>']],
#  [['<start> person walking on spiral stairs <end>'],
#   ['<start> सर्पिल सीढ़ियों पर चलने वाला व्यक्ति <end>']],
#  [['<start> window on a residential building <end>'],
#   ['<start> एक आवासीय भवन पर खिड़की <end>']],
#  [['<start> the silver butter knives <end>'],
#   ['<start> चांदी मक्खन चाकू <end>']],
#  [['<start> utensil to the left of plate <end>'],
#   ['<start> थाली के बाईं ओर बर्तन <end>']],
#  [['<start> black letters on paper <end>'],
#   ['<start> कागज पर काले अक्षर <end>']],
#  [['<start> coffee cup full of frothy coffee <end>'],
#   ['<start> फ्राई कॉफी से भरा कॉफी कप <end>']],
#  [['<start> cut banana in bowl <end>'],
#   ['<start> केले को कटोरे में काट लें <end>']],
#  [['<start> juice in glass bottle <end>'],
#   ['<start> शीशे की बोतल में रस <end>']],
#  [['<start> a vase full of red flowers <end>'],
#   ['<start> लाल फूलों से भरा फूलदान <end>']],
#  [['<start> the rainbow looks like a half moon <end>'],
#   ['<start> इंद्रधनुष आधा चाँद की तरह दिखता है <end>']],
#  [['<start> wooden slat on chair <end>'],
#   ['<start> कुर्सी पर लकड़ी की बस्ती <end>']],
#  [['<start> a brown wooden cabinet door <end>'],
#   ['<start> एक भूरे रंग की लकड़ी की कैबिनेट दरवाजा <end>']],
#  [['<start> the gun is shiny <end>'], ['<start> बंदूक चमकदार है <end>']],
#  [['<start> clear blue sky above a mountaintop <end>'],
#   ['<start> एक पहाड़ के ऊपर स्पष्ट नीला आकाश <end>']],
#  [['<start> a window in an apartment building <end>'],
#   ['<start> एक अपार्टमेंट इमारत में एक खिड़की <end>']],
#  [['<start> a black street light <end>'],
#   ['<start> एक काली स्ट्रीट लाइट <end>']],
#  [['<start> a black chair <end>'], ['<start> एक काली कुर्सी <end>']],
#  [['<start> two men sitting at a desk <end>'],
#   ['<start> एक डेस्क पर दो आदमी बैठे थे <end>']],
#  [['<start> phone with twisted cord <end>'],
#   ['<start> मुड़ कॉर्ड के साथ फोन <end>']],
#  [['<start> a white car parked on the street <end>'],
#   ['<start> एक सफेद कार सड़क पर खड़ी थी <end>']],
#  [['<start> white car parked near the fence <end>'],
#   ['<start> सफेद कार बाड़ के पास खड़ी है <end>']],
#  [['<start> window side of building <end>'],
#   ['<start> भवन की खिड़की का किनारा <end>']],
#  [['<start> this is a woman <end>'], ['<start> यह एक महिला है <end>']],
#  [['<start> the field is green <end>'], ['<start> क्षेत्र हरा है <end>']],
#  [['<start> yellow lines on the street <end>'],
#   ['<start> सड़क पर पीली लाइनें <end>']],
#  [['<start> black car parked on the street <end>'],
#   ['<start> सड़क पर काली कार पार्क <end>']],
#  [['<start> the street <end>'], ['<start> सड़क <end>']],
#  [['<start> this is a car <end>'], ['<start> यह एक कार है <end>']],
#  [['<start> the water is green in color <end>'],
#   ['<start> पानी का रंग हरा है <end>']],
#  [['<start> license plate on the car <end>'],
#   ['<start> कार पर लगी लाइसेंस प्लेट <end>']],
#  [['<start> black car on a road <end>'],
#   ['<start> एक सड़क पर काली कार <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> pane on the window <end>'], ['<start> खिड़की पर फलक <end>']],
#  [['<start> tall outdoor lamp post <end>'],
#   ['<start> लंबा आउटडोर लैंप पोस्ट <end>']],
#  [['<start> tire of the car <end>'], ['<start> गाड़ी का टायर <end>']],
#  [['<start> the brown delivery truck <end>'],
#   ['<start> भूरे रंग का डिलीवरी ट्रक <end>']],
#  [['<start> car tire made of black rubber and silver metal <end>'],
#   ['<start> कार का टायर काला रबर और चांदी की धातु से बना है <end>']],
#  [['<start> the parked white car <end>'], ['<start> खड़ी सफेद कार <end>']],
#  [['<start> a brightly lit rear brake light <end>'],
#   ['<start> एक उज्ज्वल जला हुआ रियर ब्रेक लाइट <end>']],
#  [['<start> window in a large office building <end>'],
#   ['<start> एक बड़े कार्यालय भवन में खिड़की <end>']],
#  [['<start> window in front of building <end>'],
#   ['<start> भवन के सामने की खिड़की <end>']],
#  [['<start> blue house with light brown roof <end>'],
#   ['<start> हल्के भूरे रंग की छत वाला नीला घर <end>']],
#  [['<start> the older woman walking on the sidewalk <end>'],
#   ['<start> फुटपाथ पर चलने वाली वृद्ध महिला <end>']],
#  [['<start> a large black trashcan <end>'],
#   ['<start> एक बड़े काले ट्रैशकैन <end>']],
#  [['<start> street signs says ames <end>'],
#   ['<start> स्ट्रीट संकेत कहते हैं एम्स <end>']],
#  [['<start> woman standing on sidewalk <end>'],
#   ['<start> फुटपाथ पर खड़ी महिला <end>']],
#  [['<start> square window on building <end>'],
#   ['<start> इमारत पर वर्ग खिड़की <end>']],
#  [['<start> book on brown wooden bookshelf <end>'],
#   ['<start> भूरी लकड़ी की बुकशेल्फ़ पर किताब <end>']],
#  [['<start> paper cup on top of desk <end>'],
#   ['<start> डेस्क के शीर्ष पर पेपर कप <end>']],
#  [['<start> clock on the wall <end>'], ['<start> दीवार पर घड़ी <end>']],
#  [['<start> vase on the table <end>'], ['<start> मेज पर फूलदान <end>']],
#  [['<start> a glossy blue coffee mug <end>'],
#   ['<start> एक चमकदार नीली कॉफी मग <end>']],
#  [['<start> silver faucet on kitchen sink <end>'],
#   ['<start> रसोई के सिंक पर चांदी का नल <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> the woman in jeans and a black shirt <end>'],
#   ['<start> जींस और काले रंग की शर्ट में महिला <end>']],
#  [['<start> a blue and white parking sign <end>'],
#   ['<start> एक नीले और सफेद पार्किंग साइन <end>']],
#  [['<start> the plant on the toilet <end>'],
#   ['<start> शौचालय पर संयंत्र <end>']],
#  [['<start> white book with black writing <end>'],
#   ['<start> काले लेखन के साथ सफेद किताब <end>']],
#  [['<start> a tan car parked <end>'], ['<start> एक टैन कार खड़ी थी <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> woman has black hair <end>'],
#   ['<start> स्त्री के काले बाल है <end>']],
#  [['<start> man walking on sidewalk <end>'],
#   ['<start> फुटपाथ पर चलने वाला आदमी <end>']],
#  [['<start> banners on the post <end>'], ['<start> पोस्ट पर बैनर <end>']],
#  [['<start> reflection on store window <end>'],
#   ['<start> दुकान की खिड़की पर प्रतिबिंब <end>']],
#  [['<start> the bench is long <end>'], ['<start> बेंच लंबा है <end>']],
#  [['<start> wood plank on porch <end>'],
#   ['<start> पोर्च पर लकड़ी प्लांक <end>']],
#  [['<start> crisp brown leaf fallen off of a tree <end>'],
#   ['<start> एक पेड़ से गिरने वाला कुरकुरा भूरा पत्ता <end>']],
#  [['<start> a stone in a leaf filled field <end>'],
#   ['<start> पत्ती से भरे खेत में एक पत्थर <end>']],
#  [['<start> silver suv parked on road <end>'],
#   ['<start> चांदी एसयूवी सड़क पर खड़ी है <end>']],
#  [['<start> paint on a mailbox <end>'], ['<start> मेलबॉक्स पर पेंट <end>']],
#  [['<start> window in front of white building <end>'],
#   ['<start> सफेद इमारत के सामने की खिड़की <end>']],
#  [['<start> clock on the wall <end>'], ['<start> दीवार पर घड़ी <end>']],
#  [['<start> the silver car <end>'], ['<start> चाँदी की कार <end>']],
#  [['<start> a women standing <end>'], ['<start> एक महिला खड़ी है <end>']],
#  [['<start> window in front of brick building <end>'],
#   ['<start> ईंट निर्माण के सामने की खिड़की <end>']],
#  [['<start> do not enter street sign <end>'],
#   ['<start> सड़क चिह्न नहीं दाखिल करें <end>']],
#  [['<start> the red headed woman wlaking on the sidewalk <end>'],
#   ['<start> लाल बालों वाली औरत सड़्क पर चलते हुए <end>']],
#  [['<start> window in front of building <end>'],
#   ['<start> भवन के सामने की खिड़की <end>']],
#  [['<start> maroon car parked at the curb <end>'],
#   ['<start> मैरून कार कर्ब पर खड़ी <end>']],
#  [['<start> blue vehicle parked on the street <end>'],
#   ['<start> सड़क पर खड़ा नीला वाहन <end>']],
#  [['<start> jeep suv parked on curb <end>'],
#   ['<start> जीप एसयूवी पर अंकुश लगा दिया <end>']],
#  [['<start> a street light on a metal pole <end>'],
#   ['<start> एक धातु के खंभे पर एक स्ट्रीट लाइट <end>']],
#  [['<start> the shelf is color brown <end>'],
#   ['<start> शेल्फ का रंग भूरा है <end>']],
#  [['<start> a computer is on front a keyboard <end>'],
#   ['<start> एक कंप्यूटर एक कीबोर्ड पर होता है <end>']],
#  [['<start> blue and white coffee mug <end>'],
#   ['<start> नीला और सफेद कॉफी कि जग <end>']],
#  [['<start> an empty poster board on the wall <end>'],
#   ['<start> दीवार पर एक खाली पोस्टर बोर्ड <end>']],
#  [['<start> yellow box of snack crackers <end>'],
#   ['<start> स्नैक बिस्कुट का पीला बक्सा <end>']],
#  [['<start> black monitor on desk <end>'],
#   ['<start> ब्लैक मॉनिटर ऑन डेस्क <end>']],
#  [['<start> black and white desk lamp <end>'],
#   ['<start> ब्लैक एंड व्हाइट डेस्क लैंप <end>']],
#  [['<start> gray plastic trash can under desk <end>'],
#   ['<start> डेस्क के नीचे ग्रे प्लास्टिक कचरा हो सकता है <end>']],
#  [['<start> whtie microwave oven <end>'], ['<start> माइक्रोवेव ओवन <end>']],
#  [['<start> office chair in front of computer monitor <end>'],
#   ['<start> कंप्यूटर मॉनिटर के सामने कार्यालय की कुर्सी <end>']],
#  [['<start> blue cardigan draped over blue chair <end>'],
#   ['<start> नीली कुर्सी पर नीला कार्डिगन लिपटा हुआ <end>']],
#  [['<start> a row of binders on a shelf <end>'],
#   ['<start> एक शेल्फ पर बाँधने की एक पंक्ति <end>']],
#  [['<start> a white piece of paper <end>'],
#   ['<start> कागज का एक सफेद टुकड़ा <end>']],
#  [['<start> white keyboard on top of desk <end>'],
#   ['<start> डेस्क के ऊपर सफेद कीबोर्ड <end>']],
#  [['<start> an old black tire <end>'], ['<start> एक पुरानी काली टायर <end>']],
#  [['<start> maroon suv driving down the road <end>'],
#   ['<start> सड़क के नीचे जाती लाल रंग की एसयूवी <end>']],
#  [['<start> a map hanging on the wall <end>'],
#   ['<start> दीवार पर लटका एक नक्शा <end>']],
#  [['<start> fluorescent ceiling lights <end>'],
#   ['<start> फ्लोरोसेंट छत रोशनी <end>']],
#  [['<start> a tan wooden desk <end>'], ['<start> एक लकड़ी की मेज <end>']],
#  [['<start> the blue walls <end>'], ['<start> नीली दीवारों <end>']],
#  [['<start> large window with white sill <end>'],
#   ['<start> सफेद खिड़की के साथ बड़ी खिड़की <end>']],
#  [['<start> red street sign with white lettering <end>'],
#   ['<start> लाल स्ट्रीट लाल चिह्न सफेद पट्टी के साथ <end>']],
#  [['<start> a red sign with a white stripe <end>'],
#   ['<start> एक सफेद पट्टी के साथ एक लाल संकेत <end>']],
#  [['<start> car driving on road <end>'], ['<start> सड़क पर कार चलाना <end>']],
#  [['<start> blue banner with white decorations <end>'],
#   ['<start> सफेद सजावट के साथ नीला बैनर <end>']],
#  [['<start> black railingon the sidewalk <end>'],
#   ['<start> काला रेलिंगोन सिडीचलन <end>']],
#  [['<start> person on the surfboard <end>'],
#   ['<start> सर्फ़बोर्ड पर व्यक्ति <end>']],
#  [['<start> boat in the water <end>'], ['<start> पानी में नाव <end>']],
#  [['<start> a row of parked cars <end>'],
#   ['<start> खड़ी कारों की एक पंक्ति <end>']],
#  [['<start> a black computer monitor <end>'],
#   ['<start> एक काला कंप्यूटर मॉनीटर <end>']],
#  [['<start> multicolored rainbow over water <end>'],
#   ['<start> पानी के ऊपर बहु रंगीन इंद्रधनुष <end>']],
#  [['<start> the hedges to the right <end>'],
#   ['<start> हेज करने के लिए सही है <end>']],
#  [['<start> a coffee cup on a table <end>'],
#   ['<start> एक मेज पर एक कॉफी कप <end>']],
#  [['<start> street light is off <end>'],
#   ['<start> स्ट्रीट लाइट बंद है <end>']],
#  [['<start> man standing in a black suit and blue shirt <end>'],
#   ['<start> एक काले सूट और नीली शर्ट में खड़ा आदमी <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> yellow and black pedestrian crossing signal <end>'],
#   ['<start> पीले और काले पैदल यात्री क्रॉसिंग सिग्नल <end>']],
#  [['<start> a window on a building <end>'],
#   ['<start> एक इमारत पर एक खिड़की <end>']],
#  [['<start> person in black tank top <end>'],
#   ['<start> काला टैंक टॉप में व्यक्ति <end>']],
#  [['<start> boy wearing a black shirt <end>'],
#   ['<start> एक काला शर्ट पहनने हुए लड़का <end>']],
#  [['<start> a small gray motorcycle <end>'],
#   ['<start> एक छोटी ग्रे मोटरसाइकिल <end>']],
#  [['<start> window on large building <end>'],
#   ['<start> बड़ी इमारत पर खिड़की <end>']],
#  [['<start> this is a motor vehicle <end>'],
#   ['<start> यह एक मोटर वाहन है <end>']],
#  [['<start> two people talking at the bottom of the stairs <end>'],
#   ['<start> सीढ़ियों के नीचे बात कर रहे हैं दो लोग | <end>']],
#  [['<start> the van is blue white and green <end>'],
#   ['<start> वैन नीले सफेद और हरे रंग की है <end>']],
#  [['<start> a door way to a business <end>'],
#   ['<start> किसी व्यापार का दरवाज़ा <end>']],
#  [['<start> wheel of the vehicle <end>'], ['<start> वाहन का पहिया <end>']],
#  [['<start> a car with four doors <end>'],
#   ['<start> चार द्वारों के साथ एक कार <end>']],
#  [['<start> man walking on the street <end>'],
#   ['<start> आदमी सड़क पर चल रहा है <end>']],
#  [['<start> the white car is parked <end>'],
#   ['<start> सफेद कार खड़ी है <end>']],
#  [['<start> the red tip of a pole <end>'],
#   ['<start> एक पोल की लाल टिप <end>']],
#  [['<start> a coca cola sign <end>'], ['<start> कोका कोला चिह्न <end>']],
#  [['<start> a window on a building <end>'], ['<start> इमारत पर खिड़्की <end>']],
#  [['<start> a red and white umbrella <end>'],
#   ['<start> एक लाल और सफेद छाता <end>']],
#  [['<start> the head of a man <end>'], ['<start> एक आदमी का सिर <end>']],
#  [['<start> the picture frame is gold in color <end>'],
#   ['<start> यह तस्वीर रंग में सोना है | <end>']],
#  [['<start> the stairs leading to entrance <end>'],
#   ['<start> प्रवेश द्वार की ओर जाने वाली सीढ़ियाँ <end>']],
#  [['<start> window on the building <end>'], ['<start> इमारत पर विंडो <end>']],
#  [['<start> this is a taxi cab <end>'], ['<start> यह एक टैक्सी कैब है <end>']],
#  [['<start> large tree with no leaves <end>'],
#   ['<start> बिना पत्तों वाला बड़ा पेड़ <end>']],
#  [['<start> work truck is white <end>'], ['<start> कार्य ट्रक सफेद है <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> a white car parked on the side of a street <end>'],
#   ['<start> एक सड़क के किनारे खड़ी एक सफेद कार <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> black car parked on the street <end>'],
#   ['<start> काली कार सड़क पर खड़ी <end>']],
#  [['<start> window on red brick window <end>'],
#   ['<start> लाल ईंट विंडो पर विंडो <end>']],
#  [['<start> the car is red and parked in the street <end>'],
#   ['<start> कार लाल है और गली में खड़ी है <end>']],
#  [['<start> windows on the building <end>'],
#   ['<start> इमारत पर खिड़कियाँ <end>']],
#  [['<start> window on side of building <end>'],
#   ['<start> भवन के किनारे की खिड़की <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> brown tree trunk <end>'],
#   ['<start> भूरे रंग का पेड़ का तना <end>']],
#  [['<start> townhouse is painted yellow <end>'],
#   ['<start> घर का रंग पीला होता है <end>']],
#  [['<start> a row of parked cars <end>'],
#   ['<start> खड़ी कारों की एक पंक्ति <end>']],
#  [['<start> window on side of a building <end>'],
#   ['<start> एक इमारत की तरफ खिड़की <end>']],
#  [['<start> man standing wearing orange lifesaving <end>'],
#   ['<start> नारंगी नारंगी जीवन धारण किए हुए आदमी खड़ा है <end>']],
#  [['<start> a pot on the stairs <end>'],
#   ['<start> सीढ़ियों पर एक घड़ा <end>']],
#  [['<start> tall green tree on grass <end>'],
#   ['<start> घास पर लंबा हरा पेड़ <end>']],
#  [['<start> a vast space of water <end>'],
#   ['<start> पानी का एक विशाल स्थान <end>']],
#  [['<start> moss on the wall <end>'], ['<start> दीवार पर काई <end>']],
#  [['<start> thick trees surrounding the town <end>'],
#   ['<start> शहर के चारों ओर घने पेड़ <end>']],
#  [['<start> mountains in the background <end>'],
#   ['<start> पृष्ठभूमि में पर्वत <end>']],
#  [['<start> big white boat traveling in water <end>'],
#   ['<start> पानी में बड़ी सफेद नाव यात्रा <end>']],
#  [['<start> a wheel <end>'], ['<start> एक पहिया <end>']],
#  [['<start> a red fire hydrant is visible at a distance <end>'],
#   ['<start> की दूरी पर एक लाल अग्नि हाइड्रेंट दिखाई देता है <end>']],
#  [['<start> the girls brown hair <end>'], ['<start> लड़की भूरे बाल | <end>']],
#  [['<start> window on front of brick building <end>'],
#   ['<start> ईंट इमारत के सामने खिड़की <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> brown tree trunk <end>'],
#   ['<start> भूरे रंग का पेड़ का तना <end>']],
#  [['<start> bird near a lake <end>'], ['<start> झील के निकट पक्षी <end>']],
#  [['<start> old shed with a metal roof <end>'],
#   ['<start> एक धातु की छत के साथ पुराना शेड <end>']],
#  [['<start> tall and brown mountain <end>'],
#   ['<start> लंबा और भूरा पर्वत <end>']],
#  [['<start> the pile of gray and brown rocks <end>'],
#   ['<start> ग्रे और भूरी चट्टानों का ढेर <end>']],
#  [['<start> the people are walking <end>'], ['<start> लोग चल रहे हैं <end>']],
#  [['<start> post in the ground <end>'], ['<start> जमीन पर डाक <end>']],
#  [['<start> a window with a rounded top <end>'],
# ...
#   ['<start> एक लाल जैकेट पहनने वाला आदमी <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> इमारत पर कांच की खिड़्की <end>']],
#  [['<start> a white parked car <end>'], ['<start> एक सफेद पार्क कार <end>']],
#  [['<start> bicycle leaning against pole <end>'],
#   ['<start> पोल के खिलाफ साइकिल झुकाव <end>']],
#  [['<start> the house is green <end>'], ['<start> घर हरा है <end>']],
#  [['<start> the person is walking <end>'],
#   ['<start> व्यक्ति चल रहा है <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> a window on a building <end>'], ['<start> इमारत पर खिड़्की <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> भवन पर कांच की खिड़की <end>']],
#  [['<start> a long curve walkway <end>'], ['<start> लंबा वक्र वाल्केम <end>']],
#  [['<start> a womans blue bag <end>'], ['<start> एक महिला का नीला बैग <end>']],
#  [['<start> this is a large building <end>'],
#   ['<start> यह एक बड़ी इमारत है <end>']],
#  [['<start> a light blue sky with large white clouds <end>'],
#   ['<start> बड़े सफेद बादलों के साथ एक हल्का नीला आकाश <end>']],
#  [['<start> green street sign that says congress st <end>'],
#   ['<start> हरे रंग की सड़क का संकेत जो कांग्रेस को सेंट कहता है <end>']],
#  [['<start> red and grey suv <end>'], ['<start> लाल और ग्रे एसयूवी <end>']],
#  [['<start> window on building facing street <end>'],
#   ['<start> इमारत का सामना करना पड़ सड़क पर खिड़की <end>']],
#  [['<start> some deep tire tracks in the snow <end>'],
#   ['<start> बर्फ में कुछ गहरे टायर ट्रैक <end>']],
#  [['<start> a street covered with snow <end>'],
#   ['<start> बर्फ से ढकी एक सड़क <end>']],
#  [['<start> the cars are covered in snow <end>'],
#   ['<start> कारें बर्फ में ढकी हुई हैं <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> windown on dark red building <end>'],
#   ['<start> अंधेरे लाल इमारत पर विचलित <end>']],
#  [['<start> white snow on the ground <end>'],
#   ['<start> जमीन पर सफेद बर्फ <end>']],
#  [['<start> window on top floor of white building <end>'],
#   ['<start> सफेद इमारत की ऊपरी मंजिल पर खिड़की <end>']],
#  [['<start> a yellow and blue sign <end>'],
#   ['<start> एक पीला और नीला चिह्न <end>']],
#  [['<start> person walking on the sidewalk <end>'],
#   ['<start> फुटपाथ पर चलने वाला व्यक्ति <end>']],
#  [['<start> red dresses in the window <end>'],
#   ['<start> विंडो में लाल ड्रेस <end>']],
#  [['<start> this is a city street <end>'],
#   ['<start> यह एक शहर की सड़क है <end>']],
#  [['<start> the red blurry sign <end>'], ['<start> लाल बल्री चिह्न <end>']],
#  [['<start> woman in dress walking <end>'],
#   ['<start> कपड़े पहने महिला <end>']],
#  [['<start> sign on the building <end>'],
#   ['<start> इमारत पर हस्ताक्षर <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> भवन पर कांच की खिड़की <end>']],
#  [['<start> an ornate black street light <end>'],
#   ['<start> एक अलंकृत काली स्ट्रीट लाइट <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> भवन पर कांच की खिड़की <end>']],
#  [['<start> orange bar on fence <end>'],
#   ['<start> बाड़ पर नारंगी पट्टी <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> pole on the sidewalk <end>'], ['<start> फुटपाथ पर पोल <end>']],
#  [['<start> these are a bunch of buildings <end>'],
#   ['<start> ये इमारतों का एक समूह हैं <end>']],
#  [['<start> car <end>'], ['<start> गाड़ी <end>']],
#  [['<start> the person is standing <end>'], ['<start> व्यक्ति खड़ा है <end>']],
#  [['<start> the person is walking <end>'],
#   ['<start> व्यक्ति चल रहा है <end>']],
#  [['<start> window on corner building <end>'],
#   ['<start> कोने के निर्माण पर खिड़की <end>']],
#  [['<start> glass window on the building <end>'],
#   ['<start> इमारत पर कांच की खिड़्की <end>']],
#  [['<start> tractor parked on sidewalk <end>'],
#   ['<start> ट्रैक्टर फुटपाथ पर खड़ा था <end>']],
#  [['<start> leg of the bench <end>'], ['<start> बेंच का पैर <end>']],
#  [['<start> a person walking on a sidewalk <end>'],
#   ['<start> एक व्यक्ति जो फ़ुटपाथ पर चलता है <end>']],
#  [['<start> a car on a street <end>'], ['<start> एक सड़क पर एक कार <end>']],
#  [['<start> light on the pole <end>'], ['<start> पोल पर प्रकाश <end>']],
#  [['<start> round black tire on car <end>'],
#   ['<start> कार पर गोल काला टायर <end>']],
#  [['<start> a white line in the street <end>'],
#   ['<start> सड़क में एक सफेद रेखा <end>']],
#  [['<start> car parked at the curb <end>'],
#   ['<start> कार पर अंकुश लगाया <end>']],
#  [['<start> the sky is grey and white <end>'],
#   ['<start> आकाश ग्रे और सफेद है <end>']],
#  [['<start> lamp pole near a road <end>'],
#   ['<start> एक सड़क के पास लैंप पोल <end>']],
#  [['<start> this is a car <end>'], ['<start> यह एक कार है <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> the car is gold <end>'], ['<start> कार सोना है <end>']],
#  [['<start> the grey car driving on the street <end>'],
#   ['<start> सड़क पर ग्रे कार चला रहा है <end>']],
#  [['<start> a red and white sign <end>'],
#   ['<start> एक लाल और सफेद संकेत <end>']],
#  [['<start> two semicircular tunnels set in a hill <end>'],
#   ['<start> एक पहाड़ी में सेट दो अर्ध गोलाकार ट्यूनेल <end>']],
#  [['<start> silver car parked in the street <end>'],
#   ['<start> सड़क में सिल्वर कार पार्क किया <end>']],
#  [['<start> this is a man <end>'], ['<start> यह एक आदमी है <end>']],
#  [['<start> taillight of a vehicle <end>'], ['<start> वाहन <end>']],
#  [['<start> white van parked in front of sidewalk <end>'],
#   ['<start> फुटपाथ के सामने खड़ी सफेद वैन <end>']],
#  [['<start> the car is white <end>'], ['<start> कार सफेद है <end>']],
#  [['<start> the vehicles on the road <end>'], ['<start> सड़क पर वाहन <end>']],
#  [['<start> metal guard rail beside of road <end>'],
#   ['<start> सड़क के अतिरिक्त धातु रेल <end>']],
#  [['<start> window on the building <end>'], ['<start> इमारत पर विंडो <end>']],
#  [['<start> flower bed in street <end>'],
#   ['<start> सड़क में फूलों का बिस्तर <end>']],
#  [['<start> red car parked in the street <end>'],
#   ['<start> गली में खड़ी लाल कार <end>']],
#  [['<start> round ball with letters airis <end>'],
#   ['<start> पत्र के साथ गोल गेंद <end>']],
#  [['<start> the car is black <end>'], ['<start> कार काली है <end>']],
#  [['<start> a round blue and white sign <end>'],
#   ['<start> एक गोल नीला और सफेद निशान <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> the small stone wall on the side of the road <end>'],
#   ['<start> सड़क के किनारे पर छोटी पत्थर दीवार <end>']],
#  [['<start> a red vehicle on a highway <end>'],
#   ['<start> एक राजमार्ग पर एक लाल वाहन <end>']],
#  [['<start> window on the car <end>'], ['<start> कार पर खिड़की <end>']],
#  [['<start> a car on a street <end>'], ['<start> एक सड़क पर एक कार <end>']],
#  [['<start> the black aentenna ont he hood <end>'],
#   ['<start> काले एंटेंना वह हूड पर था <end>']],
#  [['<start> board on the building <end>'], ['<start> इमारत पर बोर्ड <end>']],
#  [['<start> the car is silver <end>'], ['<start> कार चांदी है <end>']],
#  [['<start> leaves on the tree <end>'],
#   ['<start> पेड़ पर छोड़ देता है <end>']],
#  [['<start> the wooden bench on the sidewalk <end>'],
#   ['<start> फुटपाथ पर लकड़ी के बेंच <end>']],
#  [['<start> trunk of the tree <end>'], ['<start> पेड़ का तना <end>']],
#  [['<start> window on the building <end>'], ['<start> भवन पर खिड़की <end>']],
#  [['<start> tree is bare and in the park <end>'],
#   ['<start> पेड़ नंगे और पार्क में है <end>']],
#  [['<start> leaf in the water <end>'], ['<start> पानी में पत्ती <end>']],
#  [['<start> person in black shorts <end>'],
#   ['<start> काले शॉर्ट्स में व्यक्ति <end>']],
#  [['<start> car on the road <end>'], ['<start> सड़क पर कार <end>']],
#  [['<start> a tree in a city <end>'], ['<start> एक शहर में एक वृक्ष <end>']],
#  [['<start> the sitting arrangement on a street <end>'],
#   ['<start> एक सड़क पर बैठने की व्यवस्था <end>']],
#  [['<start> the numbers above the door <end>'],
#   ['<start> दरवाजे के ऊपर की संख्या <end>']],
#  [['<start> a window on a building <end>'],
#   ['<start> एक इमारत पर एक खिड़की <end>']],
#  [['<start> the plate is black in color <end>'],
#   ['<start> प्लेट का रंग काला है <end>']],
#  [['<start> orange color on truck <end>'],
#   ['<start> ट्रक पर नारंगी रंग <end>']],
#  [['<start> white lines on the road <end>'],
#   ['<start> सड़क पर सफेद लाइनें <end>']],
#  [['<start> the car is silver <end>'], ['<start> कार चाँदी है <end>']],
#  [['<start> silver car parked along the street <end>'],
#   ['<start> सड़क के किनारे खड़ी चांदी की कार <end>']],
#  [['<start> skyscraper in front of car <end>'],
#   ['<start> कार के सामने गगनचुंबी इमारत <end>']],
#  [['<start> parked silver suv <end>'], ['<start> पार्क की गई सिल्वर <end>']],
#  [['<start> round white lamp on top of lamp post <end>'],
#   ['<start> लैंप पोस्ट के शीर्ष पर गोल सफेद दीपक <end>']],
#  [['<start> green shutters on the building <end>'],
#   ['<start> इमारत पर हरे शटर | <end>']],
#  [['<start> the door is brown <end>'], ['<start> दरवाजा भूरा है <end>']],
#  [['<start> shallow pool with three fountain heads <end>'],
#   ['<start> तीन फाउंटेन हेड्स वाला उथला पूल <end>']],
#  [['<start> woman in white and red shirt <end>'],
#   ['<start> सफेद और लाल शर्ट में महिला <end>']],
#  [['<start> thick hedge bordering the sidewalk <end>'],
#   ['<start> फुटपाथ की सीमा पर मोटी हेज <end>']],
#  [['<start> the sky is shining and blue <end>'],
#   ['<start> आकाश चमक रहा है और नीला है <end>']],
#  [['<start> leaves on the tree <end>'],
#   ['<start> पेड़ पर छोड़ देता है <end>']],
#  [['<start> two street lights <end>'], ['<start> दो सड़क रोशनी <end>']],
#  [['<start> person in red jacket <end>'],
#   ['<start> लाल जैकेट में व्यक्ति <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> people eating outside <end>'],
#   ['<start> बाहर खाने वाले लोग <end>']],
#  [['<start> two traffic lights lit up red <end>'],
#   ['<start> दो यातायात रोशनी लाल जलाया <end>']],
#  [['<start> a black parked car <end>'],
#   ['<start> एक काले रंग की खड़ी कार <end>']],
#  [['<start> a parked black car <end>'], ['<start> एक खड़ी कार <end>']],
#  [['<start> dark green suv <end>'], ['<start> गहरा हरा सुव <end>']],
#  [['<start> mural of bird on a building <end>'],
#   ['<start> एक इमारत पर पक्षियों का भित्ति चित्र <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> window on a building <end>'],
#   ['<start> एक इमारत पर खिड़की <end>']],
#  [['<start> man standing in front of wall <end>'],
#   ['<start> दीवार के सामने खड़ा आदमी <end>']],
#  [['<start> man with brown hair <end>'],
#   ['<start> भूरे बालों वाला आदमी <end>']],
#  [['<start> one grey stapler <end>'], ['<start> एक ग्रे स्टेपलर <end>']],
#  [['<start> woman has an eye <end>'], ['<start> महिला की एक आंख है <end>']],
#  [['<start> bench with person sitting and waiting <end>'],
#   ['<start> बेंच पर बैठे और प्रतीक्षा करता आदमी <end>']],
#  [['<start> he is wearing blue jeans <end>'],
#   ['<start> उसने नीली जींस पहनी हुई है <end>']],
#  [['<start> the truck is red <end>'], ['<start> ट्रक लाल है <end>']],
#  [['<start> person wearing shirt <end>'], ['<start> शर्ट पहने व्यक्ति <end>']],
#  [['<start> man in a white shirt <end>'],
#   ['<start> एक सफेद शर्ट में आदमी <end>']],
#  [['<start> man walking wearing white shoes <end>'],
#   ['<start> सफेद जूते पहने हुए आदमी <end>']],
#  [['<start> tall dog in a field <end>'],
#   ['<start> मैदान मे लम्बा कुत्ते <end>']],
#  [['<start> man has white teeth <end>'],
#   ['<start> आदमी के सफेद दांत हैं <end>']],
#  [['<start> person looking at the camera <end>'],
#   ['<start> कैमरे को देख रहे व्यक्ति <end>']],
#  [['<start> person standing on mountain <end>'],
#   ['<start> पहाड़ पर खड़ा व्यक्ति <end>']],
#  [['<start> sidewalk with block pattern <end>'],
#   ['<start> ब्लॉक पैटर्न के साथ साइडवॉक <end>']],
#  [['<start> the building is tall <end>'], ['<start> भवन लंबा है <end>']],
#  [['<start> a man with short hair and a goatee <end>'],
#   ['<start> छोटे बाल और एक बकरी के साथ एक आदमी <end>']],
#  [['<start> the trunk of a tree <end>'], ['<start> एक पेड़ का तना <end>']],
#  [['<start> dog is sitting in grass <end>'],
#   ['<start> कुत्ता घास में बैठा है <end>']],
#  [['<start> man wearing a yellow sweater <end>'],
#   ['<start> पीला स्वेटर पहने व्यक्ति <end>']],
#  [['<start> a scene during the day time <end>'],
#   ['<start> दिन के समय एक दृश्य <end>']],
#  [['<start> the hand is on table <end>'], ['<start> हाथ मेज पर है | <end>']],
#  [['<start> the stapler laying on the floor <end>'],
#   ['<start> मंजिल पर रखे स्टेपलर <end>']],
#  [['<start> cliff in the water <end>'], ['<start> पानी में चट्टान <end>']],
#  [['<start> car in the arch of the hotel entrance <end>'],
#   ['<start> होटल प्रवेश के मार्च में कार <end>']],
#  [['<start> boat at the edge of water <end>'],
#   ['<start> पानी के किनारे नाव <end>']],
#  [['<start> head shot of a young white man <end>'],
#   ['<start> एक युवा श्वेत व्यक्ति के सिर में गोली लगी <end>']],
#  [['<start> a scene during the day time <end>'],
#   ['<start> दिन के समय एक दृश्य <end>']],
#  [['<start> plane sitting on the runway <end>'],
#   ['<start> विमान रनवे पर बैठा <end>']],
#  [['<start> a gray stapler on the corner desk <end>'],
#   ['<start> कोने की मेज पर एक ग्रे स्टेपलर <end>']],
#  [['<start> the person wearing red <end>'],
#   ['<start> लाल रंग का व्यक्ति <end>']],
#  [['<start> head shot of a young woman <end>'],
#   ['<start> युवती के सिर में गोली लगी <end>']],
#  [['<start> photo taken during the day <end>'],
#   ['<start> दिन के दौरान लिया गया फोटो <end>']],
#  [['<start> license plate of a car <end>'],
#   ['<start> कार की लाइसेंस प्लेट <end>']],
#  [['<start> circle on the wood door <end>'],
#   ['<start> लकड़ी के दरवाजे पर घेरा <end>']],
#  [['<start> brown rock near highway <end>'],
#   ['<start> राजमार्ग के निकट भूरी चट्टान <end>']],
#  [['<start> man in the kitchen <end>'], ['<start> आदमी रसोई में <end>']],
#  [['<start> underside of the lane highway <end>'],
#   ['<start> लेन राजमार्ग के नीचे <end>']],
#  [['<start> man has short hair <end>'],
#   ['<start> मनुष्य के बाल छोटे है <end>']],
#  [['<start> person wears a green shirt <end>'],
#   ['<start> व्यक्ति हरे रंग की शर्ट पहनता है <end>']],
#  [['<start> a green parrot <end>'], ['<start> एक हरा पारोट <end>']],
#  [['<start> green leaves on brown tree <end>'],
#   ['<start> हरे पेड़ पर हरे पत्ते <end>']],
#  [['<start> window facing red building <end>'],
#   ['<start> खिड़की लाल इमारत का सामना करना पड़ <end>']],
#  [['<start> windows on the top level <end>'],
#   ['<start> शीर्ष स्तर पर विंडोज <end>']],
#  [['<start> right ear of a man <end>'],
#   ['<start> किसी व्यक्ति का दाहिना कान <end>']],
#  [['<start> stone block on pier <end>'], ['<start> घाट पर पत्थर ब्लॉक <end>']],
#  [['<start> green wall behind a man <end>'],
#   ['<start> एक व्यक्ति के पीछे हरी दीवार <end>']],
#  [['<start> the background is blue <end>'],
#   ['<start> बैकग्राउंड नीला है <end>']],
#  [['<start> guy with short brown hair <end>'],
#   ['<start> छोटे भूरे बालों के साथ लड़का <end>']],
#  [['<start> four black chairs around a table <end>'],
#   ['<start> एक तालिका के आसपास चार काले कुर्सियाँ <end>']],
#  [['<start> big green truck on dirt road <end>'],
#   ['<start> गंदगी सड़क पर बड़ा हरा ट्रक <end>']],
#  [['<start> man wearing yellow sweater <end>'],
#   ['<start> पीला स्वेटर पहने हुए आदमी <end>']],
#  [['<start> a person walking on a sidewalk <end>'],
#   ['<start> फुटपाथ पर चलने वाला व्यक्ति <end>']],
#  [['<start> laptop computer sitting on desk <end>'],
#   ['<start> लैपटॉप कंप्यूटर डेस्क पर बैठे <end>']],
#  [['<start> coffee cup on the table <end>'], ['<start> मेज पर कॉफी कप <end>']],
#  [['<start> black sign with white letters <end>'],
#   ['<start> सफेद अक्षरों के साथ काला हस्ताक्षर <end>']],
#  [['<start> trunk of tree <end>'], ['<start> पेड़ का ट्रंक | <end>']],
#  [['<start> a rock in water <end>'], ['<start> पानी में एक चट्टान <end>']],
#  [['<start> white van in the parking lot <end>'],
#   ['<start> पार्किंग में सफेद वैन <end>']],
#  [['<start> parrot sitting on a tree branch <end>'],
#   ['<start> तोता एक पेड़ शाखा पर बैठे हुए <end>']],
#  ...]

# %%
# shuffling values
import random
BUFFER_SIZE = 28930
BATCH_SIZE = 64
num_examples = 20000
# train_dataset = clean_data[:n_train]
# val_dataset = clean_data[n_train:]
# # Let's limit the #training examples for faster training

# train_dataset = random.shuffle(train_dataset)
# val_dataset = random.shuffle(val_dataset)
# type(clean_data[0][1])

# %%
# train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# %%
clean_hindi_lines = []
clean_english_lines = []
for i in range(len(clean_data)):
    clean_hindi_lines.append(clean_data[i][1])
    clean_english_lines.append(clean_data[i][0])

# %%
clean_hindi = list()
for i in range(len(clean_hindi_lines)):
    clean_hindi.append(clean_hindi_lines[i][0])
    
clean_english = list()
for i in range(len(clean_english_lines)):
    clean_english.append(clean_english_lines[i][0])

# %%
clean_hindi
# Out:
# ['<start> यह एक इनडोर दृश्य है <end>',
#  '<start> कंप्यूटर स्क्रीन चालू <end>',
#  '<start> आदमी के छोटे बाल हैं <end>',
#  '<start> एक वयस्क की गोद में फोटो एल्बम खुला <end>',
#  '<start> काली कार के पास लड़कियों का एक समूह है <end>',
#  '<start> एक घुमक्कड़ में बच्चा <end>',
#  '<start> लंबा धातु प्रकाश पोस्ट <end>',
#  '<start> दीवार सफेद रंग की है <end>',
#  '<start> दीवार पर कई चित्र हैं <end>',
#  '<start> सागर का सामना कर रही महिला <end>',
#  '<start> यह एक कार्यालय लेआउट है <end>',
#  '<start> चार धातु की कुर्सियाँ <end>',
#  '<start> क्लटर एक मेज पर है <end>',
#  '<start> एक सफेद माइक्रोवेव ओवन <end>',
#  '<start> चौराहे के माध्यम से सफेद एसयूवी ड्राइविंग <end>',
#  '<start> छतरी के साथ सड़क पार करते व्यक्ति <end>',
#  '<start> इमारत पर झुकाव में आदमी ग्रे पैंट में <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> कारों के बीच में खड़ा एक आदमी <end>',
#  '<start> दीवार पर चित्रकला <end>',
#  '<start> कुर्सी का पैर <end>',
#  '<start> एक नाव की खिड़की <end>',
#  '<start> कैबिनेट लकड़ी है <end>',
#  '<start> एक आदमी एक किताब पढ़ रहा है <end>',
#  '<start> पानी में तैरता हुआ व्यक्ति <end>',
#  '<start> चमकती छाया के साथ दीपक <end>',
#  '<start> प्लेट पर फल <end>',
#  '<start> एक चीनी मिट्टी के बरतन सफ़ेद प्लेट <end>',
#  '<start> काला खेल नियंत्रक <end>',
#  '<start> कार की डिक्की में कुछ डालने वाला व्यक्ति <end>',
#  '<start> एक सड़क के साथ ग्रीन कार पार्क किया <end>',
#  '<start> गली पर कार <end>',
#  '<start> निर्माण कर्मचारी कवरलेस पहनते हैं <end>',
#  '<start> पीले दरवाजे के साथ एक काली कार <end>',
#  '<start> मेज पर कुर्सी <end>',
#  '<start> एक काउंटर पर एक नारंगी संतरा <end>',
#  '<start> एक इमारत की तीन खिड़कियां <end>',
#  '<start> इमारत पर खिडकि <end>',
#  '<start> भूरे रंग की मेज एक मंजिल के ऊपर खड़ी है <end>',
#  '<start> फ्लोर लैंप चालू है <end>',
#  '<start> एक पीली बस <end>',
#  '<start> वृक्ष की शाखा <end>',
#  '<start> भवन के बाहर सीमेंट की बेंच <end>',
#  '<start> एक सफेद पट्टी के साथ मोटी काली पोल <end>',
#  '<start> लकड़ी पार्क बेंच <end>',
#  '<start> एक कप <end>',
#  '<start> आदमी के भूरे बाल हैं <end>',
#  '<start> एक खेत में घास <end>',
#  '<start> एक बड़ा भूरा पेड़ का तना <end>',
#  '<start> इमारत के सामने चांदी कार <end>',
#  '<start> आदमी काउंटर पर बैठता है <end>',
#  '<start> किताब की गाड़ी पर खड़ी महिला <end>',
#  '<start> दो कहानी नीली बस <end>',
#  '<start> एक ग्रे कपड़े धोने की टोकरी <end>',
#  '<start> पीले रंग की निर्माण टोपी <end>',
#  '<start> कमरे में लकड़ी का फर्श <end>',
#  '<start> क्षितिज के ऊपर एक लंबा ताड़ का पेड़ <end>',
#  '<start> एक सभागार के अंदर कुर्सी <end>',
#  '<start> एक लंबा पत्ते का पेड़ <end>',
#  '<start> दर्पण दूर की दीवार पर है <end>',
#  '<start> फ़ुटपाथ <end>',
#  '<start> ड्राइवर के बगल का द्वार खुला है <end>',
#  '<start> भोजन से भरी थाली <end>',
#  '<start> इमारत सफेद है <end>',
#  '<start> दीवार पर छोटी सी तस्वीर <end>',
#  '<start> लकड़ी के लॉग का चौराहे <end>',
#  '<start> इमारत से संबद्ध प्रकाश <end>',
#  '<start> साइन न करें <end>',
#  '<start> सफेद धारीदार सोफे पर ब्लूज़ और रेड्स का रंगीन तकिया <end>',
#  '<start> डेंट वाहन में है <end>',
#  '<start> छत ग्रे है <end>',
#  '<start> दर्पण पर भूरे रंग का फ्रेम <end>',
#  '<start> पेड़ के नीचे सफेद फूल <end>',
#  '<start> सड़क पर सफेद एम्बुलेंस <end>',
#  '<start> दूरी में हरे पेड़ <end>',
#  '<start> यह चिह्न नीला है <end>',
#  '<start> सड़क के किनारे बैठा आदमी <end>',
#  '<start> सड़क पार करने वाला एक आदमी <end>',
#  '<start> दीवार पर साइन इन करें <end>',
#  '<start> एक ईंट के घर में खिड़की <end>',
#  '<start> कंप्यूटर की स्क्रीन नीली है <end>',
#  '<start> बाइक मार्ग का चिह्न <end>',
#  '<start> एक आदमी पर ग्रे दाढ़ी बाल <end>',
#  '<start> कार का पिछला दृश्य <end>',
#  '<start> पनीर सॉस के साथ बर्गर <end>',
#  '<start> रजत एसयूवी की ओर <end>',
#  '<start> सड़क पर घूमती हुई महिला <end>',
#  '<start> गुलाबी जैकेट पहने महिला <end>',
#  '<start> गली की बत्ती से के पास खड़ी लाल कार <end>',
#  '<start> ट्रैफिक लाइट पीले हैं <end>',
#  '<start> फुटपाथ पर सफेद रंग की लाइन <end>',
#  '<start> मेज पर काले रंग की कलम <end>',
#  '<start> सफेद शर्ट में आदमी फुटपाथ के नीचे चल रहा है <end>',
#  '<start> छत में बड़ा प्रकाश आकार <end>',
#  '<start> सफेद मॉनिटर डेस्क पर <end>',
#  '<start> डेस्क पर ब्लैक कंप्यूटर मॉनिटर <end>',
#  '<start> मग पर संभाल <end>',
#  '<start> कंप्यूटर मॉनिटर के सामने बैठा आदमी <end>',
#  '<start> ब्लैक मॉनीटर पर दिया <end>',
#  '<start> आदमी भूरा धूप का चश्मा पहने हुए <end>',
#  '<start> इमारत पर ईंट <end>',
#  '<start> जमीन पर धातु तालिका <end>',
#  '<start> एक ग्रे कचरा बिन <end>',
#  '<start> बॉल पकड़े हुए लड़का <end>',
#  '<start> प्रोजेक्शन स्क्रीन सफेद है <end>',
#  '<start> पीले ट्रैफिक सिग्नल एक ग्रे पोल से जुड़ा हुआ है <end>',
#  '<start> चांदी की कार के पीछे लाल ट्रक <end>',
#  '<start> दो मोपेड खड़ी हैं <end>',
#  '<start> सड़क पर एक नीली कार <end>',
#  '<start> पीली डोर वाली काली कार <end>',
#  '<start> चार दरवाजों वाली एक कार <end>',
#  '<start> फुटपाथ पर खड़ी बाइक <end>',
#  '<start> फुटपाथ पर लाल मोटरसाइकिल <end>',
#  '<start> नीली कमीज पहने आदमी <end>',
#  '<start> स्कूटरों का समूह एक दूसरे के बगल में खड़ा था <end>',
#  '<start> पीले वीडब्ल्यू पार्किंग को छोड़कर <end>',
#  '<start> संतरे का बैग <end>',
#  '<start> मंच पर एक बैंड है <end>',
#  '<start> सफेद घर पर खिड़की <end>',
#  '<start> ये ऊंची इमारतें हैं <end>',
#  '<start> कर्ब के पास छोटी कार <end>',
#  '<start> यह एक व्यक्ति है <end>',
#  '<start> रेत पर बैल <end>',
#  '<start> एक पीले रंग की छत के साथ इमारत <end>',
#  '<start> कप उल्टा है <end>',
#  '<start> छत में प्रकाश <end>',
#  '<start> काला ट्रक पार्क किया गया है <end>',
#  '<start> हल्के नीले कोट में आदमी <end>',
#  '<start> काले फाटक के खिलाफ बाइक झुकाव <end>',
#  '<start> विंडो पर श्वेत पर्दा <end>',
#  '<start> अलार्म घड़ी बंद है <end>',
#  '<start> दीवार पर एक मध्यम आकार का चित्र <end>',
#  '<start> टेबल पर पानी की एक बोतल <end>',
#  '<start> तार से जुड़ा तार <end>',
#  '<start> लकड़ी के मेज़ के बगल में कुर्सी <end>',
#  '<start> टेलीविजन के बगल में लैम्पपोस्ट <end>',
#  '<start> एक बिस्तर के बगल में काला बैग <end>',
#  '<start> एक बाथरूम में एक चांदी का नल <end>',
#  '<start> पोर्च पर छोटा पौधा <end>',
#  '<start> देवदार घर पर दाद <end>',
#  '<start> एक सफेद और टैन होटल का कमरा <end>',
#  '<start> एक डंडे पर पाँच गाँठ <end>',
#  '<start> सिंक स्टेनलेस स्टील है <end>',
#  '<start> एक लकड़ी के फर्श <end>',
#  '<start> खिड़की बंद है <end>',
#  '<start> चांदी रिम के साथ काली कार टायर <end>',
#  '<start> एक चार पैर वाली स्टील कुर्सी <end>',
#  '<start> लाल डेस्क लैंप डेस्क पर बैठे <end>',
#  '<start> लकड़ी की रात स्टैंड <end>',
#  '<start> लंबे घास के पौधे <end>',
#  '<start> मकान पौधे का भाग <end>',
#  '<start> लाल और हरे रंग का प्लेड सोफा <end>',
#  '<start> बड़ा रसोई क्षेत्र <end>',
#  '<start> पानी पर नाव <end>',
#  '<start> सड़क के किनारे वाहन खड़े कर दिए <end>',
#  '<start> फुटपाथ पर खड़ी एक महिला <end>',
#  '<start> फोन पर खड़ा आदमी <end>',
#  '<start> रेन जैकेट पहने एक महिला <end>',
#  '<start> सड़क पर टैक्सी टैक्सी चला रहे हैं <end>',
#  '<start> एक सड़क पर पीली टैक्सी चलती है <end>',
#  '<start> एक व्यस्त शहर में फुटपाथ के नीचे चलने वाला व्यक्ति <end>',
#  '<start> व्यक्ति फुटपाथ पर चलता है <end>',
#  '<start> लोगों का समूह खड़ा है <end>',
#  '<start> सड़क पर काली कार <end>',
#  '<start> कार की खिड़की <end>',
#  '<start> पानी के बगल में फूल <end>',
#  '<start> एक खाना फुटपाथ पर खड़ा है <end>',
#  '<start> क्रॉसवॉक पर पार करने वाला व्यक्ति <end>',
#  '<start> प्रकाश के तहत वैन ड्राइविंग <end>',
#  '<start> सड़क पर पीली टैक्सी <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> एक ऑरत ने गुलाबी कुर्ता पहना हुआ हैं <end>',
#  '<start> एक पोस्ट पर लटका तन टोपी <end>',
#  '<start> एक टरमैक पर एक सफेद विमान <end>',
#  '<start> टरमैक पर पार्क किए गए विमान <end>',
#  '<start> हवाई जहाज पर छोटी खिड़की <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> छोटी चट्टानें <end>',
#  '<start> पेड़ का तना टूट गया है <end>',
#  '<start> लाल शॉर्ट्स में व्यक्ति <end>',
#  '<start> झाड़ी बहुत कम है <end>',
#  '<start> आकाश में बादल <end>',
#  '<start> एक सड़क के पास एक भैंस <end>',
#  '<start> आकाश में बादल <end>',
#  '<start> सफेद पानी के माध्यम से चलती है <end>',
#  '<start> तोता पिंजरे के ऊपर है <end>',
#  '<start> पानी में खड़ा एक पक्षी <end>',
#  '<start> दाहिना आँख <end>',
#  '<start> पोल पर प्रकाश <end>',
#  '<start> एक शांत क्षेत्र में राजमार्ग <end>',
#  '<start> आकाश में सफेद बादल <end>',
#  '<start> गोदी के आगे सफेद नाव <end>',
#  '<start> पानी में नाव <end>',
#  '<start> नाव नारंगी है <end>',
#  '<start> फुटपाथ से लाइन में बाइक <end>',
#  '<start> छोटे हरे मिनीवान <end>',
#  '<start> इमारत के किनारे लटकता हुआ अमेरिकी झंडा <end>',
#  '<start> निर्माण के पीछे पेड़ <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> सफेद बतख पर नारंगी चोंच <end>',
#  '<start> ग्रे और सफेद आकाश <end>',
#  '<start> आदमी लंबी पीली स्की पकड़े हुए <end>',
#  '<start> बर्फ में लाल झंडा <end>',
#  '<start> सड़क पर काला स्कूटर <end>',
#  '<start> काला धातु लॉक बक्सा <end>',
#  '<start> इमारत पर कांच विंडो <end>',
#  '<start> फुटपाथ हल्का भूरा है <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> पार्क किए गए कारों सहित सड़क <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> इमारत पर खिडकि <end>',
#  '<start> सड़क के बीच में सफेद लाइनें <end>',
#  '<start> एक संकरी सड़क पर खड़ी कार <end>',
#  '<start> उसके सिर पर लाल हेलमेट <end>',
#  '<start> पानी पर नाव <end>',
#  '<start> नाव एक गोदी में है <end>',
#  '<start> गुलाबी पैंट <end>',
#  '<start> फुटपाथ पर नीली पार्किंग लाइनें <end>',
#  '<start> आदमी चल रहा है <end>',
#  '<start> फ़ुटपाथ <end>',
#  '<start> रेडियो पर हरी हथेली <end>',
#  '<start> सिल्वर हबकैप में छेद <end>',
#  '<start> नीली जीन स्कर्ट में लड़की <end>',
#  '<start> पोस्ट पर विद्युत बॉक्स <end>',
#  '<start> सड़क के किनारे साइन इन करें <end>',
#  '<start> क्षेत्र में हरी घास <end>',
#  '<start> बड़े काले आधार के साथ नीला चिन्ह <end>',
#  '<start> पेड़ पर हरा हथेली <end>',
#  '<start> एक फ्रेम में तस्वीर <end>',
#  '<start> कार काला है <end>',
#  '<start> संयंत्र के पास लाल कार <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> सड़क पर सफेद बस <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> एक सजाया हुआ क्रिसमस ट्री <end>',
#  '<start> पहाड़ द्वारा पीला डंप ट्रक <end>',
#  '<start> पेड़ पर हरा हथेली <end>',
#  '<start> आकाश में सूर्य <end>',
#  '<start> सफेद प्रिंट शैली <end>',
#  '<start> छत पर प्रकाश है <end>',
#  '<start> हल्के भूरे रंग का लकड़ी का कदम <end>',
#  '<start> महिला के होंठ <end>',
#  '<start> इसके चारों ओर घास के साथ ईंट <end>',
#  '<start> एक सीगल खड़ा है <end>',
#  '<start> इमारत बड़ी है <end>',
#  '<start> गहरे रंग की एक वैन <end>',
#  '<start> एक रंगीन शीर्ष में एक काले बालों वाली महिला <end>',
#  '<start> बिल्ली का कान <end>',
#  '<start> महिला पुरुष के बगल में है <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> धूसर रंग के ईंट फ़ुटपाथ <end>',
#  '<start> आदमी खड़ा है <end>',
#  '<start> एक समूह में तीन आदमी खड़े थे <end>',
#  '<start> एक टार्मेक पर एक सामान गाड़ी <end>',
#  '<start> एक हवाई जहाज की पूंछ <end>',
#  '<start> ब्लैक टॉयलेट साइन दीवार से जुड़ा हुआ <end>',
#  '<start> एक लंबा धातु रैक <end>',
#  '<start> एक मशीन पर प्रकाश <end>',
#  '<start> धारीदार शर्ट पहने बच्चा <end>',
#  '<start> कमरे की छत पर लगे कैमरे <end>',
#  '<start> अग्निस्थान के उप्पर ग़ुलदान <end>',
#  '<start> आदमी के पास एक बकरी है <end>',
#  '<start> कैनवास पर आदमी पेंटिंग <end>',
#  '<start> लाल कुर्सियों की एक पंक्ति <end>',
#  '<start> दो पुलिस अधिकारी <end>',
#  '<start> पानी में हाउसबोट <end>',
#  '<start> एक टोकरी में रोटी <end>',
#  '<start> छोटे काले बालों वाला आदमी <end>',
#  '<start> एक बड़ी ग्रे बॉल <end>',
#  '<start> मेज पर सफेद कपड़ा तालिका <end>',
#  '<start> एक व्यक्ति दीक्षास्नान टब में बैठे व्यक्ति | <end>',
#  '<start> क्षैतिज विनीशियन खिड़की पर अंधा कर रही है <end>',
#  '<start> ड्रेसर पर फ्लैट स्क्रीन टेलीविजन <end>',
#  '<start> छत से निलंबित प्रकाश <end>',
#  '<start> आदमी के भूरे बाल हैं <end>',
#  '<start> आदमी सफेद शर्ट पहने हुए <end>',
#  '<start> एक बस में बैठे लोग <end>',
#  '<start> एक कैंडी की दुकान में आदमी और औरत <end>',
#  '<start> कमरे में कुर्सी डेस्क कॉम्बो <end>',
#  '<start> आदमी चश्मा पहन रहा है | <end>',
#  '<start> बर्फ में कुर्ता के साथ एक व्यक्ति <end>',
#  '<start> क्यूबिकल्स के लिए ग्रे डिवाइडर <end>',
#  '<start> द्वार पर विन्ड फलक <end>',
#  '<start> ट्रक में सफेद कार्गो धारक है <end>',
#  '<start> कुर्सी के पास कोई हथियार नहीं है <end>',
#  '<start> आदमी का सिर मुड़ गया है <end>',
#  '<start> बच्चा विमान में घूम रहा है <end>',
#  '<start> गुलदस्ता के चारों ओर बैंगनी टिशू पेपर <end>',
#  '<start> एक बड़े कमरे में पूल टेबल <end>',
#  '<start> एक तालिका पर पैडल <end>',
#  '<start> एक कमरे में खड़ा आदमी <end>',
#  '<start> आदमी पानी में आराम करता है <end>',
#  '<start> आदमी एक कुंड में है <end>',
#  '<start> लड़के के भूरे बाल हैं <end>',
#  '<start> एक भूरे और सफेद सीढ़ी <end>',
#  '<start> भवन को हरे रंग से रंगा गया है <end>',
#  '<start> बर्फ में कई लोग <end>',
#  '<start> चाँदी का शौचालय <end>',
#  '<start> कमरे में पीली स्लाइड <end>',
#  '<start> बाल शॉपिंग गाड़ी से भरा हुआ भोजन <end>',
#  '<start> यह एक रसोई है <end>',
#  '<start> सिंक पर एक नल <end>',
#  '<start> एक रसोई के शेल्फ पर अनाज रखा <end>',
#  '<start> कोने में सफेद माइक्रोवेव ओवन <end>',
#  '<start> एक रसोई घर में दीवार दीवार <end>',
#  '<start> नारंगी ड्रायर्स की एक दीवार <end>',
#  '<start> दीवार पर सफेद पाइप <end>',
#  '<start> पूल के निकट डॉल्फिन <end>',
#  '<start> काउंटर के ऊपर माइक्रोवेव <end>',
#  '<start> टोपी पर लोगो <end>',
#  '<start> एक व्यक्ति ने घुटने टेक दिए <end>',
#  '<start> व्यक्ति ने काला पैंट पहना है <end>',
#  '<start> एक सोफे पर बैठे लोग <end>',
#  '<start> छत से लटके हुए प्रकाश <end>',
#  '<start> कुर्सी में चौकोर छेद <end>',
#  '<start> हवा में हथियार <end>',
#  '<start> नारंगी की दीवार से लटकी हुई <end>',
#  '<start> एक काउंटर के नीचे स्थित सफेद वॉशर <end>',
#  '<start> खिड़की के सामने बैठा व्यक्ति <end>',
#  '<start> दिन के आकाश का प्रकाश <end>',
#  '<start> पूल के बगल में ब्राउन लाउंज कुर्सी <end>',
#  '<start> एक पूल में छतरियों का एक समूह <end>',
#  '<start> सुरुचिपूर्ण कुर्सी के पास लाल बेंच <end>',
#  '<start> स्टैक में हरा कछुआ पूल <end>',
#  '<start> एक कमरे में कई लोग <end>',
#  '<start> एक नीले और काले प्लेड शर्ट के साथ आदमी <end>',
#  '<start> ट्रक पर ध्रुवीय शब्द <end>',
#  '<start> एक काला और भूरा क्षेत्र गलीचा <end>',
#  '<start> भूरे रंग की मेज के बाईं ओर काली कुर्सी <end>',
#  '<start> भूरे रंग की लकड़ी की सीढ़ी <end>',
#  '<start> एक पीला और काला बांध आदमी पर <end>',
#  '<start> राह पर चलते व्यक्ति <end>',
#  '<start> लाल स्कार्फ पहनने वाली महिला <end>',
#  '<start> जमीन पर कबूतर <end>',
#  '<start> गोदी हाउसबोट की पीठ <end>',
#  '<start> एक पीला स्कर्ट <end>',
#  '<start> कक्ष में काला टीवी <end>',
#  '<start> टेलीविज़न रिमोट एक लाल मेज़पोश पर बैठा है <end>',
#  '<start> दीवार पर लगा दर्पण <end>',
#  '<start> दीवार पर टंगी तस्वीर <end>',
#  '<start> एक दीवार पर एक बड़ी पेंटिंग <end>',
#  '<start> दिन के दौरान लिया गया फोटो <end>',
#  '<start> पुल पर चलते लोग <end>',
#  '<start> नुकीले शीर्ष वाला टॉवर <end>',
#  '<start> ये पुराने ढाँचे हैं <end>',
#  '<start> सीढ़ियों पर ग्रे कदम <end>',
#  '<start> सर्पिल सीढ़ियों पर चलने वाला व्यक्ति <end>',
#  '<start> एक आवासीय भवन पर खिड़की <end>',
#  '<start> चांदी मक्खन चाकू <end>',
#  '<start> थाली के बाईं ओर बर्तन <end>',
#  '<start> कागज पर काले अक्षर <end>',
#  '<start> फ्राई कॉफी से भरा कॉफी कप <end>',
#  '<start> केले को कटोरे में काट लें <end>',
#  '<start> शीशे की बोतल में रस <end>',
#  '<start> लाल फूलों से भरा फूलदान <end>',
#  '<start> इंद्रधनुष आधा चाँद की तरह दिखता है <end>',
#  '<start> कुर्सी पर लकड़ी की बस्ती <end>',
#  '<start> एक भूरे रंग की लकड़ी की कैबिनेट दरवाजा <end>',
#  '<start> बंदूक चमकदार है <end>',
#  '<start> एक पहाड़ के ऊपर स्पष्ट नीला आकाश <end>',
#  '<start> एक अपार्टमेंट इमारत में एक खिड़की <end>',
#  '<start> एक काली स्ट्रीट लाइट <end>',
#  '<start> एक काली कुर्सी <end>',
#  '<start> एक डेस्क पर दो आदमी बैठे थे <end>',
#  '<start> मुड़ कॉर्ड के साथ फोन <end>',
#  '<start> एक सफेद कार सड़क पर खड़ी थी <end>',
#  '<start> सफेद कार बाड़ के पास खड़ी है <end>',
#  '<start> भवन की खिड़की का किनारा <end>',
#  '<start> यह एक महिला है <end>',
#  '<start> क्षेत्र हरा है <end>',
#  '<start> सड़क पर पीली लाइनें <end>',
#  '<start> सड़क पर काली कार पार्क <end>',
#  '<start> सड़क <end>',
#  '<start> यह एक कार है <end>',
#  '<start> पानी का रंग हरा है <end>',
#  '<start> कार पर लगी लाइसेंस प्लेट <end>',
#  '<start> एक सड़क पर काली कार <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> खिड़की पर फलक <end>',
#  '<start> लंबा आउटडोर लैंप पोस्ट <end>',
#  '<start> गाड़ी का टायर <end>',
#  '<start> भूरे रंग का डिलीवरी ट्रक <end>',
#  '<start> कार का टायर काला रबर और चांदी की धातु से बना है <end>',
#  '<start> खड़ी सफेद कार <end>',
#  '<start> एक उज्ज्वल जला हुआ रियर ब्रेक लाइट <end>',
#  '<start> एक बड़े कार्यालय भवन में खिड़की <end>',
#  '<start> भवन के सामने की खिड़की <end>',
#  '<start> हल्के भूरे रंग की छत वाला नीला घर <end>',
#  '<start> फुटपाथ पर चलने वाली वृद्ध महिला <end>',
#  '<start> एक बड़े काले ट्रैशकैन <end>',
#  '<start> स्ट्रीट संकेत कहते हैं एम्स <end>',
#  '<start> फुटपाथ पर खड़ी महिला <end>',
#  '<start> इमारत पर वर्ग खिड़की <end>',
#  '<start> भूरी लकड़ी की बुकशेल्फ़ पर किताब <end>',
#  '<start> डेस्क के शीर्ष पर पेपर कप <end>',
#  '<start> दीवार पर घड़ी <end>',
#  '<start> मेज पर फूलदान <end>',
#  '<start> एक चमकदार नीली कॉफी मग <end>',
#  '<start> रसोई के सिंक पर चांदी का नल <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> जींस और काले रंग की शर्ट में महिला <end>',
#  '<start> एक नीले और सफेद पार्किंग साइन <end>',
#  '<start> शौचालय पर संयंत्र <end>',
#  '<start> काले लेखन के साथ सफेद किताब <end>',
#  '<start> एक टैन कार खड़ी थी <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> स्त्री के काले बाल है <end>',
#  '<start> फुटपाथ पर चलने वाला आदमी <end>',
#  '<start> पोस्ट पर बैनर <end>',
#  '<start> दुकान की खिड़की पर प्रतिबिंब <end>',
#  '<start> बेंच लंबा है <end>',
#  '<start> पोर्च पर लकड़ी प्लांक <end>',
#  '<start> एक पेड़ से गिरने वाला कुरकुरा भूरा पत्ता <end>',
#  '<start> पत्ती से भरे खेत में एक पत्थर <end>',
#  '<start> चांदी एसयूवी सड़क पर खड़ी है <end>',
#  '<start> मेलबॉक्स पर पेंट <end>',
#  '<start> सफेद इमारत के सामने की खिड़की <end>',
#  '<start> दीवार पर घड़ी <end>',
#  '<start> चाँदी की कार <end>',
#  '<start> एक महिला खड़ी है <end>',
#  '<start> ईंट निर्माण के सामने की खिड़की <end>',
#  '<start> सड़क चिह्न नहीं दाखिल करें <end>',
#  '<start> लाल बालों वाली औरत सड़्क पर चलते हुए <end>',
#  '<start> भवन के सामने की खिड़की <end>',
#  '<start> मैरून कार कर्ब पर खड़ी <end>',
#  '<start> सड़क पर खड़ा नीला वाहन <end>',
#  '<start> जीप एसयूवी पर अंकुश लगा दिया <end>',
#  '<start> एक धातु के खंभे पर एक स्ट्रीट लाइट <end>',
#  '<start> शेल्फ का रंग भूरा है <end>',
#  '<start> एक कंप्यूटर एक कीबोर्ड पर होता है <end>',
#  '<start> नीला और सफेद कॉफी कि जग <end>',
#  '<start> दीवार पर एक खाली पोस्टर बोर्ड <end>',
#  '<start> स्नैक बिस्कुट का पीला बक्सा <end>',
#  '<start> ब्लैक मॉनिटर ऑन डेस्क <end>',
#  '<start> ब्लैक एंड व्हाइट डेस्क लैंप <end>',
#  '<start> डेस्क के नीचे ग्रे प्लास्टिक कचरा हो सकता है <end>',
#  '<start> माइक्रोवेव ओवन <end>',
#  '<start> कंप्यूटर मॉनिटर के सामने कार्यालय की कुर्सी <end>',
#  '<start> नीली कुर्सी पर नीला कार्डिगन लिपटा हुआ <end>',
#  '<start> एक शेल्फ पर बाँधने की एक पंक्ति <end>',
#  '<start> कागज का एक सफेद टुकड़ा <end>',
#  '<start> डेस्क के ऊपर सफेद कीबोर्ड <end>',
#  '<start> एक पुरानी काली टायर <end>',
#  '<start> सड़क के नीचे जाती लाल रंग की एसयूवी <end>',
#  '<start> दीवार पर लटका एक नक्शा <end>',
#  '<start> फ्लोरोसेंट छत रोशनी <end>',
#  '<start> एक लकड़ी की मेज <end>',
#  '<start> नीली दीवारों <end>',
#  '<start> सफेद खिड़की के साथ बड़ी खिड़की <end>',
#  '<start> लाल स्ट्रीट लाल चिह्न सफेद पट्टी के साथ <end>',
#  '<start> एक सफेद पट्टी के साथ एक लाल संकेत <end>',
#  '<start> सड़क पर कार चलाना <end>',
#  '<start> सफेद सजावट के साथ नीला बैनर <end>',
#  '<start> काला रेलिंगोन सिडीचलन <end>',
#  '<start> सर्फ़बोर्ड पर व्यक्ति <end>',
#  '<start> पानी में नाव <end>',
#  '<start> खड़ी कारों की एक पंक्ति <end>',
#  '<start> एक काला कंप्यूटर मॉनीटर <end>',
#  '<start> पानी के ऊपर बहु रंगीन इंद्रधनुष <end>',
#  '<start> हेज करने के लिए सही है <end>',
#  '<start> एक मेज पर एक कॉफी कप <end>',
#  '<start> स्ट्रीट लाइट बंद है <end>',
#  '<start> एक काले सूट और नीली शर्ट में खड़ा आदमी <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> पीले और काले पैदल यात्री क्रॉसिंग सिग्नल <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> काला टैंक टॉप में व्यक्ति <end>',
#  '<start> एक काला शर्ट पहनने हुए लड़का <end>',
#  '<start> एक छोटी ग्रे मोटरसाइकिल <end>',
#  '<start> बड़ी इमारत पर खिड़की <end>',
#  '<start> यह एक मोटर वाहन है <end>',
#  '<start> सीढ़ियों के नीचे बात कर रहे हैं दो लोग | <end>',
#  '<start> वैन नीले सफेद और हरे रंग की है <end>',
#  '<start> किसी व्यापार का दरवाज़ा <end>',
#  '<start> वाहन का पहिया <end>',
#  '<start> चार द्वारों के साथ एक कार <end>',
#  '<start> आदमी सड़क पर चल रहा है <end>',
#  '<start> सफेद कार खड़ी है <end>',
#  '<start> एक पोल की लाल टिप <end>',
#  '<start> कोका कोला चिह्न <end>',
#  '<start> इमारत पर खिड़्की <end>',
#  '<start> एक लाल और सफेद छाता <end>',
#  '<start> एक आदमी का सिर <end>',
#  '<start> यह तस्वीर रंग में सोना है | <end>',
#  '<start> प्रवेश द्वार की ओर जाने वाली सीढ़ियाँ <end>',
#  '<start> इमारत पर विंडो <end>',
#  '<start> यह एक टैक्सी कैब है <end>',
#  '<start> बिना पत्तों वाला बड़ा पेड़ <end>',
#  '<start> कार्य ट्रक सफेद है <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> एक सड़क के किनारे खड़ी एक सफेद कार <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> काली कार सड़क पर खड़ी <end>',
#  '<start> लाल ईंट विंडो पर विंडो <end>',
#  '<start> कार लाल है और गली में खड़ी है <end>',
#  '<start> इमारत पर खिड़कियाँ <end>',
#  '<start> भवन के किनारे की खिड़की <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> भूरे रंग का पेड़ का तना <end>',
#  '<start> घर का रंग पीला होता है <end>',
#  '<start> खड़ी कारों की एक पंक्ति <end>',
#  '<start> एक इमारत की तरफ खिड़की <end>',
#  '<start> नारंगी नारंगी जीवन धारण किए हुए आदमी खड़ा है <end>',
#  '<start> सीढ़ियों पर एक घड़ा <end>',
#  '<start> घास पर लंबा हरा पेड़ <end>',
#  '<start> पानी का एक विशाल स्थान <end>',
#  '<start> दीवार पर काई <end>',
#  '<start> शहर के चारों ओर घने पेड़ <end>',
#  '<start> पृष्ठभूमि में पर्वत <end>',
#  '<start> पानी में बड़ी सफेद नाव यात्रा <end>',
#  '<start> एक पहिया <end>',
#  '<start> की दूरी पर एक लाल अग्नि हाइड्रेंट दिखाई देता है <end>',
#  '<start> लड़की भूरे बाल | <end>',
#  '<start> ईंट इमारत के सामने खिड़की <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> भूरे रंग का पेड़ का तना <end>',
#  '<start> झील के निकट पक्षी <end>',
#  '<start> एक धातु की छत के साथ पुराना शेड <end>',
#  '<start> लंबा और भूरा पर्वत <end>',
#  '<start> ग्रे और भूरी चट्टानों का ढेर <end>',
#  '<start> लोग चल रहे हैं <end>',
#  '<start> जमीन पर डाक <end>',
#  '<start> एक गोल शीर्ष के साथ एक खिड़की <end>',
#  '<start> साथ में खड़ा एक जोड़ा <end>',
#  '<start> यह एक बिस्तर है <end>',
#  '<start> कोठरी पर सफेद दरवाजा <end>',
#  '<start> एक काला साबुन पकवान <end>',
#  '<start> एक लंबी रोशनी चालू है <end>',
#  '<start> दीपक पर बड़ा छाया <end>',
#  '<start> एक नाइटस्टैंड पर रेडियो <end>',
#  '<start> डेस्क पर टेलीविजन <end>',
#  '<start> हेडबोर्ड पर वर्ग <end>',
#  '<start> एक सफेद कॉफी मग <end>',
#  '<start> सफेद कागजात के पतले ढेर <end>',
#  '<start> दीवार पर दीपक रंग <end>',
#  '<start> ड्रेसर भूरे रंग का है <end>',
#  '<start> बेज रंग का कॉर्डेड फोन <end>',
#  '<start> हेडबोर्ड के ऊपर चित्र <end>',
#  '<start> एक नारंगी कुर्सी <end>',
#  '<start> चौखट सफेद रंग की होती है <end>',
#  '<start> स्पॉटलेस डाइनिंग रूम <end>',
#  '<start> एक सफेद पेंट फ्रेम के साथ खिड़की <end>',
#  '<start> गंदगी के बगल में उगी घास का एक हिस्सा <end>',
#  '<start> धातु दरवाजा घुंडी <end>',
#  '<start> यह एक जीप है <end>',
#  '<start> चाय की केतली चांदी है <end>',
#  '<start> दरवाज़ा अंकुर और रिक्टेंगुलर है <end>',
#  '<start> कमरे के कोने में सोफा <end>',
#  '<start> यह एक धूसर टेलीविजन है <end>',
#  '<start> तस्वीर दीवार पर है <end>',
#  '<start> नल चांदी है <end>',
#  '<start> चांदी की बनी कैनिस्टर <end>',
#  '<start> फर्श पर खाली टोकरी <end>',
#  '<start> नाइटस्टैंड पर सफेद और काले दीपक <end>',
#  '<start> एक मोटा धूसर तकिया <end>',
#  '<start> शौचालय सफेद है <end>',
#  '<start> रसोई में कैबिनेट <end>',
#  '<start> एक सीढ़ी में ग्रे कालीन वाली सीढ़ी <end>',
#  '<start> कमरे में भूरे रंग का दरवाजा <end>',
#  '<start> फर्श पर धूप <end>',
#  '<start> यह एक सिंक है <end>',
#  '<start> ग्रे और सफेद साइडिंग <end>',
#  '<start> दिलासा देनेवाला और तकिया मामलों का मिलान होता है <end>',
#  '<start> सफेद लकड़ी की बालकनी <end>',
#  '<start> ब्लैक एंड सिल्वर रेंज <end>',
#  '<start> दिन के आकाश का प्रकाश <end>',
#  '<start> कांच की खिड़की पारदर्शी है <end>',
#  '<start> प्रकाश लटका हुआ है <end>',
#  '<start> एक कमरे के कोने में एक पौधा <end>',
#  '<start> सफेद ओवन पर कांच की खिड़की <end>',
#  '<start> हरा और पीला घर <end>',
#  '<start> एक फुटपाथ पर पेड़ <end>',
#  '<start> सजावटी हरे कांच के फूलदान <end>',
#  '<start> एक पेड़ के सामने एक कार <end>',
#  '<start> एक बड़ा तकिया सफेद आवरण मे <end>',
#  '<start> भूरे रंग की पेंटिंग के साथ सामने का लकड़ी का दरवाजा <end>',
#  '<start> आवासीय भवन के पिछवाड़े <end>',
#  '<start> बेडरूम की दीवार पर प्रकाश स्विच <end>',
#  '<start> दीवार पर टंगी एक फंसी हुई पेंटिंग <end>',
#  '<start> हल्के रंग का दरवाज़ा <end>',
#  '<start> सीट ऊपर है <end>',
#  '<start> पुराना और छोटा टेलीविजन सेट <end>',
#  '<start> बड़े नीले फूलों के साथ रंगीन आड़ू पीच <end>',
#  '<start> मेज पर ब्रोशर <end>',
#  '<start> पंखा काला है <end>',
#  '<start> आवासीय कमरे का इंटीरियर <end>',
#  '<start> खिड़की में वर्ग फलक <end>',
#  '<start> लाइट चालू है <end>',
#  '<start> बार कुर्सियां \u200b\u200bभूरे रंग के हैं <end>',
#  '<start> तस्वीर के निकट सफेद दीवार <end>',
#  '<start> प्लेट पर खाना <end>',
#  '<start> भोजन क्षेत्र का इंटीरियर <end>',
#  '<start> कुर्सी लकड़ी से बना है और चार पैर हैं <end>',
#  '<start> एक चिड़िया के मुँह में एक मछली <end>',
#  '<start> चिड़िया की बेक <end>',
#  '<start> लटका पॉट में गुलाबी फूल <end>',
#  '<start> एक छोटी ग्रे कार <end>',
#  '<start> सफेद कार पार्क की गई <end>',
#  '<start> वाहन सफेद है <end>',
#  '<start> क्षेत्र को कवर शामियाना <end>',
#  '<start> वाहन पर लाल और स्पष्ट पूंछ <end>',
#  '<start> एक सड़क पर एक सफेद तीर <end>',
#  '<start> एक सफेद वाहन <end>',
#  '<start> कार का रंग सिल्वर <end>',
#  '<start> काले और सोने के हाइड्रेंट <end>',
#  '<start> काला और सफेद चिह्न <end>',
#  '<start> पोल पर हरी चौकोर गली का चिन्ह <end>',
#  '<start> रेड वैन दाहिनी ओर खड़ी थी <end>',
#  '<start> सड़क पर एक काली कार <end>',
#  '<start> सफेद और लाल वान छत के साथ <end>',
#  '<start> हरे और सफेद संकेत <end>',
#  '<start> आदमी नीचे सड़क पर चल रहा है <end>',
#  '<start> एक गुलाबी शीर्ष के साथ महिला <end>',
#  '<start> सड़क पर पीली टैक्सी टैक्सी <end>',
#  '<start> ग्रे इमारत में एक विंडो है <end>',
#  '<start> व्यक्ति बाहर चल रहा है <end>',
#  '<start> घुमावदार पोल पर ट्रैफिक लाइट <end>',
#  '<start> एक शहर में इमारत <end>',
#  '<start> वह आदमी लाल जैकेट पहने हुए हैं <end>',
#  '<start> ग्रे पैंट में व्यक्ति खड़ा है <end>',
#  '<start> नारंगी और पीले फूलों का एक पैच <end>',
#  '<start> एक लंबी सफेद लीमोज्या <end>',
#  '<start> एक इमारत पर बड़ी खिड़की <end>',
#  '<start> गली में खड़ा अंधेरा <end>',
#  '<start> वैन पर श्वेत लिखावट <end>',
#  '<start> एक पोल पर तीन लाइट <end>',
#  '<start> सड़क पर चांदी की कार <end>',
#  '<start> एक पुराना पत्थर गिरजाघर <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> लाल और सफेद जैकेट आदमी पहने हुए है <end>',
#  '<start> एक महिला के सिर पर काला छाता <end>',
#  '<start> एक नीला और सोने का झंडा <end>',
#  '<start> टैक्सी टैक्सी एक बड़े शहर की सड़कों पर यात्रा करती है <end>',
#  '<start> कंधे पर एक लाल रंग का पर्स <end>',
#  '<start> एक पीली टैक्सी टैक्सी <end>',
#  '<start> सड़क पर कई टैक्सी टैक्सी <end>',
#  '<start> लाल बस एक सड़क पर यात्रा कर रही है <end>',
#  '<start> एक बड़े शहर में एक पार्क के चारों ओर बाड़ <end>',
#  '<start> घास में कंक्रीट ब्लॉक <end>',
#  '<start> दिन दिन का आकाश का प्रकाश <end>',
#  '<start> सफेद अक्षरों के साथ काला संकेत <end>',
#  '<start> गली में खड़ी की गई हरे रंग की कार <end>',
#  '<start> सड़क पर खड़ी सिल्वर कार <end>',
#  '<start> काले और सफेद जैकेट पहने हुए आदमी <end>',
#  '<start> एक नीली वैन <end>',
#  '<start> फुटपाथ पर चलते दो लोग <end>',
#  '<start> साइकिल को खंभे से जकड़ा जाता है <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> सड़क पर चित्रित सफेद लाइनें <end>',
#  '<start> एक लाल पार्किंग संकेत <end>',
#  '<start> पानी का पोखर <end>',
#  '<start> लोग सड़क के पार चल रहा <end>',
#  '<start> एक लाल यातायात प्रकाश <end>',
#  '<start> एक पीले टैक्सी कैब <end>',
#  '<start> सड़क पर एक कार <end>',
#  '<start> काले और हरे रंग का चिन्ह <end>',
#  '<start> फुटपाथ पर दो पीले पोस्ट <end>',
#  '<start> धातु डाक बॉक्स <end>',
#  '<start> काला कोट पहने आदमी <end>',
#  '<start> अमेरिकी ध्वज उड़ान भूमि के ऊपर <end>',
#  '<start> सड़क पर दौड़ती पीली टैक्सी <end>',
#  '<start> धूसर और सफेद आकाश <end>',
#  '<start> भवन में एक खिड़की है <end>',
#  '<start> धातु की बालकनी <end>',
#  '<start> बालकनी की रेलिंग <end>',
#  '<start> सबसे आगे मशीन आर्म <end>',
#  '<start> सड़क पर चलने वाला व्यक्ति <end>',
#  '<start> एक अमेरिकी डाक वान <end>',
#  '<start> आदमी एक कला के टुकड़े के सामने खड़ा है <end>',
#  '<start> पेंटिंग पर फूल <end>',
#  '<start> दीवार पर चित्रकारी <end>',
#  '<start> काली कुर्सी लकड़ी की है <end>',
#  '<start> नारंगी वस्तु <end>',
#  '<start> एक बड़े हवाई जहाज की पूंछ स्टेबलाइजर <end>',
#  '<start> काले अक्षर के साथ हस्ताक्षर करें <end>',
#  '<start> सड़क पर पीले आग हाइड्रेंट <end>',
#  '<start> एक नदी के सामने एक महिला <end>',
#  '<start> चौराहे से होकर निकलती सिल्वर वैन <end>',
#  '<start> एक लाल और सफेद संकेत <end>',
#  '<start> ग्रे छत के साथ सफेद घर <end>',
#  '<start> दूरी में एक बड़ी इमारत <end>',
#  '<start> एक सफेद बादल <end>',
#  '<start> इमारत पर ईंट चिमनी <end>',
#  '<start> क्षितिज में नारंगी आकाश <end>',
#  '<start> समुद्र तट के बगल में शोरलाइन <end>',
#  '<start> यह एक शहर है <end>',
#  '<start> नीला और सफेद आसमान <end>',
#  '<start> एक ट्रेन पर एक सफेद सर्कल <end>',
#  '<start> बादल सफेद होते हैं <end>',
#  '<start> एक ग्रे विस्तारित टैक्सी ट्रक <end>',
#  '<start> पर्वत की चोटी पर बढ़ रही झाड़ियों <end>',
#  '<start> काला चमकदार मीनिवान <end>',
#  '<start> दूरी में पहाड़ <end>',
#  '<start> एक खेत में एक पेड़ <end>',
#  '<start> भूरी लकड़ी की बेंच <end>',
#  '<start> सड़क से हरा पेड़ <end>',
#  '<start> हरी पत्तियों वाला विशाल वृक्ष <end>',
#  '<start> एक इमारत द्वारा सफेद ट्रक <end>',
#  '<start> एक सफेद वाणिज्यिक ट्रक <end>',
#  '<start> पानी में पीले रोशनी <end>',
#  '<start> खाने की मेज सेट <end>',
#  '<start> एक धनुषाकार शीर्ष के साथ अलंकृत खिड़की <end>',
#  '<start> एक पहाड़ी पर नारंगी इमारत <end>',
#  '<start> कुत्ता फुटपाथ पर चल रहा है <end>',
#  '<start> सीढ़ियों के नीचे चलने वाला आदमी <end>',
#  '<start> इमारत पर खिड़कियाँ <end>',
#  '<start> एक खेत में एक पेड़ <end>',
#  '<start> एक लंबा काला प्रकाश पोल <end>',
#  '<start> एक खेत में एक पेड़ <end>',
#  '<start> एक इमारत पर नीले शब्द <end>',
#  '<start> गुब्बारा लाल है <end>',
#  '<start> घर के बाहर एक संकेत <end>',
#  '<start> एक शाखा पर माता अंहिंगा चिड़िया <end>',
#  '<start> पक्षी की चोंच <end>',
#  '<start> भूरे और सफेद पफर मछली तैराकी <end>',
#  '<start> शाखा पर पक्षी <end>',
#  '<start> एक डाल पर पझी <end>',
#  '<start> पेड़ पर छोड़ देता है <end>',
#  '<start> ग्रे चट्टान से बना क्लिफ फेस <end>',
#  '<start> ज़ेबरा पर पट्टी <end>',
#  '<start> पशु के सिर पर बाँया सींग <end>',
#  '<start> सूरज पीला है <end>',
#  '<start> खेत पर झेब्रा <end>',
#  '<start> ब्लैक एंड व्हाइट ज़ेबरा <end>',
#  '<start> एक संकीर्ण शरीर वाला पक्षी <end>',
#  '<start> एक बच्चा हाथी <end>',
#  '<start> एक रिज पर उपयोगी मुर्गियाँ <end>',
#  '<start> एक रस्सी संलग्न <end>',
#  '<start> भवन की छत <end>',
#  '<start> सड़क पर काली कार <end>',
#  '<start> एक ध्रुव पर चिह्न <end>',
#  '<start> सड़क के दाईं ओर धातु की रेलिंग <end>',
#  '<start> पीला कंटेनर करीब है <end>',
#  '<start> एक साफ और नीला आकाश <end>',
#  '<start> सड़क पर सफेद ट्रक <end>',
#  '<start> सड़क के बगल में पेड़ <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> आसमान नीला है <end>',
#  '<start> एक लंबी काली पोस्ट पर स्ट्रीट लाइट <end>',
#  '<start> नाव में सफेद पाल हैं <end>',
#  '<start> लाल शर्ट पहने आदमी <end>',
#  '<start> दिन के दौरान एक दृश्य <end>',
#  '<start> उज्ज्वल सफेद पालकी अंकुश के पास खड़ी <end>',
#  '<start> लंबा और गोल झाड़ियों <end>',
#  '<start> सड़क से हरा पेड़ <end>',
#  '<start> दिन के समय एक दृश्य <end>',
#  '<start> घर के बगल में सफेद पिकनिक तालिका <end>',
#  '<start> वॉकवे के बाईं ओर घास <end>',
#  '<start> घर की नाव पर खिड़की <end>',
#  '<start> एक शहर की सड़क पर सफेद इमारत <end>',
#  '<start> यह एक आदमी है <end>',
#  '<start> बाहर एक दृश्य <end>',
#  '<start> कार सड़क पर खड़ी है <end>',
#  '<start> काली पैंट की एक जोड़ी <end>',
#  '<start> एक सफेद वाणिज्यिक वैन <end>',
#  '<start> सड़क पर रोशनी कम है <end>',
#  '<start> सड़क के द्वारा चमकीला प्रकाश <end>',
#  '<start> सड़क पर चलने वाला व्यक्ति <end>',
#  '<start> रात में एक लंबा लैंप पोस्ट जलाया गया <end>',
#  '<start> यह एक कोर्ट यार्ड है <end>',
#  '<start> फुटपाथ पर चलने वाला व्यक्ति <end>',
#  '<start> सफेद हैचबैक <end>',
#  '<start> एक सड़क पर एक कार <end>',
#  '<start> फुटपाथ पर कई लोग <end>',
#  '<start> एक लाल चार दरवाजे वाला वाहन <end>',
#  '<start> रास्ता काला और सफेद रंग में है <end>',
#  '<start> तोरण अलंकृत है <end>',
#  '<start> बड़ी भड़कीली जीन्स पहने महिला <end>',
#  '<start> एक लंबा काला कचरे का डब्बा <end>',
#  '<start> भवन पर कांच की खिड़की <end>',
#  '<start> एक बास्केट के साथ एक बाइक <end>',
#  '<start> छत पर चिमनी <end>',
#  '<start> पानी में प्रतिबिंब <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> काले खत्म के साथ दीपक <end>',
#  '<start> हरे रंग की पोशाक में महिला <end>',
#  '<start> एक पोल के खिलाफ लाल साइकिल झुकाव <end>',
#  '<start> दूरी में भवन <end>',
#  '<start> एक स्त्री नीले जीन्स पहने हुए <end>',
#  '<start> एक सफेद फ्रेम के साथ एक खिड़की <end>',
#  '<start> एक समानांतर खड़ी कार <end>',
#  '<start> लंबा पतला पाइन पेड़ <end>',
#  '<start> एक रबर कार टायर <end>',
#  '<start> कई खिड़कियों के ऊर्ध्वाधर स्तंभ <end>',
#  '<start> एक पीले रंग की लाइसेंस प्लेट <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> एक चाँदी का सूव <end>',
#  '<start> आकाश में कई बादल <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> कचरा पत्थर और धातु से बना हो सकता है <end>',
#  '<start> कारों से भरपूर <end>',
#  '<start> इमारत पर विंडो <end>',
#  '<start> एक इमारत के ऊपर दो ताड़ के पेड़ <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> एक बंद सफेद मिनीवैन <end>',
#  '<start> यह एक इमारत है <end>',
#  '<start> पीठ के ऊपर मूर्ति <end>',
#  '<start> यह एक शहरी क्षेत्र है <end>',
#  '<start> गहरे भूरे रंग की लकड़ी से बनी बेंच <end>',
#  '<start> एक आदमी दुकान से पीछे चल रहा है <end>',
#  '<start> इमारत पर कांच की खिड़्की <end>',
#  '<start> एक इमारत पर लाल निशान <end>',
#  '<start> यह वॉच टॉवर है <end>',
#  '<start> सड़क पर नीली कार ड्राइविंग <end>',
#  '<start> तीर के साथ नीला चिह्न <end>',
#  '<start> एक लाल इमारत पर खिड़कियों की पंक्ति <end>',
#  '<start> सफेद स्तंभों वाला लाल भवन <end>',
#  '<start> एक छोटी सफेद कार <end>',
#  '<start> एक सड़क पर एक कार <end>',
#  '<start> एक महिला एक बच्चे को घुमक्कड़ धक्का <end>',
#  '<start> गंदगी पर कार <end>',
#  '<start> इमारत के शीर्ष पर धातु का निर्माण <end>',
#  '<start> छत पर टाइल लगाई गई है <end>',
#  '<start> दूरी में पहाड़ी पहाड़ियों <end>',
#  '<start> कार पार्क किया जाता है <end>',
#  '<start> तीन कहानी पत्थर की इमारत <end>',
#  '<start> एक पंक्ति में दो लाल कारें <end>',
#  '<start> गली में सफेद कार पार्क <end>',
#  '<start> नीला और सफेद आसमान <end>',
#  '<start> चौराहे पर एक काली कार <end>',
#  '<start> इमारत पर खिड़्की <end>',
#  '<start> एक लाल जैकेट पहनने वाला आदमी <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> इमारत पर कांच की खिड़्की <end>',
#  '<start> एक सफेद पार्क कार <end>',
#  '<start> पोल के खिलाफ साइकिल झुकाव <end>',
#  '<start> घर हरा है <end>',
#  '<start> व्यक्ति चल रहा है <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> इमारत पर खिड़्की <end>',
#  '<start> भवन पर कांच की खिड़की <end>',
#  '<start> लंबा वक्र वाल्केम <end>',
#  '<start> एक महिला का नीला बैग <end>',
#  '<start> यह एक बड़ी इमारत है <end>',
#  '<start> बड़े सफेद बादलों के साथ एक हल्का नीला आकाश <end>',
#  '<start> हरे रंग की सड़क का संकेत जो कांग्रेस को सेंट कहता है <end>',
#  '<start> लाल और ग्रे एसयूवी <end>',
#  '<start> इमारत का सामना करना पड़ सड़क पर खिड़की <end>',
#  '<start> बर्फ में कुछ गहरे टायर ट्रैक <end>',
#  '<start> बर्फ से ढकी एक सड़क <end>',
#  '<start> कारें बर्फ में ढकी हुई हैं <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> अंधेरे लाल इमारत पर विचलित <end>',
#  '<start> जमीन पर सफेद बर्फ <end>',
#  '<start> सफेद इमारत की ऊपरी मंजिल पर खिड़की <end>',
#  '<start> एक पीला और नीला चिह्न <end>',
#  '<start> फुटपाथ पर चलने वाला व्यक्ति <end>',
#  '<start> विंडो में लाल ड्रेस <end>',
#  '<start> यह एक शहर की सड़क है <end>',
#  '<start> लाल बल्री चिह्न <end>',
#  '<start> कपड़े पहने महिला <end>',
#  '<start> इमारत पर हस्ताक्षर <end>',
#  '<start> भवन पर कांच की खिड़की <end>',
#  '<start> एक अलंकृत काली स्ट्रीट लाइट <end>',
#  '<start> भवन पर कांच की खिड़की <end>',
#  '<start> बाड़ पर नारंगी पट्टी <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> फुटपाथ पर पोल <end>',
#  '<start> ये इमारतों का एक समूह हैं <end>',
#  '<start> गाड़ी <end>',
#  '<start> व्यक्ति खड़ा है <end>',
#  '<start> व्यक्ति चल रहा है <end>',
#  '<start> कोने के निर्माण पर खिड़की <end>',
#  '<start> इमारत पर कांच की खिड़्की <end>',
#  '<start> ट्रैक्टर फुटपाथ पर खड़ा था <end>',
#  '<start> बेंच का पैर <end>',
#  '<start> एक व्यक्ति जो फ़ुटपाथ पर चलता है <end>',
#  '<start> एक सड़क पर एक कार <end>',
#  '<start> पोल पर प्रकाश <end>',
#  '<start> कार पर गोल काला टायर <end>',
#  '<start> सड़क में एक सफेद रेखा <end>',
#  '<start> कार पर अंकुश लगाया <end>',
#  '<start> आकाश ग्रे और सफेद है <end>',
#  '<start> एक सड़क के पास लैंप पोल <end>',
#  '<start> यह एक कार है <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> कार सोना है <end>',
#  '<start> सड़क पर ग्रे कार चला रहा है <end>',
#  '<start> एक लाल और सफेद संकेत <end>',
#  '<start> एक पहाड़ी में सेट दो अर्ध गोलाकार ट्यूनेल <end>',
#  '<start> सड़क में सिल्वर कार पार्क किया <end>',
#  '<start> यह एक आदमी है <end>',
#  '<start> वाहन <end>',
#  '<start> फुटपाथ के सामने खड़ी सफेद वैन <end>',
#  '<start> कार सफेद है <end>',
#  '<start> सड़क पर वाहन <end>',
#  '<start> सड़क के अतिरिक्त धातु रेल <end>',
#  '<start> इमारत पर विंडो <end>',
#  '<start> सड़क में फूलों का बिस्तर <end>',
#  '<start> गली में खड़ी लाल कार <end>',
#  '<start> पत्र के साथ गोल गेंद <end>',
#  '<start> कार काली है <end>',
#  '<start> एक गोल नीला और सफेद निशान <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> सड़क के किनारे पर छोटी पत्थर दीवार <end>',
#  '<start> एक राजमार्ग पर एक लाल वाहन <end>',
#  '<start> कार पर खिड़की <end>',
#  '<start> एक सड़क पर एक कार <end>',
#  '<start> काले एंटेंना वह हूड पर था <end>',
#  '<start> इमारत पर बोर्ड <end>',
#  '<start> कार चांदी है <end>',
#  '<start> पेड़ पर छोड़ देता है <end>',
#  '<start> फुटपाथ पर लकड़ी के बेंच <end>',
#  '<start> पेड़ का तना <end>',
#  '<start> भवन पर खिड़की <end>',
#  '<start> पेड़ नंगे और पार्क में है <end>',
#  '<start> पानी में पत्ती <end>',
#  '<start> काले शॉर्ट्स में व्यक्ति <end>',
#  '<start> सड़क पर कार <end>',
#  '<start> एक शहर में एक वृक्ष <end>',
#  '<start> एक सड़क पर बैठने की व्यवस्था <end>',
#  '<start> दरवाजे के ऊपर की संख्या <end>',
#  '<start> एक इमारत पर एक खिड़की <end>',
#  '<start> प्लेट का रंग काला है <end>',
#  '<start> ट्रक पर नारंगी रंग <end>',
#  '<start> सड़क पर सफेद लाइनें <end>',
#  '<start> कार चाँदी है <end>',
#  '<start> सड़क के किनारे खड़ी चांदी की कार <end>',
#  '<start> कार के सामने गगनचुंबी इमारत <end>',
#  '<start> पार्क की गई सिल्वर <end>',
#  '<start> लैंप पोस्ट के शीर्ष पर गोल सफेद दीपक <end>',
#  '<start> इमारत पर हरे शटर | <end>',
#  '<start> दरवाजा भूरा है <end>',
#  '<start> तीन फाउंटेन हेड्स वाला उथला पूल <end>',
#  '<start> सफेद और लाल शर्ट में महिला <end>',
#  '<start> फुटपाथ की सीमा पर मोटी हेज <end>',
#  '<start> आकाश चमक रहा है और नीला है <end>',
#  '<start> पेड़ पर छोड़ देता है <end>',
#  '<start> दो सड़क रोशनी <end>',
#  '<start> लाल जैकेट में व्यक्ति <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> बाहर खाने वाले लोग <end>',
#  '<start> दो यातायात रोशनी लाल जलाया <end>',
#  '<start> एक काले रंग की खड़ी कार <end>',
#  '<start> एक खड़ी कार <end>',
#  '<start> गहरा हरा सुव <end>',
#  '<start> एक इमारत पर पक्षियों का भित्ति चित्र <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> एक इमारत पर खिड़की <end>',
#  '<start> दीवार के सामने खड़ा आदमी <end>',
#  '<start> भूरे बालों वाला आदमी <end>',
#  '<start> एक ग्रे स्टेपलर <end>',
#  '<start> महिला की एक आंख है <end>',
#  '<start> बेंच पर बैठे और प्रतीक्षा करता आदमी <end>',
#  '<start> उसने नीली जींस पहनी हुई है <end>',
#  '<start> ट्रक लाल है <end>',
#  '<start> शर्ट पहने व्यक्ति <end>',
#  '<start> एक सफेद शर्ट में आदमी <end>',
#  '<start> सफेद जूते पहने हुए आदमी <end>',
#  '<start> मैदान मे लम्बा कुत्ते <end>',
#  '<start> आदमी के सफेद दांत हैं <end>',
#  '<start> कैमरे को देख रहे व्यक्ति <end>',
#  '<start> पहाड़ पर खड़ा व्यक्ति <end>',
#  '<start> ब्लॉक पैटर्न के साथ साइडवॉक <end>',
#  '<start> भवन लंबा है <end>',
#  '<start> छोटे बाल और एक बकरी के साथ एक आदमी <end>',
#  '<start> एक पेड़ का तना <end>',
#  '<start> कुत्ता घास में बैठा है <end>',
#  '<start> पीला स्वेटर पहने व्यक्ति <end>',
#  '<start> दिन के समय एक दृश्य <end>',
#  '<start> हाथ मेज पर है | <end>',
#  '<start> मंजिल पर रखे स्टेपलर <end>',
#  '<start> पानी में चट्टान <end>',
#  '<start> होटल प्रवेश के मार्च में कार <end>',
#  '<start> पानी के किनारे नाव <end>',
#  '<start> एक युवा श्वेत व्यक्ति के सिर में गोली लगी <end>',
#  '<start> दिन के समय एक दृश्य <end>',
#  '<start> विमान रनवे पर बैठा <end>',
#  '<start> कोने की मेज पर एक ग्रे स्टेपलर <end>',
#  '<start> लाल रंग का व्यक्ति <end>',
#  '<start> युवती के सिर में गोली लगी <end>',
#  '<start> दिन के दौरान लिया गया फोटो <end>',
#  '<start> कार की लाइसेंस प्लेट <end>',
#  '<start> लकड़ी के दरवाजे पर घेरा <end>',
#  '<start> राजमार्ग के निकट भूरी चट्टान <end>',
#  '<start> आदमी रसोई में <end>',
#  '<start> लेन राजमार्ग के नीचे <end>',
#  '<start> मनुष्य के बाल छोटे है <end>',
#  '<start> व्यक्ति हरे रंग की शर्ट पहनता है <end>',
#  '<start> एक हरा पारोट <end>',
#  '<start> हरे पेड़ पर हरे पत्ते <end>',
#  '<start> खिड़की लाल इमारत का सामना करना पड़ <end>',
#  '<start> शीर्ष स्तर पर विंडोज <end>',
#  '<start> किसी व्यक्ति का दाहिना कान <end>',
#  '<start> घाट पर पत्थर ब्लॉक <end>',
#  '<start> एक व्यक्ति के पीछे हरी दीवार <end>',
#  '<start> बैकग्राउंड नीला है <end>',
#  '<start> छोटे भूरे बालों के साथ लड़का <end>',
#  '<start> एक तालिका के आसपास चार काले कुर्सियाँ <end>',
#  '<start> गंदगी सड़क पर बड़ा हरा ट्रक <end>',
#  '<start> पीला स्वेटर पहने हुए आदमी <end>',
#  '<start> फुटपाथ पर चलने वाला व्यक्ति <end>',
#  '<start> लैपटॉप कंप्यूटर डेस्क पर बैठे <end>',
#  '<start> मेज पर कॉफी कप <end>',
#  '<start> सफेद अक्षरों के साथ काला हस्ताक्षर <end>',
#  '<start> पेड़ का ट्रंक | <end>',
#  '<start> पानी में एक चट्टान <end>',
#  '<start> पार्किंग में सफेद वैन <end>',
#  '<start> तोता एक पेड़ शाखा पर बैठे हुए <end>',
#  ...]

# %%
# input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(padded_tensor_hin, padded_tensor_eng, test_size=0.2, random_state = 42)
input_train , input_val, target_train, target_val = train_test_split(clean_english , clean_hindi, test_size = 0.2, random_state = 42)

# %%
hin_lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='', oov_token='<OOV>')
hin_lang_tokenizer.fit_on_texts(clean_hindi)
hin_dict = hin_lang_tokenizer.word_index
tensor_hin = hin_lang_tokenizer.texts_to_sequences(target_train) 
padded_tensor_hin = tf.keras.preprocessing.sequence.pad_sequences(tensor_hin, padding='post')
# print(tensor)
# len(hin_dict)
target_tensor_train =  padded_tensor_hin
print(len(padded_tensor_hin))
print(len(hin_dict))
# Out:
# 23144
# 7013

# %%
eng_lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='', oov_token='<OOV>')
eng_lang_tokenizer.fit_on_texts(clean_english)
eng_dict = eng_lang_tokenizer.word_index
tensor_eng = eng_lang_tokenizer.texts_to_sequences(input_train) 
padded_tensor_eng = tf.keras.preprocessing.sequence.pad_sequences(tensor_eng, padding='post')
input_tensor_train = padded_tensor_eng
# print(tensor)
# len(hin_dict)
print(len(padded_tensor_eng))
print(len(eng_dict))
# Out:
# 23144
# 5553

# %%
# # train test split
# input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(padded_tensor_eng, padded_tensor_hin, test_size=0.2, random_state = 42)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train))
train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
# val_dataset = tf.data.Dataset.from_tensor_slices((input_tensor_val, target_tensor_val))
# val_dataset = val_dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
train_dataset
# Out:
# <BatchDataset shapes: ((64, 26), (64, 34)), types: (tf.int32, tf.int32)>

# %%
len(target_tensor_train[0])
# Out:
# 34

# %%
example_input_batch, example_target_batch = next(iter(train_dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 26]), TensorShape([64, 34]))

# %%
# some important parameters
vocab_inp_size = len(eng_lang_tokenizer.word_index)+1
vocab_tar_size = len(hin_lang_tokenizer.word_index)+1
max_length_input = len(input_tensor_train[0])
max_length_output = len(target_tensor_train[0])

embedding_dim = 100
units = 1024
steps_per_epoch = num_examples//BATCH_SIZE

# %%
print("max_length_english, max_length_hindi, vocab_size_english, vocab_size_hindi")
max_length_input, max_length_output, vocab_inp_size, vocab_tar_size
# Out:
# max_length_english, max_length_hindi, vocab_size_english, vocab_size_hindi
# (26, 34, 5554, 7014)

# %%
### english embedding:
embeddings_dictionary = dict()
glove_file = open('glove.6B.100d.txt' ,  encoding = 'utf-8')

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:] , dtype='float32')
    embeddings_dictionary[word] = vector_dimensions

glove_file.close()

# %%
num_words = min(vocab_inp_size, vocab_inp_size )
embedding_matrix = zeros((vocab_inp_size, 100))
for word, index in eng_lang_tokenizer.word_index.items(): #input_lang_word2idx=1847
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector

# %%
print(vocab_inp_size)
embedding_matrix.shape
# embedding_matrix[90]
# Out:
# 5554
# (5554, 100)

# %%
vocab_inp_size
# Out:
# 5554

# %%
### hindi embeddings

embeddings_dictionary_h = dict()
glove_file = open('hi-d100-glove.txt' ,  encoding = 'UTF-8', errors='ignore')
for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:] , dtype='float32')
    embeddings_dictionary_h[word] = vector_dimensions

glove_file.close()

# %%
print(len(embeddings_dictionary_h))
# Out:
# 1732951

# %%
num_words_h = vocab_tar_size
embedding_matrix_h = zeros((num_words_h, 100))
for word, index in hin_lang_tokenizer.word_index.items(): #input_lang_word2idx=1847
    embedding_vector = embeddings_dictionary_h.get(word)
    if embedding_vector is not None:
        embedding_matrix_h[index] = embedding_vector

# %%
# embedding_matrix_h[46]

print(vocab_tar_size)
print(embedding_matrix_h.shape)
# Out:
# 7014
# (7014, 100)

# %%
class Encoder(tf.keras.Model):
    
    
    def __init__(self,embedding_matrix, vocab_size, embedding_dim, enc_units, batch_sz):
        
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        embedding_matrix = embedding_matrix
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim, weights = [embedding_matrix])

        ##-------- LSTM layer in Encoder ------- ##
        self.lstm_layer = tf.keras.layers.LSTM(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')



    def call(self, x, hidden):
        
        x = self.embedding(x)
        output, h, c = self.lstm_layer(x, initial_state = hidden)
        return output, h, c

    def initialize_hidden_state(self):
        return [tf.zeros((self.batch_sz, self.enc_units)), tf.zeros((self.batch_sz, self.enc_units))]

# %%
## Test Encoder Stack

encoder = Encoder(embedding_matrix, vocab_inp_size, embedding_dim, units, BATCH_SIZE)


# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_h, sample_c = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder h vecotr shape: (batch size, units) {}'.format(sample_h.shape))
print ('Encoder c vector shape: (batch size, units) {}'.format(sample_c.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 26, 1024)
# Encoder h vecotr shape: (batch size, units) (64, 1024)
# Encoder c vector shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, embedding_matrix_h, vocab_size_h, embedding_dim, dec_units, batch_sz, attention_type = 'luong'):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.attention_type = attention_type
        embedding_matrix_h = embedding_matrix_h
        
        #Embedding layer
        
        self.embedding = tf.keras.layers.Embedding(vocab_size_h, embedding_dim, weights = [embedding_matrix_h])
        
        #final dense layer on which softmax will be applied
        self.fc = tf.keras.layers.Dense(vocab_size_h)
        
        # define the fundamental cell for decoder recurrent structure
        
        self.decoder_rnn_cell = tf.keras.layers.LSTMCell(self.dec_units)
        
        # sampler 
        self.sampler = tfa.seq2seq.sampler.TrainingSampler()
        
        # create attention mechanism with memory = None
        self.attention_mechanism = self.build_attention_mechanism(self.dec_units, None, self.batch_sz*[max_length_input], self.attention_type)
        
        # wrap attention mechanism with the fundamental rnn cell
        self.rnn_cell = self.build_rnn_cell(batch_sz)
        
        # define the decoder with respect to fundamental rnn cell
        self.decoder = tfa.seq2seq.BasicDecoder(self.rnn_cell, sampler=self.sampler, output_layer=self.fc)

        
        
    def build_rnn_cell(self, batch_sz):
        rnn_cell = tfa.seq2seq.AttentionWrapper(self.decoder_rnn_cell, 
                                      self.attention_mechanism, attention_layer_size=self.dec_units)
        return rnn_cell
    
    def build_attention_mechanism(self, dec_units, memory,memory_sequence_length, attention_type = 'luong'):
         # ------------- #
        # typ: Which sort of attention (Bahdanau, Luong)
        # dec_units: final dimension of attention outputs 
        # memory: encoder hidden states of shape (batch_size, max_length_input, enc_units)
        # memory_sequence_length: 1d array of shape (batch_size) with every element set to max_length_input (for masking purpose)
        if(attention_type == 'bahdanau'):
            return tfa.seq2seq.BahdanauAttention(units=dec_units, memory=memory, memory_sequence_length=memory_sequence_length)
        
        else:
             return tfa.seq2seq.LuongAttention(units=dec_units, memory=memory, memory_sequence_length=memory_sequence_length)
            
    def build_initial_state(self, batch_sz, encoder_state, Dtype):
        decoder_initial_state = self.rnn_cell.get_initial_state(batch_size=batch_sz, dtype=Dtype)
        decoder_initial_state = decoder_initial_state.clone(cell_state=encoder_state)
        return decoder_initial_state


    def call(self, inputs, initial_state):
        x = self.embedding(inputs)
        outputs, _, _ = self.decoder(x, initial_state=initial_state, sequence_length=self.batch_sz*[max_length_output-1])
        return outputs

# %%
# Test decoder stack

decoder = Decoder(embedding_matrix_h, vocab_tar_size, embedding_dim, units, BATCH_SIZE, 'luong')
sample_x = tf.random.uniform((BATCH_SIZE, max_length_output))
decoder.attention_mechanism.setup_memory(sample_output)
initial_state = decoder.build_initial_state(BATCH_SIZE, [sample_h, sample_c], tf.float32)


sample_decoder_outputs = decoder(sample_x, initial_state)

print("Decoder Outputs Shape: ", sample_decoder_outputs.rnn_output.shape)
# Out:
# Decoder Outputs Shape:  (64, 33, 7014)

# %%
# defing optimizer and loss function

optimizer = tf.keras.optimizers.Adam()


def loss_function(real, pred):
    # real shape = (BATCH_SIZE, max_length_output)
    # pred shape = (BATCH_SIZE, max_length_output, tar_vocab_size )
    cross_entropy = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
    loss = cross_entropy(y_true=real, y_pred=pred)
    mask = tf.logical_not(tf.math.equal(real,0))   #output 0 for y=0 else output 1
    mask = tf.cast(mask, dtype=loss.dtype)  
    loss = mask* loss
    loss = tf.reduce_mean(loss)
    return loss

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0
    
    with tf.GradientTape() as tape:
        enc_output, enc_h, enc_c = encoder(inp, enc_hidden)


        dec_input = targ[ : , :-1 ] # Ignore <end> token
        real = targ[ : , 1: ]         # ignore <start> token

        # Set the AttentionMechanism object with encoder_outputs
        decoder.attention_mechanism.setup_memory(enc_output)

        # Create AttentionWrapperState as initial_state for decoder
        decoder_initial_state = decoder.build_initial_state(BATCH_SIZE, [enc_h, enc_c], tf.float32)
        pred = decoder(dec_input, decoder_initial_state)
        logits = pred.rnn_output
        loss = loss_function(real, logits)

    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return loss

# %%
# EPOCHS = 10

# for epoch in range(EPOCHS):
#     start = time.time()
#     enc_hidden = encoder.initialize_hidden_state()
#     total_loss = 0
#     # print(enc_hidden[0].shape, enc_hidden[1].shape)
    
#     for (batch, (inp, targ)) in enumerate(train_dataset.take(steps_per_epoch)):
#         batch_loss = train_step(inp, targ, enc_hidden)
#         total_loss += batch_loss
#         if batch % 100 == 0:
#             print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
#                                                    batch,
#                                                    batch_loss.numpy()))
#    # saving (checkpoint) the model every 2 epochs
#     if (epoch + 1) % 2 == 0:
#         checkpoint.save(file_prefix = checkpoint_prefix)

#     print('Epoch {} Loss {:.4f}'.format(epoch + 1,
#                                       total_loss / steps_per_epoch))
#     print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))

# %%
def evaluate_sentence(sentence):
    sentence = clean_english_data(sentence)
    string = " ".join(sentence)
    inputs = [eng_lang_tokenizer.word_index[i] for i in string.split(" ")]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                          maxlen=max_length_input,
                                                          padding='post')
    inputs = tf.convert_to_tensor(inputs)
    inference_batch_size = inputs.shape[0]
    result = ''
    enc_start_state = [tf.zeros((inference_batch_size, units)), tf.zeros((inference_batch_size,units))]
    enc_out, enc_h, enc_c = encoder(inputs, enc_start_state)
    dec_h = enc_h
    dec_c = enc_c
    start_tokens = tf.fill([inference_batch_size], hin_lang_tokenizer.word_index['<start>'])
    end_token = hin_lang_tokenizer.word_index['<end>']
    greedy_sampler = tfa.seq2seq.GreedyEmbeddingSampler()
    # Instantiate BasicDecoder object
    decoder_instance = tfa.seq2seq.BasicDecoder(cell=decoder.rnn_cell, sampler=greedy_sampler, output_layer=decoder.fc)
    # Setup Memory in decoder stack
    decoder.attention_mechanism.setup_memory(enc_out)

    # set decoder_initial_state
    decoder_initial_state = decoder.build_initial_state(inference_batch_size, [enc_h, enc_c], tf.float32)


    ### Since the BasicDecoder wraps around Decoder's rnn cell only, you have to ensure that the inputs to BasicDecoder 
    ### decoding step is output of embedding layer. tfa.seq2seq.GreedyEmbeddingSampler() takes care of this. 
    ### You only need to get the weights of embedding layer, which can be done by decoder.embedding.variables[0] and pass this callabble to BasicDecoder's call() function
    decoder_embedding_matrix = decoder.embedding.variables[0]
    outputs, _, _ = decoder_instance(decoder_embedding_matrix, start_tokens = start_tokens, end_token= end_token, initial_state=decoder_initial_state)
    return outputs.sample_id.numpy()

def translate(sentence):
    result = evaluate_sentence(sentence)
    print(result)
    result = hin_lang_tokenizer.sequences_to_texts(result)
    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))
    return result, sentence

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
input_val
# Out:
# ['<start> this is the sky <end>',
#  '<start> boy with purple and white shoes <end>',
#  '<start> man wearing dapper red hat <end>',
#  '<start> green colored leaves <end>',
#  '<start> a runner leading off of first base <end>',
#  '<start> a red train <end>',
#  '<start> windown on dark red building <end>',
#  '<start> black suit jacket on man <end>',
#  '<start> big grey indian elephant <end>',
#  '<start> man has a ring on <end>',
#  '<start> the girl is wearing a necklace <end>',
#  '<start> man drawing water from borehole <end>',
#  '<start> street sign <end>',
#  '<start> a window on the building <end>',
#  '<start> tops of purple flowers in the field <end>',
#  '<start> woman holding a cell phone <end>',
#  '<start> black ipod with white plug <end>',
#  '<start> stripes on the zebra <end>',
#  '<start> a sliced piece of black olive <end>',
#  '<start> the cow lying down <end>',
#  '<start> wooden bench with wooden slats <end>',
#  '<start> this is a buiding <end>',
#  '<start> women are sitting on the chair <end>',
#  '<start> sliced red tomatoes on plate <end>',
#  '<start> two is written on the jersey <end>',
#  '<start> this is a toilet bow <end>',
#  '<start> the hydrant is yellow <end>',
#  '<start> people sitting at a table <end>',
#  '<start> blue surf board <end>',
#  '<start> metal cage near giraffe <end>',
#  '<start> shallow body of water <end>',
#  '<start> a group of people <end>',
#  '<start> phone on table <end>',
#  '<start> glass window on boat <end>',
#  '<start> train traveling on rails <end>',
#  '<start> a tv on a table <end>',
#  '<start> a glossy blue coffee mug <end>',
#  '<start> two women in the bathroom <end>',
#  '<start> red cap of the tennis player <end>',
#  '<start> a little boy reading a book <end>',
#  '<start> part of the sky <end>',
#  '<start> bird near a lake <end>',
#  '<start> a leaning red bike <end>',
#  '<start> a man flying kites <end>',
#  '<start> partially eaten cookie on a plate <end>',
#  '<start> green leaves on trees <end>',
#  '<start> white patch on screen <end>',
#  '<start> face of the cat <end>',
#  '<start> part of a floor <end>',
#  '<start> a mouse is printed on the shirt <end>',
#  '<start> a bench to sit on <end>',
#  '<start> a wall on the side of a building <end>',
#  '<start> a person wearing a custom <end>',
#  '<start> two dogs with tongues visible <end>',
#  '<start> this is the sky <end>',
#  '<start> knife on the table <end>',
#  '<start> green leaf on plant <end>',
#  '<start> giraffes tail sticking out <end>',
#  '<start> shot in the tray <end>',
#  '<start> the man is skiing <end>',
#  '<start> this is a tire <end>',
#  '<start> dark sunglasses on a mans face <end>',
#  '<start> two people are wearing goggles <end>',
#  '<start> woman sitting at table <end>',
#  '<start> blue lanyard in the neck <end>',
#  '<start> picture of two mail boxes <end>',
#  '<start> man with a skateboard <end>',
#  '<start> sheep next to sheep <end>',
#  '<start> woman on skis on snow <end>',
#  '<start> brown teddy bear sitting on counter <end>',
#  '<start> three black pillows <end>',
#  '<start> small duckling in water <end>',
#  '<start> this is a man <end>',
#  '<start> the person is standing <end>',
#  '<start> a table scene <end>',
#  '<start> man carrying a surfboard <end>',
#  '<start> snow on top of mountain <end>',
#  '<start> birds in the shot <end>',
#  '<start> this is a man <end>',
#  '<start> elephant standing in clearing <end>',
#  '<start> ud on the clock <end>',
#  '<start> woman eating a slice of pizza <end>',
#  '<start> serviceman standing in a line <end>',
#  '<start> head of a person <end>',
#  '<start> the bear is up in a tree <end>',
#  '<start> light blue pillow case <end>',
#  '<start> this is the sky <end>',
#  '<start> the shirt is yellow <end>',
#  '<start> this is a picture <end>',
#  '<start> yellow and white toothbrush <end>',
#  '<start> these are three people <end>',
#  '<start> white window sill on the pink wall <end>',
#  '<start> a vehicle is going through slush <end>',
#  '<start> this is a zebra <end>',
#  '<start> red cow in water <end>',
#  '<start> two wooden beach chairs <end>',
#  '<start> gathering of brown elephants <end>',
#  '<start> a grey parking meter <end>',
#  '<start> a yellow umbrella over some beach chairs <end>',
#  '<start> the table is blue <end>',
#  '<start> clock on a tower <end>',
#  '<start> a woman in white <end>',
#  '<start> woman with a surfboard standing in the sand <end>',
#  '<start> this is a woman <end>',
#  '<start> man wearing a helmet <end>',
#  '<start> this is a train <end>',
#  '<start> front wheel of a motorcycle <end>',
#  '<start> she is a batter <end>',
#  '<start> airplane landing gear <end>',
#  '<start> small brown plank of wood <end>',
#  '<start> a cat wearing a hat <end>',
#  '<start> three surfers <end>',
#  '<start> this is a horse <end>',
#  '<start> brick oven in the back <end>',
#  '<start> a zebra is the center focus <end>',
#  '<start> keyboard on the desk <end>',
#  '<start> the shirt is black <end>',
#  '<start> green cooked broccoli <end>',
#  '<start> a computer screen <end>',
#  '<start> the boys playing base ball <end>',
#  '<start> old fashioned car on road <end>',
#  '<start> a baby boy sitting on the bed <end>',
#  '<start> person on a board for skating <end>',
#  '<start> this is a teddy bear <end>',
#  '<start> black motorcycle racing helmet <end>',
#  '<start> this is the grass <end>',
#  '<start> pizza spatula on pan <end>',
#  '<start> part of a shirt <end>',
#  '<start> white tennis net on court <end>',
#  '<start> person skateboarding on sidewalk <end>',
#  '<start> the bench is empty <end>',
#  '<start> a snowboarder in the air <end>',
#  '<start> man standing on tennis court <end>',
#  '<start> a sailboat on the water <end>',
#  '<start> white frisbee in air <end>',
#  '<start> the couch is red <end>',
#  '<start> a large blue and white tent <end>',
#  '<start> boy on bicycle <end>',
#  '<start> a red and white t shirt with a face on it <end>',
#  '<start> black and white sign <end>',
#  '<start> a plaque located on a bench <end>',
#  '<start> brown horse in field <end>',
#  '<start> three bells on top of the building <end>',
#  '<start> boy on a skateboard <end>',
#  '<start> the boy holding a spoon <end>',
#  '<start> glowing computer logo <end>',
#  '<start> bunch of yellow bananas <end>',
#  '<start> the bowl is blue <end>',
#  '<start> a large furry cat <end>',
#  '<start> bus parked at curb <end>',
#  '<start> theres an old wood building in background <end>',
#  '<start> a scene outside <end>',
#  '<start> man standing in a black suit and blue shirt <end>',
#  '<start> this is the sky <end>',
#  '<start> bright white sedan parked near curb <end>',
#  '<start> shorts are blue <end>',
#  '<start> man riding a skateboard <end>',
#  '<start> bridge crossing over the waterway <end>',
#  '<start> a skateboard in the air <end>',
#  '<start> clear and blue plastic water bottle <end>',
#  '<start> dill pickle spear resting on lettuce leaf <end>',
#  '<start> slice of italian bread <end>',
#  '<start> a wall on the side of a building <end>',
#  '<start> zipper around the suitcase <end>',
#  '<start> a large framed drawing <end>',
#  '<start> two people are at a conference <end>',
#  '<start> clock on the side of the tower <end>',
#  '<start> the light post with the signs on it <end>',
#  '<start> stuffed bears together <end>',
#  '<start> a birthday cake with chocolate frosting <end>',
#  '<start> a large picture on the wall <end>',
#  '<start> a skater figure <end>',
#  '<start> two arrows on a road <end>',
#  '<start> a large group of zebras <end>',
#  '<start> the train is black <end>',
#  '<start> handle on the mug <end>',
#  '<start> bony cow being milked <end>',
#  '<start> part of a white dish <end>',
#  '<start> a vehicle on the road <end>',
#  '<start> a bicyclist is zooming down the bike path <end>',
#  '<start> reflection in the water <end>',
#  '<start> very old coke truck <end>',
#  '<start> illuminated green traffic light <end>',
#  '<start> kitten sitting on laptop keyboard <end>',
#  '<start> a yellow plane parked in the grass <end>',
#  '<start> white writing on side of boat <end>',
#  '<start> small ripples in the water <end>',
#  '<start> woman cutting a cake with a sword <end>',
#  '<start> white bird with bright red feet <end>',
#  '<start> man is on surfboard <end>',
#  '<start> store has a window <end>',
#  '<start> small grey brick on a wall <end>',
#  '<start> plane on the ground <end>',
#  '<start> a persons shadow on the snow <end>',
#  '<start> a tow truck on the road <end>',
#  '<start> series of street lamps along road <end>',
#  '<start> the trunk of the elephant <end>',
#  '<start> grey colored sidewalk brick <end>',
#  '<start> metal spiked fence <end>',
#  '<start> a young boy in the foreground <end>',
#  '<start> white toilet with raised lid <end>',
#  '<start> man in purple shirt <end>',
#  '<start> traffic control signal light <end>',
#  '<start> multiple sets of train tracks near each other <end>',
#  '<start> girl on the beach <end>',
#  '<start> a raspberry on top of a dessert <end>',
#  '<start> beautiful little girl with brown hair <end>',
#  '<start> man has cat on lap <end>',
#  '<start> the sky is clear and blue <end>',
#  '<start> phone is on mans ear <end>',
#  '<start> this is an egg <end>',
#  '<start> vegetables and butter in pot <end>',
#  '<start> the sky has some clouds <end>',
#  '<start> bike is yellow <end>',
#  '<start> the man is wearing grey socks <end>',
#  '<start> boogie board in the sand <end>',
#  '<start> cat riding on a black skateboard <end>',
#  '<start> a white post <end>',
#  '<start> large building with a clock tower <end>',
#  '<start> this is a sheep <end>',
#  '<start> a rough paved ground <end>',
#  '<start> a man talking on a cellphone <end>',
#  '<start> an image of a tarmac <end>',
#  '<start> they are in the water <end>',
#  '<start> tan and white teddy bear <end>',
#  '<start> broken toilet in the corner <end>',
#  '<start> a green tennis ball <end>',
#  '<start> a clear blue ocean <end>',
#  '<start> face of the cow <end>',
#  '<start> drain in the sink <end>',
#  '<start> a plane is in air <end>',
#  '<start> the stop light is black <end>',
#  '<start> the couch is red <end>',
#  '<start> one zebra in a pack <end>',
#  '<start> guy paddle boarding on calm waters <end>',
#  '<start> silver microwave with black edges <end>',
#  '<start> kids performing on a stage <end>',
#  '<start> a bicycle parked by the fence <end>',
#  '<start> the man is on a tennis court <end>',
#  '<start> an elephant is visible <end>',
#  '<start> empty train tracks on right <end>',
#  '<start> head of a person <end>',
#  '<start> the umbrella is purple <end>',
#  '<start> woman walking through airline terminal <end>',
#  '<start> the bird on the balcony <end>',
#  '<start> a yellow fire hydrant <end>',
#  '<start> the lamp on the side table <end>',
#  '<start> cellphone in the mans hand <end>',
#  '<start> man is holding a bat <end>',
#  '<start> a bowl of fruit <end>',
#  '<start> man sitting on wooden bench <end>',
#  '<start> train is red white and blue <end>',
#  '<start> book on the bed <end>',
#  '<start> a busy street <end>',
#  '<start> this is a kitchen knife <end>',
#  '<start> three rectangular train cars <end>',
#  '<start> cup is white in color <end>',
#  '<start> the door of an airplane <end>',
#  '<start> these are legs folded <end>',
#  '<start> a very large tower <end>',
#  '<start> wooden bench in green forest <end>',
#  '<start> baseball batter at home plate <end>',
#  '<start> knife in couples hands <end>',
#  '<start> a passenger rail over a city <end>',
#  '<start> spoke of motorcycle wheel <end>',
#  '<start> a light that is on <end>',
#  '<start> part of a glove <end>',
#  '<start> a plate of food <end>',
#  '<start> red and white boat <end>',
#  '<start> two half cut sandwiches <end>',
#  '<start> mirror on a pole <end>',
#  '<start> the leg of a man laying on the street <end>',
#  '<start> a horse walks down the street <end>',
#  '<start> orange post designating lane <end>',
#  '<start> the suit is in the chair <end>',
#  '<start> woman standing at airport <end>',
#  '<start> large yellow writing on the red bus <end>',
#  '<start> old airplane in the air <end>',
#  '<start> a man walking on a sidewalk <end>',
#  '<start> this is the sky <end>',
#  '<start> the shirt is white <end>',
#  '<start> this is the sky <end>',
#  '<start> two birds sitting on a tree branch <end>',
#  '<start> black framed art print <end>',
#  '<start> time is about <end>',
#  '<start> edge of a dish <end>',
#  '<start> two cats are sleeping <end>',
#  '<start> man is wearing a red and white snowsuit <end>',
#  '<start> two zebras next to each other <end>',
#  '<start> stuffed teddy bear sitting in blue chair <end>',
#  '<start> there are three giraffes in the picture <end>',
#  '<start> tiny pair of scissors <end>',
#  '<start> house with brown roof <end>',
#  '<start> a window with a gray curtain <end>',
#  '<start> food on the plate <end>',
#  '<start> dark blue curtain poking out of left wall <end>',
#  '<start> a man playing tennis <end>',
#  '<start> hands texting on a smart phone <end>',
#  '<start> there is a dark brown trunk <end>',
#  '<start> boy in red tshirt <end>',
#  '<start> double decker bus <end>',
#  '<start> baseball batter holding bat <end>',
#  '<start> someone has set their glasses on the table <end>',
#  '<start> green ceramic vase on table <end>',
#  '<start> woman with orange hair <end>',
#  '<start> cross country racer <end>',
#  '<start> red circle with a slash through it <end>',
#  '<start> man hair is black <end>',
#  '<start> a young baby boy <end>',
#  '<start> the black roman numeral xii on the clock <end>',
#  '<start> tv across the room <end>',
#  '<start> the american flag is up <end>',
#  '<start> the man is wearing a red coat <end>',
#  '<start> the dogs yellow frisbee <end>',
#  '<start> bright yellow lawn chair <end>',
#  '<start> the tail of the plane <end>',
#  '<start> red and white stop sign <end>',
#  '<start> car has a light <end>',
#  '<start> a scene during the day <end>',
#  '<start> red string in the sky <end>',
#  '<start> the blue sky in the background <end>',
#  '<start> two cats in a window <end>',
#  '<start> the cow is spotted <end>',
#  '<start> peoples are discussing <end>',
#  '<start> darker blue and white tennis court <end>',
#  '<start> a white building with red shutters around the windows <end>',
#  '<start> dirty unflushed toilet <end>',
#  '<start> part of the cloudy sky <end>',
#  '<start> blond woman wearing white sash <end>',
#  '<start> the left horn of the giraffe in the back <end>',
#  '<start> a young man with bare feet surfing <end>',
#  '<start> couple walking on the beach <end>',
#  '<start> boy jumping in the air <end>',
#  '<start> triangular road sign <end>',
#  '<start> baked bean piled on white plate <end>',
#  '<start> the man is riding a bicycle <end>',
#  '<start> knife with a white handle <end>',
#  '<start> bike sitting next to man <end>',
#  '<start> cow in the field <end>',
#  '<start> the pizza is half eaten <end>',
#  '<start> blue and white kite over ocean <end>',
#  '<start> a yellow tennis ball <end>',
#  '<start> this is a cake <end>',
#  '<start> a person that is parasailing <end>',
#  '<start> a plate of food <end>',
#  '<start> the basket is blue <end>',
#  '<start> the letter is black <end>',
#  '<start> woman has blonde hair <end>',
#  '<start> man carrying bags <end>',
#  '<start> fire hydrant on a sidewalk <end>',
#  '<start> lots of sheep <end>',
#  '<start> american flag flying in the background <end>',
#  '<start> people in a restaurant <end>',
#  '<start> towels hanging on a stove handle <end>',
#  '<start> this is taken in a rural setting <end>',
#  '<start> tip of the cats tail <end>',
#  '<start> brown teddy bear <end>',
#  '<start> the elephant <end>',
#  '<start> the number on the side of the trolley <end>',
#  '<start> four oblong decorated panels <end>',
#  '<start> a pastry in basket <end>',
#  '<start> a penny loafer <end>',
#  '<start> the red bus is on the street <end>',
#  '<start> a lamp that is switched on <end>',
#  '<start> a small piece of cake <end>',
#  '<start> brown plant stem <end>',
#  '<start> part of a ground <end>',
#  '<start> plane logo <end>',
#  '<start> man in white shirt walking down the sidewalk <end>',
#  '<start> child playing baseball game <end>',
#  '<start> a man is in a suit holding a glass <end>',
#  '<start> an unkempt man picking at his finger nails <end>',
#  '<start> a man wearing jeans <end>',
#  '<start> part of the grass <end>',
#  '<start> pile of feta cheese on a pizza <end>',
#  '<start> black and white zebra with a bent neck <end>',
#  '<start> a person is playing <end>',
#  '<start> knife leaning on apple <end>',
#  '<start> elephants walking <end>',
#  '<start> collection of refrigerator magnets <end>',
#  '<start> clock on side of tower building <end>',
#  '<start> a window on a train <end>',
#  '<start> helmet on persons head <end>',
#  '<start> a group of horses standing in field <end>',
#  '<start> green kite near the water <end>',
#  '<start> a sheeps tail <end>',
#  '<start> sweet and low in a dispenser bowl <end>',
#  '<start> a man drinking wine <end>',
#  '<start> tall brown wooden pole <end>',
#  '<start> tennis court is blue <end>',
#  '<start> clear container with liquid in it <end>',
#  '<start> a jar of cherry jam <end>',
#  '<start> this is a clock <end>',
#  '<start> person bent over a computer <end>',
#  '<start> a small red bird <end>',
#  '<start> a long asphalt road <end>',
#  '<start> a dark red canoe <end>',
#  '<start> people riding horses on the beach <end>',
#  '<start> a clear and blue sky <end>',
#  '<start> four livestock on field <end>',
#  '<start> eyes on a costume <end>',
#  '<start> the clock on the stove <end>',
#  '<start> black and white seagall <end>',
#  '<start> an iphone on a stand <end>',
#  '<start> a person in the street <end>',
#  '<start> a young boy wearing glasses <end>',
#  '<start> a gray and white cat <end>',
#  '<start> coffee cup full of frothy coffee <end>',
#  '<start> guys standing and playing video games <end>',
#  '<start> seated baby looking at hand <end>',
#  '<start> the bench is old <end>',
#  '<start> the head and neck of a giraffe <end>',
#  '<start> fried food on plate <end>',
#  '<start> the wave is huge <end>',
#  '<start> front tire of bike <end>',
#  '<start> birds flying over surface of water <end>',
#  '<start> a man in a uniform <end>',
#  '<start> this is a person <end>',
#  '<start> the saddle is black <end>',
#  '<start> two elephants in rocks <end>',
#  '<start> airplane in sky surrounded by birds <end>',
#  '<start> cardboard coffee cup sleeve <end>',
#  '<start> these are trains <end>',
#  '<start> shadow of a man on the ground <end>',
#  '<start> white clouds in blue sky <end>',
#  '<start> man with a black suit on <end>',
#  '<start> a man water skiing <end>',
#  '<start> a mushroom and red pepper pizza <end>',
#  '<start> grey and orange cat on desk <end>',
#  '<start> truck parked on the road <end>',
#  '<start> street sign is blue <end>',
#  '<start> semi truck <end>',
#  '<start> yellow bunch of bananas for sale <end>',
#  '<start> a zebra is grazing on grass <end>',
#  '<start> man is on surfboard <end>',
#  '<start> man in the water <end>',
#  '<start> white paddle for rowing <end>',
#  '<start> man has dark hair <end>',
#  '<start> seven giraffes together <end>',
#  '<start> the woman is wearing blue jeans <end>',
#  '<start> the person is flying a kite <end>',
#  '<start> the small stone cottage <end>',
#  '<start> an airplane <end>',
#  '<start> man holding his phone <end>',
#  '<start> whiskers on a giraffe <end>',
#  '<start> a black electric blender <end>',
#  '<start> little girl pointing at sheep <end>',
#  '<start> the sheets are white <end>',
#  '<start> red stop sign with white trim <end>',
#  '<start> the nose is brown <end>',
#  '<start> a very large group of old fashion suitcases <end>',
#  '<start> the countertop is empty <end>',
#  '<start> these are playing cards <end>',
#  '<start> these are signs <end>',
#  '<start> a kitchen countertop <end>',
#  '<start> girl wearing purple shorts <end>',
#  '<start> fish on a plate covered in sauce <end>',
#  '<start> a reflection of a mountain <end>',
#  '<start> a dog with one brown eye <end>',
#  '<start> the boy is wearing sunglasses <end>',
#  '<start> a white truck parked on the street <end>',
#  '<start> two trains are together <end>',
#  '<start> a little child sitting on a wooden bench <end>',
#  '<start> toilet with the seat and lid down <end>',
#  '<start> man is sitting down <end>',
#  '<start> some train tracks on the ground <end>',
#  '<start> picture taken outside <end>',
#  '<start> apples cut to eat <end>',
#  '<start> a pile of random stuff <end>',
#  '<start> a metal pole <end>',
#  '<start> white metal pole with red stripe <end>',
#  '<start> a plane in the photo <end>',
#  '<start> snows on a plain field <end>',
#  '<start> the jeans are blue <end>',
#  '<start> two girls playing soccer <end>',
#  '<start> red train on bridge <end>',
#  '<start> man batting in baseball game <end>',
#  '<start> sandwich cut in half <end>',
#  '<start> this is a baseball player <end>',
#  '<start> person skateboarding down the street <end>',
#  '<start> this is a long pizza <end>',
#  '<start> people walking between silver railings <end>',
#  '<start> silver flag pole with american flag <end>',
#  '<start> sign on the building <end>',
#  '<start> this person is skiing <end>',
#  '<start> hat with floral accented band <end>',
#  '<start> dog running in grass <end>',
#  '<start> people playing wii <end>',
#  '<start> eggs on top of pizza <end>',
#  '<start> people playing in the water <end>',
#  '<start> the photograph is black and white <end>',
#  '<start> a watch on the shelf <end>',
#  '<start> a brown lamp shade <end>',
#  '<start> man carries skateboard <end>',
#  '<start> brown wooden bench surrounded by water <end>',
#  '<start> a light above a kitchen counter <end>',
#  '<start> this is a monkey <end>',
#  '<start> tables with equipment <end>',
#  '<start> a light on the wall <end>',
#  '<start> empty wooden bench in distance <end>',
#  '<start> a body of water <end>',
#  '<start> pink trim around window <end>',
#  '<start> a young alpaca stands in the pasture <end>',
#  '<start> the short is blue <end>',
#  '<start> a beach during daylight hours <end>',
#  '<start> two people are in living room <end>',
#  '<start> a parked grey car <end>',
#  '<start> it is sheep head <end>',
#  '<start> small dark brown wooden chair on the ground <end>',
#  '<start> black traffic signal on metal pole <end>',
#  '<start> photo taken at the beach <end>',
#  '<start> this is a picture <end>',
#  '<start> woman wearing a blue and red scarf <end>',
#  '<start> a cup full of a dark beverage <end>',
#  '<start> man with dreadlocks in his hair <end>',
#  '<start> boy bent over playing a game <end>',
#  '<start> person and a bench <end>',
#  '<start> surfer <end>',
#  '<start> a young girl is wearing red goggles <end>',
#  '<start> mouse on the table <end>',
#  '<start> head of a person <end>',
#  '<start> a man with a black sheep <end>',
#  '<start> a birthday cookie cake <end>',
#  '<start> a small furry dog <end>',
#  '<start> square window on wall <end>',
#  '<start> part of a shirt <end>',
#  '<start> a table with dishes <end>',
#  '<start> vases with blue flowers <end>',
#  '<start> the kite is on the ground <end>',
#  '<start> longhaired surfer in the ocean <end>',
#  '<start> the two orange and white cones <end>',
#  '<start> yellow lines on the road <end>',
#  '<start> person skiing down a slope <end>',
#  '<start> backpacks and bags on the ground <end>',
#  '<start> light in the ceiling <end>',
#  '<start> giraffe and zebra in round enclosure <end>',
#  '<start> head of a person <end>',
#  '<start> a toilet brush next to a toilet <end>',
#  '<start> bus going crosstown <end>',
#  '<start> tennis player reaching up with racket <end>',
#  '<start> child in a small train <end>',
#  '<start> alphabet on a plate <end>',
#  '<start> apartment bathroom <end>',
#  '<start> guy on a surfboard <end>',
#  '<start> the umbrella is open <end>',
#  '<start> apple is next to tomato <end>',
#  '<start> broken tree in the background <end>',
#  '<start> woman in red hat <end>',
#  '<start> the man has ski boots on <end>',
#  '<start> a man is eating food <end>',
#  '<start> white wave in water <end>',
#  '<start> a tennis ball in the air <end>',
#  '<start> large yellow sign with black letters <end>',
#  '<start> decorative round bathroom sink <end>',
#  '<start> batter ready to hit the ball <end>',
#  '<start> several cows in a foeld <end>',
#  '<start> the grass is overgrown <end>',
#  '<start> head of a person <end>',
#  '<start> white and blue book <end>',
#  '<start> almondshaped eyes on woman <end>',
#  '<start> hair on horse head <end>',
#  '<start> the floor is brown <end>',
#  '<start> older man sitting on a bench <end>',
#  '<start> wing of a plane is tan and red <end>',
#  '<start> a woman walking on a tennis court <end>',
#  '<start> the head of a woman <end>',
#  '<start> a girls white sock <end>',
#  '<start> woman with shuggy hair <end>',
#  '<start> this is a zebra <end>',
#  '<start> people at the beach with an ox in the foreground <end>',
#  '<start> can below black stool laying on the cement <end>',
#  '<start> the cake on the table <end>',
#  '<start> blue of daytime sky <end>',
#  '<start> horse pulling the wagon <end>',
#  '<start> broccoli crown on fabric <end>',
#  '<start> a plastic bag of trash <end>',
#  '<start> a white and blue bus <end>',
#  '<start> the glass globes around the street lights <end>',
#  '<start> two people standing in the grass <end>',
#  '<start> black wet elephant walking in river <end>',
#  '<start> woman is on phone <end>',
#  '<start> gray smoke in the back <end>',
#  '<start> three hanging lights <end>',
#  '<start> flower in glass vase <end>',
#  '<start> black and white photos <end>',
#  '<start> a motorcycle is parked <end>',
#  '<start> a black cat with its leg stretched out <end>',
#  '<start> this is the sky <end>',
#  '<start> a colorful umbrella <end>',
#  '<start> piece of sandwich <end>',
#  '<start> the girl in the bed <end>',
#  '<start> cable car schedule board <end>',
#  '<start> young boy with one foot on a skateboard <end>',
#  '<start> yellow toothbrush in a cup <end>',
#  '<start> cell phone leaning against drinking glass <end>',
#  '<start> white shear bedroom curtains <end>',
#  '<start> girl in a white cardigan <end>',
#  '<start> a white snow field <end>',
#  '<start> a blue sky with a few clouds <end>',
#  '<start> white colander on table <end>',
#  '<start> sprinkled pastry in hand <end>',
#  '<start> the head of a horse <end>',
#  '<start> the plane is white <end>',
#  '<start> rectangular pizza <end>',
#  '<start> a brown cow with a black face <end>',
#  '<start> sign on the building <end>',
#  '<start> a green pedestrian light <end>',
#  '<start> baby sitting on bed <end>',
#  '<start> a street sign with a safety light <end>',
#  '<start> the clothes are green and yellow <end>',
#  '<start> man sitting on concrete <end>',
#  '<start> brown clock tower <end>',
#  '<start> orange and white barriers <end>',
#  '<start> woman sitting outside <end>',
#  '<start> vehicles on the road <end>',
#  '<start> nintendo wii remote with blue light on <end>',
#  '<start> beige door that is open <end>',
#  '<start> red pillow on bed <end>',
#  '<start> group of horses in a field <end>',
#  '<start> white tower on top of building <end>',
#  '<start> beautiful baby boy with short hair <end>',
#  '<start> person is playing tennis <end>',
#  '<start> a girl is walking with items on her head <end>',
#  '<start> man is wearing sun glasses <end>',
#  '<start> head of a person <end>',
#  '<start> a person carrying a yellow surfboard <end>',
#  '<start> light blue sky above mountains <end>',
#  '<start> red double decker bus <end>',
#  '<start> two giraffes in the distant <end>',
#  '<start> a clear vase with flowers <end>',
#  '<start> a red and white cvs pharmacy sign <end>',
#  '<start> the mint leaf on the whipped cream of the dessert <end>',
#  '<start> sign for san diego convention center <end>',
#  '<start> dark skinned man on right <end>',
#  '<start> large tree with many curvy branches <end>',
#  '<start> the zebras are running in the wild <end>',
#  '<start> a train riding along some tracks <end>',
#  '<start> bunch of carrots with stems <end>',
#  '<start> man playing tennis <end>',
#  '<start> green light on traffic signal <end>',
#  '<start> picture on a wall <end>',
#  '<start> a rusty door with a white symbol <end>',
#  '<start> wing of the bird <end>',
#  '<start> white mark is spotted <end>',
#  '<start> a black pick up truck <end>',
#  '<start> woman holding a tennis racket <end>',
#  '<start> red and white light on a truck <end>',
#  '<start> direction sign attached to pole <end>',
#  '<start> the head of a man <end>',
#  '<start> the letter is black <end>',
#  '<start> this is a lady <end>',
#  '<start> a dog <end>',
#  '<start> this is a table <end>',
#  '<start> person on tan motorcycle <end>',
#  '<start> a man riding a motorcycle <end>',
#  '<start> brown horse in the ground <end>',
#  '<start> a hand holding a wii control <end>',
#  '<start> two airplanes going up <end>',
#  '<start> large red stop sign <end>',
#  '<start> a body of water <end>',
#  '<start> man in white playing tennis <end>',
#  '<start> lights suspended from ceiling <end>',
#  '<start> red light on top of sign <end>',
#  '<start> a beautiful white wall <end>',
#  '<start> hole in a bench <end>',
#  '<start> a small carrying bag <end>',
#  '<start> this elephant is walking <end>',
#  '<start> the tin foil container <end>',
#  '<start> the cats paw is white <end>',
#  '<start> a wall on the side of a building <end>',
#  '<start> colorful bible truck <end>',
#  '<start> people kneeling on raft <end>',
#  '<start> cats lay in hallway <end>',
#  '<start> choppy and shallow large lake <end>',
#  '<start> a man standing next to a vehicle <end>',
#  '<start> a red stop sign <end>',
#  '<start> three horses grazing in pasture <end>',
#  '<start> yoga ball is pink <end>',
#  '<start> bright yellow snow jacket <end>',
#  '<start> the polaroids are on the table <end>',
#  '<start> white dog running away <end>',
#  '<start> helmet on the player <end>',
#  '<start> a large yellow bus <end>',
#  '<start> a snowy hilly landscape <end>',
#  '<start> splash of a snow <end>',
#  '<start> logos on the side panel of the motorcycle <end>',
#  '<start> a stop sign <end>',
#  '<start> a tv screen displaying a video game <end>',
#  '<start> part of an ocean <end>',
#  '<start> that is a zebra <end>',
#  '<start> a skier is in the air <end>',
#  '<start> pillow on top of bed <end>',
#  '<start> close up view of an orange <end>',
#  '<start> a train in a train station <end>',
#  '<start> white cat <end>',
#  '<start> the tree is the color green <end>',
#  '<start> obstacle course on dried tan and green grass <end>',
#  '<start> goggles on the face <end>',
#  '<start> this looks like the inside of a motor home <end>',
#  '<start> part of a sheet <end>',
#  '<start> airplane on the tarmac <end>',
#  '<start> the backside of a giraffe <end>',
#  '<start> the snow on the train platform <end>',
#  '<start> an orange painted fire hydrant <end>',
#  '<start> a black horned cow standing in the street <end>',
#  '<start> three zebra walking together <end>',
#  '<start> different types of pizza on the table <end>',
#  '<start> american flag hanging on side of building <end>',
#  '<start> girls hair is blonde <end>',
#  '<start> grey pary of a parking meter <end>',
#  '<start> the person is wearing a shirt <end>',
#  '<start> a banana is on the table <end>',
#  '<start> a woman <end>',
#  '<start> a picture of a small bathroom <end>',
#  '<start> black and orange table <end>',
#  '<start> two ducks in the water <end>',
#  '<start> kite flying in sky <end>',
#  '<start> black grate on the street <end>',
#  '<start> the woman is wearing a dark coat <end>',
#  '<start> plane <end>',
#  '<start> truck on the ground <end>',
#  '<start> man looking at fruit <end>',
#  '<start> smoke coming from stack <end>',
#  '<start> a wall on the side of a building <end>',
#  '<start> group of people waiting at the train station <end>',
#  '<start> yellow fire hydrant on street <end>',
#  '<start> the train on the tracks <end>',
#  '<start> woman is playing tennis <end>',
#  '<start> woman surfing <end>',
#  '<start> train coming down the tracks <end>',
#  '<start> black and blue eyes on hat <end>',
#  '<start> a blue van <end>',
#  '<start> part of a water body <end>',
#  '<start> man standing with elephants <end>',
#  '<start> the person walking on the platform <end>',
#  '<start> this is a man <end>',
#  '<start> several kites in the air <end>',
#  '<start> long black colored tie <end>',
#  '<start> giraffe is drinking water <end>',
#  '<start> person riding a motorcycle <end>',
#  '<start> brown tabby cat on a window sill <end>',
#  '<start> clock in front of tall building <end>',
#  '<start> grilled weiner on bun <end>',
#  '<start> man driving a motorcycle <end>',
#  '<start> a white number <end>',
#  '<start> townhouse is painted yellow <end>',
#  '<start> a woman <end>',
#  '<start> white horse on the road <end>',
#  '<start> clock in the photo <end>',
#  '<start> train on the tracks <end>',
#  '<start> smaller brown bag with checkerboard print <end>',
#  '<start> houses are on the beach <end>',
#  '<start> tail of a cat <end>',
#  '<start> a water bottle on a stump <end>',
#  '<start> furry white dog on bed <end>',
#  '<start> man walking with animals <end>',
#  '<start> the <end>',
#  '<start> a multicolored umbrella <end>',
#  '<start> small tennis net for kids <end>',
#  '<start> pink umbrellas at the tables <end>',
#  '<start> people sitting on a couch <end>',
#  '<start> the man standing in front of the stove <end>',
#  '<start> this is a giraffe <end>',
#  '<start> the ribbon is red and blue <end>',
#  '<start> a style snow board <end>',
#  '<start> two women standing in the water <end>',
#  '<start> man wearing brown boots <end>',
#  '<start> a large pink window <end>',
#  '<start> this man is using a skateboard <end>',
#  '<start> a frame leaning on the wall <end>',
#  '<start> the door <end>',
#  '<start> man wearing a red jacket <end>',
#  '<start> a traffic light mounted on a pole <end>',
#  '<start> two women on a tennis court <end>',
#  '<start> horse pulling a cart along a dirt road <end>',
#  '<start> three sheep walking down road <end>',
#  '<start> person on a snowboard <end>',
#  '<start> chair at the table <end>',
#  '<start> black number one on a train <end>',
#  '<start> men are playing tennis <end>',
#  '<start> a bottle of water <end>',
#  '<start> black and white picture <end>',
#  '<start> the number on a clock <end>',
#  '<start> a fruit stand <end>',
#  '<start> a car driving down the street <end>',
#  '<start> a giraffe standing tall <end>',
#  '<start> a slice of tomatoe <end>',
#  '<start> the sign is gold <end>',
#  '<start> a boat on the water <end>',
#  '<start> two glasses on table <end>',
#  '<start> someone is on the mountain today <end>',
#  '<start> two bears face to face <end>',
#  '<start> part of a plain <end>',
#  '<start> openface bacon and cheese sandwich <end>',
#  '<start> wooden bench in a park <end>',
#  '<start> bad bananas on a tree <end>',
#  '<start> chair desk combo in the room <end>',
#  '<start> the ground is gray <end>',
#  '<start> man looking out to the ocean <end>',
#  '<start> this is an airplane <end>',
#  '<start> feathery ostrich looking to right <end>',
#  '<start> part of the sky <end>',
#  '<start> the truck on the road <end>',
#  '<start> head of a person <end>',
#  '<start> clock suspended from ceiling <end>',
#  '<start> tan cooked mushroom <end>',
#  '<start> a cat laying on a computer table <end>',
#  '<start> crowded market street scene <end>',
#  '<start> grey steps on stairs <end>',
#  '<start> part of a plantation <end>',
#  '<start> this is a seat <end>',
#  '<start> a person wearing snow skis <end>',
#  '<start> a giraffe on the grass <end>',
#  '<start> a hand towel hanging from the rack <end>',
#  '<start> two zebras <end>',
#  '<start> part of a green grass <end>',
#  '<start> grey asphalt surface <end>',
#  '<start> a cream colored dress <end>',
#  '<start> shoes sole is blue <end>',
#  '<start> a marque on the front of a train <end>',
#  '<start> a sign that says paid for with a bike symbol on it <end>',
#  '<start> the man playing wii <end>',
#  '<start> red and white city bus <end>',
#  '<start> person getting on bus <end>',
#  '<start> mans head <end>',
#  '<start> person looking out at the water <end>',
#  '<start> this is a train <end>',
#  '<start> cut up carrots on the plate <end>',
#  '<start> lady wearing short sleeve orange t shirt <end>',
#  '<start> the tail <end>',
#  '<start> black and silver refrigerator <end>',
#  '<start> this is a football player <end>',
#  '<start> horse riding inside white vehicle <end>',
#  '<start> a man riding a motorcycle <end>',
#  '<start> a dog is asleep <end>',
#  '<start> board for cutting fabric and paper <end>',
#  '<start> man skiing on mountain <end>',
#  '<start> three people <end>',
#  '<start> the person riding the motorcycle <end>',
#  '<start> gloves in back pocket of mans pants <end>',
#  '<start> a group of snow boarders <end>',
#  '<start> window on a bridge <end>',
#  '<start> young boy with a coyboy hat <end>',
#  '<start> four elephants performing <end>',
#  '<start> the dog is brown <end>',
#  '<start> sliced onion on bowl <end>',
#  '<start> orange vegetable in pot <end>',
#  '<start> part of a ceiling <end>',
#  '<start> a white baseball in hand <end>',
#  '<start> man standing in bathroom <end>',
#  '<start> small elephant with large white tusks <end>',
#  '<start> a pile of mashed potatoes <end>',
#  '<start> large clock on side of building <end>',
#  '<start> tall metal lightpost <end>',
#  '<start> door made of light colored wood <end>',
#  '<start> green grass on the ground <end>',
#  '<start> the train is in the station <end>',
#  '<start> the faucet is silver <end>',
#  '<start> part of the sky <end>',
#  '<start> part of a board <end>',
#  '<start> a black shingle sign attached to a building <end>',
#  '<start> pump is red and yellow in color <end>',
#  '<start> the white lines on the tennis court <end>',
#  '<start> brown nostrils of a bear <end>',
#  '<start> two zebras near each other <end>',
#  '<start> windows on a building <end>',
#  '<start> people near a plane <end>',
#  '<start> the shelf is color brown <end>',
#  '<start> lady standing at train station <end>',
#  '<start> white and black striped zebra walking in grassy field <end>',
#  '<start> this is a tv screen <end>',
#  '<start> snowboarder in yellow pants <end>',
#  '<start> the boat is on the sand <end>',
#  '<start> a large open field <end>',
#  '<start> downhill skier on the slope <end>',
#  '<start> green herb on plate <end>',
#  '<start> glasses on the helmet <end>',
#  '<start> part of a rock <end>',
#  '<start> a large tall clock <end>',
#  '<start> light fixture <end>',
#  '<start> basil leaf on pizza <end>',
#  '<start> several bags on display <end>',
#  '<start> a man kneeling over a hammock <end>',
#  '<start> top of trash can lid <end>',
#  '<start> blue and yellow train on train track <end>',
#  '<start> window with curved top <end>',
#  '<start> the panda is white and black <end>',
#  '<start> this is a cow <end>',
#  '<start> professional tennis playing hitting a ball <end>',
#  '<start> man wearing white shirt <end>',
#  '<start> large rock in the grass <end>',
#  '<start> red doubledecker bus <end>',
#  '<start> a wicker basket filled with healthy colorful fruits <end>',
#  '<start> a red and white street sign <end>',
#  '<start> the elephants are visible <end>',
#  '<start> red and yellow flag <end>',
#  '<start> rolling black suitcase <end>',
#  '<start> brown bear in chair <end>',
#  '<start> a man surfing in the sea <end>',
#  '<start> woman in front riding bike <end>',
#  '<start> a green and grey chair <end>',
#  '<start> part of a smoke <end>',
#  '<start> brown horse in stall <end>',
#  '<start> caramel on the plate <end>',
#  '<start> white oven with front window <end>',
#  '<start> leg of the bench <end>',
#  '<start> picture on the wall above the fireplace <end>',
#  '<start> this person is wearing a hat <end>',
#  '<start> a messy unmade bed with a white bowl in it <end>',
#  '<start> a blue stuffed elephant <end>',
#  '<start> this is a person <end>',
#  '<start> white birch tree with knots on the trunk <end>',
#  '<start> the number on the motorcycle <end>',
#  '<start> head of a bear <end>',
#  '<start> green grass on ground <end>',
#  '<start> man writing in a notebook <end>',
#  '<start> a surfer in a black wetsuit <end>',
#  '<start> a man hitting a tennis ball <end>',
#  '<start> white dot on pink luggage <end>',
#  '<start> blue frisbee in the air <end>',
#  '<start> spectators sitting in the bleachers <end>',
#  '<start> pigeon looking for food on plate <end>',
#  '<start> these are three boats <end>',
#  '<start> two beds in a room <end>',
#  '<start> black cursive writing on refrigerator door <end>',
#  '<start> pottery in the photo <end>',
#  '<start> animal fur that is being gathered <end>',
#  '<start> statue of liberty in background <end>',
#  '<start> a lot of oranges <end>',
#  '<start> man carrying a surf board <end>',
#  '<start> wheel of the vehicle <end>',
#  '<start> gray bench sitting by sidewalk <end>',
#  '<start> grey colored brick in wall <end>',
#  '<start> white tennis shoes with pink <end>',
#  '<start> livestock are very visible <end>',
#  '<start> computer laptop screen <end>',
#  '<start> black saddlebags on motorcycle <end>',
#  '<start> a pizza pie with a slice missing <end>',
#  '<start> large area of calm water <end>',
#  '<start> a black and white picture <end>',
#  '<start> a glass on the table <end>',
#  '<start> the woman is holding a cell phone <end>',
#  '<start> the ball player is dressed in black yellow uniform shirt <end>',
#  '<start> metal truss on bridge <end>',
#  '<start> the ski boards are black <end>',
#  '<start> part of a floor <end>',
#  '<start> a boat in the water <end>',
#  '<start> blue and white shorts on the person <end>',
#  '<start> there is a clock on the building <end>',
#  '<start> leaves on the tree <end>',
#  '<start> boy is skate boarding <end>',
#  '<start> frisbee is round and orange <end>',
#  '<start> the water is dark <end>',
#  '<start> soccer player wearing a uniform <end>',
#  '<start> this is a woman <end>',
#  '<start> a sheep in a field of grass <end>',
#  '<start> the doors are orange <end>',
#  '<start> white text on a blue background <end>',
#  '<start> childs face smirking to the camera <end>',
#  '<start> boy jumping into the air <end>',
#  '<start> a hut on a bridge <end>',
#  '<start> dark pair of sun glasses <end>',
#  '<start> someone is holding the camera <end>',
#  '<start> urinal in a restroom <end>',
#  '<start> wings on a pilots hat <end>',
#  '<start> a zebra grazing on grass <end>',
#  '<start> a boy playing in a pool <end>',
#  '<start> white clouds in blue sky <end>',
#  '<start> a case in the room <end>',
#  '<start> the bananas are yellow <end>',
#  '<start> silver headlights with black borders <end>',
#  '<start> the wall is made of brick <end>',
#  '<start> bowl of soup with noodles <end>',
#  '<start> small patch of the blue sky <end>',
#  '<start> one horse in the shot <end>',
#  '<start> the building is white <end>',
#  '<start> the frisbee is white <end>',
#  '<start> the bear is eating <end>',
#  '<start> giraffe in the wild <end>',
#  '<start> eye of the boy <end>',
#  '<start> this group has been sentenced to ski lessons <end>',
#  '<start> the jeans are blue <end>',
#  '<start> a red traffic signal <end>',
#  '<start> this is a dougnut <end>',
#  '<start> pitcher preparing to throw <end>',
#  '<start> scissors with orange handle <end>',
#  '<start> three people in a kitchen <end>',
#  '<start> toilet fixture in a bathroom <end>',
#  '<start> a fountain squirting water <end>',
#  '<start> a left teddy bear eye <end>',
#  '<start> silver car on the street <end>',
#  '<start> plane <end>',
#  '<start> woman with large blue bag <end>',
#  '<start> young man playing tennis <end>',
#  '<start> a pink sign on the wall <end>',
#  '<start> a white frisbee flying through the air <end>',
#  '<start> a group of giraffes <end>',
#  '<start> the silver white chair <end>',
#  '<start> a man riding a motorcycle <end>',
#  '<start> foamy wave like water <end>',
#  ...]

# %%
target_val
# Out:
# ['<start> यह आकाश है <end>',
#  '<start> बैंगनी और सफेद जूते के साथ लड़का <end>',
#  '<start> डैपर लाल टोपी पहने हुए आदमी <end>',
#  '<start> हरे रंग के पत्ते <end>',
#  '<start> एक धावक पहले बेस से आगे निकल गया <end>',
#  '<start> एक लाल रंग की ट्रेन <end>',
#  '<start> अंधेरे लाल इमारत पर विचलित <end>',
#  '<start> आदमी पर काला सूट जैकेट <end>',
#  '<start> बड़ा धूसर भारतीय हाथी <end>',
#  '<start> आदमी के पास एक अंगूठी है <end>',
#  '<start> लड़की ने हार पहना हुआ है <end>',
#  '<start> बोरहोल से पानी खींचता आदमी <end>',
#  '<start> सड़क संकेत <end>',
#  '<start> इमारत पर खिडकि <end>',
#  '<start> मैदान में बैंगनी फूलों के शीर्ष <end>',
#  '<start> फोन पकड़े हुए एक महीला <end>',
#  '<start> सफेद प्लग के साथ काले आइपॉड <end>',
#  '<start> ज़ेबरा पर धारियाँ <end>',
#  '<start> काले जैतून का एक कटा हुआ टुकड़ा <end>',
#  '<start> गाय लेटी हुई थी <end>',
#  '<start> लकड़ी के स्लेट के साथ लकड़ी की बेंच <end>',
#  '<start> यह एक इमारत है <end>',
#  '<start> महिलाएं कुर्सी पर बैठी हैं <end>',
#  '<start> प्लेट पर कटा हुआ लाल टमाटर <end>',
#  '<start> दो जर्सी पर लिखा गया है <end>',
#  '<start> यह एक शौचालय धनुष है <end>',
#  '<start> हाइड्रेंट पीला है <end>',
#  '<start> एक मेज पर बैठे लोग <end>',
#  '<start> ब्लू सर्फ बोर्ड <end>',
#  '<start> जिराफ के पास धातु का पिंजरा <end>',
#  '<start> पानी का उथला शरीर <end>',
#  '<start> लोगों का एक समूह <end>',
#  '<start> टेबल पर फोन <end>',
#  '<start> नाव पर कांच की खिड़की <end>',
#  '<start> रेलगाड़ी पर ट्रेन <end>',
#  '<start> एक मेज पर एक टीव <end>',
#  '<start> एक चमकदार नीली कॉफी मग <end>',
#  '<start> बाथरूम में दो महिलाएं <end>',
#  '<start> टेनिस खिलाड़ी की लाल टोपी <end>',
#  '<start> एक छोटा लड़का किताब पढ़ रहा है <end>',
#  '<start> आकाश का हिस्सा <end>',
#  '<start> झील के निकट पक्षी <end>',
#  '<start> एक लाल बाइक <end>',
#  '<start> एक आदमी पतंग उड़ाता है <end>',
#  '<start> आंशिक रूप से कुकी को एक प्लेट पर खाया <end>',
#  '<start> पेड़ों पर हरे पत्ते <end>',
#  '<start> स्क्रीन पर सफेद पैच <end>',
#  '<start> बिल्ली का चेहरा <end>',
#  '<start> एक मंजिल का हिस्सा <end>',
#  '<start> एक माउस शर्ट पर मुद्रित है <end>',
#  '<start> बैठने के लिए एक बेंच <end>',
#  '<start> इमारत के किनारे पर एक दीवार <end>',
#  '<start> कस्टम पहने हुए एक व्यक्ति <end>',
#  '<start> जीभ वाले दो कुत्ते दिखाई दिए <end>',
#  '<start> यह आकाश है <end>',
#  '<start> मेज पर चाकू <end>',
#  '<start> पौधे पर हरी पत्ती <end>',
#  '<start> जिराफ की पूंछ बाहर चिपकी हुई <end>',
#  '<start> ट्रे में गोली मार दी <end>',
#  '<start> आदमी स्कीइंग कर रहा है <end>',
#  '<start> यह एक टायर है <end>',
#  '<start> एक आदमी के चेहरे पर गहरे धूप के चश्मे <end>',
#  '<start> दो लोग गॉगल पहने हुए हैं <end>',
#  '<start> मेज पर बैठे महिला <end>',
#  '<start> गले में नीला आंगन <end>',
#  '<start> दो मेल बॉक्स की तस्वीर <end>',
#  '<start> स्केटबोर्ड वाला आदमी <end>',
#  '<start> भेड़ों के आगे भेड़ <end>',
#  '<start> बर्फ पर स्की पर महिला <end>',
#  '<start> काउंटर पर बैठा भूरा टेडी भालू <end>',
#  '<start> तीन काले तकिए <end>',
#  '<start> पानी में छोटा बत्तख का बच्चा <end>',
#  '<start> यह एक आदमी है <end>',
#  '<start> व्यक्ति खड़ा है <end>',
#  '<start> एक टेबल सीन <end>',
#  '<start> सर्फबोर्ड ले जाने वाला आदमी <end>',
#  '<start> पहाड़ की चोटी पर बर्फ <end>',
#  '<start> शॉट में पक्षी <end>',
#  '<start> यह एक आदमी है <end>',
#  '<start> हाथी समाशोधन में खड़ा है <end>',
#  '<start> घड़ी पर यूडी <end>',
#  '<start> पिज्जा का एक टुकड़ा खा रही महिला <end>',
#  '<start> सर्विसमैन एक लाइन में खड़ा है <end>',
#  '<start> एक व्यक्ति का सिर <end>',
#  '<start> भालू एक पेड़ में ऊपर है <end>',
#  '<start> हल्के नीले तकिया मामले <end>',
#  '<start> यह आकाश है <end>',
#  '<start> शर्ट पीली है <end>',
#  '<start> यह एक तस्वीर है <end>',
#  '<start> पीला और सफेद दांत <end>',
#  '<start> ये तीन लोग हैं <end>',
#  '<start> गुलाबी दीवार पर सफेद खिड़की <end>',
#  '<start> एक वाहन स्लश से गुजर रहा है <end>',
#  '<start> यह एक ज़ेबरा है <end>',
#  '<start> पानी में लाल गाय <end>',
#  '<start> दो लकड़ी के बीच कुर्सियाँ <end>',
#  '<start> भूरे हाथियों का इकट्ठा होना <end>',
#  '<start> एक ग्रे पार्किंग मीटर <end>',
#  '<start> कुछ समुद्र तट कुर्सियों पर एक पीला छाता <end>',
#  '<start> मेज नीली है <end>',
#  '<start> एक टॉवर पर घड़ी <end>',
#  '<start> सफेद मे महिला <end>',
#  '<start> रेत में खड़ी एक सर्बोर्ड के साथ महिला <end>',
#  '<start> यह एक महिला है <end>',
#  '<start> हेलमेट पहने हुए आदमी <end>',
#  '<start> यह एक ट्रेन है <end>',
#  '<start> मोटरसाइकिल का सामने का पहिया <end>',
#  '<start> वह एक बल्लेबाज है <end>',
#  '<start> हवाई जहाज लैंडिंग गियर <end>',
#  '<start> लकड़ी का छोटा भूरा तख़्त <end>',
#  '<start> टोपी पहने बिल्ली <end>',
#  '<start> तीन सर्फर <end>',
#  '<start> यह एक घोड़ा है <end>',
#  '<start> पीठ में ईंट ओवन <end>',
#  '<start> एक ज़ेबरा केंद्र फ़ोकस है <end>',
#  '<start> डेस्क पर कीबोर्ड <end>',
#  '<start> शर्ट काली है <end>',
#  '<start> हरी पकी हुई ब्रोकली <end>',
#  '<start> एक कंप्यूटर स्क्रीन | <end>',
#  '<start> बेस बॉल खेलने वाले लड़के <end>',
#  '<start> सड़क पर पुराने जमाने की कार <end>',
#  '<start> बिस्तर पर बैठा एक बच्चा <end>',
#  '<start> स्केटिंग के लिए एक बोर्ड पर व्यक्ति <end>',
#  '<start> यह एक टेडी बियर है <end>',
#  '<start> ब्लैक मोटरसाइकिल रेसिंग हेलमेट <end>',
#  '<start> यह घास है <end>',
#  '<start> पिज्जा स्पैटुला तवे पर <end>',
#  '<start> एक शर्ट का हिस्सा <end>',
#  '<start> कोर्ट पर सफेद टेनिस नेट <end>',
#  '<start> फुटपाथ पर व्यक्ति <end>',
#  '<start> बेंच खाली है <end>',
#  '<start> हवा में एक स्नोबोर्डर <end>',
#  '<start> टेनीस कोर्ट पर मैन स्टैण्डिंग <end>',
#  '<start> पानी पर एक सेलबोट <end>',
#  '<start> हवा में सफेद फ्रिसबी <end>',
#  '<start> सोफ़ा लाल है <end>',
#  '<start> एक बड़ा नीला और सफेद तंबू <end>',
#  '<start> लड़का साइकिल पर <end>',
#  '<start> उस पर एक चेहरे के साथ एक लाल और सफेद टी शर्ट <end>',
#  '<start> काले और सफेद संकेत <end>',
#  '<start> बेंच पर स्थित एक प्लैक <end>',
#  '<start> भूरा घोड़ा क्षेत्र में <end>',
#  '<start> भवन के ऊपर तीन घंटियाँ <end>',
#  '<start> एक स्केटबोर्ड पर लड़का <end>',
#  '<start> एक चम्मच पकड़े लड़का <end>',
#  '<start> कंप्यूटर लोगो चमक रहा है <end>',
#  '<start> पीले केले का गुच्छा <end>',
#  '<start> कटोरा नीला है <end>',
#  '<start> एक बड़ी प्यारे बिल्ली <end>',
#  '<start> बस पर अंकुश लगाया <end>',
#  '<start> पृष्ठभूमि में एक पुरानी लकड़ी की इमारत है <end>',
#  '<start> बाहर एक दृश्य <end>',
#  '<start> एक काले सूट और नीली शर्ट में खड़ा आदमी <end>',
#  '<start> यह आकाश है <end>',
#  '<start> उज्ज्वल सफेद पालकी अंकुश के पास खड़ी <end>',
#  '<start> शॉर्ट्स नीले हैं <end>',
#  '<start> एक स्केटबोर्ड पर सवार आदमी <end>',
#  '<start> जलमार्ग पर पुल पार करना <end>',
#  '<start> हवा में स्केटबोर्ड <end>',
#  '<start> साफ और नीले रंग की प्लास्टिक की पानी की बोतल <end>',
#  '<start> सलाद पत्ता पर डिल अचार भाला आराम <end>',
#  '<start> इतालवी ब्रेड का टुकड़ा <end>',
#  '<start> किसी भवन के किनारे की एक दीवार <end>',
#  '<start> सूटकेस के चारों ओर जिपर <end>',
#  '<start> एक बड़ी फ़्रेमयुक्त ड्राइंग <end>',
#  '<start> दो लोग एक सम्मेलन में हैं <end>',
#  '<start> टॉवर के किनारे घड़ी <end>',
#  '<start> इस पर संकेतों के साथ प्रकाश पोस्ट <end>',
#  '<start> एक साथ भरवां भालू <end>',
#  '<start> चॉकलेट फ्रॉस्टिंग के साथ जन्मदिन का केक <end>',
#  '<start> दीवार पर एक बड़ी तस्वीर <end>',
#  '<start> एक स्केटर आंकड़ा <end>',
#  '<start> सड़क पर दो तीर <end>',
#  '<start> ज़ेबरा का एक बड़ा समूह <end>',
#  '<start> ट्रेन काली है <end>',
#  '<start> मग पर संभाल <end>',
#  '<start> बोनी गाय का दूध <end>',
#  '<start> श्वेत डिश का हिस्सा <end>',
#  '<start> सड़क पर एक वाहन <end>',
#  '<start> एक साइकिल चालक नीचे बाइक पथ को ज़ूम कर रहा है <end>',
#  '<start> पानी में प्रतिबिंब <end>',
#  '<start> बहुत पुराना कोक ट्रक <end>',
#  '<start> रोशन हरी ट्रैफिक लाइट <end>',
#  '<start> लैपटॉप कीबोर्ड पर बैठे बिल्ली का बच्चा <end>',
#  '<start> एक पीला विमान घास में खड़ा है <end>',
#  '<start> नाव के किनारे सफेद लेखन <end>',
#  '<start> पानी में छोटे छोटे दाने <end>',
#  '<start> तलवार से केक काटती महिला <end>',
#  '<start> चमकदार लाल पैरों वाला सफेद पक्षी <end>',
#  '<start> आदमी सर्फ़बोर्ड पर है <end>',
#  '<start> स्टोर में एक खिड़की है <end>',
#  '<start> एक दीवार पर छोटे भूरे रंग की ईंट <end>',
#  '<start> जमीन पर रखा हुआ <end>',
#  '<start> बर्फ पर एक व्यक्ति की छाया <end>',
#  '<start> सड़क पर एक टो ट्रक <end>',
#  '<start> सड़क के साथ साथ लैंपो का शृंखला <end>',
#  '<start> हाथी की सूंड <end>',
#  '<start> धूसर रंग के ईंट फ़ुटपाथ <end>',
#  '<start> धातु नुकीला बाड़ <end>',
#  '<start> अग्रभूमि में एक युवा लड़का <end>',
#  '<start> उठाया शौचालय के साथ सफेद शौचालय <end>',
#  '<start> बैंगनी शर्ट में आदमी <end>',
#  '<start> ट्रैफिक कंट्रोल सिग्नल लाइट <end>',
#  '<start> एक दूसरे के पास रेल की पटरियों के कई सेट <end>',
#  '<start> समुद्र तट पर लड़की <end>',
#  '<start> एक मार्ग के शीर्ष पर एक रासप्बरी <end>',
#  '<start> भूरे बालों के साथ सुंदर छोटी लड़की <end>',
#  '<start> आदमी की गोद में बिल्ली है <end>',
#  '<start> आसमान साफ \u200b\u200bऔर नीला है <end>',
#  '<start> फोन आदमी के कान पर है <end>',
#  '<start> यह एक अंडा है <end>',
#  '<start> पॉट में सब्जियां और मक्खन <end>',
#  '<start> आकाश में कुछ बादल है <end>',
#  '<start> बाइक पीली है <end>',
#  '<start> आदमी ग्रे मोजे पहने हुए है <end>',
#  '<start> रेत में बूगी बोर्ड <end>',
#  '<start> एक काली स्केटबोर्ड पर सवार बिल्ली <end>',
#  '<start> एक सफेद पोस्ट <end>',
#  '<start> एक घड़ी टावर के साथ बड़ी इमारत <end>',
#  '<start> यह एक भेड़ है <end>',
#  '<start> एक खुरदरा पक्का मैदान <end>',
#  '<start> एक आदमी सेलफोन पर बात कर रहा है <end>',
#  '<start> एक की एक छवि <end>',
#  '<start> वे पानी में हैं <end>',
#  '<start> तन और सफेद टेडी भालू <end>',
#  '<start> कोने में टूटा हुआ शौचालय <end>',
#  '<start> एक हरे रंग की टेनिस बॉल <end>',
#  '<start> एक नीला नीला सागर <end>',
#  '<start> गाय का चेहरा <end>',
#  '<start> सिंक में नाली <end>',
#  '<start> एक विमान हवा में है <end>',
#  '<start> स्टॉप लाइट काली है <end>',
#  '<start> सोफे लाल है <end>',
#  '<start> एक पैक में एक ज़ेबरा <end>',
#  '<start> शांत पानी पर मंडराता हुआ आदमी <end>',
#  '<start> काले किनारों के साथ चांदी का माइक्रोवेव <end>',
#  '<start> एक मंच पर प्रदर्शन करते बच्चे <end>',
#  '<start> बाड़ द्वारा खड़ी एक साइकिल <end>',
#  '<start> वह शख्स टेनिस कोर्ट पर है <end>',
#  '<start> एक हाथी दिख रहा है <end>',
#  '<start> खाली ट्रेन सही पर ट्रैक करती है <end>',
#  '<start> एक व्यक्ति का सिर <end>',
#  '<start> छतरी बैंगनी है <end>',
#  '<start> एयरलाइन टर्मिनल के माध्यम से चलने वाली महिला <end>',
#  '<start> बालकनी पर पक्षी <end>',
#  '<start> एक पीला आग हाइड्रेंट <end>',
#  '<start> साइड टेबल पर दीपक <end>',
#  '<start> आदमी के हाथ में सेलफोन <end>',
#  '<start> मनुष्य एक बल्ला पकडा है | <end>',
#  '<start> फल का एक कटोरा <end>',
#  '<start> लकड़ी की बेंच पर बैठा आदमी <end>',
#  '<start> ट्रेन लाल सफेद और नीले रंग की है <end>',
#  '<start> बिस्तर पर किताब <end>',
#  '<start> एक व्यस्त सड़क <end>',
#  '<start> यह एक रसोई का चाकू है <end>',
#  '<start> तीन आयताकार ट्रेन कारें <end>',
#  '<start> कप सफेद रंग का होता है <end>',
#  '<start> एक हवाई जहाज का दरवाजा <end>',
#  '<start> ये टांगें जोड़ रहे हैं <end>',
#  '<start> एक बहुत बड़ा टॉवर <end>',
#  '<start> हरे भरे जंगल में लकड़ी की बेंच <end>',
#  '<start> घर की प्लेट पर बेसबॉल बल्लेबाज <end>',
#  '<start> युगल के हाथों में चाकू <end>',
#  '<start> एक शहर में यात्री रेल <end>',
#  '<start> मोटरसाइकिल के पहिये की बात की <end>',
#  '<start> एक प्रकाश जो चालु है <end>',
#  '<start> दस्ताने का हिस्सा <end>',
#  '<start> खाने की थाली <end>',
#  '<start> लाल और सफेद नाव <end>',
#  '<start> दो आधे कटे हुए सैंडविच <end>',
#  '<start> एक पोल पर दर्पण <end>',
#  '<start> एक आदमी सड़क पर लेट गया <end>',
#  '<start> एक घोड़ा सड़क पर चलता है <end>',
#  '<start> ऑरेंज पोस्ट पदनाम लेन <end>',
#  '<start> सूट कुर्सी में है <end>',
#  '<start> हवाई अड्डे पर खड़ी महिला <end>',
#  '<start> लाल बस पर बड़ा पीला लेखन <end>',
#  '<start> पुराने हवाई जहाज में <end>',
#  '<start> एक आदमी फुटपाथ पर चल रहा है <end>',
#  '<start> यह आकाश है <end>',
#  '<start> कुर्ता सफेद है <end>',
#  '<start> यह आकाश है <end>',
#  '<start> एक पेड़ की शाखा पर बैठे दो पक्षी <end>',
#  '<start> ब्लैक फ्राड आर्ट प्रिंट <end>',
#  '<start> समय लगभग है <end>',
#  '<start> एक डिश के किनारे <end>',
#  '<start> दो बिल्लियाँ सो रही हैं <end>',
#  '<start> आदमी लाल और सफेद स्नोजिट पहन रहा है <end>',
#  '<start> एक दूसरे के बगल में दो ज़ेबरा <end>',
#  '<start> भरवां टेडी बियर नीले रंग की कुर्सी पर बैठे <end>',
#  '<start> तस्वीर में तीन जिराफ हैं <end>',
#  '<start> कैंची की छोटी जोड़ी <end>',
#  '<start> भूरे रंग की छत वाला घर <end>',
#  '<start> एक ग्रे पर्दे के साथ एक खिड़की <end>',
#  '<start> प्लेट पर खाना <end>',
#  '<start> बाईं दीवार से बाहर गहरे नीले रंग का पर्दा <end>',
#  '<start> एक आदमी टेनिस खेल रहा है <end>',
#  '<start> स्मार्ट फोन पर हैंड टेक्सटिंग <end>',
#  '<start> एक गहरा भूरा ट्रंक है <end>',
#  '<start> लाल टीशर्ट में लड़का <end>',
#  '<start> डबल डेकर बस <end>',
#  '<start> बेसबॉल बल्लेबाज बल्लेबाजी <end>',
#  '<start> किसी ने मेज पर अपना चश्मा लगा रखा है <end>',
#  '<start> टेबल पर हरे सिरेमिक फूलदान <end>',
#  '<start> नारंगी बालों वाली महिला <end>',
#  '<start> क्रॉस कंट्री रेसर <end>',
#  '<start> इसके माध्यम से स्लैश के साथ लाल सर्कल <end>',
#  '<start> मानव का बाल काला है | <end>',
#  '<start> एक छोटा बच्चा <end>',
#  '<start> घड़ी पर काला रोमन अंक <end>',
#  '<start> पूरे कमरे में टीवी <end>',
#  '<start> अमेरिकी झंडा है <end>',
#  '<start> आदमी लाल कोट पहने है <end>',
#  '<start> कुत्ते और पीले फ्रिस्\u200dबि <end>',
#  '<start> चमकीले पीले लॉन की कुर्सी <end>',
#  '<start> हवाई जहाज की पूंछ <end>',
#  '<start> लाल और सफेद स्टॉप साइन <end>',
#  '<start> कार में रोशनी है <end>',
#  '<start> दिन के दौरान एक दृश्य <end>',
#  '<start> आकाश में लाल तार <end>',
#  '<start> पृष्ठभूमि में नीला आकाश <end>',
#  '<start> एक खिड़की में दो बिल्लियां <end>',
#  '<start> गाय चित्तीदार है <end>',
#  '<start> लोग विचार विमर्श कर रहे हैं <end>',
#  '<start> गहरे नीले और सफेद टेनिस कोर्ट <end>',
#  '<start> खिड़कियों के चारों ओर लाल शटर के साथ एक सफेद इमारत <end>',
#  '<start> गंदे अप्रभावित शौचालय <end>',
#  '<start> बादल आकाश का हिस्सा <end>',
#  '<start> गोरे रंग की महिला <end>',
#  '<start> पीठ में जिराफ का बायां सींग <end>',
#  '<start> नंगे पैर सर्फिंग वाला एक युवक <end>',
#  '<start> समुद्र तट पर चलते हुए युगल <end>',
#  '<start> लड़का हवा में उछलता है <end>',
#  '<start> त्रिकोणीय सड़क संकेत <end>',
#  '<start> सफेद प्लेट पर पके हुए सेम <end>',
#  '<start> आदमी एक साइकिल की सवारी कर रहा है <end>',
#  '<start> सफेद संभाल के साथ चाकू <end>',
#  '<start> आदमी के बगल में बैठी बाइक <end>',
#  '<start> खेत में गाय <end>',
#  '<start> पिज्जा आधा खाया जाता है <end>',
#  '<start> समुद्र के नीले और सफेद किताब <end>',
#  '<start> एक पीले रंग की टेनिस बॉल <end>',
#  '<start> यह एक केक है <end>',
#  '<start> एक व्यक्ति जो पैरासेलिंग कर रहा है <end>',
#  '<start> खाने की थाली <end>',
#  '<start> बास्केट नीला है <end>',
#  '<start> अक्षर काला है <end>',
#  '<start> महिला के सुनहरे बाल हैं <end>',
#  '<start> आदमी बैग ले जाता है <end>',
#  '<start> एक फुटपाथ पर अग्नि हाइड्रेंट <end>',
#  '<start> बहुत सारी भेड़ <end>',
#  '<start> बपृष्ठभूमि में उड़ने वाला अमेरिकी ध्वज <end>',
#  '<start> एक रेस्तरां में लोग <end>',
#  '<start> तौलिया एक स्टोव हत्था पर लटका <end>',
#  '<start> यह एक ग्रामीण सेटिंग में लिया जाता है <end>',
#  '<start> बिल्ली की पूंछ का किनारा <end>',
#  '<start> भू्रा टेडी भालू | <end>',
#  '<start> हाथी <end>',
#  '<start> ट्राली के किनारे नंबर <end>',
#  '<start> चार आयताकार सजाए गए पैनल <end>',
#  '<start> टोकरी में एक पेस्ट्री <end>',
#  '<start> एक पैसा लोफर <end>',
#  '<start> लाल बस सड़क पर है <end>',
#  '<start> एक दीपक जिसे चालू किया गया है <end>',
#  '<start> केक का एक छोटा टुकड़ा <end>',
#  '<start> भूरे पौधे का तना <end>',
#  '<start> एक जमीन का हिस्सा <end>',
#  '<start> विमान का लोगो <end>',
#  '<start> सफेद शर्ट में आदमी फुटपाथ के नीचे चल रहा है <end>',
#  '<start> बेसबॉल खेल खेल रहा बच्चा <end>',
#  '<start> एक आदमी एक गिलास पकड़े सूट में है <end>',
#  '<start> एक अनाम आदमी अपनी अंगुली के नाखूनों पर उठाता हुआ <end>',
#  '<start> एक आदमी जींस पहने हुए <end>',
#  '<start> घास का हिस्सा <end>',
#  '<start> पिज़्ज़ा पर पनीर का ढेर <end>',
#  '<start> काले और सफेद ज़ेबरा एक तुला गर्दन के साथ <end>',
#  '<start> एक व्यक्ति खेल रहा है <end>',
#  '<start> सेब पर चाकू का झुकाव <end>',
#  '<start> हाथियों का चलना <end>',
#  '<start> रेफ्रिजरेटर मैग्नेट का संग्रह <end>',
#  '<start> टावर बिल्डिंग के किनारे घड़ी <end>',
#  '<start> एक ट्रेन में एक खिड़की <end>',
#  '<start> व्यक्ति के सिर पर हेलमेट <end>',
#  '<start> क्षेत्र में घोड़ों का एक समूह <end>',
#  '<start> पानी के पास हरी पतंग <end>',
#  '<start> एक भेड़ की पूंछ <end>',
#  '<start> एक डिस्पेंसर कटोरे में मीठा और कम <end>',
#  '<start> एक आदमी शराब पी रहा है <end>',
#  '<start> लंबा भूरा लकड़ी का पोल <end>',
#  '<start> टेनिस कोर्ट नीला है <end>',
#  '<start> इसमें तरल के साथ साफ कंटेनर <end>',
#  '<start> चेरी जाम का एक जार <end>',
#  '<start> यह एक घड़ी है <end>',
#  '<start> कंप्यूटर पर झुका व्यक्ति | <end>',
#  '<start> एक छोटी लाल चिड़िया <end>',
#  '<start> एक लंबी डामर सड़क <end>',
#  '<start> एक गहरा लाल डोंगी <end>',
#  '<start> समुद्र तट पर घोड़ों की सवारी करने वाले लोग <end>',
#  '<start> एक साफ और नीला आकाश <end>',
#  '<start> चार पशुधन क्षेत्र मे <end>',
#  '<start> एक पोशाक पर आँखें <end>',
#  '<start> स्टोव पर घड़ी <end>',
#  '<start> काले और सफेद सीगल <end>',
#  '<start> एक स्टैंड पर एक आईफोन <end>',
#  '<start> सड़क पर एक व्यक्ति <end>',
#  '<start> चश्मा पहने एक युवा लड़का <end>',
#  '<start> एक ग्रे और सफेद बिल्ली <end>',
#  '<start> फ्राई कॉफी से भरा कॉफी कप <end>',
#  '<start> लोग खड़े होकर वीडियो गेम खेल रहे हैं <end>',
#  '<start> हाथ जोड़कर बैठा बच्चा <end>',
#  '<start> बेंच पुरानी है <end>',
#  '<start> जिराफ का सिर और गर्दन <end>',
#  '<start> थाली पर तला हुआ भोजन <end>',
#  '<start> लहर विशाल है <end>',
#  '<start> बाइक के सामने टायर <end>',
#  '<start> पानी की सतह पर उड़ने वाले पक्षी <end>',
#  '<start> वर्दी मे एक व्यक्ति <end>',
#  '<start> यह एक व्यक्ति है <end>',
#  '<start> काठी काला है <end>',
#  '<start> चट्टानों में दो हाथियाँ <end>',
#  '<start> पक्षियों से घिरा आकाश में हवाई जहाज <end>',
#  '<start> कार्डबोर्ड कॉफी कप आस्तीन <end>',
#  '<start> ये ट्रेनें हैं <end>',
#  '<start> जमीन पर एक आदमी की छाया <end>',
#  '<start> नीले आकाश में सफेद बादल <end>',
#  '<start> काले सूट वाला आदमी <end>',
#  '<start> एक आदमी पानी स्कीइंग <end>',
#  '<start> एक मशरूम और लाल मिर्च पिज्जा <end>',
#  '<start> डेस्क पर ग्रे और नारंगी बिल्ली <end>',
#  '<start> ट्रक सड़क पर खड़ा था <end>',
#  '<start> गली चिह्न नीला है <end>',
#  '<start> अर्ध ट्रक <end>',
#  '<start> बिक्री के लिए पीला गुच्छा <end>',
#  '<start> एक ज़ेबरा घास पर चर रहा है <end>',
#  '<start> मनुष्य सर्फ़बोर्ड पर है <end>',
#  '<start> पानी में आदमी <end>',
#  '<start> रोइंग के लिए सफेद पैडल <end>',
#  '<start> आदमी के काले बाल हैं <end>',
#  '<start> एक साथ सात जिराफ <end>',
#  '<start> महिला ने नीली जींस पहन रखी है <end>',
#  '<start> व्यक्ति पतंग उड़ा रहा है <end>',
#  '<start> छोटे पत्थर की कुटिया <end>',
#  '<start> एक हवाई जहाज <end>',
#  '<start> आदमी अपने फोन को पकड़े हुए <end>',
#  '<start> एक जिराफ पर मूंछ <end>',
#  '<start> एक काला इलेक्ट्रिक ब्लेंडर <end>',
#  '<start> भेड़ की ओर इशारा करती छोटी लड़की <end>',
#  '<start> चादरें सफेद हैं <end>',
#  '<start> सफेद ट्रिम के साथ लाल स्टॉप साइन <end>',
#  '<start> नाक भूरी है <end>',
#  '<start> पुराने फैशन सूटकेस का एक बहुत बड़ा समूह <end>',
#  '<start> काउंटरटॉप खाली है <end>',
#  '<start> ये ताश खेल रहे हैं <end>',
#  '<start> ये संकेत हैं <end>',
#  '<start> एक रसोई काउंटरटॉप <end>',
#  '<start> बैंगनी रंग की शॉर्ट्स पहने लड़की <end>',
#  '<start> सॉस में ढकी प्लेट पर मछली <end>',
#  '<start> एक पहाड़ का प्रतिबिंब <end>',
#  '<start> एक भूरी आंख वाला कुत्ता <end>',
#  '<start> लड़का सुन्नचित्र पहन रहा है <end>',
#  '<start> सड़क पर खड़ा एक सफेद ट्रक <end>',
#  '<start> दो ट्रेनें एक साथ हैं <end>',
#  '<start> एक छोटा बच्चा लकड़ी की बेंच पर बैठा <end>',
#  '<start> सीट के साथ शौचालय और ढक्कन नीचे <end>',
#  '<start> आदमी नीचे बैठा है <end>',
#  '<start> जमीन पर कुछ रेल की पटरियाँ <end>',
#  '<start> बाहर की तस्वीर <end>',
#  '<start> सेब खाने के लिए कटौती <end>',
#  '<start> यादृच्छिक सामान का ढेर <end>',
#  '<start> एक धातु का खंभा <end>',
#  '<start> लाल धारी के साथ सफेद धातु का पोल <end>',
#  '<start> फोटो में एक प्लेन <end>',
#  '<start> एक सादे मैदान पर <end>',
#  '<start> जीन्स नीले हैं <end>',
#  '<start> दो लड़कियां फुटबॉल खेलती हैं <end>',
#  '<start> पुल पर लाल ट्रेन <end>',
#  '<start> आदमी बेसबॉल गेम में बल्लेबाजी कर रहा है <end>',
#  '<start> सैंडविच आधा में काटा गया <end>',
#  '<start> यह एक बेसबॉल खिलाड़ी है <end>',
#  '<start> सड़क के नीचे स्केटबोर्डिंग करते हुए व्यक्ति <end>',
#  '<start> यह एक लंबा पिज़्ज़ा है <end>',
#  '<start> चांदी की रेलिंग के बीच चलते लोग <end>',
#  '<start> अमेरिकी झंडे के साथ चांदी का झंडा पोल <end>',
#  '<start> इमारत पर हस्ताक्षर <end>',
#  '<start> यह व्यक्ति स्कीइंग कर रहा है <end>',
#  '<start> फ्लोरेंड बैंड के साथ हैट <end>',
#  '<start> घास में चलने वाला कुत्ता <end>',
#  '<start> खेल रहे लोग <end>',
#  '<start> पिज्जा के शीर्ष पर अंडे <end>',
#  '<start> पानी में खेल रहे लोग <end>',
#  '<start> तस्वीर ब्लैक एंड व्हाइट है <end>',
#  '<start> शेल्फ पर एक घड़ी <end>',
#  '<start> एक ब्राउन लैंप शेड <end>',
#  '<start> मैन स्केटबोर्ड कैरी करता है <end>',
#  '<start> भूरे लकड़ी के बेंच पानी से घिरे <end>',
#  '<start> एक रसोई काउंटर के ऊपर एक प्रकाश <end>',
#  '<start> यह एक बंदर है <end>',
#  '<start> उपकरण के साथ तालिकाओं <end>',
#  '<start> दीवार पर एक प्रकाश <end>',
#  '<start> दूरी में खाली लकड़ी की बेंच <end>',
#  '<start> पानी का भाग <end>',
#  '<start> विंडो के चारों ओर गुलाबी ट्रिम <end>',
#  '<start> एक युवा अल्पका चारे में स्थित है <end>',
#  '<start> छोटा नीला है <end>',
#  '<start> दिन के उजाले के दौरान एक समुद्र तट <end>',
#  '<start> दो लोग लिविंग रूम में हैं <end>',
#  '<start> एक पार्क वाली ग्रे कार <end>',
#  '<start> यह भेड़ का सिर है <end>',
#  '<start> जमीन पर छोटे गहरे भूरे रंग की लकड़ी की कुर्सी <end>',
#  '<start> धातु ध्रुव पर काला यातायात संकेत <end>',
#  '<start> फोटो समुद्र तट पर लिया गया <end>',
#  '<start> यह एक तस्वीर है <end>',
#  '<start> महिला एक नीले और लाल दुपट्टा पहने हुए <end>',
#  '<start> एक अंधेरे पेय से भरा कप <end>',
#  '<start> अपने बालों में ड्रेडलॉक्स के साथ आदमी <end>',
#  '<start> लड़का खेल खेलने पर आमादा हो गया <end>',
#  '<start> व्यक्ति और एक बेंच <end>',
#  '<start> सर्फर <end>',
#  '<start> एक जवान लड़की ने लाल चश्मे पहन रखे हैं <end>',
#  '<start> मेज पर माउस <end>',
#  '<start> एक व्यक्ति का सिर <end>',
#  '<start> काली भेड़ वाला आदमी <end>',
#  '<start> जन्मदिन का कुकी केक <end>',
#  '<start> एक छोटे प्यारे कुत्ते <end>',
#  '<start> दीवार पर चौकोर खिड़की <end>',
#  '<start> एक शर्ट का हिस्सा <end>',
#  '<start> व्यंजनों के साथ एक मेज <end>',
#  '<start> नीले फूलों के साथ फूलदान <end>',
#  '<start> पतंग जमीन पर है <end>',
#  '<start> समुद्र में लंबे समय तक रहने वाले सर्फर <end>',
#  '<start> दो नारंगी और सफेद शंकु <end>',
#  '<start> सड़क पर पीली लाइनें <end>',
#  '<start> एक ढलान नीचे स्कीइंग व्यक्ति <end>',
#  '<start> मैदान पर बैकबैक और बैग <end>',
#  '<start> छत में प्रकाश <end>',
#  '<start> जिराफ़ और ज़ेबरा दौर के बाड़े में <end>',
#  '<start> एक व्यक्ति का सिर <end>',
#  '<start> एक शौचालय के बगल में एक शौचालय ब्रश <end>',
#  '<start> बस क्रॉसटाउन जा रहा है <end>',
#  '<start> टेनिस खिलाड़ी रैकेट लेकर पहुंची <end>',
#  '<start> एक छोटी सी ट्रेन में बच्चा <end>',
#  '<start> एक प्लेट पर वर्णमाला <end>',
#  '<start> अपार्टमेंट का बाथरूम <end>',
#  '<start> एक सर्फ़बोर्ड पर आदमी <end>',
#  '<start> छाता खुला है <end>',
#  '<start> टमाटर के बगल में सेब है <end>',
#  '<start> पृष्ठभूमि में टूटा हुआ पेड़ <end>',
#  '<start> लाल टोपी में महिला <end>',
#  '<start> आदमी के पास स्की बूट हैं <end>',
#  '<start> एक आदमी खाना खा रहा है <end>',
#  '<start> पानी में सफेद लहर <end>',
#  '<start> हवा में एक टेनिस बॉल <end>',
#  '<start> काले अक्षरों के साथ बड़ा पीला चिन्ह <end>',
#  '<start> सजावटी गोल बाथरूम सिंक <end>',
#  '<start> गेंद मार करने के लिए तैयार <end>',
#  '<start> एक फेल्ड में कई गाय <end>',
#  '<start> घास उग आई है <end>',
#  '<start> किसी व्यक्ति का सर <end>',
#  '<start> सफेद और नीली किताब <end>',
#  '<start> औरत पर बादाम के आकार की आँखें <end>',
#  '<start> घोड़े के सिर पर बाल <end>',
#  '<start> फर्श भूरा है <end>',
#  '<start> एक बेंच पर बैठा बूढ़ा आदमी <end>',
#  '<start> एक विमान का पंख तन और लाल है <end>',
#  '<start> टेनिस कोर्ट पर एक महिला <end>',
#  '<start> एक महिला का सिर <end>',
#  '<start> एक लड़की का सफेद साक <end>',
#  '<start> सांवले बालों वाली महिला <end>',
#  '<start> यह एक ज़ेबरा है <end>',
#  '<start> अग्रभूमि में एक बैल के साथ समुद्र तट पर लोग <end>',
#  '<start> क्या सीमेंट पर काले मल के नीचे काला मल लगा सकता है <end>',
#  '<start> मेज पर केक है <end>',
#  '<start> दिन के आसमान का नीला <end>',
#  '<start> घोड़ा <end>',
#  '<start> कपड़े पर ब्रोकोली मुकुट <end>',
#  '<start> रद्दी का एक प्लास्टिक बैग <end>',
#  '<start> एक सफेद और नीली बस <end>',
#  '<start> स्ट्रीट लाइट के चारों ओर कांच लगे हुए हैं <end>',
#  '<start> दो लोग घास में खड़े होते हैं <end>',
#  '<start> काला गीला हाथी नदी में चलते हुए <end>',
#  '<start> महिला फोन पर है <end>',
#  '<start> पीठ में धूसर धुआँ <end>',
#  '<start> तीन हैंगिंग लाइट्स <end>',
#  '<start> फुल काँच के वास्तु मे है <end>',
#  '<start> काला और सफेद तस्वीर <end>',
#  '<start> मोटरसाइकिल खड़ी है <end>',
#  '<start> एक काली बिल्ली जिसके पैर में खिंचाव था <end>',
#  '<start> यह आकाश है <end>',
#  '<start> एक रंगीन छाता <end>',
#  '<start> सैंडविच का टुकड़ा <end>',
#  '<start> बिस्तर में लड़की <end>',
#  '<start> केबल कार शेड्यूल बोर्ड <end>',
#  '<start> स्केटबोर्ड पर एक पैर के साथ युवक <end>',
#  '<start> कप में पीला टूथब्रुश <end>',
#  '<start> सेल फोन छोड़ने वाली कांच के गिलास का निर्माण <end>',
#  '<start> सफेद कतरनी बेडरूम के पर्दे <end>',
#  '<start> एक सफेद कार्डिगन में लड़की <end>',
#  '<start> एक सफेद बर्फ क्षेत्र <end>',
#  '<start> कुछ बादलों के साथ एक नीला आकाश <end>',
#  '<start> मेज पर सफेद कोलंडर <end>',
#  '<start> हाथ में छिड़का हुआ पेस्ट्री <end>',
#  '<start> घोड़े का सिर <end>',
#  '<start> ग्रह सफेद है <end>',
#  '<start> आयताकार पिज्जा <end>',
#  '<start> काले चेहरे वाली एक भूरी गाय <end>',
#  '<start> इमारत पर हस्ताक्षर करें <end>',
#  '<start> एक हरी पेडेस्ट्रियन रोशनी <end>',
#  '<start> बिस्तर पर बैठे बच्चे <end>',
#  '<start> एक सुरक्षा प्रकाश के साथ एक सड़क संकेत <end>',
#  '<start> कपड़े हरे और पीले होते हैं <end>',
#  '<start> कंक्रीट पर बैठा आदमी <end>',
#  '<start> भूरे रंग की घड़ी टॉवर <end>',
#  '<start> नारंगी और सफेद बाधाएँ <end>',
#  '<start> बाहर बैठी महिला <end>',
#  '<start> सड़क पर वाहन <end>',
#  '<start> रिमोट नीली बत्ती के साथ <end>',
#  '<start> बेज दरवाजा जो खुला है <end>',
#  '<start> लाल तकिया <end>',
#  '<start> एक खेत में घोड़ों का समूह <end>',
#  '<start> इमारत के शीर्ष पर सफेद टावर <end>',
#  '<start> छोटे बाल के साथ सुंदर बच्चा लड़का <end>',
#  '<start> व्यक्ति टेनिस खेल रहा है <end>',
#  '<start> एक लड़की अपने सिर पर आइटम रखकर चल रही है <end>',
#  '<start> आदमी सन ग्लासेस पहने हुए है <end>',
#  '<start> किसी व्यक्ति का सर <end>',
#  '<start> एक पीले रंग की सर्फ़बोर्ड ले जाने वाला व्यक्ति <end>',
#  '<start> पहाड़ों के ऊपर हल्का नीला आकाश <end>',
#  '<start> लाल डबल डेकर बस <end>',
#  '<start> दूर में दो जिराफ <end>',
#  '<start> फूलों के साथ एक स्पष्ट फूलदान <end>',
#  '<start> लाल और सफेद सीवीएस फार्मेसी चिह्न | <end>',
#  '<start> वीप्ड क्रीम पर पुदीने की पत्ती <end>',
#  '<start> सैन डिएगो कन्वेंशन सेंटर के लिए साइन इन करें <end>',
#  '<start> सही पर अंधेरे चमड़ी आदमी <end>',
#  '<start> बहुत सी मुर्गियों वाली वृक्ष <end>',
#  '<start> जंगली में चल रहे हैं <end>',
#  '<start> कुछ पटरियों के साथ एक ट्रेन की सवारी <end>',
#  '<start> तनों के साथ गाजर का गुच्छा <end>',
#  '<start> व्यक्ति टेनिस खेल रहा है <end>',
#  '<start> ट्रैफिक सिग्नल पर हरी बत्ती <end>',
#  '<start> एक दीवार पर चित्र <end>',
#  '<start> एक सफेद प्रतीक के साथ एक जंग खाए दरवाजे <end>',
#  '<start> चिड़िया का पंख <end>',
#  '<start> सफेद निशान देखा गया है <end>',
#  '<start> एक काला पिकअप ट्रक <end>',
#  '<start> टेनिस रैकेट पकड़े महिला <end>',
#  '<start> एक ट्रक पर लाल और सफेद रोशनी <end>',
#  '<start> ध्रुव से जुड़ा दिशा संकेत <end>',
#  '<start> एक आदमी का सिर <end>',
#  '<start> अक्षर काला है <end>',
#  '<start> यह एक महिला है <end>',
#  '<start> एक कुत्ता <end>',
#  '<start> यह एक मेज है <end>',
#  '<start> टैन मोटरसाइकिल पर व्यक्ति <end>',
#  '<start> मोटरसाइकिल पर सवार एक व्यक्ति <end>',
#  '<start> जमीन में भूरा घोड़ा <end>',
#  '<start> एक नियंत्रण पकड़े हाथ <end>',
#  '<start> दो विमान ऊपर जा रहे हैं <end>',
#  '<start> बड़े लाल स्टॉप साइन <end>',
#  '<start> पानी का भाग <end>',
#  '<start> आदमी सफेद टेनिस खेल रहा है <end>',
#  '<start> छत से निलंबित प्रकाश <end>',
#  '<start> साइन के ऊपर लाल बत्ती <end>',
#  '<start> एक सुंदर सफेद दीवार <end>',
#  '<start> एक बेंच में छेद <end>',
#  '<start> एक छोटा ले जाने वाला बैग <end>',
#  '<start> यह हाथी चल रहा है <end>',
#  '<start> टिन पन्नी कंटेनर <end>',
#  '<start> बिल्ली का पंजा सफेद होता है <end>',
#  '<start> किसी भवन के किनारे की एक दीवार <end>',
#  '<start> रंगीन बाइबिल ट्रक <end>',
#  '<start> लोग घुटने टेकते हुए <end>',
#  '<start> बिल्लियाँ दालान में लेटी थीं <end>',
#  '<start> तड़का हुआ और उथली बड़ी झील <end>',
#  '<start> एक व्यक्ति जो वाहन के बगल में खड़ा होता है | <end>',
#  '<start> एक लाल स्टॉप संकेत <end>',
#  '<start> चारागाह में चरने वाले तीन घोड़े <end>',
#  '<start> योग बॉल गुलाबी है <end>',
#  '<start> चमकीला पीला हिम जैकेट <end>',
#  '<start> पोलारोबिस टेबल पर हैं <end>',
#  '<start> सफेद कुत्ता भाग रहा है <end>',
#  '<start> खिलाड़ी पर हेलमेट <end>',
#  '<start> एक बड़ी पीली बस <end>',
#  '<start> एक बर्फीली पहाड़ी परिदृश्य <end>',
#  '<start> एक बर्फ का स्थान <end>',
#  '<start> मोटरसाइकिल के साइड पैनल पर लोगो <end>',
#  '<start> एक स्टॉप साइन <end>',
#  '<start> एक टीवी स्क्रीन एक वीडियो गेम प्रदर्शित करता है <end>',
#  '<start> एक महासागर का हिस्सा <end>',
#  '<start> यह एक ज़ेबरा है <end>',
#  '<start> एक स्कीयर हवा में है <end>',
#  '<start> बिस्तर के ऊपर तकिया <end>',
#  '<start> एक नारंगी का दृश्य <end>',
#  '<start> एक ट्रेन स्टेशन में एक ट्रेन <end>',
#  '<start> सफेद बिल्ली <end>',
#  '<start> पेड़ का रंग हरा होता है <end>',
#  '<start> सूखे तन और हरी घास पर बाधा कोर्स <end>',
#  '<start> चेहरे पर काले चश्मे <end>',
#  '<start> यह एक मोटर घर के अंदर का द्रिशय है <end>',
#  '<start> चादर का भाग <end>',
#  '<start> तर्पण पर हवाई जहाज <end>',
#  '<start> जिराफ की पीठ <end>',
#  '<start> ट्रेन प्लेटफार्म पर बर्फ <end>',
#  '<start> एक नारंगी रंग की आग हाइड्रांट <end>',
#  '<start> गली में खड़ी एक काली सींग वाली गाय <end>',
#  '<start> तीन ज़ेबरा एक साथ चलते हैं <end>',
#  '<start> मेज पर विभिन्न प्रकार के पिज्जा <end>',
#  '<start> इमारत के किनारे लटकता हुआ अमेरिकी झंडा <end>',
#  '<start> लड़की के बाल सुनहरे हैं <end>',
#  '<start> पार्किंग का ग्रे पार्किंग मीटर <end>',
#  '<start> व्यक्ति एक कुर्ता पहन रहा है <end>',
#  '<start> एक केला मेज पर है <end>',
#  '<start> एक औरत <end>',
#  '<start> एक छोटे से बाथरूम की तस्वीर <end>',
#  '<start> काले और नारंगी तालिका <end>',
#  '<start> पानी में दो बत्तख <end>',
#  '<start> आसमान में पतंग उड़ाना <end>',
#  '<start> सड़क पर काला ग्रेड <end>',
#  '<start> महिला एक काला कोट पहनी है <end>',
#  '<start> विमान <end>',
#  '<start> जमीन पर ट्रक <end>',
#  '<start> फल देख रहा आदमी <end>',
#  '<start> सस्टैक से आने वाला धुआं <end>',
#  '<start> इमारत के किनारे पर एक दीवार <end>',
#  '<start> ट्रेन स्टेशन पर इंतजार कर रहे लोगों का समूह <end>',
#  '<start> सड़क पर पीली अग्नि हाइड्रेंट <end>',
#  '<start> ट्रेन पर ट्रेन <end>',
#  '<start> महिला टेनिस खेल रही है <end>',
#  '<start> महिला सर्फिंग <end>',
#  '<start> पटरियों के नीचे आ रही ट्रेन <end>',
#  '<start> टोपी पर काली और नीली आँखें <end>',
#  '<start> एक नीली वैन <end>',
#  '<start> एक पानी शरीर का हिस्सा <end>',
#  '<start> हाथी के साथ खड़ा आदमी <end>',
#  '<start> प्लेटफॉर्म पर चलने वाला व्यक्ति <end>',
#  '<start> यह एक आदमी है <end>',
#  '<start> हवा में कई पतंग <end>',
#  '<start> लंबे काले रंग की टाई <end>',
#  '<start> जिराफ पानी पी रहा है <end>',
#  '<start> मोटरसाइकिल पर सवार व्यक्ति <end>',
#  '<start> एक खिड़की दासा पर भूरे रंग की टैबी बिल्ली <end>',
#  '<start> ऊंची इमारत के सामने घड़ी <end>',
#  '<start> बन पर ग्रिल्ड वेनर <end>',
#  '<start> आदमी एक मोटरसाइकिल चला रहा <end>',
#  '<start> एक सफेद संख्या <end>',
#  '<start> घर का रंग पीला होता है <end>',
#  '<start> स्त्री <end>',
#  '<start> सड़क पर सफेद घोड़ा <end>',
#  '<start> तस्वीर में घड़ी <end>',
#  '<start> ट्रैकस पर ट्रेन | <end>',
#  '<start> चेकबोर्ड के छाप वाला छोटा भूरा बस्ता <end>',
#  '<start> घर समुद्र तट पर हैं <end>',
#  '<start> एक बिल्ली की पूंछ <end>',
#  '<start> एक स्टंप पर एक पानी बोतल <end>',
#  '<start> फेराइट सफेद बिस्तर पर <end>',
#  '<start> जानवरों के साथ घूमना <end>',
#  '<start> संख्या <end>',
#  '<start> एक बहुरंग छाता <end>',
#  '<start> बच्चों के लिए टेनिस <end>',
#  '<start> मेज पर गुलाबी छतरियां <end>',
#  '<start> एक सोफे पर बैठे लोग <end>',
#  '<start> स्टोव के सामने खड़ा आदमी <end>',
#  '<start> यह एक जिराफ है <end>',
#  '<start> रिबन लाल और नीला है <end>',
#  '<start> की शैली वाला स्नो बोर्ड <end>',
#  '<start> पानी में खड़ी दो महिलाएं <end>',
#  '<start> मैन पहनें ब्राउन जूते <end>',
#  '<start> एक बड़ा गुलाबी खिड़की <end>',
#  '<start> यह व्यक्ति स्केटबोर्ड का प्रयोग कर रहा है <end>',
#  '<start> दीवार पर एक फ्रेम झुका हुआ <end>',
#  '<start> दरवाज़ा <end>',
#  '<start> एक लाल जैकेट पहनने वाला आदमी <end>',
#  '<start> एक ध्रुव पर यातायात में एक ध्रुव पर चढ़ा हुआ <end>',
#  '<start> टेनिस न्यायालय में दो महिलाएँ <end>',
#  '<start> गंदगी वाली सड़क के किनारे गाड़ी खींचता घोड़ा <end>',
#  '<start> तीन भेड़ सड़क पर चलते हुए <end>',
#  '<start> स्नोबोर्ड पर व्यक्ति <end>',
#  '<start> मेज पर कुर्सी <end>',
#  '<start> ट्रेन में ब्लैक नंबर एक <end>',
#  '<start> पुरुष टेनिस खेल रहे हैं <end>',
#  '<start> पानी की एक बोतल <end>',
#  '<start> ब्लैक एंड व्हाइट तस्वीर <end>',
#  '<start> एक घड़ी पर संख्या <end>',
#  '<start> एक स्वादिष्ट फल <end>',
#  '<start> सड़क पर कार चला रहा है <end>',
#  '<start> जिराफ लंबा खड़ा है <end>',
#  '<start> टमाटर का एक टुकड़ा <end>',
#  '<start> चिह्न सोना है <end>',
#  '<start> पानी पर एक नाव <end>',
#  '<start> मेज पर दो गिलास <end>',
#  '<start> आज कोई पहाड़ पर है <end>',
#  '<start> दो भालू आमनेसामने <end>',
#  '<start> एक मैदान का हिस्सा <end>',
#  '<start> खुले चेहरे बेकन और पनीर सैंडविच <end>',
#  '<start> एक पार्क में लकड़ी की बेंच <end>',
#  '<start> एक पेड़ पर खराब केले <end>',
#  '<start> कमरे में कुर्सी डेस्क कॉम्बो <end>',
#  '<start> जमीन धूसर है <end>',
#  '<start> आदमी बाहर सागर को देख रहा है <end>',
#  '<start> यह एक हवाई अड्डा है <end>',
#  '<start> पंख शुतुरमुर्ग सही देख रहे हैं <end>',
#  '<start> आकाश का हिस्सा <end>',
#  '<start> सड़क पर ट्रक <end>',
#  '<start> किसी व्यक्ति का सर <end>',
#  '<start> छत से घड़ी निलंबित <end>',
#  '<start> पन पका हुआ मशरूम <end>',
#  '<start> कंप्यूटर मेज पर बिल्ली देना <end>',
#  '<start> भीड़भाड़ वाले बाजार सड़क दृश्य <end>',
#  '<start> सीढ़ियों पर ग्रे कदम <end>',
#  '<start> एक वृक्षारोपण का हिस्सा <end>',
#  '<start> यह एक आसन है <end>',
#  '<start> एक व्यक्ति बर्फ स्किस <end>',
#  '<start> घास पर एक जिराफ़ <end>',
#  '<start> रैक से लटका हुआ एक हाथ तौलिया <end>',
#  '<start> दो ज़ेबरा <end>',
#  '<start> हरी घास का हिस्सा <end>',
#  '<start> धूसर की सतह <end>',
#  '<start> एक क्रीम रंगीन पोशाक <end>',
#  '<start> जूते का एकमात्र नीला है <end>',
#  '<start> एक रेलगाड़ी के सामने एक मार्की <end>',
#  '<start> एक संकेत जो कहता है कि उस पर बाइक के प्रतीक के लिए पीएआईडी <end>',
#  '<start> आदमी खेल <end>',
#  '<start> लाल और सफेद सिटी बस <end>',
#  '<start> व्यक्ति बस में हो रहा है <end>',
#  '<start> मनुष्य का सिर <end>',
#  '<start> व्यक्ति पानी को देख रहा है <end>',
#  '<start> यह एक ट्रेन है <end>',
#  '<start> प्लेट पर गाजर काट लें <end>',
#  '<start> महिला लघु आस्तीन नारंगी टी शर्ट पहने हुए <end>',
#  '<start> पुंछ <end>',
#  '<start> काले और चांदी के रेफ्रिजरेटर <end>',
#  '<start> यह एक फुटबॉल खिलाड़ी है <end>',
#  '<start> सफेद वाहन के अंदर घुड़सवारी <end>',
#  '<start> एक आदमी मोटर साइकिल की सवारी कर रहा है <end>',
#  '<start> कुत्ता सो रहा है <end>',
#  '<start> कपड़े और कागज काटने के लिए बोर्ड <end>',
#  '<start> पहाड़ पर आदमी स्कीइंग <end>',
#  '<start> तीन लोग <end>',
#  '<start> मोटरसाइकिल पर सवार व्यक्ति <end>',
#  '<start> आदमी की पैंट की पिछली जेब में दस्ताने <end>',
#  '<start> बर्फ उधारकर्ताओं का एक समूह <end>',
#  '<start> एक पुल पर खिड़की <end>',
#  '<start> एक लड़के के साथ लड़का <end>',
#  '<start> हाथी निष्पादन <end>',
#  '<start> कुत्ता भूरा है <end>',
#  '<start> कटोरे में कटा हुआ प्याज <end>',
#  '<start> बर्तन में नारंगी सब्जियां <end>',
#  '<start> एक छत का हिस्सा <end>',
#  '<start> हाथ में एक सफेद बेसबॉल <end>',
#  '<start> आदमी बाथरूम में खड़ा है <end>',
#  '<start> छोटा हाथी बड़े सफेद तुस्क के साथ <end>',
#  '<start> मसले हुए आलू का ढेर <end>',
#  '<start> इमारत की तरफ बड़ी घड़ी <end>',
#  '<start> लंबा धातु प्रकाश पोस्ट <end>',
#  '<start> हल्के रंग का दरवाज़ा <end>',
#  '<start> जमीन पर हरा घास <end>',
#  '<start> रेलगाड़ी स्टेशन में है <end>',
#  '<start> नल चांदी है <end>',
#  '<start> आकाश का हिस्सा <end>',
#  '<start> एक बोर्ड का हिस्सा <end>',
#  '<start> एक इमारत से जुड़ा एक काले दाद का निशान <end>',
#  '<start> पंप लाल और पीले रंग का होता है <end>',
#  '<start> टेनिस कोर्ट पर सफेद लाइनें <end>',
#  '<start> एक भालू के भूरे रंग के नथुने <end>',
#  '<start> एक दूसरे के पास दो ज़ेबरा <end>',
#  '<start> इमारत पर खिड़कियाँ <end>',
#  '<start> एक विमान के पास लोग <end>',
#  '<start> शेल्फ का रंग भूरा है <end>',
#  '<start> ट्रेन स्टेशन पर स्थित महिला <end>',
#  '<start> सफेद और काली धारीदार ज़ेबरा घास के मैदान में चलते हुए <end>',
#  '<start> यह एक टीवी स्क्रीन है <end>',
#  '<start> पीले रंग की पैंट में स्नोबोर्डर <end>',
#  '<start> नाव रेत पर है <end>',
#  '<start> एक बड़ा खुला मैदान <end>',
#  '<start> ढलान पर डाउनहिल स्कीयर <end>',
#  '<start> प्लेट पर हरी जड़ी बूटी <end>',
#  '<start> हेलमेट पर चश्मा <end>',
#  '<start> चट्टान का हिस्सा <end>',
#  '<start> एक बड़ी लम्बी घड़ी <end>',
#  '<start> प्रकाश स्थिरता <end>',
#  '<start> तुलसी का पत्ता पिज़्ज़ा पर <end>',
#  '<start> प्रदर्शन पर कई बैग <end>',
#  '<start> एक आदमी एक झूले पर घुटने टेकना <end>',
#  '<start> कचरे के ऊपर ढक्कन कर सकते हैं <end>',
#  '<start> ट्रेन ट्रैक पर नीले और पीले रंग की ट्रेन <end>',
#  '<start> घुमावदार शीर्ष के साथ खिड़की <end>',
#  '<start> पांडा सफेद और काला है <end>',
#  '<start> यह गाय है <end>',
#  '<start> पेशेवर टेनिस खिलाड़ी एक गेंद को मारते हैं <end>',
#  '<start> आदमी सफेद शर्ट पहने हुए <end>',
#  '<start> घास में बड़ी चट्टान <end>',
#  '<start> लाल डबल डेकर बस <end>',
#  '<start> स्वस्थ रंगीन फलों से भरा एक विकर टोकरी <end>',
#  '<start> एक लाल और सफेद सड़क पर हस्ताक्षर <end>',
#  '<start> हाथी दिखाई देते हैं <end>',
#  '<start> लाल और पीला झंडा <end>',
#  '<start> लूढकता हुआ काला सूटकेस <end>',
#  '<start> भूरे भालू कुर्सी में <end>',
#  '<start> समुद्र में सर्फिंग करता हुआ एक आदमी <end>',
#  '<start> सामने बाइक सवार महिला <end>',
#  '<start> एक हरे और भूरे रंग की कुर्सी <end>',
#  '<start> एक धुएं का हिस्सा <end>',
#  '<start> स्टाल में भूरे रंग का घोड़ा <end>',
#  '<start> प्लेट पर कारामल | <end>',
#  '<start> सामने की खिड़की के साथ सफेद ओवन <end>',
#  '<start> बेंच का पैर <end>',
#  '<start> चिमनी के ऊपर की दीवार पर चित्र <end>',
#  '<start> इस व्यक्ति ने टोपी पहन रखी है <end>',
#  '<start> एक सफेद कटोरे के साथ एक गन्दा बिस्तर <end>',
#  '<start> एक नीला भरवां हाथी <end>',
#  '<start> यह एक व्यक्ति है <end>',
#  '<start> ट्रंक पर समुद्री मील के साथ सफेद सन्टी का पेड़ <end>',
#  '<start> मोटरसाइकिल पर नंबर <end>',
#  '<start> भालू का सिर <end>',
#  '<start> जमीन पर हरा घास <end>',
#  '<start> एक नोटबुक में आदमी लिख रहा है <end>',
#  '<start> एक काले में एक सर्फर <end>',
#  '<start> एक आदमी एक टेनिस बॉल मार रहा है <end>',
#  '<start> गुलाबी रंग के सामान पर सफेद बिंदी <end>',
#  '<start> हवा में नीला फ्रिसबी <end>',
#  '<start> ब्लीचर्स में बैठे दर्शक <end>',
#  '<start> कबूतर प्लेट पर भोजन की तलाश में है <end>',
#  '<start> ये तीन नावें हैं <end>',
#  '<start> कमरे में दो बिस्तर <end>',
#  '<start> रेफ्रिजरेटर दरवाजे पर काले सरसरी लेखन <end>',
#  '<start> तस्वीर में मिट्टी के बर्तन <end>',
#  '<start> पशु फर जो इकट्ठा किया जा रहा है <end>',
#  '<start> पृष्ठभूमि में स्वतंत्रता की प्रतिमा <end>',
#  '<start> बहुत सारे संतरे <end>',
#  '<start> सर्फ बोर्ड ले जाने वाला आदमी <end>',
#  '<start> वाहन का पहिया <end>',
#  '<start> साइड के द्वारा पक्षी बैंच <end>',
#  '<start> दीवार में ग्रे रंगीन ईंट <end>',
#  '<start> गुलाबी के साथ सफेद टेनिस जूते <end>',
#  '<start> पशुधन बहुत दिखाई देते हैं <end>',
#  '<start> कंप्यूटर लैपटॉप स्क्रीन <end>',
#  '<start> मोटरसाइकिल पर काले सैडलबैग <end>',
#  '<start> एक पिज्जा पाई जिसमें एक टुकड़ा गायब है <end>',
#  '<start> शान्त पानी का बड़ा क्षेत्र <end>',
#  '<start> एक काले और सफेद तस्वीर <end>',
#  '<start> मेज पर एक गिलास <end>',
#  '<start> महिला एक सेल फोन पकड़े हुए है <end>',
#  '<start> गेंद खिलाड़ी को काले और पीले रंग की एक जैसी शर्ट पहनाई जाती है <end>',
#  '<start> पुल पर धातु पुलिंदा <end>',
#  '<start> स्की बोर्ड काले हैं <end>',
#  '<start> एक मंजिल का हिस्सा <end>',
#  '<start> पानी में एक नाव <end>',
#  '<start> व्यक्ति पर नीला और सफेद निकर | <end>',
#  '<start> इमारत पर एक घड़ी है <end>',
#  '<start> पेड़ पर छोड़ देता है <end>',
#  '<start> स्केट बोर्डिंग है <end>',
#  '<start> फ्रिसबी गोल और नारंगी है <end>',
#  '<start> पानी अंधेरा है <end>',
#  '<start> फुटबॉल खिलाड़ी एक वर्दी पहने हुए <end>',
#  '<start> यह एक महिला है <end>',
#  '<start> घास के एक क्षेत्र में एक भेड़ <end>',
#  '<start> दरवाजे नारंगी हैं <end>',
#  '<start> एक नीले रंग की पृष्ठभूमि पर सफेद पाठ <end>',
#  '<start> बच्चे का चेहरा कैमरे की तरफ मुस्कुराता हुआ <end>',
#  '<start> लड़का हवा में उछलता है <end>',
#  '<start> एक पुल पर एक झोपड़ी <end>',
#  '<start> अंधेरे जोड़ी सूरज चश्मा <end>',
#  '<start> किसी ने कैमरा पकड़ा हुआ है <end>',
#  '<start> एक टॉयलेट में मूत्रालय <end>',
#  '<start> एक पायलट टोपी पर पंख <end>',
#  '<start> एक ज़ेबरा घास पर चराई <end>',
#  '<start> एक पूल में खेल रहा लड़का <end>',
#  '<start> नीले आकाश में सफेद बादल <end>',
#  '<start> कमरे में एक मामला <end>',
#  '<start> केले पीले होते हैं <end>',
#  '<start> काली सीमाओं के साथ चांदी रोशनी <end>',
#  '<start> यह दीवार ईटों से बनी है <end>',
#  '<start> नूडल्स के साथ सूप का कटोरा <end>',
#  '<start> नीले आकाश का छोटा पाटा <end>',
#  '<start> शॉट में एक घोड़ा <end>',
#  '<start> इमारत सफेद है <end>',
#  '<start> फ्रिसबी सफेद है <end>',
#  '<start> भालू खा रहा है <end>',
#  '<start> जंगल में जिराफ <end>',
#  '<start> लड़के की आँख <end>',
#  '<start> इस समूह को स्की पाठ के लिए सजा सुनाई गई है <end>',
#  '<start> जीन्स नीले हैं <end>',
#  '<start> एक लाल ट्रैफ़िक सिग्नल <end>',
#  '<start> यह एक डॉगनट है <end>',
#  '<start> पिचर फेकने के तैयारी मे <end>',
#  '<start> नारंगी संभाल के साथ कैंची <end>',
#  '<start> एक रसोई में तीन लोग <end>',
#  '<start> बाथरूम में शौचालय फिक्चर <end>',
#  '<start> एक फव्वारा फुहार पानी <end>',
#  '<start> एक बाईं टेडी बियर की आंख <end>',
#  '<start> सड़क पर चांदी की कार <end>',
#  '<start> विमान <end>',
#  '<start> विशाल नीले बैग के साथ महिला <end>',
#  '<start> टेनिस खेल रहा युवक <end>',
#  '<start> दीवार पर एक गुलाबी चिन्ह <end>',
#  '<start> एक सफेद फ्रिसबी हवा के माध्यम से उड़ान <end>',
#  '<start> जिराफों का एक समूह <end>',
#  '<start> चांदी सफेद कुर्सी <end>',
#  '<start> एक आदमी मोटर साइकिल की सवारी कर रहा है <end>',
#  '<start> पानी की तरह झागदार लहर <end>',
#  ...]

# %%
# removing <start> and <end> from input_val
input_val_rem = []
for i in range(len(input_val)):
    l = input_val[i].split(" ")
    l.pop(0)
    n = len(l)-1
    l.pop(n)
    s = " ".join(l)
    input_val_rem.append(s)

# %%
input_val_rem.index('')
# Out:
# 3575

# %%
print(len(input_val_rem), len(target_val))
# Out:
# 5786 5786

# %%
input_val_rem.pop(3575) , target_val.pop(3575)
# Out:
# ('', '<start> समुद्र तट पर बाइक <end>')

# %%
print(len(input_val_rem), len(target_val))
# Out:
# 5785 5785

# %%
input_val_rem.pop(1346)
target_val.pop(1346)
# Out:
# '<start>  <end>'

# %%
input_val_rem.pop(1655)
target_val.pop(1655)
# Out:
# '<start>  <end>'

# %%
print(len(input_val_rem) , len(target_val))
# Out:
# 5783 5783

# %%
input_val_rem.pop(258)
target_val.pop(258)
print(len(input_val_rem) , len(target_val))
# Out:
# 5782 5782

# %%
translation = []
for i in range(0,100):
    translated_sent = translate(input_val_rem[i])
    translation.append(translated_sent)
# Out:
# [[16 32  6  3]]
# Input: this is the sky
# Predicted translation: ['यह आकाश है <end>']
# [[238  13  10 231   7  15  70   3]]
# Input: boy with purple and white shoes
# Predicted translation: ['बैंगनी और सफेद जूते के साथ लड़का <end>']
# [[12 31 25 14 79 31  3]]
# Input: man wearing dapper red hat
# Predicted translation: ['आदमी पहने हुए लाल टोपी पहने <end>']
# [[ 54  19   9  54 356   3]]
# Input: green colored leaves
# Predicted translation: ['हरे रंग का हरे पत्ते <end>']
# [[   4  787 3540   24    4 2350    3]]
# Input: a runner leading off of first base
# Predicted translation: ['एक बेस रैक्वेट से एक पोडियम <end>']
# [[ 4 14 28  3]]
# Input: a red train
# Predicted translation: ['एक लाल ट्रेन <end>']
# [[611  14  50   5   3]]
# Input: windown on dark red building
# Predicted translation: ['अंधेरे लाल इमारत पर <end>']
# [[ 12   5  46 322 200   3]]
# Input: black suit jacket on man
# Predicted translation: ['आदमी पर काली सूट जैकेट <end>']
# [[  85  341 1457   48    3]]
# Input: big grey indian elephant
# Predicted translation: ['बड़ा धूसर भारतीय हाथी <end>']
# [[  12   11    4 1124    6    3]]
# Input: man has a ring on
# Predicted translation: ['आदमी की एक अंगूठी है <end>']
# [[ 55   4  55 260  53   6   3]]
# Input: the girl is wearing a necklace
# Predicted translation: ['लड़की एक लड़की पहन रही है <end>']
# [[868  24  30  24  30  11 104   3]]
# Input: man drawing water from borehole
# Predicted translation: ['मानव से पानी से पानी की तस्वीर <end>']
# [[347 138   3]]
# Input: street sign
# Predicted translation: ['स्ट्रीट साइन <end>']
# [[50  5  4 57  3]]
# Input: a window on the building
# Predicted translation: ['इमारत पर एक खिड़की <end>']
# [[216   8 238 433   9 265   3]]
# Input: tops of purple flowers in the field
# Predicted translation: ['खेत में बैंगनी फूलों का पैंट <end>']
# [[270 123  87  20   3]]
# Input: woman holding a cell phone
# Predicted translation: ['सेल फोन पकड़े महिला <end>']
# [[  10 3881    7   15   46  136    3]]
# Input: black ipod with white plug
# Predicted translation: ['सफेद प्लगिन के साथ काली लैपटॉप <end>']
# [[  81    5 1799    3]]
# Input: stripes on the zebra
# Predicted translation: ['ज़ेबरा पर स्ट्रिप्स <end>']
# [[  26 1847    9    4  529   43  147    3]]
# Input: a sliced piece of black olive
# Predicted translation: ['काले जैतून का एक कटा हुआ टुकड़ा <end>']
# [[115  49 893  25   3]]
# Input: the cow lying down
# Predicted translation: ['गाय को गोद हुए <end>']
# [[  52    7 2252    7   15   52   11   69    3]]
# Input: wooden bench with wooden slats
# Predicted translation: ['लकड़ी के स्लैट के साथ लकड़ी की बेंच <end>']
# [[  16    4 7007    6    3]]
# Input: this is a buiding
# Predicted translation: ['यह एक डाउन्नर्ट है <end>']
# [[ 20 146   5 154  18   3]]
# Input: women are sitting on the chair
# Predicted translation: ['महिला कुर्सी पर बैठी हैं <end>']
# [[ 45   5 529  43  14 555   3]]
# Input: sliced red tomatoes on plate
# Predicted translation: ['प्लेट पर कटा हुआ लाल टमाटर <end>']
# [[ 685    5 1921  525   18    3]]
# Input: two is written on the jersey
# Predicted translation: ['जर्सी पर लिखे गए हैं <end>']
# [[ 16   4 252 598   6   3]]
# Input: this is a toilet bow
# Predicted translation: ['यह एक टॉयलेट टॉप है <end>']
# [[185  77   6   3]]
# Input: the hydrant is yellow
# Predicted translation: ['हाइड्रेंट पीला है <end>']
# [[  4  51   5 129  41   3]]
# Input: people sitting at a table
# Predicted translation: ['एक मेज पर बैठे लोग <end>']
# [[ 47 453 124   3]]
# Input: blue surf board
# Predicted translation: ['नीले सर्फ बोर्ड <end>']
# [[  59    7  111  126 1151    3]]
# Input: metal cage near giraffe
# Predicted translation: ['जिराफ के पास धातु पिंजरे <end>']
# [[ 30   9 317   3]]
# Input: shallow body of water
# Predicted translation: ['पानी का भाग <end>']
# [[202   9 139   3]]
# Input: a group of people
# Predicted translation: ['लोगों का समूह <end>']
# [[ 51   5 123   3]]
# Input: phone on table
# Predicted translation: ['मेज पर फोन <end>']
# [[107   5 259  11  57   3]]
# Input: glass window on boat
# Predicted translation: ['नाव पर कांच की खिड़की <end>']
# [[ 28   5 678 334  28   3]]
# Input: train traveling on rails
# Predicted translation: ['ट्रेन पर यात्रा करती ट्रेन <end>']
# [[  4  51   5 343   3]]
# Input: a tv on a table
# Predicted translation: ['एक मेज पर टीवी <end>']
# [[   4 1234   33  403  608    3]]
# Input: a glossy blue coffee mug
# Predicted translation: ['एक प्यारा नीला कॉफी मग <end>']
# [[ 163    8   22 1226    3]]
# Input: two women in the bathroom
# Predicted translation: ['बाथरूम में दो महिलाएँ <end>']
# [[34 86 11 14 79  3]]
# Input: red cap of the tennis player
# Predicted translation: ['टेनिस खिलाड़ी की लाल टोपी <end>']
# [[   4 2181 1277   44   70    3]]
# Input: a little boy reading a book
# Predicted translation: ['एक व्यापार पढ़ने वाला लड़का <end>']
# [[32  9 37  3]]
# Input: part of the sky
# Predicted translation: ['आकाश का हिस्सा <end>']
# [[  4 746   7 111  94   3]]
# Input: bird near a lake
# Predicted translation: ['एक झील के पास पक्षी <end>']
# [[  4 668  44  14 140   3]]
# Input: a leaning red bike
# Predicted translation: ['एक झुकाव वाला लाल बाइक <end>']
# [[   4   12  109 1138   21    6    3]]
# Input: a man flying kites
# Predicted translation: ['एक आदमी पतंग उड़ा रहा है <end>']
# [[  4  45   5 771 531  24 879 879 879   3]]
# Input: partially eaten cookie on a plate
# Predicted translation: ['एक प्लेट पर आंशिक रूप से खाया खाया खाया <end>']
# [[ 72   5  54 356   3]]
# Input: green leaves on trees
# Predicted translation: ['पेड़ पर हरे पत्ते <end>']
# [[232   5  10 636   3]]
# Input: white patch on screen
# Predicted translation: ['स्क्रीन पर सफेद पैच <end>']
# [[ 36   9 194   3]]
# Input: face of the cat
# Predicted translation: ['बिल्ली का चेहरा <end>']
# [[  4 422   9  37   3]]
# Input: part of a floor
# Predicted translation: ['एक मंजिल का हिस्सा <end>']
# [[ 64   5   4 405 671 197 118   6   3]]
# Input: a mouse is printed on the shirt
# Predicted translation: ['शर्ट पर एक माउस प्रिंट किया गया है <end>']
# [[  69    5  129 1197    7  100    3]]
# Input: a bench to sit on
# Predicted translation: ['बेंच पर बैठे रहने के लिए <end>']
# [[50  7 76  5  4 29  3]]
# Input: a wall on the side of a building
# Predicted translation: ['इमारत के किनारे पर एक दीवार <end>']
# [[   4   17 1506    4  388   31   25    3]]
# Input: a person wearing a custom
# Predicted translation: ['एक व्यक्ति जिस एक कपड़े पहने हुए <end>']
# [[688   7  15  22 142   3]]
# Input: two dogs with tongues visible
# Predicted translation: ['जीभ के साथ दो कुत्ते <end>']
# [[16 32  6  3]]
# Input: this is the sky
# Predicted translation: ['यह आकाश है <end>']
# [[ 51   5 397   3]]
# Input: knife on the table
# Predicted translation: ['मेज पर चाकू <end>']
# [[547   5  54 696   3]]
# Input: green leaf on plant
# Predicted translation: ['पौधे पर हरे पत्ती <end>']
# [[  59  133   24 1772   21    6    3]]
# Input: giraffes tail sticking out
# Predicted translation: ['जिराफ बाहर से चाट रहा है <end>']
# [[ 392    8 1359    3]]
# Input: shot in the tray
# Predicted translation: ['ट्रे में गोली <end>']
# [[ 12 221  58  21   6   3]]
# Input: the man is skiing
# Predicted translation: ['आदमी स्कीइंग कर रहा है <end>']
# [[ 16   4 331   6   3]]
# Input: this is a tire
# Predicted translation: ['यह एक टायर है <end>']
# [[  4  12   7 273   5 321 350   9 173   3]]
# Input: dark sunglasses on a mans face
# Predicted translation: ['एक आदमी के चेहरे पर गहरे धूप का चश्मा <end>']
# [[  22   41  160 1067  388   31   18    3]]
# Input: two people are wearing goggles
# Predicted translation: ['दो लोग ने पूरी कपड़े पहने हैं <end>']
# [[ 51   5 154  20   3]]
# Input: woman sitting at table
# Predicted translation: ['मेज पर बैठी महिला <end>']
# [[480   8  68 724   3]]
# Input: blue lanyard in the neck
# Predicted translation: ['गर्दन में नीली टीशर्ट <end>']
# [[  22 2607   11  104    3]]
# Input: picture of two mail boxes
# Predicted translation: ['दो मेल की तस्वीर <end>']
# [[ 4 99  7 15 12  3]]
# Input: man with a skateboard
# Predicted translation: ['एक स्केटबोर्ड के साथ आदमी <end>']
# [[169   7 180   8 169   3]]
# Input: sheep next to sheep
# Predicted translation: ['भेड़ के बगल में भेड़ <end>']
# [[65  5 65  5 20  3]]
# Input: woman on skis on snow
# Predicted translation: ['बर्फ पर बर्फ पर महिला <end>']
# [[312 193 211 280   5 129   3]]
# Input: brown teddy bear sitting on counter
# Predicted translation: ['ब्राउन टेडी बियर काउंटर पर बैठे <end>']
# [[102  26 824   3]]
# Input: three black pillows
# Predicted translation: ['तीन काले तकिए <end>']
# [[  30    8 4917   80 2213    3]]
# Input: small duckling in water
# Predicted translation: ['पानी में रहनेवाला छोटा पग <end>']
# [[16  4 12  6  3]]
# Input: this is a man
# Predicted translation: ['यह एक आदमी है <end>']
# [[17 67  6  3]]
# Input: the person is standing
# Predicted translation: ['व्यक्ति खड़ा है <end>']
# [[  4  51 166   3]]
# Input: a table scene
# Predicted translation: ['एक मेज दृश्य <end>']
# [[  4 187 295 539  44  12   3]]
# Input: man carrying a surfboard
# Predicted translation: ['एक सर्फ़बोर्ड ले जाने वाला आदमी <end>']
# [[803   7  82  65   3]]
# Input: snow on top of mountain
# Predicted translation: ['पर्वत के ऊपर बर्फ <end>']
# [[1557    8   94    3]]
# Input: birds in the shot
# Predicted translation: ['शॉट में पक्षी <end>']
# [[16  4 12  6  3]]
# Input: this is a man
# Predicted translation: ['यह एक आदमी है <end>']
# [[4143    8   48   67    6    3]]
# Input: elephant standing in clearing
# Predicted translation: ['सम्मुख में हाथी खड़ा है <end>']
# [[  39    5 2262    3]]
# Input: ud on the clock
# Predicted translation: ['घड़ी पर उपग्रह <end>']
# [[108  11   4 660 283 103  20   3]]
# Input: woman eating a slice of pizza
# Predicted translation: ['पिज्जा की एक स्लाइस खाने वाली महिला <end>']
# [[   4  311    8   67 2010    3]]
# Input: serviceman standing in a line
# Predicted translation: ['एक पंक्ति में खड़ा पुतला <end>']
# [[ 4 17  9 40  3]]
# Input: head of a person
# Predicted translation: ['एक व्यक्ति का सिर <end>']
# [[84  4 72  8  6  3]]
# Input: the bear is up in a tree
# Predicted translation: ['भालू एक पेड़ में है <end>']
# [[ 379   47  373    9 1004    3]]
# Input: light blue pillow case
# Predicted translation: ['हल्के नीले तकिया का मामला <end>']
# [[16 32  6  3]]
# Input: this is the sky
# Predicted translation: ['यह आकाश है <end>']
# [[ 64 148   6   3]]
# Input: the shirt is yellow
# Predicted translation: ['शर्ट पीली है <end>']
# [[ 16   4 104   6   3]]
# Input: this is a picture
# Predicted translation: ['यह एक तस्वीर है <end>']
# [[ 66  13  10 605   3]]
# Input: yellow and white toothbrush
# Predicted translation: ['पीले और सफेद टूथब्रश <end>']
# [[330 102  41  18   3]]
# Input: these are three people
# Predicted translation: ['ये तीन लोग हैं <end>']
# [[ 114   29    5   10  467 2578    3]]
# Input: white window sill on the pink wall
# Predicted translation: ['गुलाबी दीवार पर सफेद विंडो सिले <end>']
# [[  4 282  49 415  24 254  21   6   3]]
# Input: a vehicle is going through slush
# Predicted translation: ['एक वाहन को माध्यम से जा रहा है <end>']
# [[16  4 81  6  3]]
# Input: this is a zebra
# Predicted translation: ['यह एक ज़ेबरा है <end>']
# [[ 30   8  14 115   3]]
# Input: red cow in water
# Predicted translation: ['पानी में लाल गाय <end>']
# [[ 22  52  95 132   3]]
# Input: two wooden beach chairs
# Predicted translation: ['दो लकड़ी समुद्र तट <end>']
# [[ 38  19   9 615 567   3]]
# Input: gathering of brown elephants
# Predicted translation: ['भूरे रंग का सामना करना <end>']
# [[  4  78 267 348   3]]
# Input: a grey parking meter
# Predicted translation: ['एक ग्रे पार्किंग मीटर <end>']
# [[  4  66  19  11  95 132   5   4  66 151   3]]
# Input: a yellow umbrella over some beach chairs
# Predicted translation: ['एक पीले रंग की समुद्र तट पर एक पीले छाता <end>']
# [[51 33  6  3]]
# Input: the table is blue
# Predicted translation: ['मेज नीला है <end>']

# %%
target_val_1 = target_val[:100]
for i in range(len(target_val_1)):
    target_val_1[i] = target_val_1[i].split(" ")[1:-1]
    
t = []
for i in range(len(translation)):
    t.append(translation[i][0])    

t1=[]
for i in range(len(t)):
    l = t[i][0].split(" ")[:-1]
    s = " ".join(l)
    t1.append(s)

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu
avg_1g_score = 0
for i in range(len(t1)):
    candidate = t1[i].split(" ")
    reference = [target_val_1[i]]
    score = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0))
#     print(score)
    avg_1g_score = avg_1g_score + score

avg_1g_score = avg_1g_score/len(t1)
avg_1g_score
# Out:
# 0.695522223933798

# %%
avg_2g_score = 0
for i in range(len(t1)):
    candidate = t1[i].split(" ")
    reference = [target_val_1[i]]
    score = sentence_bleu(reference, candidate, weights=(0, 1, 0, 0))
#     print(score)
    avg_2g_score = avg_2g_score + score

avg_2g_score = avg_2g_score/len(t1)
avg_2g_score
# Out:
# 0.5239425451115022

# %%
avg_ng_score = 0
for i in range(len(t1)):
    candidate = t1[i].split(" ")
    reference = [target_val_1[i]]
    score = sentence_bleu(reference, candidate, weights=(0.25, 0.25, 0.25, 0.25))
#     print(score)
    avg_ng_score = avg_ng_score + score

avg_ng_score = avg_ng_score/len(t1)
avg_ng_score
# Out:
# 0.24910837991948254
